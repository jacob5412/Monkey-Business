# %% [markdown]
# # SVM: Version 2
#
# ## SVM with PCA

# %%
import os
import glob
import time
import mlflow
import shutil
import itertools

import numpy as np
import pandas as pd

from PIL import Image
from sklearn.decomposition import PCA
from sklearn import svm
from sklearn.model_selection import cross_validate, StratifiedKFold
from sklearn.metrics import (
    make_scorer,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
)

# %%
TRAIN_DIR = "../data/train"
CLASS_FOLDERS = ["Class A", "Class B", "Class C", "Class D"]
ML_FLOW_DIRECTORY = "SVM_Logs"

# %%
mlflow.set_tracking_uri(ML_FLOW_DIRECTORY)
mlflow.set_experiment("SVM_PCA")
# Out:
# <Experiment: artifact_location='/Users/jacob/Code/Monkey-Business/SVM/SVM_Logs/216794599421195463', creation_time=1701926432685, experiment_id='216794599421195463', last_update_time=1701926432685, lifecycle_stage='active', name='SVM_PCA', tags={}>

# %%
pca_components = [40 * 40, 45 * 45, 50 * 50]
C_values = [0.1, 1, 10]
kernel_types = ["linear", "rbf"]
gamma_values = ["scale", "auto"]

# %%
hyperparameter_combinations = list(
    itertools.product(pca_components, C_values, kernel_types, gamma_values)
)
print(
    f"Total number of hyperparameter combinations: {len(hyperparameter_combinations)}"
)
# Out:
# Total number of hyperparameter combinations: 36

# %%
pca_models_dict = {}

# %%
def train_with_params(pca_components, C, kernel, gamma, train_images, train_labels):
    # Check if PCA model for pca_components already exists
    if pca_components in pca_models_dict:
        pca = pca_models_dict[pca_components]
        print(f"Using existing PCA model for {pca_components} components")
    else:
        # Apply PCA
        pca = PCA(n_components=pca_components)
        pca.fit(train_images)
        pca_models_dict[pca_components] = pca

    # Transform images with PCA
    train_images_pca = pca.transform(train_images)

    with mlflow.start_run() as run:
        start_time = time.time()

        # Initialize SVM model
        svm_model = svm.SVC(
            C=C, kernel=kernel, gamma=gamma, class_weight="balanced", verbose=True
        )

        # Perform cross-validation
        skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
        scoring = {
            "f1_weighted": make_scorer(f1_score, average="weighted"),
            "accuracy": "accuracy",
            "precision": make_scorer(precision_score, average="weighted"),
            "recall": make_scorer(recall_score, average="weighted"),
        }
        cv_results = cross_validate(
            svm_model,
            train_images_pca,
            train_labels,
            cv=skf,
            scoring=scoring,
            verbose=2,
        )

        # Log hyperparameters and metrics
        mlflow.log_params(
            {"pca_components": pca_components, "C": C, "kernel": kernel, "gamma": gamma}
        )
        mlflow.log_metrics(
            {
                "mean_f1_weighted": cv_results["test_f1_weighted"].mean(),
                "mean_accuracy": cv_results["test_accuracy"].mean(),
                "mean_precision": cv_results["test_precision"].mean(),
                "mean_recall": cv_results["test_recall"].mean(),
            }
        )
        end_time = time.time()
        duration = end_time - start_time
        param_details = f"PCA={pca_components}, C={C}, kernel={kernel}, gamma={gamma}"
        duration_details = f"Training duration for {param_details}: {duration} seconds"
        print(duration_details)
        run_id = run.info.run_id
        return run_id

# %%
def load_image(img_path):
    img = Image.open(img_path)
    img = img.resize((224, 224))
    img = np.array(img)
    img = img.astype("float32") / 255.0
    return img

# %%
def load_images_from_folder(folder):
    images = []
    labels = []
    for class_folder in CLASS_FOLDERS:
        start_time = time.time()
        class_path = os.path.join(folder, class_folder)
        image_files = glob.glob(os.path.join(class_path, "*.png"))
        for img_file in image_files:
            processed_image = load_image(img_file)
            flattened_image = processed_image.flatten()
            images.append(flattened_image)
            labels.append(class_folder)
        end_time = time.time()
        duration = end_time - start_time
        print(f"Processing {class_folder} took {duration} seconds")
    return np.array(images), np.array(labels)

# %%
train_images, train_labels = load_images_from_folder(TRAIN_DIR)
# Out:
# Processing Class A took 2.7697389125823975 seconds
# Processing Class B took 1.5491418838500977 seconds
# Processing Class C took 1.0512456893920898 seconds
# Processing Class D took 1.2895679473876953 seconds

# %%
print(
    f"Shape of train_images: {train_images.shape}, Shape of train_labels: {train_labels.shape}"
)
# Out:
# Shape of train_images: (2796, 150528), Shape of train_labels: (2796,)

# %%
run_ids = []

for params in hyperparameter_combinations:
    pca_components, C, kernel, gamma = params
    run_id = train_with_params(pca_components, C, kernel, gamma, train_images, train_labels)
    run_ids.append(run_id)
# Out:
# Using existing PCA model for 1600 components
# [LibSVM]........*....*
# optimization finished, #iter = 12881
# obj = -0.771869, rho = 0.707572
# nSV = 417, nBSV = 0
# .*.*
# optimization finished, #iter = 2126
# obj = -0.049240, rho = -0.509753
# nSV = 198, nBSV = 0
# ...*
# optimization finished, #iter = 3675
# obj = -0.125562, rho = -0.444424
# nSV = 250, nBSV = 0
# ....*..*
# optimization finished, #iter = 4551
# obj = -0.355675, rho = -1.404315
# nSV = 326, nBSV = 0
# ....*..*
# optimization finished, #iter = 4932
# obj = -0.198372, rho = -1.102659
# nSV = 329, nBSV = 0
# ....*..*
# optimization finished, #iter = 4256
# obj = -0.187187, rho = -0.097329
# nSV = 343, nBSV = 0
# Total nSV = 1138
# [CV] END .................................................... total time=   2.3s
# [LibSVM]...........*...*
# optimization finished, #iter = 14267
# obj = -0.644068, rho = 0.609817
# nSV = 404, nBSV = 0
# .*
# optimization finished, #iter = 1626
# obj = -0.045683, rho = -0.497757
# nSV = 187, nBSV = 0
# ..*..*
# optimization finished, #iter = 4178
# obj = -0.115221, rho = -0.532458
# nSV = 248, nBSV = 0
# ...*..*
# optimization finished, #iter = 4268
# obj = -0.224672, rho = -1.112040
# nSV = 323, nBSV = 0
# ....*..*
# optimization finished, #iter = 5368
# obj = -0.181155, rho = -1.057619
# nSV = 326, nBSV = 0
# ....*..*
# optimization finished, #iter = 4189
# obj = -0.220242, rho = -0.424222
# nSV = 344, nBSV = 0
# Total nSV = 1119
# [CV] END .................................................... total time=   2.2s
# [LibSVM]........*....*
# optimization finished, #iter = 12601
# obj = -0.623574, rho = 0.466474
# nSV = 414, nBSV = 0
# .*.*
# optimization finished, #iter = 2188
# obj = -0.052908, rho = -0.477702
# nSV = 215, nBSV = 0
# ..*..*
# optimization finished, #iter = 4409
# obj = -0.125128, rho = -0.462453
# nSV = 258, nBSV = 0
# ....*.*
# optimization finished, #iter = 4324
# obj = -0.216990, rho = -1.282264
# nSV = 342, nBSV = 0
# .....*..*
# optimization finished, #iter = 5812
# obj = -0.207121, rho = -1.146311
# nSV = 339, nBSV = 0
# ....*..*
# optimization finished, #iter = 4102
# obj = -0.153083, rho = -0.318779
# nSV = 353, nBSV = 0
# Total nSV = 1124
# [CV] END .................................................... total time=   2.2s
# Training duration for PCA=1600, C=0.1, kernel=linear, gamma=scale: 6.691372871398926 seconds
# Using existing PCA model for 1600 components
# [LibSVM]........*....*
# optimization finished, #iter = 12881
# obj = -0.771869, rho = 0.707572
# nSV = 417, nBSV = 0
# .*.*
# optimization finished, #iter = 2126
# obj = -0.049240, rho = -0.509753
# nSV = 198, nBSV = 0
# ...*
# optimization finished, #iter = 3675
# obj = -0.125562, rho = -0.444424
# nSV = 250, nBSV = 0
# ....*..*
# optimization finished, #iter = 4551
# obj = -0.355675, rho = -1.404315
# nSV = 326, nBSV = 0
# ....*..*
# optimization finished, #iter = 4932
# obj = -0.198372, rho = -1.102659
# nSV = 329, nBSV = 0
# ....*..*
# optimization finished, #iter = 4256
# obj = -0.187187, rho = -0.097329
# nSV = 343, nBSV = 0
# Total nSV = 1138
# [CV] END .................................................... total time=   2.2s
# [LibSVM]...........*...*
# optimization finished, #iter = 14267
# obj = -0.644068, rho = 0.609817
# nSV = 404, nBSV = 0
# .*
# optimization finished, #iter = 1626
# obj = -0.045683, rho = -0.497757
# nSV = 187, nBSV = 0
# ..*..*
# optimization finished, #iter = 4178
# obj = -0.115221, rho = -0.532458
# nSV = 248, nBSV = 0
# ...*..*
# optimization finished, #iter = 4268
# obj = -0.224672, rho = -1.112040
# nSV = 323, nBSV = 0
# ....*..*
# optimization finished, #iter = 5368
# obj = -0.181155, rho = -1.057619
# nSV = 326, nBSV = 0
# ....*..*
# optimization finished, #iter = 4189
# obj = -0.220242, rho = -0.424222
# nSV = 344, nBSV = 0
# Total nSV = 1119
# [CV] END .................................................... total time=   2.2s
# [LibSVM]........*....*
# optimization finished, #iter = 12601
# obj = -0.623574, rho = 0.466474
# nSV = 414, nBSV = 0
# .*.*
# optimization finished, #iter = 2188
# obj = -0.052908, rho = -0.477702
# nSV = 215, nBSV = 0
# ..*..*
# optimization finished, #iter = 4409
# obj = -0.125128, rho = -0.462453
# nSV = 258, nBSV = 0
# ....*.*
# optimization finished, #iter = 4324
# obj = -0.216990, rho = -1.282264
# nSV = 342, nBSV = 0
# .....*..*
# optimization finished, #iter = 5812
# obj = -0.207121, rho = -1.146311
# nSV = 339, nBSV = 0
# ....*..*
# optimization finished, #iter = 4102
# obj = -0.153083, rho = -0.318779
# nSV = 353, nBSV = 0
# Total nSV = 1124
# [CV] END .................................................... total time=   2.2s
# Training duration for PCA=1600, C=0.1, kernel=linear, gamma=auto: 6.628159046173096 seconds
# Using existing PCA model for 1600 components
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1062
# obj = -64.692766, rho = 0.262932
# nSV = 1032, nBSV = 935
# *
# optimization finished, #iter = 694
# obj = -40.641689, rho = 0.380706
# nSV = 669, nBSV = 607
# *
# optimization finished, #iter = 929
# obj = -51.685903, rho = 0.574723
# nSV = 886, nBSV = 804
# *
# optimization finished, #iter = 665
# obj = -66.668223, rho = 0.618500
# nSV = 636, nBSV = 587
# *
# optimization finished, #iter = 793
# obj = -71.643506, rho = 0.728827
# nSV = 755, nBSV = 703
# *
# optimization finished, #iter = 649
# obj = -70.320298, rho = 0.186180
# nSV = 620, nBSV = 591
# Total nSV = 1763
# [CV] END .................................................... total time=   5.0s
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1063
# obj = -65.248404, rho = 0.289166
# nSV = 1033, nBSV = 941
# *
# optimization finished, #iter = 659
# obj = -38.789196, rho = 0.415632
# nSV = 645, nBSV = 585
# *
# optimization finished, #iter = 917
# obj = -49.629677, rho = 0.673029
# nSV = 865, nBSV = 759
# *
# optimization finished, #iter = 639
# obj = -62.370605, rho = 0.644458
# nSV = 609, nBSV = 553
# *
# optimization finished, #iter = 786
# obj = -66.384632, rho = 0.787779
# nSV = 714, nBSV = 648
# *
# optimization finished, #iter = 637
# obj = -68.256788, rho = 0.234461
# nSV = 613, nBSV = 579
# Total nSV = 1765
# [CV] END .................................................... total time=   4.7s
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1078
# obj = -66.167797, rho = 0.197292
# nSV = 1056, nBSV = 944
# *
# optimization finished, #iter = 710
# obj = -41.352355, rho = 0.414427
# nSV = 683, nBSV = 626
# *
# optimization finished, #iter = 945
# obj = -51.760379, rho = 0.616640
# nSV = 889, nBSV = 811
# *
# optimization finished, #iter = 645
# obj = -64.099166, rho = 0.581039
# nSV = 615, nBSV = 564
# *
# optimization finished, #iter = 781
# obj = -69.677080, rho = 0.762481
# nSV = 737, nBSV = 681
# *
# optimization finished, #iter = 642
# obj = -70.439864, rho = 0.266822
# nSV = 618, nBSV = 592
# Total nSV = 1778
# [CV] END .................................................... total time=   4.8s
# Training duration for PCA=1600, C=0.1, kernel=rbf, gamma=scale: 14.483896970748901 seconds
# Using existing PCA model for 1600 components
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1187
# obj = -77.584412, rho = 0.777168
# nSV = 1166, nBSV = 998
# *
# optimization finished, #iter = 977
# obj = -65.845883, rho = 0.810215
# nSV = 970, nBSV = 830
# .*
# optimization finished, #iter = 1061
# obj = -71.471289, rho = 0.818552
# nSV = 1072, nBSV = 954
# *.*
# optimization finished, #iter = 732
# obj = -80.155611, rho = 0.624306
# nSV = 730, nBSV = 722
# *.*
# optimization finished, #iter = 804
# obj = -83.597865, rho = 0.610512
# nSV = 804, nBSV = 803
# *
# optimization finished, #iter = 667
# obj = -82.504583, rho = -0.135700
# nSV = 668, nBSV = 667
# Total nSV = 1837
# [CV] END .................................................... total time=   5.5s
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1176
# obj = -76.870270, rho = 0.797322
# nSV = 1160, nBSV = 962
# *
# optimization finished, #iter = 956
# obj = -63.745310, rho = 0.820919
# nSV = 955, nBSV = 788
# *.*
# optimization finished, #iter = 1049
# obj = -69.161012, rho = 0.841426
# nSV = 1058, nBSV = 919
# *
# optimization finished, #iter = 732
# obj = -78.562165, rho = 0.703229
# nSV = 728, nBSV = 708
# *
# optimization finished, #iter = 803
# obj = -82.445479, rho = 0.519531
# nSV = 804, nBSV = 803
# *
# optimization finished, #iter = 666
# obj = -82.877664, rho = -0.354939
# nSV = 667, nBSV = 666
# Total nSV = 1831
# [CV] END .................................................... total time=   5.3s
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1198
# obj = -79.186056, rho = 0.716445
# nSV = 1189, nBSV = 994
# *
# optimization finished, #iter = 985
# obj = -66.599216, rho = 0.802390
# nSV = 981, nBSV = 856
# .*
# optimization finished, #iter = 1081
# obj = -71.691437, rho = 0.806233
# nSV = 1082, nBSV = 964
# *.*
# optimization finished, #iter = 734
# obj = -78.591399, rho = 0.727298
# nSV = 726, nBSV = 696
# *
# optimization finished, #iter = 802
# obj = -82.496963, rho = 0.640699
# nSV = 803, nBSV = 798
# *
# optimization finished, #iter = 666
# obj = -82.987286, rho = -0.503800
# nSV = 667, nBSV = 666
# Total nSV = 1856
# [CV] END .................................................... total time=   5.4s
# Training duration for PCA=1600, C=0.1, kernel=rbf, gamma=auto: 16.22430992126465 seconds
# Using existing PCA model for 1600 components
# [LibSVM]........*....*
# optimization finished, #iter = 12881
# obj = -0.771869, rho = 0.707572
# nSV = 417, nBSV = 0
# .*.*
# optimization finished, #iter = 2126
# obj = -0.049240, rho = -0.509753
# nSV = 198, nBSV = 0
# ...*
# optimization finished, #iter = 3675
# obj = -0.125562, rho = -0.444424
# nSV = 250, nBSV = 0
# ....*..*
# optimization finished, #iter = 4551
# obj = -0.355675, rho = -1.404315
# nSV = 326, nBSV = 0
# ....*..*
# optimization finished, #iter = 4932
# obj = -0.198372, rho = -1.102659
# nSV = 329, nBSV = 0
# ....*..*
# optimization finished, #iter = 4256
# obj = -0.187187, rho = -0.097329
# nSV = 343, nBSV = 0
# Total nSV = 1138
# [CV] END .................................................... total time=   2.2s
# [LibSVM]...........*...*
# optimization finished, #iter = 14267
# obj = -0.644068, rho = 0.609817
# nSV = 404, nBSV = 0
# .*
# optimization finished, #iter = 1626
# obj = -0.045683, rho = -0.497757
# nSV = 187, nBSV = 0
# ..*..*
# optimization finished, #iter = 4178
# obj = -0.115221, rho = -0.532458
# nSV = 248, nBSV = 0
# ...*..*
# optimization finished, #iter = 4268
# obj = -0.224672, rho = -1.112040
# nSV = 323, nBSV = 0
# ....*..*
# optimization finished, #iter = 5368
# obj = -0.181155, rho = -1.057619
# nSV = 326, nBSV = 0
# ....*..*
# optimization finished, #iter = 4189
# obj = -0.220242, rho = -0.424222
# nSV = 344, nBSV = 0
# Total nSV = 1119
# [CV] END .................................................... total time=   2.2s
# [LibSVM]........*....*
# optimization finished, #iter = 12601
# obj = -0.623574, rho = 0.466474
# nSV = 414, nBSV = 0
# .*.*
# optimization finished, #iter = 2188
# obj = -0.052908, rho = -0.477702
# nSV = 215, nBSV = 0
# ..*..*
# optimization finished, #iter = 4409
# obj = -0.125128, rho = -0.462453
# nSV = 258, nBSV = 0
# ....*.*
# optimization finished, #iter = 4324
# obj = -0.216990, rho = -1.282264
# nSV = 342, nBSV = 0
# .....*..*
# optimization finished, #iter = 5812
# obj = -0.207121, rho = -1.146311
# nSV = 339, nBSV = 0
# ....*..*
# optimization finished, #iter = 4102
# obj = -0.153083, rho = -0.318779
# nSV = 353, nBSV = 0
# Total nSV = 1124
# [CV] END .................................................... total time=   2.2s
# Training duration for PCA=1600, C=1, kernel=linear, gamma=scale: 6.632379055023193 seconds
# Using existing PCA model for 1600 components
# [LibSVM]........*....*
# optimization finished, #iter = 12881
# obj = -0.771869, rho = 0.707572
# nSV = 417, nBSV = 0
# .*.*
# optimization finished, #iter = 2126
# obj = -0.049240, rho = -0.509753
# nSV = 198, nBSV = 0
# ...*
# optimization finished, #iter = 3675
# obj = -0.125562, rho = -0.444424
# nSV = 250, nBSV = 0
# ....*..*
# optimization finished, #iter = 4551
# obj = -0.355675, rho = -1.404315
# nSV = 326, nBSV = 0
# ....*..*
# optimization finished, #iter = 4932
# obj = -0.198372, rho = -1.102659
# nSV = 329, nBSV = 0
# ....*..*
# optimization finished, #iter = 4256
# obj = -0.187187, rho = -0.097329
# nSV = 343, nBSV = 0
# Total nSV = 1138
# [CV] END .................................................... total time=   2.3s
# [LibSVM]...........*...*
# optimization finished, #iter = 14267
# obj = -0.644068, rho = 0.609817
# nSV = 404, nBSV = 0
# .*
# optimization finished, #iter = 1626
# obj = -0.045683, rho = -0.497757
# nSV = 187, nBSV = 0
# ..*..*
# optimization finished, #iter = 4178
# obj = -0.115221, rho = -0.532458
# nSV = 248, nBSV = 0
# ...*..*
# optimization finished, #iter = 4268
# obj = -0.224672, rho = -1.112040
# nSV = 323, nBSV = 0
# ....*..*
# optimization finished, #iter = 5368
# obj = -0.181155, rho = -1.057619
# nSV = 326, nBSV = 0
# ....*..*
# optimization finished, #iter = 4189
# obj = -0.220242, rho = -0.424222
# nSV = 344, nBSV = 0
# Total nSV = 1119
# [CV] END .................................................... total time=   2.2s
# [LibSVM]........*....*
# optimization finished, #iter = 12601
# obj = -0.623574, rho = 0.466474
# nSV = 414, nBSV = 0
# .*.*
# optimization finished, #iter = 2188
# obj = -0.052908, rho = -0.477702
# nSV = 215, nBSV = 0
# ..*..*
# optimization finished, #iter = 4409
# obj = -0.125128, rho = -0.462453
# nSV = 258, nBSV = 0
# ....*.*
# optimization finished, #iter = 4324
# obj = -0.216990, rho = -1.282264
# nSV = 342, nBSV = 0
# .....*..*
# optimization finished, #iter = 5812
# obj = -0.207121, rho = -1.146311
# nSV = 339, nBSV = 0
# ....*..*
# optimization finished, #iter = 4102
# obj = -0.153083, rho = -0.318779
# nSV = 353, nBSV = 0
# Total nSV = 1124
# [CV] END .................................................... total time=   2.2s
# Training duration for PCA=1600, C=1, kernel=linear, gamma=auto: 6.6538732051849365 seconds
# Using existing PCA model for 1600 components
# [LibSVM]*.*
# optimization finished, #iter = 1056
# obj = -327.910881, rho = -0.057290
# nSV = 737, nBSV = 448
# *
# optimization finished, #iter = 717
# obj = -120.272759, rho = -0.117986
# nSV = 402, nBSV = 121
# *
# optimization finished, #iter = 909
# obj = -164.541697, rho = -0.132673
# nSV = 536, nBSV = 192
# .*
# optimization finished, #iter = 1002
# obj = -314.350204, rho = 0.230791
# nSV = 577, nBSV = 159
# .*
# optimization finished, #iter = 1107
# obj = -303.269944, rho = 0.294914
# nSV = 629, nBSV = 147
# .*
# optimization finished, #iter = 966
# obj = -299.324607, rho = 0.143372
# nSV = 543, nBSV = 184
# Total nSV = 1526
# [CV] END .................................................... total time=   3.7s
# [LibSVM]*.*
# optimization finished, #iter = 1100
# obj = -330.769393, rho = 0.188256
# nSV = 748, nBSV = 448
# *
# optimization finished, #iter = 690
# obj = -110.695727, rho = 0.053870
# nSV = 384, nBSV = 104
# *
# optimization finished, #iter = 903
# obj = -160.434366, rho = 0.009675
# nSV = 533, nBSV = 191
# *.*
# optimization finished, #iter = 935
# obj = -282.500174, rho = 0.307681
# nSV = 541, nBSV = 152
# .*
# optimization finished, #iter = 1112
# obj = -293.450517, rho = 0.365058
# nSV = 630, nBSV = 141
# .*
# optimization finished, #iter = 977
# obj = -286.194135, rho = 0.199144
# nSV = 529, nBSV = 166
# Total nSV = 1529
# [CV] END .................................................... total time=   3.6s
# [LibSVM]*.*
# optimization finished, #iter = 1108
# obj = -330.966902, rho = -0.015016
# nSV = 763, nBSV = 438
# *
# optimization finished, #iter = 744
# obj = -121.306144, rho = -0.056968
# nSV = 410, nBSV = 120
# *
# optimization finished, #iter = 884
# obj = -162.219049, rho = -0.105468
# nSV = 533, nBSV = 196
# .*
# optimization finished, #iter = 980
# obj = -312.311209, rho = 0.371241
# nSV = 568, nBSV = 183
# .*
# optimization finished, #iter = 1115
# obj = -308.635402, rho = 0.413896
# nSV = 633, nBSV = 150
# .*
# optimization finished, #iter = 1031
# obj = -296.607558, rho = 0.180453
# nSV = 556, nBSV = 181
# Total nSV = 1542
# [CV] END .................................................... total time=   3.7s
# Training duration for PCA=1600, C=1, kernel=rbf, gamma=scale: 11.070850133895874 seconds
# Using existing PCA model for 1600 components
# [LibSVM].*
# optimization finished, #iter = 1458
# obj = -335.358695, rho = 0.102395
# nSV = 1042, nBSV = 311
# *.*
# optimization finished, #iter = 1148
# obj = -219.624819, rho = 0.097393
# nSV = 776, nBSV = 284
# .*
# optimization finished, #iter = 1361
# obj = -254.779191, rho = 0.141131
# nSV = 895, nBSV = 253
# .*
# optimization finished, #iter = 1178
# obj = -281.745417, rho = 0.047015
# nSV = 692, nBSV = 36
# .*
# optimization finished, #iter = 1395
# obj = -298.219561, rho = 0.081389
# nSV = 780, nBSV = 31
# .*
# optimization finished, #iter = 1167
# obj = -269.575483, rho = 0.040893
# nSV = 650, nBSV = 17
# Total nSV = 1727
# [CV] END .................................................... total time=   5.1s
# [LibSVM].*
# optimization finished, #iter = 1460
# obj = -327.084564, rho = 0.122496
# nSV = 1034, nBSV = 288
# *.*
# optimization finished, #iter = 1067
# obj = -214.247261, rho = 0.137364
# nSV = 748, nBSV = 275
# *.*
# optimization finished, #iter = 1295
# obj = -250.688700, rho = 0.204318
# nSV = 880, nBSV = 257
# .*
# optimization finished, #iter = 1202
# obj = -260.584754, rho = 0.090125
# nSV = 682, nBSV = 26
# .*
# optimization finished, #iter = 1357
# obj = -293.445811, rho = 0.146035
# nSV = 776, nBSV = 31
# .*
# optimization finished, #iter = 1171
# obj = -268.747736, rho = 0.059182
# nSV = 650, nBSV = 15
# Total nSV = 1718
# [CV] END .................................................... total time=   5.2s
# [LibSVM].*
# optimization finished, #iter = 1479
# obj = -328.009736, rho = 0.091179
# nSV = 1046, nBSV = 294
# *.*
# optimization finished, #iter = 1160
# obj = -215.878852, rho = 0.106905
# nSV = 777, nBSV = 268
# .*
# optimization finished, #iter = 1347
# obj = -252.228094, rho = 0.158089
# nSV = 905, nBSV = 249
# .*
# optimization finished, #iter = 1174
# obj = -272.692451, rho = 0.065058
# nSV = 687, nBSV = 32
# .*
# optimization finished, #iter = 1383
# obj = -300.534765, rho = 0.116123
# nSV = 777, nBSV = 35
# .*
# optimization finished, #iter = 1146
# obj = -268.535211, rho = 0.055695
# nSV = 653, nBSV = 12
# Total nSV = 1736
# [CV] END .................................................... total time=   5.2s
# Training duration for PCA=1600, C=1, kernel=rbf, gamma=auto: 15.528319835662842 seconds
# Using existing PCA model for 1600 components
# [LibSVM]........*....*
# optimization finished, #iter = 12881
# obj = -0.771869, rho = 0.707572
# nSV = 417, nBSV = 0
# .*.*
# optimization finished, #iter = 2126
# obj = -0.049240, rho = -0.509753
# nSV = 198, nBSV = 0
# ...*
# optimization finished, #iter = 3675
# obj = -0.125562, rho = -0.444424
# nSV = 250, nBSV = 0
# ....*..*
# optimization finished, #iter = 4551
# obj = -0.355675, rho = -1.404315
# nSV = 326, nBSV = 0
# ....*..*
# optimization finished, #iter = 4932
# obj = -0.198372, rho = -1.102659
# nSV = 329, nBSV = 0
# ....*..*
# optimization finished, #iter = 4256
# obj = -0.187187, rho = -0.097329
# nSV = 343, nBSV = 0
# Total nSV = 1138
# [CV] END .................................................... total time=   2.2s
# [LibSVM]...........*...*
# optimization finished, #iter = 14267
# obj = -0.644068, rho = 0.609817
# nSV = 404, nBSV = 0
# .*
# optimization finished, #iter = 1626
# obj = -0.045683, rho = -0.497757
# nSV = 187, nBSV = 0
# ..*..*
# optimization finished, #iter = 4178
# obj = -0.115221, rho = -0.532458
# nSV = 248, nBSV = 0
# ...*..*
# optimization finished, #iter = 4268
# obj = -0.224672, rho = -1.112040
# nSV = 323, nBSV = 0
# ....*..*
# optimization finished, #iter = 5368
# obj = -0.181155, rho = -1.057619
# nSV = 326, nBSV = 0
# ....*..*
# optimization finished, #iter = 4189
# obj = -0.220242, rho = -0.424222
# nSV = 344, nBSV = 0
# Total nSV = 1119
# [CV] END .................................................... total time=   2.2s
# [LibSVM]........*....*
# optimization finished, #iter = 12601
# obj = -0.623574, rho = 0.466474
# nSV = 414, nBSV = 0
# .*.*
# optimization finished, #iter = 2188
# obj = -0.052908, rho = -0.477702
# nSV = 215, nBSV = 0
# ..*..*
# optimization finished, #iter = 4409
# obj = -0.125128, rho = -0.462453
# nSV = 258, nBSV = 0
# ....*.*
# optimization finished, #iter = 4324
# obj = -0.216990, rho = -1.282264
# nSV = 342, nBSV = 0
# .....*..*
# optimization finished, #iter = 5812
# obj = -0.207121, rho = -1.146311
# nSV = 339, nBSV = 0
# ....*..*
# optimization finished, #iter = 4102
# obj = -0.153083, rho = -0.318779
# nSV = 353, nBSV = 0
# Total nSV = 1124
# [CV] END .................................................... total time=   2.2s
# Training duration for PCA=1600, C=10, kernel=linear, gamma=scale: 6.686321973800659 seconds
# Using existing PCA model for 1600 components
# [LibSVM]........*....*
# optimization finished, #iter = 12881
# obj = -0.771869, rho = 0.707572
# nSV = 417, nBSV = 0
# .*.*
# optimization finished, #iter = 2126
# obj = -0.049240, rho = -0.509753
# nSV = 198, nBSV = 0
# ...*
# optimization finished, #iter = 3675
# obj = -0.125562, rho = -0.444424
# nSV = 250, nBSV = 0
# ....*..*
# optimization finished, #iter = 4551
# obj = -0.355675, rho = -1.404315
# nSV = 326, nBSV = 0
# ....*..*
# optimization finished, #iter = 4932
# obj = -0.198372, rho = -1.102659
# nSV = 329, nBSV = 0
# ....*..*
# optimization finished, #iter = 4256
# obj = -0.187187, rho = -0.097329
# nSV = 343, nBSV = 0
# Total nSV = 1138
# [CV] END .................................................... total time=   2.2s
# [LibSVM]...........*...*
# optimization finished, #iter = 14267
# obj = -0.644068, rho = 0.609817
# nSV = 404, nBSV = 0
# .*
# optimization finished, #iter = 1626
# obj = -0.045683, rho = -0.497757
# nSV = 187, nBSV = 0
# ..*..*
# optimization finished, #iter = 4178
# obj = -0.115221, rho = -0.532458
# nSV = 248, nBSV = 0
# ...*..*
# optimization finished, #iter = 4268
# obj = -0.224672, rho = -1.112040
# nSV = 323, nBSV = 0
# ....*..*
# optimization finished, #iter = 5368
# obj = -0.181155, rho = -1.057619
# nSV = 326, nBSV = 0
# ....*..*
# optimization finished, #iter = 4189
# obj = -0.220242, rho = -0.424222
# nSV = 344, nBSV = 0
# Total nSV = 1119
# [CV] END .................................................... total time=   2.3s
# [LibSVM]........*....*
# optimization finished, #iter = 12601
# obj = -0.623574, rho = 0.466474
# nSV = 414, nBSV = 0
# .*.*
# optimization finished, #iter = 2188
# obj = -0.052908, rho = -0.477702
# nSV = 215, nBSV = 0
# ..*..*
# optimization finished, #iter = 4409
# obj = -0.125128, rho = -0.462453
# nSV = 258, nBSV = 0
# ....*.*
# optimization finished, #iter = 4324
# obj = -0.216990, rho = -1.282264
# nSV = 342, nBSV = 0
# .....*..*
# optimization finished, #iter = 5812
# obj = -0.207121, rho = -1.146311
# nSV = 339, nBSV = 0
# ....*..*
# optimization finished, #iter = 4102
# obj = -0.153083, rho = -0.318779
# nSV = 353, nBSV = 0
# Total nSV = 1124
# [CV] END .................................................... total time=   2.3s
# Training duration for PCA=1600, C=10, kernel=linear, gamma=auto: 6.795831918716431 seconds
# Using existing PCA model for 1600 components
# [LibSVM].*.*
# optimization finished, #iter = 2086
# obj = -855.712323, rho = 0.041463
# nSV = 653, nBSV = 46
# *
# optimization finished, #iter = 942
# obj = -162.349120, rho = -0.088375
# nSV = 388, nBSV = 1
# *.*
# optimization finished, #iter = 1275
# obj = -254.289950, rho = -0.066968
# nSV = 475, nBSV = 10
# .*.*
# optimization finished, #iter = 1591
# obj = -543.080084, rho = 0.147230
# nSV = 586, nBSV = 4
# .*.*
# optimization finished, #iter = 1677
# obj = -437.520982, rho = 0.224876
# nSV = 607, nBSV = 2
# .*.*
# optimization finished, #iter = 1348
# obj = -400.213598, rho = 0.112929
# nSV = 546, nBSV = 2
# Total nSV = 1458
# [CV] END .................................................... total time=   3.9s
# [LibSVM].*
# optimization finished, #iter = 1984
# obj = -832.174104, rho = 0.081901
# nSV = 641, nBSV = 49
# *
# optimization finished, #iter = 926
# obj = -155.952232, rho = 0.019774
# nSV = 374, nBSV = 0
# *.*
# optimization finished, #iter = 1240
# obj = -225.012302, rho = 0.026236
# nSV = 465, nBSV = 6
# .*
# optimization finished, #iter = 1407
# obj = -434.610998, rho = 0.345220
# nSV = 534, nBSV = 0
# .*.*
# optimization finished, #iter = 1633
# obj = -429.696475, rho = 0.328316
# nSV = 599, nBSV = 0
# .*.*
# optimization finished, #iter = 1377
# obj = -409.643829, rho = 0.238158
# nSV = 532, nBSV = 3
# Total nSV = 1446
# [CV] END .................................................... total time=   3.6s
# [LibSVM].*.*
# optimization finished, #iter = 2034
# obj = -784.947971, rho = 0.050502
# nSV = 641, nBSV = 47
# *
# optimization finished, #iter = 958
# obj = -156.479848, rho = -0.102779
# nSV = 384, nBSV = 0
# *.*
# optimization finished, #iter = 1277
# obj = -237.627224, rho = -0.138401
# nSV = 475, nBSV = 9
# .*.*
# optimization finished, #iter = 1615
# obj = -479.737073, rho = 0.206304
# nSV = 573, nBSV = 3
# .*.*
# optimization finished, #iter = 1681
# obj = -454.292550, rho = 0.364454
# nSV = 607, nBSV = 1
# .*.*
# optimization finished, #iter = 1447
# obj = -379.759269, rho = 0.258694
# nSV = 549, nBSV = 1
# Total nSV = 1457
# [CV] END .................................................... total time=   3.6s
# Training duration for PCA=1600, C=10, kernel=rbf, gamma=scale: 11.029897212982178 seconds
# Using existing PCA model for 1600 components
# [LibSVM].*
# optimization finished, #iter = 1960
# obj = -402.058921, rho = -0.024470
# nSV = 1039, nBSV = 3
# *.*
# optimization finished, #iter = 1333
# obj = -227.315678, rho = 0.000449
# nSV = 782, nBSV = 0
# .*
# optimization finished, #iter = 1608
# obj = -266.316622, rho = 0.030122
# nSV = 907, nBSV = 0
# .*
# optimization finished, #iter = 1278
# obj = -303.445070, rho = 0.035218
# nSV = 696, nBSV = 0
# .*
# optimization finished, #iter = 1433
# obj = -305.818696, rho = 0.077874
# nSV = 781, nBSV = 0
# .*
# optimization finished, #iter = 1192
# obj = -278.130454, rho = 0.042625
# nSV = 650, nBSV = 0
# Total nSV = 1730
# [CV] END .................................................... total time=   5.2s
# [LibSVM].*
# optimization finished, #iter = 1901
# obj = -381.994215, rho = -0.029247
# nSV = 1012, nBSV = 1
# *.*
# optimization finished, #iter = 1322
# obj = -223.756987, rho = 0.019164
# nSV = 758, nBSV = 0
# .*
# optimization finished, #iter = 1629
# obj = -261.937079, rho = 0.069555
# nSV = 880, nBSV = 0
# .*
# optimization finished, #iter = 1223
# obj = -271.243970, rho = 0.081812
# nSV = 686, nBSV = 0
# .*
# optimization finished, #iter = 1447
# obj = -302.765824, rho = 0.135319
# nSV = 778, nBSV = 0
# .*
# optimization finished, #iter = 1180
# obj = -280.454178, rho = 0.059483
# nSV = 649, nBSV = 0
# Total nSV = 1709
# [CV] END .................................................... total time=   5.1s
# [LibSVM].*
# optimization finished, #iter = 1948
# obj = -377.788600, rho = -0.033860
# nSV = 1027, nBSV = 1
# *.*
# optimization finished, #iter = 1355
# obj = -222.565611, rho = 0.008676
# nSV = 787, nBSV = 0
# .*
# optimization finished, #iter = 1653
# obj = -262.858998, rho = 0.046431
# nSV = 917, nBSV = 0
# .*
# optimization finished, #iter = 1229
# obj = -281.351627, rho = 0.054597
# nSV = 687, nBSV = 0
# .*
# optimization finished, #iter = 1484
# obj = -308.763849, rho = 0.107770
# nSV = 777, nBSV = 0
# .*
# optimization finished, #iter = 1199
# obj = -272.511501, rho = 0.054528
# nSV = 653, nBSV = 0
# Total nSV = 1733
# [CV] END .................................................... total time=   5.1s
# Training duration for PCA=1600, C=10, kernel=rbf, gamma=auto: 15.458761215209961 seconds
# [LibSVM]........*..*
# optimization finished, #iter = 10829
# obj = -0.619446, rho = 0.630263
# nSV = 447, nBSV = 0
# .*
# optimization finished, #iter = 1899
# obj = -0.046664, rho = -0.497714
# nSV = 212, nBSV = 0
# ..*..*
# optimization finished, #iter = 4069
# obj = -0.115027, rho = -0.432550
# nSV = 269, nBSV = 0
# ...*..*
# optimization finished, #iter = 4036
# obj = -0.227252, rho = -1.162199
# nSV = 355, nBSV = 0
# ....*..*
# optimization finished, #iter = 4938
# obj = -0.177229, rho = -1.028055
# nSV = 356, nBSV = 0
# ...*..*
# optimization finished, #iter = 3627
# obj = -0.152888, rho = -0.043356
# nSV = 361, nBSV = 0
# Total nSV = 1188
# [CV] END .................................................... total time=   3.1s
# [LibSVM].......*....*
# optimization finished, #iter = 11522
# obj = -0.535636, rho = 0.559623
# nSV = 427, nBSV = 0
# .*
# optimization finished, #iter = 1691
# obj = -0.043328, rho = -0.486790
# nSV = 192, nBSV = 0
# ...*.*
# optimization finished, #iter = 4276
# obj = -0.107738, rho = -0.501227
# nSV = 260, nBSV = 0
# ...*..*
# optimization finished, #iter = 3723
# obj = -0.169728, rho = -1.040059
# nSV = 340, nBSV = 0
# ....*..*
# optimization finished, #iter = 5103
# obj = -0.165850, rho = -0.992974
# nSV = 343, nBSV = 0
# ....*.*
# optimization finished, #iter = 3688
# obj = -0.171952, rho = -0.296376
# nSV = 358, nBSV = 0
# Total nSV = 1150
# [CV] END .................................................... total time=   2.9s
# [LibSVM]........*..*
# optimization finished, #iter = 10856
# obj = -0.520876, rho = 0.394385
# nSV = 451, nBSV = 0
# .*.*
# optimization finished, #iter = 2154
# obj = -0.050671, rho = -0.460466
# nSV = 223, nBSV = 0
# ...*.*
# optimization finished, #iter = 4226
# obj = -0.116412, rho = -0.445249
# nSV = 269, nBSV = 0
# ...*..*
# optimization finished, #iter = 4289
# obj = -0.181753, rho = -1.145793
# nSV = 369, nBSV = 0
# ....*..*
# optimization finished, #iter = 5081
# obj = -0.186569, rho = -1.075234
# nSV = 354, nBSV = 0
# ...*..*
# optimization finished, #iter = 3724
# obj = -0.130874, rho = -0.250788
# nSV = 371, nBSV = 0
# Total nSV = 1178
# [CV] END .................................................... total time=   3.5s
# Training duration for PCA=2025, C=0.1, kernel=linear, gamma=scale: 9.4598970413208 seconds
# Using existing PCA model for 2025 components
# [LibSVM]........*..*
# optimization finished, #iter = 10829
# obj = -0.619446, rho = 0.630263
# nSV = 447, nBSV = 0
# .*
# optimization finished, #iter = 1899
# obj = -0.046664, rho = -0.497714
# nSV = 212, nBSV = 0
# ..*..*
# optimization finished, #iter = 4069
# obj = -0.115027, rho = -0.432550
# nSV = 269, nBSV = 0
# ...*..*
# optimization finished, #iter = 4036
# obj = -0.227252, rho = -1.162199
# nSV = 355, nBSV = 0
# ....*..*
# optimization finished, #iter = 4938
# obj = -0.177229, rho = -1.028055
# nSV = 356, nBSV = 0
# ...*..*
# optimization finished, #iter = 3627
# obj = -0.152888, rho = -0.043356
# nSV = 361, nBSV = 0
# Total nSV = 1188
# [CV] END .................................................... total time=   3.1s
# [LibSVM].......*....*
# optimization finished, #iter = 11522
# obj = -0.535636, rho = 0.559623
# nSV = 427, nBSV = 0
# .*
# optimization finished, #iter = 1691
# obj = -0.043328, rho = -0.486790
# nSV = 192, nBSV = 0
# ...*.*
# optimization finished, #iter = 4276
# obj = -0.107738, rho = -0.501227
# nSV = 260, nBSV = 0
# ...*..*
# optimization finished, #iter = 3723
# obj = -0.169728, rho = -1.040059
# nSV = 340, nBSV = 0
# ....*..*
# optimization finished, #iter = 5103
# obj = -0.165850, rho = -0.992974
# nSV = 343, nBSV = 0
# ....*.*
# optimization finished, #iter = 3688
# obj = -0.171952, rho = -0.296376
# nSV = 358, nBSV = 0
# Total nSV = 1150
# [CV] END .................................................... total time=   3.0s
# [LibSVM]........*..*
# optimization finished, #iter = 10856
# obj = -0.520876, rho = 0.394385
# nSV = 451, nBSV = 0
# .*.*
# optimization finished, #iter = 2154
# obj = -0.050671, rho = -0.460466
# nSV = 223, nBSV = 0
# ...*.*
# optimization finished, #iter = 4226
# obj = -0.116412, rho = -0.445249
# nSV = 269, nBSV = 0
# ...*..*
# optimization finished, #iter = 4289
# obj = -0.181753, rho = -1.145793
# nSV = 369, nBSV = 0
# ....*..*
# optimization finished, #iter = 5081
# obj = -0.186569, rho = -1.075234
# nSV = 354, nBSV = 0
# ...*..*
# optimization finished, #iter = 3724
# obj = -0.130874, rho = -0.250788
# nSV = 371, nBSV = 0
# Total nSV = 1178
# [CV] END .................................................... total time=   3.3s
# Training duration for PCA=2025, C=0.1, kernel=linear, gamma=auto: 9.360658884048462 seconds
# Using existing PCA model for 2025 components
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1062
# obj = -64.812058, rho = 0.257179
# nSV = 1036, nBSV = 933
# *
# optimization finished, #iter = 700
# obj = -40.765898, rho = 0.373336
# nSV = 670, nBSV = 609
# *
# optimization finished, #iter = 945
# obj = -51.853389, rho = 0.570169
# nSV = 890, nBSV = 807
# *
# optimization finished, #iter = 668
# obj = -66.733970, rho = 0.612950
# nSV = 637, nBSV = 587
# *
# optimization finished, #iter = 795
# obj = -71.735065, rho = 0.725842
# nSV = 755, nBSV = 700
# *
# optimization finished, #iter = 651
# obj = -70.375234, rho = 0.190773
# nSV = 620, nBSV = 593
# Total nSV = 1765
# [CV] END .................................................... total time=   6.1s
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1068
# obj = -65.365080, rho = 0.286348
# nSV = 1041, nBSV = 939
# *
# optimization finished, #iter = 672
# obj = -38.912256, rho = 0.409487
# nSV = 649, nBSV = 584
# *
# optimization finished, #iter = 919
# obj = -49.795075, rho = 0.669871
# nSV = 864, nBSV = 762
# *
# optimization finished, #iter = 634
# obj = -62.449057, rho = 0.638083
# nSV = 608, nBSV = 554
# *
# optimization finished, #iter = 776
# obj = -66.479206, rho = 0.782480
# nSV = 713, nBSV = 652
# *
# optimization finished, #iter = 640
# obj = -68.310942, rho = 0.240123
# nSV = 613, nBSV = 580
# Total nSV = 1767
# [CV] END .................................................... total time=   6.3s
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1075
# obj = -66.297668, rho = 0.193256
# nSV = 1057, nBSV = 940
# *
# optimization finished, #iter = 711
# obj = -41.486039, rho = 0.407891
# nSV = 684, nBSV = 630
# *
# optimization finished, #iter = 940
# obj = -51.947576, rho = 0.612936
# nSV = 890, nBSV = 812
# *
# optimization finished, #iter = 657
# obj = -64.166020, rho = 0.575368
# nSV = 615, nBSV = 564
# *
# optimization finished, #iter = 792
# obj = -69.770048, rho = 0.758562
# nSV = 738, nBSV = 679
# *
# optimization finished, #iter = 645
# obj = -70.496306, rho = 0.268607
# nSV = 618, nBSV = 593
# Total nSV = 1777
# [CV] END .................................................... total time=   6.3s
# Training duration for PCA=2025, C=0.1, kernel=rbf, gamma=scale: 18.65696692466736 seconds
# Using existing PCA model for 2025 components
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1174
# obj = -74.849526, rho = 0.735258
# nSV = 1149, nBSV = 975
# *
# optimization finished, #iter = 906
# obj = -60.482055, rho = 0.791350
# nSV = 917, nBSV = 756
# *.*
# optimization finished, #iter = 1056
# obj = -67.386977, rho = 0.806074
# nSV = 1046, nBSV = 912
# *
# optimization finished, #iter = 731
# obj = -76.940355, rho = 0.721930
# nSV = 720, nBSV = 688
# *.*
# optimization finished, #iter = 808
# obj = -81.880620, rho = 0.560861
# nSV = 804, nBSV = 800
# *.*
# optimization finished, #iter = 670
# obj = -80.680270, rho = -0.359335
# nSV = 668, nBSV = 664
# Total nSV = 1823
# [CV] END .................................................... total time=   6.9s
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1173
# obj = -74.241931, rho = 0.753150
# nSV = 1148, nBSV = 957
# *
# optimization finished, #iter = 912
# obj = -58.068628, rho = 0.805640
# nSV = 905, nBSV = 729
# *.*
# optimization finished, #iter = 1030
# obj = -64.867525, rho = 0.837337
# nSV = 1023, nBSV = 856
# *
# optimization finished, #iter = 727
# obj = -74.651033, rho = 0.745671
# nSV = 717, nBSV = 671
# *.*
# optimization finished, #iter = 805
# obj = -79.754779, rho = 0.619151
# nSV = 802, nBSV = 781
# *
# optimization finished, #iter = 666
# obj = -81.134918, rho = -0.272672
# nSV = 667, nBSV = 665
# Total nSV = 1821
# [CV] END .................................................... total time=   6.9s
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1188
# obj = -76.538745, rho = 0.677186
# nSV = 1169, nBSV = 994
# *
# optimization finished, #iter = 930
# obj = -61.138988, rho = 0.783450
# nSV = 929, nBSV = 782
# *.*
# optimization finished, #iter = 1043
# obj = -67.579699, rho = 0.808993
# nSV = 1044, nBSV = 930
# *.*
# optimization finished, #iter = 741
# obj = -74.919970, rho = 0.766864
# nSV = 715, nBSV = 645
# *.*
# optimization finished, #iter = 806
# obj = -80.304216, rho = 0.690633
# nSV = 800, nBSV = 779
# *
# optimization finished, #iter = 666
# obj = -81.302096, rho = -0.357437
# nSV = 667, nBSV = 666
# Total nSV = 1840
# [CV] END .................................................... total time=   6.8s
# Training duration for PCA=2025, C=0.1, kernel=rbf, gamma=auto: 20.615103006362915 seconds
# Using existing PCA model for 2025 components
# [LibSVM]........*..*
# optimization finished, #iter = 10829
# obj = -0.619446, rho = 0.630263
# nSV = 447, nBSV = 0
# .*
# optimization finished, #iter = 1899
# obj = -0.046664, rho = -0.497714
# nSV = 212, nBSV = 0
# ..*..*
# optimization finished, #iter = 4069
# obj = -0.115027, rho = -0.432550
# nSV = 269, nBSV = 0
# ...*..*
# optimization finished, #iter = 4036
# obj = -0.227252, rho = -1.162199
# nSV = 355, nBSV = 0
# ....*..*
# optimization finished, #iter = 4938
# obj = -0.177229, rho = -1.028055
# nSV = 356, nBSV = 0
# ...*..*
# optimization finished, #iter = 3627
# obj = -0.152888, rho = -0.043356
# nSV = 361, nBSV = 0
# Total nSV = 1188
# [CV] END .................................................... total time=   3.0s
# [LibSVM].......*....*
# optimization finished, #iter = 11522
# obj = -0.535636, rho = 0.559623
# nSV = 427, nBSV = 0
# .*
# optimization finished, #iter = 1691
# obj = -0.043328, rho = -0.486790
# nSV = 192, nBSV = 0
# ...*.*
# optimization finished, #iter = 4276
# obj = -0.107738, rho = -0.501227
# nSV = 260, nBSV = 0
# ...*..*
# optimization finished, #iter = 3723
# obj = -0.169728, rho = -1.040059
# nSV = 340, nBSV = 0
# ....*..*
# optimization finished, #iter = 5103
# obj = -0.165850, rho = -0.992974
# nSV = 343, nBSV = 0
# ....*.*
# optimization finished, #iter = 3688
# obj = -0.171952, rho = -0.296376
# nSV = 358, nBSV = 0
# Total nSV = 1150
# [CV] END .................................................... total time=   2.9s
# [LibSVM]........*..*
# optimization finished, #iter = 10856
# obj = -0.520876, rho = 0.394385
# nSV = 451, nBSV = 0
# .*.*
# optimization finished, #iter = 2154
# obj = -0.050671, rho = -0.460466
# nSV = 223, nBSV = 0
# ...*.*
# optimization finished, #iter = 4226
# obj = -0.116412, rho = -0.445249
# nSV = 269, nBSV = 0
# ...*..*
# optimization finished, #iter = 4289
# obj = -0.181753, rho = -1.145793
# nSV = 369, nBSV = 0
# ....*..*
# optimization finished, #iter = 5081
# obj = -0.186569, rho = -1.075234
# nSV = 354, nBSV = 0
# ...*..*
# optimization finished, #iter = 3724
# obj = -0.130874, rho = -0.250788
# nSV = 371, nBSV = 0
# Total nSV = 1178
# [CV] END .................................................... total time=   3.2s
# Training duration for PCA=2025, C=1, kernel=linear, gamma=scale: 9.139956951141357 seconds
# Using existing PCA model for 2025 components
# [LibSVM]........*..*
# optimization finished, #iter = 10829
# obj = -0.619446, rho = 0.630263
# nSV = 447, nBSV = 0
# .*
# optimization finished, #iter = 1899
# obj = -0.046664, rho = -0.497714
# nSV = 212, nBSV = 0
# ..*..*
# optimization finished, #iter = 4069
# obj = -0.115027, rho = -0.432550
# nSV = 269, nBSV = 0
# ...*..*
# optimization finished, #iter = 4036
# obj = -0.227252, rho = -1.162199
# nSV = 355, nBSV = 0
# ....*..*
# optimization finished, #iter = 4938
# obj = -0.177229, rho = -1.028055
# nSV = 356, nBSV = 0
# ...*..*
# optimization finished, #iter = 3627
# obj = -0.152888, rho = -0.043356
# nSV = 361, nBSV = 0
# Total nSV = 1188
# [CV] END .................................................... total time=   3.0s
# [LibSVM].......*....*
# optimization finished, #iter = 11522
# obj = -0.535636, rho = 0.559623
# nSV = 427, nBSV = 0
# .*
# optimization finished, #iter = 1691
# obj = -0.043328, rho = -0.486790
# nSV = 192, nBSV = 0
# ...*.*
# optimization finished, #iter = 4276
# obj = -0.107738, rho = -0.501227
# nSV = 260, nBSV = 0
# ...*..*
# optimization finished, #iter = 3723
# obj = -0.169728, rho = -1.040059
# nSV = 340, nBSV = 0
# ....*..*
# optimization finished, #iter = 5103
# obj = -0.165850, rho = -0.992974
# nSV = 343, nBSV = 0
# ....*.*
# optimization finished, #iter = 3688
# obj = -0.171952, rho = -0.296376
# nSV = 358, nBSV = 0
# Total nSV = 1150
# [CV] END .................................................... total time=   2.9s
# [LibSVM]........*..*
# optimization finished, #iter = 10856
# obj = -0.520876, rho = 0.394385
# nSV = 451, nBSV = 0
# .*.*
# optimization finished, #iter = 2154
# obj = -0.050671, rho = -0.460466
# nSV = 223, nBSV = 0
# ...*.*
# optimization finished, #iter = 4226
# obj = -0.116412, rho = -0.445249
# nSV = 269, nBSV = 0
# ...*..*
# optimization finished, #iter = 4289
# obj = -0.181753, rho = -1.145793
# nSV = 369, nBSV = 0
# ....*..*
# optimization finished, #iter = 5081
# obj = -0.186569, rho = -1.075234
# nSV = 354, nBSV = 0
# ...*..*
# optimization finished, #iter = 3724
# obj = -0.130874, rho = -0.250788
# nSV = 371, nBSV = 0
# Total nSV = 1178
# [CV] END .................................................... total time=   3.1s
# Training duration for PCA=2025, C=1, kernel=linear, gamma=auto: 9.027405977249146 seconds
# Using existing PCA model for 2025 components
# [LibSVM]*.*
# optimization finished, #iter = 1056
# obj = -327.934685, rho = -0.062964
# nSV = 741, nBSV = 451
# *
# optimization finished, #iter = 709
# obj = -120.327824, rho = -0.123666
# nSV = 408, nBSV = 122
# *
# optimization finished, #iter = 892
# obj = -164.741454, rho = -0.138516
# nSV = 542, nBSV = 192
# .*
# optimization finished, #iter = 1004
# obj = -313.817609, rho = 0.225643
# nSV = 581, nBSV = 158
# .*
# optimization finished, #iter = 1103
# obj = -303.215899, rho = 0.295048
# nSV = 634, nBSV = 144
# .*
# optimization finished, #iter = 970
# obj = -299.056215, rho = 0.147283
# nSV = 546, nBSV = 181
# Total nSV = 1529
# [CV] END .................................................... total time=   4.8s
# [LibSVM]*.*
# optimization finished, #iter = 1093
# obj = -330.762195, rho = 0.189536
# nSV = 756, nBSV = 446
# *
# optimization finished, #iter = 719
# obj = -110.823926, rho = 0.048787
# nSV = 389, nBSV = 104
# *
# optimization finished, #iter = 908
# obj = -160.674246, rho = 0.005172
# nSV = 543, nBSV = 191
# *.*
# optimization finished, #iter = 933
# obj = -282.249962, rho = 0.301815
# nSV = 545, nBSV = 150
# .*
# optimization finished, #iter = 1104
# obj = -293.291549, rho = 0.361712
# nSV = 633, nBSV = 138
# .*
# optimization finished, #iter = 985
# obj = -285.920936, rho = 0.201501
# nSV = 532, nBSV = 165
# Total nSV = 1537
# [CV] END .................................................... total time=   4.9s
# [LibSVM]*.*
# optimization finished, #iter = 1109
# obj = -331.006216, rho = -0.018984
# nSV = 767, nBSV = 432
# *
# optimization finished, #iter = 751
# obj = -121.447457, rho = -0.061566
# nSV = 411, nBSV = 120
# *
# optimization finished, #iter = 912
# obj = -162.510095, rho = -0.112036
# nSV = 541, nBSV = 194
# *.*
# optimization finished, #iter = 961
# obj = -311.914146, rho = 0.363166
# nSV = 574, nBSV = 180
# .*
# optimization finished, #iter = 1122
# obj = -308.560981, rho = 0.408240
# nSV = 638, nBSV = 149
# .*
# optimization finished, #iter = 1018
# obj = -296.384121, rho = 0.187265
# nSV = 560, nBSV = 182
# Total nSV = 1548
# [CV] END .................................................... total time=   4.8s
# Training duration for PCA=2025, C=1, kernel=rbf, gamma=scale: 14.5554358959198 seconds
# Using existing PCA model for 2025 components
# [LibSVM].*
# optimization finished, #iter = 1472
# obj = -313.825656, rho = 0.077087
# nSV = 1003, nBSV = 253
# *.*
# optimization finished, #iter = 1138
# obj = -184.931122, rho = 0.105625
# nSV = 724, nBSV = 167
# *.*
# optimization finished, #iter = 1293
# obj = -221.973906, rho = 0.155115
# nSV = 844, nBSV = 192
# .*
# optimization finished, #iter = 1153
# obj = -270.682698, rho = 0.097286
# nSV = 685, nBSV = 41
# .*
# optimization finished, #iter = 1314
# obj = -281.915755, rho = 0.132441
# nSV = 772, nBSV = 37
# .*
# optimization finished, #iter = 1108
# obj = -259.182573, rho = 0.057129
# nSV = 642, nBSV = 26
# Total nSV = 1692
# [CV] END .................................................... total time=   6.4s
# [LibSVM].*
# optimization finished, #iter = 1451
# obj = -307.968332, rho = 0.094183
# nSV = 993, nBSV = 250
# *.*
# optimization finished, #iter = 1063
# obj = -180.671759, rho = 0.138952
# nSV = 686, nBSV = 180
# *.*
# optimization finished, #iter = 1293
# obj = -219.666575, rho = 0.212861
# nSV = 832, nBSV = 191
# .*
# optimization finished, #iter = 1171
# obj = -247.300649, rho = 0.152272
# nSV = 666, nBSV = 31
# .*
# optimization finished, #iter = 1390
# obj = -276.506694, rho = 0.216586
# nSV = 767, nBSV = 36
# .*
# optimization finished, #iter = 1083
# obj = -256.206279, rho = 0.077590
# nSV = 645, nBSV = 25
# Total nSV = 1687
# [CV] END .................................................... total time=   6.4s
# [LibSVM].*
# optimization finished, #iter = 1480
# obj = -308.397748, rho = 0.069096
# nSV = 1012, nBSV = 252
# *.*
# optimization finished, #iter = 1141
# obj = -182.505136, rho = 0.115078
# nSV = 725, nBSV = 164
# *.*
# optimization finished, #iter = 1349
# obj = -219.993274, rho = 0.170006
# nSV = 850, nBSV = 189
# .*
# optimization finished, #iter = 1148
# obj = -262.569708, rho = 0.116096
# nSV = 677, nBSV = 39
# .*
# optimization finished, #iter = 1365
# obj = -285.065150, rho = 0.177610
# nSV = 774, nBSV = 37
# .*
# optimization finished, #iter = 1173
# obj = -257.660444, rho = 0.076391
# nSV = 646, nBSV = 21
# Total nSV = 1716
# [CV] END .................................................... total time=   6.7s
# Training duration for PCA=2025, C=1, kernel=rbf, gamma=auto: 19.539405822753906 seconds
# Using existing PCA model for 2025 components
# [LibSVM]........*..*
# optimization finished, #iter = 10829
# obj = -0.619446, rho = 0.630263
# nSV = 447, nBSV = 0
# .*
# optimization finished, #iter = 1899
# obj = -0.046664, rho = -0.497714
# nSV = 212, nBSV = 0
# ..*..*
# optimization finished, #iter = 4069
# obj = -0.115027, rho = -0.432550
# nSV = 269, nBSV = 0
# ...*..*
# optimization finished, #iter = 4036
# obj = -0.227252, rho = -1.162199
# nSV = 355, nBSV = 0
# ....*..*
# optimization finished, #iter = 4938
# obj = -0.177229, rho = -1.028055
# nSV = 356, nBSV = 0
# ...*..*
# optimization finished, #iter = 3627
# obj = -0.152888, rho = -0.043356
# nSV = 361, nBSV = 0
# Total nSV = 1188
# [CV] END .................................................... total time=   3.1s
# [LibSVM].......*....*
# optimization finished, #iter = 11522
# obj = -0.535636, rho = 0.559623
# nSV = 427, nBSV = 0
# .*
# optimization finished, #iter = 1691
# obj = -0.043328, rho = -0.486790
# nSV = 192, nBSV = 0
# ...*.*
# optimization finished, #iter = 4276
# obj = -0.107738, rho = -0.501227
# nSV = 260, nBSV = 0
# ...*..*
# optimization finished, #iter = 3723
# obj = -0.169728, rho = -1.040059
# nSV = 340, nBSV = 0
# ....*..*
# optimization finished, #iter = 5103
# obj = -0.165850, rho = -0.992974
# nSV = 343, nBSV = 0
# ....*.*
# optimization finished, #iter = 3688
# obj = -0.171952, rho = -0.296376
# nSV = 358, nBSV = 0
# Total nSV = 1150
# [CV] END .................................................... total time=   2.9s
# [LibSVM]........*..*
# optimization finished, #iter = 10856
# obj = -0.520876, rho = 0.394385
# nSV = 451, nBSV = 0
# .*.*
# optimization finished, #iter = 2154
# obj = -0.050671, rho = -0.460466
# nSV = 223, nBSV = 0
# ...*.*
# optimization finished, #iter = 4226
# obj = -0.116412, rho = -0.445249
# nSV = 269, nBSV = 0
# ...*..*
# optimization finished, #iter = 4289
# obj = -0.181753, rho = -1.145793
# nSV = 369, nBSV = 0
# ....*..*
# optimization finished, #iter = 5081
# obj = -0.186569, rho = -1.075234
# nSV = 354, nBSV = 0
# ...*..*
# optimization finished, #iter = 3724
# obj = -0.130874, rho = -0.250788
# nSV = 371, nBSV = 0
# Total nSV = 1178
# [CV] END .................................................... total time=   3.2s
# Training duration for PCA=2025, C=10, kernel=linear, gamma=scale: 9.15693187713623 seconds
# Using existing PCA model for 2025 components
# [LibSVM]........*..*
# optimization finished, #iter = 10829
# obj = -0.619446, rho = 0.630263
# nSV = 447, nBSV = 0
# .*
# optimization finished, #iter = 1899
# obj = -0.046664, rho = -0.497714
# nSV = 212, nBSV = 0
# ..*..*
# optimization finished, #iter = 4069
# obj = -0.115027, rho = -0.432550
# nSV = 269, nBSV = 0
# ...*..*
# optimization finished, #iter = 4036
# obj = -0.227252, rho = -1.162199
# nSV = 355, nBSV = 0
# ....*..*
# optimization finished, #iter = 4938
# obj = -0.177229, rho = -1.028055
# nSV = 356, nBSV = 0
# ...*..*
# optimization finished, #iter = 3627
# obj = -0.152888, rho = -0.043356
# nSV = 361, nBSV = 0
# Total nSV = 1188
# [CV] END .................................................... total time=   3.1s
# [LibSVM].......*....*
# optimization finished, #iter = 11522
# obj = -0.535636, rho = 0.559623
# nSV = 427, nBSV = 0
# .*
# optimization finished, #iter = 1691
# obj = -0.043328, rho = -0.486790
# nSV = 192, nBSV = 0
# ...*.*
# optimization finished, #iter = 4276
# obj = -0.107738, rho = -0.501227
# nSV = 260, nBSV = 0
# ...*..*
# optimization finished, #iter = 3723
# obj = -0.169728, rho = -1.040059
# nSV = 340, nBSV = 0
# ....*..*
# optimization finished, #iter = 5103
# obj = -0.165850, rho = -0.992974
# nSV = 343, nBSV = 0
# ....*.*
# optimization finished, #iter = 3688
# obj = -0.171952, rho = -0.296376
# nSV = 358, nBSV = 0
# Total nSV = 1150
# [CV] END .................................................... total time=   3.0s
# [LibSVM]........*..*
# optimization finished, #iter = 10856
# obj = -0.520876, rho = 0.394385
# nSV = 451, nBSV = 0
# .*.*
# optimization finished, #iter = 2154
# obj = -0.050671, rho = -0.460466
# nSV = 223, nBSV = 0
# ...*.*
# optimization finished, #iter = 4226
# obj = -0.116412, rho = -0.445249
# nSV = 269, nBSV = 0
# ...*..*
# optimization finished, #iter = 4289
# obj = -0.181753, rho = -1.145793
# nSV = 369, nBSV = 0
# ....*..*
# optimization finished, #iter = 5081
# ...
# [LibSVM]......*...*
# optimization finished, #iter = 9103
# obj = -0.432433, rho = 0.362818
# nSV = 476, nBSV = 0
# .*.*
# optimization finished, #iter = 2035
# obj = -0.048973, rho = -0.452772
# nSV = 223, nBSV = 0
# ..*.*
# optimization finished, #iter = 3896
# obj = -0.107496, rho = -0.411725
# nSV = 282, nBSV = 0
# ....*.*
# optimization finished, #iter = 4252
# obj = -0.162164, rho = -1.087219
# nSV = 393, nBSV = 0
# ....*..*
# optimization finished, #iter = 4996
# obj = -0.168470, rho = -1.022769
# nSV = 381, nBSV = 0
# ...*..*
# optimization finished, #iter = 3559
# obj = -0.120439, rho = -0.226264
# nSV = 386, nBSV = 0
# Total nSV = 1211
# [CV] END .................................................... total time=   4.1s
# Training duration for PCA=2500, C=1, kernel=linear, gamma=scale: 11.860060930252075 seconds
# Using existing PCA model for 2500 components
# [LibSVM]......*...*
# optimization finished, #iter = 9026
# obj = -0.504399, rho = 0.542130
# nSV = 478, nBSV = 0
# .*
# optimization finished, #iter = 1861
# obj = -0.045256, rho = -0.486960
# nSV = 216, nBSV = 0
# ..*.*
# optimization finished, #iter = 3434
# obj = -0.105950, rho = -0.416767
# nSV = 280, nBSV = 0
# ....*.*
# optimization finished, #iter = 4082
# obj = -0.181205, rho = -1.090024
# nSV = 385, nBSV = 0
# ...*..*
# optimization finished, #iter = 4649
# obj = -0.161777, rho = -0.977067
# nSV = 377, nBSV = 0
# ...*..*
# optimization finished, #iter = 3586
# obj = -0.131792, rho = -0.040023
# nSV = 383, nBSV = 0
# Total nSV = 1228
# [CV] END .................................................... total time=   3.9s
# [LibSVM]......*...*
# optimization finished, #iter = 9790
# obj = -0.441164, rho = 0.483532
# nSV = 473, nBSV = 0
# .*
# optimization finished, #iter = 1596
# obj = -0.041683, rho = -0.480266
# nSV = 204, nBSV = 0
# ..*.*
# optimization finished, #iter = 3556
# obj = -0.100662, rho = -0.467903
# nSV = 272, nBSV = 0
# ...*.*
# optimization finished, #iter = 3482
# obj = -0.142299, rho = -1.006780
# nSV = 363, nBSV = 0
# ....*.*
# optimization finished, #iter = 4793
# obj = -0.152566, rho = -0.940422
# nSV = 362, nBSV = 0
# ...*..*
# optimization finished, #iter = 3486
# obj = -0.139945, rho = -0.202758
# nSV = 372, nBSV = 0
# Total nSV = 1204
# [CV] END .................................................... total time=   3.8s
# [LibSVM]......*...*
# optimization finished, #iter = 9103
# obj = -0.432433, rho = 0.362818
# nSV = 476, nBSV = 0
# .*.*
# optimization finished, #iter = 2035
# obj = -0.048973, rho = -0.452772
# nSV = 223, nBSV = 0
# ..*.*
# optimization finished, #iter = 3896
# obj = -0.107496, rho = -0.411725
# nSV = 282, nBSV = 0
# ....*.*
# optimization finished, #iter = 4252
# obj = -0.162164, rho = -1.087219
# nSV = 393, nBSV = 0
# ....*..*
# optimization finished, #iter = 4996
# obj = -0.168470, rho = -1.022769
# nSV = 381, nBSV = 0
# ...*..*
# optimization finished, #iter = 3559
# obj = -0.120439, rho = -0.226264
# nSV = 386, nBSV = 0
# Total nSV = 1211
# [CV] END .................................................... total time=   4.0s
# Training duration for PCA=2500, C=1, kernel=linear, gamma=auto: 11.749045133590698 seconds
# Using existing PCA model for 2500 components
# [LibSVM]*.*
# optimization finished, #iter = 1060
# obj = -327.959144, rho = -0.069771
# nSV = 744, nBSV = 446
# *
# optimization finished, #iter = 674
# obj = -120.421554, rho = -0.127203
# nSV = 411, nBSV = 121
# *
# optimization finished, #iter = 943
# obj = -164.838898, rho = -0.142429
# nSV = 549, nBSV = 189
# .*
# optimization finished, #iter = 1021
# obj = -313.664062, rho = 0.220205
# nSV = 584, nBSV = 155
# .*
# optimization finished, #iter = 1094
# obj = -303.295345, rho = 0.288621
# nSV = 636, nBSV = 140
# .*
# optimization finished, #iter = 956
# obj = -299.095518, rho = 0.145961
# nSV = 550, nBSV = 180
# Total nSV = 1533
# [CV] END .................................................... total time=   6.0s
# [LibSVM]*.*
# optimization finished, #iter = 1111
# obj = -330.866522, rho = 0.181753
# nSV = 759, nBSV = 443
# *
# optimization finished, #iter = 708
# obj = -110.958340, rho = 0.046116
# nSV = 392, nBSV = 104
# *
# optimization finished, #iter = 939
# obj = -160.823338, rho = 0.001430
# nSV = 546, nBSV = 190
# *.*
# optimization finished, #iter = 925
# obj = -282.231217, rho = 0.298787
# nSV = 548, nBSV = 146
# .*
# optimization finished, #iter = 1114
# obj = -293.312315, rho = 0.351774
# nSV = 638, nBSV = 137
# .*
# optimization finished, #iter = 961
# obj = -285.940187, rho = 0.196029
# nSV = 536, nBSV = 165
# Total nSV = 1541
# [CV] END .................................................... total time=   6.1s
# [LibSVM]*.*
# optimization finished, #iter = 1114
# obj = -331.112842, rho = -0.026534
# nSV = 772, nBSV = 434
# *
# optimization finished, #iter = 750
# obj = -121.567455, rho = -0.065422
# nSV = 413, nBSV = 119
# *
# optimization finished, #iter = 921
# obj = -162.664449, rho = -0.115895
# nSV = 544, nBSV = 192
# *.*
# optimization finished, #iter = 955
# obj = -311.753518, rho = 0.360781
# nSV = 577, nBSV = 175
# .*
# optimization finished, #iter = 1068
# obj = -308.562009, rho = 0.404549
# nSV = 640, nBSV = 147
# .*
# optimization finished, #iter = 1033
# obj = -296.440253, rho = 0.185937
# nSV = 563, nBSV = 181
# Total nSV = 1553
# [CV] END .................................................... total time=   6.1s
# Training duration for PCA=2500, C=1, kernel=rbf, gamma=scale: 18.16974425315857 seconds
# Using existing PCA model for 2500 components
# [LibSVM].*
# optimization finished, #iter = 1445
# obj = -300.510029, rho = 0.041000
# nSV = 967, nBSV = 247
# *.*
# optimization finished, #iter = 1071
# obj = -158.011889, rho = 0.068068
# nSV = 686, nBSV = 129
# *.*
# optimization finished, #iter = 1278
# obj = -196.903471, rho = 0.139410
# nSV = 807, nBSV = 152
# .*
# optimization finished, #iter = 1182
# obj = -264.333267, rho = 0.127351
# nSV = 679, nBSV = 49
# .*
# optimization finished, #iter = 1351
# obj = -270.705165, rho = 0.169969
# nSV = 760, nBSV = 39
# .*
# optimization finished, #iter = 1112
# obj = -252.013635, rho = 0.086592
# nSV = 634, nBSV = 35
# Total nSV = 1678
# [CV] END .................................................... total time=   7.9s
# [LibSVM].*
# optimization finished, #iter = 1439
# obj = -296.665007, rho = 0.061126
# nSV = 959, nBSV = 259
# *.*
# optimization finished, #iter = 1049
# obj = -153.708672, rho = 0.099269
# nSV = 660, nBSV = 130
# *.*
# optimization finished, #iter = 1243
# obj = -195.100799, rho = 0.186916
# nSV = 795, nBSV = 157
# .*
# optimization finished, #iter = 1200
# obj = -239.447092, rho = 0.190608
# nSV = 655, nBSV = 38
# .*
# optimization finished, #iter = 1362
# obj = -265.419003, rho = 0.264597
# nSV = 758, nBSV = 41
# .*
# optimization finished, #iter = 1139
# obj = -246.712227, rho = 0.106681
# nSV = 639, nBSV = 36
# Total nSV = 1668
# [CV] END .................................................... total time=   7.9s
# [LibSVM].*
# optimization finished, #iter = 1413
# obj = -297.276264, rho = 0.037353
# nSV = 963, nBSV = 266
# *.*
# optimization finished, #iter = 1127
# obj = -156.469879, rho = 0.077472
# nSV = 693, nBSV = 121
# *.*
# optimization finished, #iter = 1303
# obj = -194.737407, rho = 0.148752
# nSV = 815, nBSV = 146
# .*
# optimization finished, #iter = 1142
# obj = -257.395317, rho = 0.149901
# nSV = 665, nBSV = 45
# .*
# optimization finished, #iter = 1379
# obj = -274.438769, rho = 0.224030
# nSV = 765, nBSV = 48
# .*
# optimization finished, #iter = 1151
# obj = -249.512849, rho = 0.106349
# nSV = 644, nBSV = 40
# Total nSV = 1690
# [CV] END .................................................... total time=   8.4s
# Training duration for PCA=2500, C=1, kernel=rbf, gamma=auto: 24.26753520965576 seconds
# Using existing PCA model for 2500 components
# [LibSVM]......*...*
# optimization finished, #iter = 9026
# obj = -0.504399, rho = 0.542130
# nSV = 478, nBSV = 0
# .*
# optimization finished, #iter = 1861
# obj = -0.045256, rho = -0.486960
# nSV = 216, nBSV = 0
# ..*.*
# optimization finished, #iter = 3434
# obj = -0.105950, rho = -0.416767
# nSV = 280, nBSV = 0
# ....*.*
# optimization finished, #iter = 4082
# obj = -0.181205, rho = -1.090024
# nSV = 385, nBSV = 0
# ...*..*
# optimization finished, #iter = 4649
# obj = -0.161777, rho = -0.977067
# nSV = 377, nBSV = 0
# ...*..*
# optimization finished, #iter = 3586
# obj = -0.131792, rho = -0.040023
# nSV = 383, nBSV = 0
# Total nSV = 1228
# [CV] END .................................................... total time=   4.0s
# [LibSVM]......*...*
# optimization finished, #iter = 9790
# obj = -0.441164, rho = 0.483532
# nSV = 473, nBSV = 0
# .*
# optimization finished, #iter = 1596
# obj = -0.041683, rho = -0.480266
# nSV = 204, nBSV = 0
# ..*.*
# optimization finished, #iter = 3556
# obj = -0.100662, rho = -0.467903
# nSV = 272, nBSV = 0
# ...*.*
# optimization finished, #iter = 3482
# obj = -0.142299, rho = -1.006780
# nSV = 363, nBSV = 0
# ....*.*
# optimization finished, #iter = 4793
# obj = -0.152566, rho = -0.940422
# nSV = 362, nBSV = 0
# ...*..*
# optimization finished, #iter = 3486
# obj = -0.139945, rho = -0.202758
# nSV = 372, nBSV = 0
# Total nSV = 1204
# [CV] END .................................................... total time=   3.8s
# [LibSVM]......*...*
# optimization finished, #iter = 9103
# obj = -0.432433, rho = 0.362818
# nSV = 476, nBSV = 0
# .*.*
# optimization finished, #iter = 2035
# obj = -0.048973, rho = -0.452772
# nSV = 223, nBSV = 0
# ..*.*
# optimization finished, #iter = 3896
# obj = -0.107496, rho = -0.411725
# nSV = 282, nBSV = 0
# ....*.*
# optimization finished, #iter = 4252
# obj = -0.162164, rho = -1.087219
# nSV = 393, nBSV = 0
# ....*..*
# optimization finished, #iter = 4996
# obj = -0.168470, rho = -1.022769
# nSV = 381, nBSV = 0
# ...*..*
# optimization finished, #iter = 3559
# obj = -0.120439, rho = -0.226264
# nSV = 386, nBSV = 0
# Total nSV = 1211
# [CV] END .................................................... total time=   3.9s
# Training duration for PCA=2500, C=10, kernel=linear, gamma=scale: 11.687827348709106 seconds
# Using existing PCA model for 2500 components
# [LibSVM]......*...*
# optimization finished, #iter = 9026
# obj = -0.504399, rho = 0.542130
# nSV = 478, nBSV = 0
# .*
# optimization finished, #iter = 1861
# obj = -0.045256, rho = -0.486960
# nSV = 216, nBSV = 0
# ..*.*
# optimization finished, #iter = 3434
# obj = -0.105950, rho = -0.416767
# nSV = 280, nBSV = 0
# ....*.*
# optimization finished, #iter = 4082
# obj = -0.181205, rho = -1.090024
# nSV = 385, nBSV = 0
# ...*..*
# optimization finished, #iter = 4649
# obj = -0.161777, rho = -0.977067
# nSV = 377, nBSV = 0
# ...*..*
# optimization finished, #iter = 3586
# obj = -0.131792, rho = -0.040023
# nSV = 383, nBSV = 0
# Total nSV = 1228
# [CV] END .................................................... total time=   3.9s
# [LibSVM]......*...*
# optimization finished, #iter = 9790
# obj = -0.441164, rho = 0.483532
# nSV = 473, nBSV = 0
# .*
# optimization finished, #iter = 1596
# obj = -0.041683, rho = -0.480266
# nSV = 204, nBSV = 0
# ..*.*
# optimization finished, #iter = 3556
# obj = -0.100662, rho = -0.467903
# nSV = 272, nBSV = 0
# ...*.*
# optimization finished, #iter = 3482
# obj = -0.142299, rho = -1.006780
# nSV = 363, nBSV = 0
# ....*.*
# optimization finished, #iter = 4793
# obj = -0.152566, rho = -0.940422
# nSV = 362, nBSV = 0
# ...*..*
# optimization finished, #iter = 3486
# obj = -0.139945, rho = -0.202758
# nSV = 372, nBSV = 0
# Total nSV = 1204
# [CV] END .................................................... total time=   3.6s
# [LibSVM]......*...*
# optimization finished, #iter = 9103
# obj = -0.432433, rho = 0.362818
# nSV = 476, nBSV = 0
# .*.*
# optimization finished, #iter = 2035
# obj = -0.048973, rho = -0.452772
# nSV = 223, nBSV = 0
# ..*.*
# optimization finished, #iter = 3896
# obj = -0.107496, rho = -0.411725
# nSV = 282, nBSV = 0
# ....*.*
# optimization finished, #iter = 4252
# obj = -0.162164, rho = -1.087219
# nSV = 393, nBSV = 0
# ....*..*
# optimization finished, #iter = 4996
# obj = -0.168470, rho = -1.022769
# nSV = 381, nBSV = 0
# ...*..*
# optimization finished, #iter = 3559
# obj = -0.120439, rho = -0.226264
# nSV = 386, nBSV = 0
# Total nSV = 1211
# [CV] END .................................................... total time=   3.8s
# Training duration for PCA=2500, C=10, kernel=linear, gamma=auto: 11.408762216567993 seconds
# Using existing PCA model for 2500 components
# [LibSVM].*.*
# optimization finished, #iter = 2104
# obj = -795.543085, rho = 0.027316
# nSV = 684, nBSV = 36
# *
# optimization finished, #iter = 940
# obj = -157.748807, rho = -0.098671
# nSV = 402, nBSV = 0
# *.*
# optimization finished, #iter = 1249
# obj = -243.442477, rho = -0.070749
# nSV = 492, nBSV = 7
# .*.*
# optimization finished, #iter = 1550
# obj = -500.493827, rho = 0.126819
# nSV = 603, nBSV = 3
# .*.*
# optimization finished, #iter = 1678
# obj = -421.630114, rho = 0.219979
# nSV = 628, nBSV = 2
# .*.*
# optimization finished, #iter = 1382
# obj = -384.709388, rho = 0.135291
# nSV = 557, nBSV = 2
# Total nSV = 1483
# [CV] END .................................................... total time=   6.2s
# [LibSVM].*
# optimization finished, #iter = 1941
# obj = -775.552091, rho = 0.070991
# nSV = 666, nBSV = 35
# *
# optimization finished, #iter = 929
# obj = -150.604747, rho = 0.014314
# nSV = 389, nBSV = 0
# *.*
# optimization finished, #iter = 1182
# obj = -219.946092, rho = 0.023289
# nSV = 481, nBSV = 5
# .*
# optimization finished, #iter = 1441
# obj = -409.899451, rho = 0.335419
# nSV = 556, nBSV = 0
# .*.*
# optimization finished, #iter = 1629
# obj = -414.336140, rho = 0.315503
# nSV = 622, nBSV = 0
# .*
# optimization finished, #iter = 1333
# obj = -390.797806, rho = 0.239330
# nSV = 545, nBSV = 3
# Total nSV = 1471
# [CV] END .................................................... total time=   6.0s
# [LibSVM].*
# optimization finished, #iter = 1977
# obj = -731.861327, rho = 0.035487
# nSV = 668, nBSV = 30
# *
# optimization finished, #iter = 946
# obj = -152.724085, rho = -0.104108
# nSV = 405, nBSV = 0
# *.*
# optimization finished, #iter = 1266
# obj = -228.706988, rho = -0.144284
# nSV = 496, nBSV = 6
# .*.*
# optimization finished, #iter = 1564
# obj = -451.956088, rho = 0.206086
# nSV = 587, nBSV = 3
# .*.*
# optimization finished, #iter = 1734
# obj = -433.232273, rho = 0.362165
# nSV = 616, nBSV = 1
# .*.*
# optimization finished, #iter = 1419
# obj = -367.183564, rho = 0.268473
# nSV = 564, nBSV = 1
# Total nSV = 1486
# [CV] END .................................................... total time=   6.2s
# Training duration for PCA=2500, C=10, kernel=rbf, gamma=scale: 18.452807903289795 seconds
# Using existing PCA model for 2500 components
# [LibSVM].*
# optimization finished, #iter = 1988
# obj = -402.492162, rho = -0.048196
# nSV = 958, nBSV = 1
# *.*
# optimization finished, #iter = 1268
# obj = -165.856955, rho = -0.009066
# nSV = 696, nBSV = 0
# .*
# optimization finished, #iter = 1535
# obj = -210.455229, rho = 0.047777
# nSV = 808, nBSV = 0
# .*
# optimization finished, #iter = 1331
# obj = -290.126669, rho = 0.097131
# nSV = 686, nBSV = 0
# .*
# optimization finished, #iter = 1455
# obj = -285.139692, rho = 0.160274
# nSV = 763, nBSV = 0
# .*
# optimization finished, #iter = 1188
# obj = -261.481096, rho = 0.087025
# nSV = 634, nBSV = 0
# Total nSV = 1675
# [CV] END .................................................... total time=   7.9s
# [LibSVM].*
# optimization finished, #iter = 1919
# obj = -385.981467, rho = -0.049252
# nSV = 935, nBSV = 1
# *.*
# optimization finished, #iter = 1236
# obj = -162.553311, rho = 0.019138
# nSV = 672, nBSV = 0
# .*
# optimization finished, #iter = 1504
# obj = -204.542698, rho = 0.089174
# nSV = 790, nBSV = 0
# .*
# optimization finished, #iter = 1269
# obj = -253.633551, rho = 0.162101
# nSV = 667, nBSV = 0
# .*
# optimization finished, #iter = 1495
# obj = -281.522824, rho = 0.240098
# nSV = 762, nBSV = 0
# .*
# optimization finished, #iter = 1199
# obj = -259.972327, rho = 0.107393
# nSV = 642, nBSV = 0
# Total nSV = 1654
# [CV] END .................................................... total time=   7.8s
# [LibSVM].*
# optimization finished, #iter = 1921
# obj = -371.764807, rho = -0.058603
# nSV = 942, nBSV = 1
# *.*
# optimization finished, #iter = 1286
# obj = -162.167723, rho = -0.001247
# nSV = 697, nBSV = 0
# .*
# optimization finished, #iter = 1579
# obj = -205.774033, rho = 0.055456
# nSV = 808, nBSV = 0
# .*
# optimization finished, #iter = 1298
# obj = -272.222442, rho = 0.112833
# nSV = 672, nBSV = 0
# .*
# optimization finished, #iter = 1541
# obj = -288.617666, rho = 0.200449
# nSV = 768, nBSV = 0
# .*
# optimization finished, #iter = 1211
# obj = -254.541317, rho = 0.105923
# nSV = 643, nBSV = 0
# Total nSV = 1667
# [CV] END .................................................... total time=   7.8s
# Training duration for PCA=2500, C=10, kernel=rbf, gamma=auto: 23.58081316947937 seconds

# %%
run_metrics = {}

for run_id in run_ids:
    client = mlflow.tracking.MlflowClient(ML_FLOW_DIRECTORY)
    run = client.get_run(run_id)
    metrics = run.data.metrics
    run_metrics[run_id] = metrics

for run_id, metrics in run_metrics.items():
    print(f"Run ID: {run_id}")
    for metric, value in metrics.items():
        print(f"\t{metric}: {value}")
# Out:
# Run ID: 72f7477f192e41d38f9e98b7f94a62b0
# 	mean_f1_weighted: 0.785832523572699
# 	mean_accuracy: 0.7871959942775394
# 	mean_recall: 0.7871959942775394
# 	mean_precision: 0.7859339856424669
# Run ID: 20236e442d0e44d8a4ff391561a2b148
# 	mean_f1_weighted: 0.785832523572699
# 	mean_accuracy: 0.7871959942775394
# 	mean_recall: 0.7871959942775394
# 	mean_precision: 0.7859339856424669
# Run ID: 66c4fe78d2494bb19cf22ac9d22dd2be
# 	mean_f1_weighted: 0.6136776175878488
# 	mean_accuracy: 0.6133762517882689
# 	mean_recall: 0.6133762517882689
# 	mean_precision: 0.6202479873572102
# Run ID: 7ff96bca30564451b44df226fa9a2171
# 	mean_f1_weighted: 0.3227990208754488
# 	mean_accuracy: 0.34442060085836906
# 	mean_recall: 0.34442060085836906
# 	mean_precision: 0.6543248698056973
# Run ID: 4b65874ea04f4d4595fe5b1142eed655
# 	mean_f1_weighted: 0.785832523572699
# 	mean_accuracy: 0.7871959942775394
# 	mean_recall: 0.7871959942775394
# 	mean_precision: 0.7859339856424669
# Run ID: f8954268417647bcbe68a502d99b71b0
# 	mean_f1_weighted: 0.785832523572699
# 	mean_accuracy: 0.7871959942775394
# 	mean_recall: 0.7871959942775394
# 	mean_precision: 0.7859339856424669
# Run ID: 294b744485f242f094db0b71662900bd
# 	mean_f1_weighted: 0.8100680511382533
# 	mean_accuracy: 0.8125894134477826
# 	mean_recall: 0.8125894134477826
# 	mean_precision: 0.8097951673248476
# Run ID: e536e78c66f343fda59f2b9336c6ddec
# 	mean_f1_weighted: 0.7760890166220871
# 	mean_accuracy: 0.7753934191702432
# 	mean_recall: 0.7753934191702432
# 	mean_precision: 0.7876867435040026
# Run ID: 193ff5771c35453ebb9ce16fdb24a7f1
# 	mean_f1_weighted: 0.785832523572699
# 	mean_accuracy: 0.7871959942775394
# 	mean_recall: 0.7871959942775394
# 	mean_precision: 0.7859339856424669
# Run ID: 589f97266b364421bb98605b8cc2d27d
# 	mean_f1_weighted: 0.785832523572699
# 	mean_accuracy: 0.7871959942775394
# 	mean_recall: 0.7871959942775394
# 	mean_precision: 0.7859339856424669
# Run ID: 03843588cc604be8bab6183d1ca396f0
# 	mean_f1_weighted: 0.8369612776549178
# 	mean_accuracy: 0.838340486409156
# 	mean_recall: 0.838340486409156
# 	mean_precision: 0.836202617046942
# Run ID: ba82a38860fe46488aa7d1a495e4fa3f
# 	mean_f1_weighted: 0.7958172700759842
# 	mean_accuracy: 0.7989985693848355
# 	mean_recall: 0.7989985693848355
# 	mean_precision: 0.8001277681809013
# Run ID: 3607d5382e794f5a830412306511d688
# 	mean_f1_weighted: 0.7970122464077015
# 	mean_accuracy: 0.7982832618025751
# 	mean_recall: 0.7982832618025751
# 	mean_precision: 0.7969781425458472
# Run ID: dbd287c9ea6b4ef59a9a475a47bce841
# 	mean_f1_weighted: 0.7970122464077015
# 	mean_accuracy: 0.7982832618025751
# 	mean_recall: 0.7982832618025751
# 	mean_precision: 0.7969781425458472
# Run ID: 3e2e9d9a530b4c379363f19c059c2b21
# 	mean_f1_weighted: 0.6140274868742179
# 	mean_accuracy: 0.6137339055793992
# 	mean_recall: 0.6137339055793992
# 	mean_precision: 0.6203766706752983
# Run ID: 852f651b21e042b287af442b375f3664
# 	mean_f1_weighted: 0.3677863936523817
# 	mean_accuracy: 0.3766094420600858
# 	mean_recall: 0.3766094420600858
# 	mean_precision: 0.5895068004679177
# Run ID: 62e7aa372f92471b8542e33b5368f75a
# 	mean_f1_weighted: 0.7970122464077015
# 	mean_accuracy: 0.7982832618025751
# 	mean_recall: 0.7982832618025751
# 	mean_precision: 0.7969781425458472
# Run ID: e521cd2816d8421a9122260eaca9e9e7
# 	mean_f1_weighted: 0.7970122464077015
# 	mean_accuracy: 0.7982832618025751
# 	mean_recall: 0.7982832618025751
# 	mean_precision: 0.7969781425458472
# Run ID: aa412dbacce540a3af72120461e3b87b
# 	mean_f1_weighted: 0.8100680511382533
# 	mean_accuracy: 0.8125894134477826
# 	mean_recall: 0.8125894134477826
# 	mean_precision: 0.8097951673248476
# Run ID: e2d5e91c52104d24af48411a86db43d1
# 	mean_f1_weighted: 0.7926926024658658
# 	mean_accuracy: 0.7932761087267526
# 	mean_recall: 0.7932761087267526
# 	mean_precision: 0.7969238745527685
# Run ID: 5a1b5a9367ed4ee4b886fac80692ea8c
# 	mean_f1_weighted: 0.7970122464077015
# 	mean_accuracy: 0.7982832618025751
# 	mean_recall: 0.7982832618025751
# 	mean_precision: 0.7969781425458472
# Run ID: 491ed73e4945406aa15e3cea4936763a
# 	mean_f1_weighted: 0.7970122464077015
# 	mean_accuracy: 0.7982832618025751
# 	mean_recall: 0.7982832618025751
# 	mean_precision: 0.7969781425458472
# Run ID: ded76353831241588f602ffeb2d15344
# 	mean_f1_weighted: 0.8376340921446065
# 	mean_accuracy: 0.8390557939914164
# 	mean_recall: 0.8390557939914164
# 	mean_precision: 0.8368662942713628
# Run ID: 3daee0a31f904186a1ba1706f9aa0548
# 	mean_f1_weighted: 0.8091274264636871
# 	mean_accuracy: 0.8118741058655221
# 	mean_recall: 0.8118741058655221
# 	mean_precision: 0.8098170612116694
# Run ID: 217be494374f4dcebaddb35809b2f6a9
# 	mean_f1_weighted: 0.8049952487599411
# 	mean_accuracy: 0.8065092989985695
# 	mean_recall: 0.8065092989985695
# 	mean_precision: 0.8051015848260729
# Run ID: 5002d926b856447d947bd490df79150d
# 	mean_f1_weighted: 0.8049952487599411
# 	mean_accuracy: 0.8065092989985695
# 	mean_recall: 0.8065092989985695
# 	mean_precision: 0.8051015848260729
# Run ID: e0e372cc8ec0485389eaff1f965cac74
# 	mean_f1_weighted: 0.6133458380095286
# 	mean_accuracy: 0.6130185979971388
# 	mean_recall: 0.6130185979971388
# 	mean_precision: 0.619591771626081
# Run ID: 3014d1e4ffef4fd9b327c0742cf44f35
# 	mean_f1_weighted: 0.41756516146757044
# 	mean_accuracy: 0.4227467811158798
# 	mean_recall: 0.4227467811158798
# 	mean_precision: 0.5714946164444324
# Run ID: 40fccf2246d34f4f86fd38a98342597e
# 	mean_f1_weighted: 0.8049952487599411
# 	mean_accuracy: 0.8065092989985695
# 	mean_recall: 0.8065092989985695
# 	mean_precision: 0.8051015848260729
# Run ID: b4eea5d3795c426db31f2028ab9a1f8e
# 	mean_f1_weighted: 0.8049952487599411
# 	mean_accuracy: 0.8065092989985695
# 	mean_recall: 0.8065092989985695
# 	mean_precision: 0.8051015848260729
# Run ID: 7577da17ce734e16a72f99878efe2540
# 	mean_f1_weighted: 0.8107774320868485
# 	mean_accuracy: 0.8133047210300429
# 	mean_recall: 0.8133047210300429
# 	mean_precision: 0.8104893664493921
# Run ID: 445eebdb61e24db89dbcfec843e810b8
# 	mean_f1_weighted: 0.8052822919209118
# 	mean_accuracy: 0.8068669527896996
# 	mean_recall: 0.8068669527896996
# 	mean_precision: 0.8061010998147252
# Run ID: 98f692a334f44dc48b0fb41f1d84e2c6
# 	mean_f1_weighted: 0.8049952487599411
# 	mean_accuracy: 0.8065092989985695
# 	mean_recall: 0.8065092989985695
# 	mean_precision: 0.8051015848260729
# Run ID: 0306ceb9b08b486e9beeb2d42a37b302
# 	mean_f1_weighted: 0.8049952487599411
# 	mean_accuracy: 0.8065092989985695
# 	mean_recall: 0.8065092989985695
# 	mean_precision: 0.8051015848260729
# Run ID: 689f277e799841fa94f6b05a08c14cf8
# 	mean_f1_weighted: 0.8375532254258272
# 	mean_accuracy: 0.8390557939914164
# 	mean_recall: 0.8390557939914164
# 	mean_precision: 0.8367832923504993
# Run ID: 49309fd963f5487bbdf3549cd1bee9ce
# 	mean_f1_weighted: 0.821464787826179
# 	mean_accuracy: 0.8236766809728184
# 	mean_recall: 0.8236766809728184
# 	mean_precision: 0.8211336748243094

# %%
best_run_id = max(run_metrics, key=lambda x: run_metrics[x]["mean_f1_weighted"])
best_params = client.get_run(best_run_id).data.params
best_run_metrics = run_metrics[best_run_id]

print(f"\nBest Run ID: {best_run_id}")
print("Best Parameters:")
for key, value in best_params.items():
    print(f"\t{key}: {value}")

print("\nBest Run Metrics:")
for metric, value in best_run_metrics.items():
    print(f"\t{metric}: {value}")
# Out:
# Best Run ID: ded76353831241588f602ffeb2d15344
# Best Parameters:
# 	gamma: scale
# 	pca_components: 2025
# 	C: 10
# 	kernel: rbf
#
# Best Run Metrics:
# 	mean_f1_weighted: 0.8376340921446065
# 	mean_accuracy: 0.8390557939914164
# 	mean_recall: 0.8390557939914164
# 	mean_precision: 0.8368662942713628
