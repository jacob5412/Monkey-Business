# %% [markdown]
# # SVM: Version 1
#
# Checking to see what the baseline metric for the SVM is.

# %%
import os
import cv2
import glob
import time
import mlflow
import shutil
import itertools

import numpy as np
import pandas as pd

from PIL import Image
from sklearn import svm
from sklearn.model_selection import cross_validate, StratifiedKFold
from sklearn.metrics import (
    make_scorer,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
)

# %%
TRAIN_DIR = "../data/train"
CLASS_FOLDERS = ["Class A", "Class B", "Class C", "Class D"]
ML_FLOW_DIRECTORY = "SVM_Logs"

# %%
mlflow.set_tracking_uri(ML_FLOW_DIRECTORY)
mlflow.set_experiment("SVM_V1")
# Out:
# <Experiment: artifact_location='/Users/jacob/Code/Monkey-Business/SVM/SVM_V1_Logs/331033974301432080', creation_time=1701907697832, experiment_id='331033974301432080', last_update_time=1701907697832, lifecycle_stage='active', name='SVM_V1', tags={}>

# %%
C_values = [0.1, 1, 10]
kernel_types = ['linear', 'rbf']
gamma_values = ['scale', 'auto']

# %%
hyperparameter_combinations = list(
    itertools.product(C_values, kernel_types, gamma_values)
)
print(f"Total number of hyperparameter combinations: {len(hyperparameter_combinations)}")
# Out:
# Total number of hyperparameter combinations: 12

# %%
def train_with_params(C, kernel, gamma, train_images, train_labels):
    with mlflow.start_run() as run:
        start_time = time.time()

        # Initialize SVM model
        svm_model = svm.SVC(
            C=C, kernel=kernel, gamma=gamma, class_weight="balanced", verbose=True
        )

        # Perform cross-validation
        skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
        scoring = {
            "f1_weighted": make_scorer(f1_score, average="weighted"),
            "accuracy": "accuracy",
            "precision": make_scorer(precision_score, average="weighted"),
            "recall": make_scorer(recall_score, average="weighted"),
        }
        cv_results = cross_validate(
            svm_model, train_images, train_labels, cv=skf, scoring=scoring, verbose=2
        )

        # Log hyperparameters and metrics
        mlflow.log_params({"C": C, "kernel": kernel, "gamma": gamma})
        mlflow.log_metrics(
            {
                "mean_f1_weighted": cv_results["test_f1_weighted"].mean(),
                "mean_accuracy": cv_results["test_accuracy"].mean(),
                "mean_precision": cv_results["test_precision"].mean(),
                "mean_recall": cv_results["test_recall"].mean(),
            }
        )
        end_time = time.time()
        duration = end_time - start_time
        param_details = f"C={C}, kernel={kernel}, gamma={gamma}"
        duration_details = f"Training duration for {param_details}: {duration} seconds"
        print(duration_details)
        run_id = run.info.run_id
        return run_id

# %%
def load_images_from_folder(folder):
    images = []
    labels = []
    for class_folder in CLASS_FOLDERS:
        start_time = time.time()
        class_path = os.path.join(folder, class_folder)
        image_files = glob.glob(os.path.join(class_path, "*.png"))
        for img_file in image_files:
            processed_image = cv2.imread(img_file)
            flattened_image = processed_image.flatten()
            images.append(flattened_image)
            labels.append(class_folder)
        end_time = time.time()
        duration = end_time - start_time
        print(f"Processing {class_folder} took {duration} seconds")
    return np.array(images), np.array(labels)

# %%
train_images, train_labels = load_images_from_folder(TRAIN_DIR)
# Out:
# Processing Class A took 1.707284927368164 seconds
# Processing Class B took 0.9642601013183594 seconds
# Processing Class C took 0.681333065032959 seconds
# Processing Class D took 0.7671737670898438 seconds

# %%
print(
    f"Shape of train_images: {train_images.shape}, Shape of train_labels: {train_labels.shape}"
)
# Out:
# Shape of train_images: (2796, 150528), Shape of train_labels: (2796,)

# %%
run_ids = []

for params in hyperparameter_combinations:
    C, kernel, gamma = params
    run_id = train_with_params(C, kernel, gamma, train_images, train_labels)
    run_ids.append(run_id)
# Out:
# [LibSVM].....*...*
# optimization finished, #iter = 8063
# obj = -0.431008, rho = -1.120097
# nSV = 526, nBSV = 0
# .*
# optimization finished, #iter = 1708
# obj = -0.044959, rho = -1.695860
# nSV = 219, nBSV = 0
# ..*.*
# optimization finished, #iter = 3496
# obj = -0.101756, rho = -0.157115
# nSV = 292, nBSV = 0
# ...*..*
# optimization finished, #iter = 4196
# obj = -0.178770, rho = -1.377789
# nSV = 390, nBSV = 0
# ...*..*
# optimization finished, #iter = 4624
# obj = -0.152781, rho = 0.765236
# nSV = 389, nBSV = 0
# ...*..*
# optimization finished, #iter = 3634
# obj = -0.129693, rho = 2.038100
# nSV = 391, nBSV = 0
# Total nSV = 1260
# [CV] END .................................................... total time= 4.1min
# [LibSVM].......*..*
# optimization finished, #iter = 9477
# obj = -0.391359, rho = -0.979554
# nSV = 506, nBSV = 0
# .*
# optimization finished, #iter = 1673
# obj = -0.041186, rho = -2.073674
# nSV = 207, nBSV = 0
# ..*.*
# optimization finished, #iter = 3482
# obj = -0.095444, rho = -0.104243
# nSV = 290, nBSV = 0
# ...*.*
# optimization finished, #iter = 3411
# obj = -0.140217, rho = -1.783220
# nSV = 372, nBSV = 0
# ....*.*
# optimization finished, #iter = 4588
# obj = -0.145581, rho = 0.437842
# nSV = 374, nBSV = 0
# ...*..*
# optimization finished, #iter = 3449
# obj = -0.136631, rho = 2.104737
# nSV = 371, nBSV = 0
# Total nSV = 1235
# [CV] END .................................................... total time= 4.1min
# [LibSVM]......*..*
# optimization finished, #iter = 8462
# obj = -0.384634, rho = -0.949881
# nSV = 518, nBSV = 0
# .*.*
# optimization finished, #iter = 2000
# obj = -0.048624, rho = -1.691965
# nSV = 226, nBSV = 0
# ..*.*
# optimization finished, #iter = 3752
# obj = -0.103052, rho = -0.019900
# nSV = 294, nBSV = 0
# ...*..*
# optimization finished, #iter = 4169
# obj = -0.159822, rho = -1.487529
# nSV = 397, nBSV = 0
# ...*..*
# optimization finished, #iter = 4650
# obj = -0.163055, rho = 0.819320
# nSV = 393, nBSV = 0
# ...*..*
# optimization finished, #iter = 3513
# obj = -0.119808, rho = 2.046780
# nSV = 389, nBSV = 0
# Total nSV = 1243
# [CV] END .................................................... total time= 4.2min
# Training duration for C=0.1, kernel=linear, gamma=scale: 745.5028939247131 seconds
# [LibSVM].....*...*
# optimization finished, #iter = 8063
# obj = -0.431008, rho = -1.120097
# nSV = 526, nBSV = 0
# .*
# optimization finished, #iter = 1708
# obj = -0.044959, rho = -1.695860
# nSV = 219, nBSV = 0
# ..*.*
# optimization finished, #iter = 3496
# obj = -0.101756, rho = -0.157115
# nSV = 292, nBSV = 0
# ...*..*
# optimization finished, #iter = 4196
# obj = -0.178770, rho = -1.377789
# nSV = 390, nBSV = 0
# ...*..*
# optimization finished, #iter = 4624
# obj = -0.152781, rho = 0.765236
# nSV = 389, nBSV = 0
# ...*..*
# optimization finished, #iter = 3634
# obj = -0.129693, rho = 2.038100
# nSV = 391, nBSV = 0
# Total nSV = 1260
# [CV] END .................................................... total time= 4.2min
# [LibSVM].......*..*
# optimization finished, #iter = 9477
# obj = -0.391359, rho = -0.979554
# nSV = 506, nBSV = 0
# .*
# optimization finished, #iter = 1673
# obj = -0.041186, rho = -2.073674
# nSV = 207, nBSV = 0
# ..*.*
# optimization finished, #iter = 3482
# obj = -0.095444, rho = -0.104243
# nSV = 290, nBSV = 0
# ...*.*
# optimization finished, #iter = 3411
# obj = -0.140217, rho = -1.783220
# nSV = 372, nBSV = 0
# ....*.*
# optimization finished, #iter = 4588
# obj = -0.145581, rho = 0.437842
# nSV = 374, nBSV = 0
# ...*..*
# optimization finished, #iter = 3449
# obj = -0.136631, rho = 2.104737
# nSV = 371, nBSV = 0
# Total nSV = 1235
# [CV] END .................................................... total time= 5.1min
# [LibSVM]......*..*
# optimization finished, #iter = 8462
# obj = -0.384634, rho = -0.949881
# nSV = 518, nBSV = 0
# .*.*
# optimization finished, #iter = 2000
# obj = -0.048624, rho = -1.691965
# nSV = 226, nBSV = 0
# ..*.*
# optimization finished, #iter = 3752
# obj = -0.103052, rho = -0.019900
# nSV = 294, nBSV = 0
# ...*..*
# optimization finished, #iter = 4169
# obj = -0.159822, rho = -1.487529
# nSV = 397, nBSV = 0
# ...*..*
# optimization finished, #iter = 4650
# obj = -0.163055, rho = 0.819320
# nSV = 393, nBSV = 0
# ...*..*
# optimization finished, #iter = 3513
# obj = -0.119808, rho = 2.046780
# nSV = 389, nBSV = 0
# Total nSV = 1243
# [CV] END .................................................... total time= 6.0min
# Training duration for C=0.1, kernel=linear, gamma=auto: 915.9669373035431 seconds
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1057
# obj = -65.015329, rho = 0.209904
# nSV = 1029, nBSV = 942
# *
# optimization finished, #iter = 703
# obj = -40.600900, rho = 0.330098
# nSV = 669, nBSV = 602
# *
# optimization finished, #iter = 935
# obj = -51.957099, rho = 0.551003
# nSV = 886, nBSV = 805
# *
# optimization finished, #iter = 658
# obj = -66.869423, rho = 0.588274
# nSV = 626, nBSV = 587
# *
# optimization finished, #iter = 797
# obj = -71.812803, rho = 0.721908
# nSV = 751, nBSV = 700
# *
# optimization finished, #iter = 651
# obj = -70.238629, rho = 0.237927
# nSV = 618, nBSV = 590
# Total nSV = 1759
# [CV] END .................................................... total time= 8.5min
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1074
# obj = -65.656933, rho = 0.240798
# nSV = 1039, nBSV = 933
# *
# optimization finished, #iter = 672
# obj = -38.785374, rho = 0.362485
# nSV = 644, nBSV = 580
# *
# optimization finished, #iter = 932
# obj = -49.964943, rho = 0.654764
# nSV = 865, nBSV = 765
# *
# optimization finished, #iter = 636
# obj = -62.649161, rho = 0.603907
# nSV = 603, nBSV = 555
# *
# optimization finished, #iter = 784
# obj = -66.637530, rho = 0.781858
# nSV = 713, nBSV = 655
# *
# optimization finished, #iter = 640
# obj = -68.085685, rho = 0.274894
# nSV = 609, nBSV = 576
# Total nSV = 1767
# [CV] END .................................................... total time= 8.2min
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1080
# obj = -66.536929, rho = 0.166654
# nSV = 1054, nBSV = 940
# *
# optimization finished, #iter = 699
# obj = -41.413191, rho = 0.378459
# nSV = 678, nBSV = 623
# *
# optimization finished, #iter = 929
# obj = -52.163103, rho = 0.593279
# nSV = 886, nBSV = 815
# *
# optimization finished, #iter = 647
# obj = -64.326181, rho = 0.539562
# nSV = 612, nBSV = 565
# *
# optimization finished, #iter = 783
# obj = -69.943663, rho = 0.754677
# nSV = 734, nBSV = 677
# *
# optimization finished, #iter = 637
# obj = -70.337148, rho = 0.302678
# nSV = 619, nBSV = 593
# Total nSV = 1774
# [CV] END .................................................... total time= 7.8min
# Training duration for C=0.1, kernel=rbf, gamma=scale: 1471.312782049179 seconds
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1195
# obj = -86.777648, rho = -0.401035
# nSV = 1196, nBSV = 942
# *
# optimization finished, #iter = 982
# obj = -70.029998, rho = -0.037212
# nSV = 978, nBSV = 974
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1118
# obj = -79.617829, rho = 0.087176
# nSV = 1099, nBSV = 1014
# *
# optimization finished, #iter = 731
# obj = -84.680638, rho = 0.198035
# nSV = 728, nBSV = 726
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 807
# obj = -87.507546, rho = 0.240580
# nSV = 804, nBSV = 801
# *.*
# optimization finished, #iter = 668
# obj = -88.257691, rho = 0.763231
# nSV = 668, nBSV = 667
# Total nSV = 1864
# [CV] END .................................................... total time= 8.8min
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1196
# obj = -87.222872, rho = 0.196434
# nSV = 1197, nBSV = 919
# *
# optimization finished, #iter = 959
# obj = -67.851509, rho = -0.022538
# nSV = 953, nBSV = 948
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1118
# obj = -78.550247, rho = 0.164530
# nSV = 1078, nBSV = 982
# *
# optimization finished, #iter = 711
# obj = -80.935927, rho = 0.211186
# nSV = 707, nBSV = 704
# *
# optimization finished, #iter = 802
# obj = -84.654914, rho = 0.299289
# nSV = 785, nBSV = 783
# *
# optimization finished, #iter = 666
# obj = -87.056192, rho = -0.192626
# nSV = 667, nBSV = 666
# Total nSV = 1864
# [CV] END .................................................... total time= 8.7min
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1196
# obj = -87.731436, rho = 0.329943
# nSV = 1197, nBSV = 878
# *
# optimization finished, #iter = 983
# obj = -70.324203, rho = -0.069324
# nSV = 979, nBSV = 973
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1119
# obj = -81.054508, rho = 0.098611
# nSV = 1110, nBSV = 1005
# *
# optimization finished, #iter = 720
# obj = -82.526111, rho = 0.136465
# nSV = 717, nBSV = 715
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 806
# obj = -87.139503, rho = 0.249973
# nSV = 804, nBSV = 798
# *
# optimization finished, #iter = 666
# obj = -87.770022, rho = -0.249904
# nSV = 667, nBSV = 666
# Total nSV = 1864
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time= 8.8min
# Training duration for C=0.1, kernel=rbf, gamma=auto: 1577.7833938598633 seconds
# [LibSVM].....*...*
# optimization finished, #iter = 8063
# obj = -0.431008, rho = -1.120097
# nSV = 526, nBSV = 0
# .*
# optimization finished, #iter = 1708
# obj = -0.044959, rho = -1.695860
# nSV = 219, nBSV = 0
# ..*.*
# optimization finished, #iter = 3496
# obj = -0.101756, rho = -0.157115
# nSV = 292, nBSV = 0
# ...*..*
# optimization finished, #iter = 4196
# obj = -0.178770, rho = -1.377789
# nSV = 390, nBSV = 0
# ...*..*
# optimization finished, #iter = 4624
# obj = -0.152781, rho = 0.765236
# nSV = 389, nBSV = 0
# ...*..*
# optimization finished, #iter = 3634
# obj = -0.129693, rho = 2.038100
# nSV = 391, nBSV = 0
# Total nSV = 1260
# [CV] END .................................................... total time= 4.0min
# [LibSVM].......*..*
# optimization finished, #iter = 9477
# obj = -0.391359, rho = -0.979554
# nSV = 506, nBSV = 0
# .*
# optimization finished, #iter = 1673
# obj = -0.041186, rho = -2.073674
# nSV = 207, nBSV = 0
# ..*.*
# optimization finished, #iter = 3482
# obj = -0.095444, rho = -0.104243
# nSV = 290, nBSV = 0
# ...*.*
# optimization finished, #iter = 3411
# obj = -0.140217, rho = -1.783220
# nSV = 372, nBSV = 0
# ....*.*
# optimization finished, #iter = 4588
# obj = -0.145581, rho = 0.437842
# nSV = 374, nBSV = 0
# ...*..*
# optimization finished, #iter = 3449
# obj = -0.136631, rho = 2.104737
# nSV = 371, nBSV = 0
# Total nSV = 1235
# [CV] END .................................................... total time= 3.9min
# [LibSVM]......*..*
# optimization finished, #iter = 8462
# obj = -0.384634, rho = -0.949881
# nSV = 518, nBSV = 0
# .*.*
# optimization finished, #iter = 2000
# obj = -0.048624, rho = -1.691965
# nSV = 226, nBSV = 0
# ..*.*
# optimization finished, #iter = 3752
# obj = -0.103052, rho = -0.019900
# nSV = 294, nBSV = 0
# ...*..*
# optimization finished, #iter = 4169
# obj = -0.159822, rho = -1.487529
# nSV = 397, nBSV = 0
# ...*..*
# optimization finished, #iter = 4650
# obj = -0.163055, rho = 0.819320
# nSV = 393, nBSV = 0
# ...*..*
# optimization finished, #iter = 3513
# obj = -0.119808, rho = 2.046780
# nSV = 389, nBSV = 0
# Total nSV = 1243
# [CV] END .................................................... total time= 4.0min
# Training duration for C=1, kernel=linear, gamma=scale: 718.822991847992 seconds
# [LibSVM].....*...*
# optimization finished, #iter = 8063
# obj = -0.431008, rho = -1.120097
# nSV = 526, nBSV = 0
# .*
# optimization finished, #iter = 1708
# obj = -0.044959, rho = -1.695860
# nSV = 219, nBSV = 0
# ..*.*
# optimization finished, #iter = 3496
# obj = -0.101756, rho = -0.157115
# nSV = 292, nBSV = 0
# ...*..*
# optimization finished, #iter = 4196
# obj = -0.178770, rho = -1.377789
# nSV = 390, nBSV = 0
# ...*..*
# optimization finished, #iter = 4624
# obj = -0.152781, rho = 0.765236
# nSV = 389, nBSV = 0
# ...*..*
# optimization finished, #iter = 3634
# obj = -0.129693, rho = 2.038100
# nSV = 391, nBSV = 0
# Total nSV = 1260
# [CV] END .................................................... total time= 4.0min
# [LibSVM].......*..*
# optimization finished, #iter = 9477
# obj = -0.391359, rho = -0.979554
# nSV = 506, nBSV = 0
# .*
# optimization finished, #iter = 1673
# obj = -0.041186, rho = -2.073674
# nSV = 207, nBSV = 0
# ..*.*
# optimization finished, #iter = 3482
# obj = -0.095444, rho = -0.104243
# nSV = 290, nBSV = 0
# ...*.*
# optimization finished, #iter = 3411
# obj = -0.140217, rho = -1.783220
# nSV = 372, nBSV = 0
# ....*.*
# optimization finished, #iter = 4588
# obj = -0.145581, rho = 0.437842
# nSV = 374, nBSV = 0
# ...*..*
# optimization finished, #iter = 3449
# obj = -0.136631, rho = 2.104737
# nSV = 371, nBSV = 0
# Total nSV = 1235
# [CV] END .................................................... total time= 3.9min
# [LibSVM]......*..*
# optimization finished, #iter = 8462
# obj = -0.384634, rho = -0.949881
# nSV = 518, nBSV = 0
# .*.*
# optimization finished, #iter = 2000
# obj = -0.048624, rho = -1.691965
# nSV = 226, nBSV = 0
# ..*.*
# optimization finished, #iter = 3752
# obj = -0.103052, rho = -0.019900
# nSV = 294, nBSV = 0
# ...*..*
# optimization finished, #iter = 4169
# obj = -0.159822, rho = -1.487529
# nSV = 397, nBSV = 0
# ...*..*
# optimization finished, #iter = 4650
# obj = -0.163055, rho = 0.819320
# nSV = 393, nBSV = 0
# ...*..*
# optimization finished, #iter = 3513
# obj = -0.119808, rho = 2.046780
# nSV = 389, nBSV = 0
# Total nSV = 1243
# [CV] END .................................................... total time= 4.0min
# Training duration for C=1, kernel=linear, gamma=auto: 714.1788079738617 seconds
# [LibSVM]*.*
# optimization finished, #iter = 1040
# obj = -337.238968, rho = -0.086346
# nSV = 740, nBSV = 472
# *
# optimization finished, #iter = 664
# obj = -123.459001, rho = -0.138693
# nSV = 394, nBSV = 129
# *
# optimization finished, #iter = 907
# obj = -169.197428, rho = -0.185723
# nSV = 533, nBSV = 203
# .*
# optimization finished, #iter = 974
# obj = -325.227936, rho = 0.236850
# nSV = 576, nBSV = 172
# .*
# optimization finished, #iter = 1095
# obj = -314.202139, rho = 0.292464
# nSV = 629, nBSV = 162
# .*
# optimization finished, #iter = 940
# obj = -311.341653, rho = 0.141017
# nSV = 539, nBSV = 200
# Total nSV = 1533
# [CV] END .................................................... total time= 6.0min
# [LibSVM]*.*
# optimization finished, #iter = 1082
# obj = -340.807458, rho = 0.209138
# nSV = 754, nBSV = 471
# *
# optimization finished, #iter = 687
# obj = -113.867632, rho = 0.056432
# nSV = 378, nBSV = 112
# *
# optimization finished, #iter = 904
# obj = -165.435128, rho = -0.028823
# nSV = 530, nBSV = 198
# *.*
# optimization finished, #iter = 919
# obj = -293.244198, rho = 0.310808
# nSV = 541, nBSV = 167
# *.*
# optimization finished, #iter = 1075
# obj = -302.848133, rho = 0.340455
# nSV = 626, nBSV = 158
# .*
# optimization finished, #iter = 965
# obj = -297.700553, rho = 0.174237
# nSV = 527, nBSV = 178
# Total nSV = 1535
# [CV] END .................................................... total time= 6.0min
# [LibSVM]*.*
# optimization finished, #iter = 1105
# obj = -340.373195, rho = -0.029915
# nSV = 764, nBSV = 455
# *
# optimization finished, #iter = 675
# obj = -125.004083, rho = -0.066166
# nSV = 402, nBSV = 136
# *
# optimization finished, #iter = 905
# obj = -167.149224, rho = -0.147471
# nSV = 537, nBSV = 206
# *.*
# optimization finished, #iter = 947
# obj = -323.253762, rho = 0.380585
# nSV = 560, nBSV = 195
# .*
# optimization finished, #iter = 1092
# obj = -319.092657, rho = 0.408798
# nSV = 631, nBSV = 168
# .*
# optimization finished, #iter = 968
# obj = -309.076317, rho = 0.174014
# nSV = 553, nBSV = 203
# Total nSV = 1550
# [CV] END .................................................... total time= 6.1min
# Training duration for C=1, kernel=rbf, gamma=scale: 1090.7822997570038 seconds
# [LibSVM]*
# optimization finished, #iter = 978
# obj = -623.949474, rho = -1.018171
# nSV = 940, nBSV = 921
# *
# optimization finished, #iter = 607
# obj = -367.050416, rho = -1.114470
# nSV = 566, nBSV = 534
# *
# optimization finished, #iter = 883
# obj = -491.418815, rho = -0.514330
# nSV = 786, nBSV = 744
# *
# optimization finished, #iter = 642
# obj = -646.657087, rho = -0.249598
# nSV = 603, nBSV = 580
# *
# optimization finished, #iter = 770
# obj = -691.515319, rho = 0.789535
# nSV = 706, nBSV = 684
# *
# optimization finished, #iter = 619
# obj = -637.669277, rho = 0.809877
# nSV = 561, nBSV = 534
# Total nSV = 1689
# [CV] END .................................................... total time= 7.2min
# [LibSVM]*.*
# optimization finished, #iter = 1007
# obj = -636.942265, rho = -0.629348
# nSV = 954, nBSV = 936
# *
# optimization finished, #iter = 574
# obj = -352.321742, rho = -0.844207
# nSV = 542, nBSV = 516
# *
# optimization finished, #iter = 893
# obj = -483.813992, rho = 0.203829
# nSV = 784, nBSV = 738
# *
# optimization finished, #iter = 604
# obj = -611.710346, rho = -0.136434
# nSV = 570, nBSV = 549
# *
# optimization finished, #iter = 750
# obj = -656.721156, rho = 1.114116
# nSV = 677, nBSV = 649
# *
# optimization finished, #iter = 595
# obj = -608.528042, rho = 0.919324
# nSV = 533, nBSV = 507
# Total nSV = 1687
# [CV] END .................................................... total time= 7.1min
# [LibSVM].*
# optimization finished, #iter = 1019
# obj = -645.397143, rho = -0.917396
# nSV = 977, nBSV = 957
# *
# optimization finished, #iter = 627
# obj = -383.706374, rho = -1.015212
# nSV = 582, nBSV = 552
# *
# optimization finished, #iter = 881
# obj = -505.729050, rho = -0.180602
# nSV = 795, nBSV = 767
# *
# optimization finished, #iter = 618
# obj = -623.917451, rho = -0.371295
# nSV = 574, nBSV = 552
# *
# optimization finished, #iter = 771
# obj = -686.270233, rho = 0.733353
# nSV = 697, nBSV = 675
# *
# optimization finished, #iter = 632
# obj = -636.837565, rho = 0.879092
# nSV = 554, nBSV = 520
# Total nSV = 1699
# [CV] END .................................................... total time= 7.3min
# Training duration for C=1, kernel=rbf, gamma=auto: 1296.235414981842 seconds
# [LibSVM].....*...*
# optimization finished, #iter = 8063
# obj = -0.431008, rho = -1.120097
# nSV = 526, nBSV = 0
# .*
# optimization finished, #iter = 1708
# obj = -0.044959, rho = -1.695860
# nSV = 219, nBSV = 0
# ..*.*
# optimization finished, #iter = 3496
# obj = -0.101756, rho = -0.157115
# nSV = 292, nBSV = 0
# ...*..*
# optimization finished, #iter = 4196
# obj = -0.178770, rho = -1.377789
# nSV = 390, nBSV = 0
# ...*..*
# optimization finished, #iter = 4624
# obj = -0.152781, rho = 0.765236
# nSV = 389, nBSV = 0
# ...*..*
# optimization finished, #iter = 3634
# obj = -0.129693, rho = 2.038100
# nSV = 391, nBSV = 0
# Total nSV = 1260
# [CV] END .................................................... total time= 4.0min
# [LibSVM].......*..*
# optimization finished, #iter = 9477
# obj = -0.391359, rho = -0.979554
# nSV = 506, nBSV = 0
# .*
# optimization finished, #iter = 1673
# obj = -0.041186, rho = -2.073674
# nSV = 207, nBSV = 0
# ..*.*
# optimization finished, #iter = 3482
# obj = -0.095444, rho = -0.104243
# nSV = 290, nBSV = 0
# ...*.*
# optimization finished, #iter = 3411
# obj = -0.140217, rho = -1.783220
# nSV = 372, nBSV = 0
# ....*.*
# optimization finished, #iter = 4588
# obj = -0.145581, rho = 0.437842
# nSV = 374, nBSV = 0
# ...*..*
# optimization finished, #iter = 3449
# obj = -0.136631, rho = 2.104737
# nSV = 371, nBSV = 0
# Total nSV = 1235
# [CV] END .................................................... total time= 4.0min
# [LibSVM]......*..*
# optimization finished, #iter = 8462
# obj = -0.384634, rho = -0.949881
# nSV = 518, nBSV = 0
# .*.*
# optimization finished, #iter = 2000
# obj = -0.048624, rho = -1.691965
# nSV = 226, nBSV = 0
# ..*.*
# optimization finished, #iter = 3752
# obj = -0.103052, rho = -0.019900
# nSV = 294, nBSV = 0
# ...*..*
# optimization finished, #iter = 4169
# obj = -0.159822, rho = -1.487529
# nSV = 397, nBSV = 0
# ...*..*
# optimization finished, #iter = 4650
# obj = -0.163055, rho = 0.819320
# nSV = 393, nBSV = 0
# ...*..*
# optimization finished, #iter = 3513
# obj = -0.119808, rho = 2.046780
# nSV = 389, nBSV = 0
# Total nSV = 1243
# [CV] END .................................................... total time= 4.1min
# Training duration for C=10, kernel=linear, gamma=scale: 724.9985768795013 seconds
# [LibSVM].....*...*
# optimization finished, #iter = 8063
# obj = -0.431008, rho = -1.120097
# nSV = 526, nBSV = 0
# .*
# optimization finished, #iter = 1708
# obj = -0.044959, rho = -1.695860
# nSV = 219, nBSV = 0
# ..*.*
# optimization finished, #iter = 3496
# obj = -0.101756, rho = -0.157115
# nSV = 292, nBSV = 0
# ...*..*
# optimization finished, #iter = 4196
# obj = -0.178770, rho = -1.377789
# nSV = 390, nBSV = 0
# ...*..*
# optimization finished, #iter = 4624
# obj = -0.152781, rho = 0.765236
# nSV = 389, nBSV = 0
# ...*..*
# optimization finished, #iter = 3634
# obj = -0.129693, rho = 2.038100
# nSV = 391, nBSV = 0
# Total nSV = 1260
# [CV] END .................................................... total time= 4.0min
# [LibSVM].......*..*
# optimization finished, #iter = 9477
# obj = -0.391359, rho = -0.979554
# nSV = 506, nBSV = 0
# .*
# optimization finished, #iter = 1673
# obj = -0.041186, rho = -2.073674
# nSV = 207, nBSV = 0
# ..*.*
# optimization finished, #iter = 3482
# obj = -0.095444, rho = -0.104243
# nSV = 290, nBSV = 0
# ...*.*
# optimization finished, #iter = 3411
# obj = -0.140217, rho = -1.783220
# nSV = 372, nBSV = 0
# ....*.*
# optimization finished, #iter = 4588
# obj = -0.145581, rho = 0.437842
# nSV = 374, nBSV = 0
# ...*..*
# optimization finished, #iter = 3449
# obj = -0.136631, rho = 2.104737
# nSV = 371, nBSV = 0
# Total nSV = 1235
# [CV] END .................................................... total time= 3.9min
# [LibSVM]......*..*
# optimization finished, #iter = 8462
# obj = -0.384634, rho = -0.949881
# nSV = 518, nBSV = 0
# .*.*
# optimization finished, #iter = 2000
# obj = -0.048624, rho = -1.691965
# nSV = 226, nBSV = 0
# ..*.*
# optimization finished, #iter = 3752
# obj = -0.103052, rho = -0.019900
# nSV = 294, nBSV = 0
# ...*..*
# optimization finished, #iter = 4169
# obj = -0.159822, rho = -1.487529
# nSV = 397, nBSV = 0
# ...*..*
# optimization finished, #iter = 4650
# obj = -0.163055, rho = 0.819320
# nSV = 393, nBSV = 0
# ...*..*
# optimization finished, #iter = 3513
# obj = -0.119808, rho = 2.046780
# nSV = 389, nBSV = 0
# Total nSV = 1243
# [CV] END .................................................... total time= 4.1min
# Training duration for C=10, kernel=linear, gamma=auto: 718.332937002182 seconds
# [LibSVM].*.*
# optimization finished, #iter = 2046
# obj = -858.224206, rho = 0.028998
# nSV = 673, nBSV = 42
# *
# optimization finished, #iter = 930
# obj = -168.549769, rho = -0.107214
# nSV = 384, nBSV = 1
# *.*
# optimization finished, #iter = 1267
# obj = -261.545839, rho = -0.089361
# nSV = 471, nBSV = 9
# .*.*
# optimization finished, #iter = 1616
# obj = -545.911904, rho = 0.127902
# nSV = 597, nBSV = 3
# .*.*
# optimization finished, #iter = 1707
# obj = -453.744630, rho = 0.218286
# nSV = 615, nBSV = 2
# .*.*
# optimization finished, #iter = 1401
# obj = -416.122158, rho = 0.118627
# nSV = 543, nBSV = 2
# Total nSV = 1479
# [CV] END .................................................... total time= 6.5min
# [LibSVM].*
# optimization finished, #iter = 1995
# obj = -839.716296, rho = 0.078419
# nSV = 661, nBSV = 47
# *
# optimization finished, #iter = 908
# obj = -160.886389, rho = 0.017412
# nSV = 370, nBSV = 0
# *.*
# optimization finished, #iter = 1241
# obj = -236.118620, rho = 0.009556
# nSV = 464, nBSV = 6
# .*
# optimization finished, #iter = 1433
# obj = -447.046672, rho = 0.367963
# nSV = 546, nBSV = 0
# .*.*
# optimization finished, #iter = 1635
# obj = -446.325325, rho = 0.309212
# nSV = 603, nBSV = 0
# .*.*
# optimization finished, #iter = 1381
# obj = -422.683920, rho = 0.238753
# nSV = 535, nBSV = 3
# Total nSV = 1466
# [CV] END .................................................... total time= 6.3min
# [LibSVM].*
# optimization finished, #iter = 1992
# obj = -793.472187, rho = 0.054500
# nSV = 667, nBSV = 44
# *
# optimization finished, #iter = 944
# obj = -163.165674, rho = -0.108950
# nSV = 385, nBSV = 0
# *.*
# optimization finished, #iter = 1259
# obj = -245.595250, rho = -0.180989
# nSV = 474, nBSV = 8
# .*.*
# optimization finished, #iter = 1589
# obj = -491.975765, rho = 0.227248
# nSV = 578, nBSV = 2
# .*.*
# optimization finished, #iter = 1711
# obj = -468.095966, rho = 0.379187
# nSV = 605, nBSV = 1
# .*.*
# optimization finished, #iter = 1428
# obj = -398.015250, rho = 0.278862
# nSV = 559, nBSV = 1
# Total nSV = 1478
# [CV] END .................................................... total time= 6.6min
# Training duration for C=10, kernel=rbf, gamma=scale: 1161.9648101329803 seconds
# [LibSVM]*.*
# optimization finished, #iter = 1100
# obj = -3951.641099, rho = -1.585663
# nSV = 693, nBSV = 570
# *
# optimization finished, #iter = 561
# obj = -1440.897588, rho = -1.619201
# nSV = 306, nBSV = 198
# *
# optimization finished, #iter = 893
# obj = -2072.837072, rho = -3.330606
# nSV = 448, nBSV = 307
# *.*
# optimization finished, #iter = 871
# obj = -3802.717784, rho = 0.273876
# nSV = 468, nBSV = 322
# .*
# optimization finished, #iter = 1055
# obj = -3639.003381, rho = -0.310864
# nSV = 535, nBSV = 329
# .*
# optimization finished, #iter = 869
# obj = -3702.119435, rho = -1.816408
# nSV = 424, nBSV = 278
# Total nSV = 1437
# [CV] END .................................................... total time= 5.6min
# [LibSVM]*.*
# optimization finished, #iter = 1088
# obj = -4035.393925, rho = -0.072167
# nSV = 716, nBSV = 583
# *
# optimization finished, #iter = 569
# obj = -1364.870482, rho = -0.450876
# nSV = 296, nBSV = 191
# *
# optimization finished, #iter = 849
# obj = -2040.743000, rho = -1.329011
# nSV = 438, nBSV = 305
# *.*
# optimization finished, #iter = 822
# obj = -3458.517034, rho = 1.262583
# nSV = 439, nBSV = 293
# .*
# optimization finished, #iter = 1057
# obj = -3412.831147, rho = 1.056383
# nSV = 513, nBSV = 305
# *.*
# optimization finished, #iter = 834
# obj = -3519.800841, rho = -1.371390
# nSV = 410, nBSV = 270
# Total nSV = 1427
# [CV] END .................................................... total time= 5.6min
# [LibSVM]*.*
# optimization finished, #iter = 1073
# obj = -4030.606369, rho = -0.704865
# nSV = 723, nBSV = 595
# *
# optimization finished, #iter = 591
# obj = -1531.291042, rho = -0.697917
# nSV = 320, nBSV = 213
# *
# optimization finished, #iter = 785
# obj = -2124.633780, rho = -2.225724
# nSV = 437, nBSV = 324
# *.*
# optimization finished, #iter = 820
# obj = -3816.297795, rho = 1.367152
# nSV = 462, nBSV = 334
# .*
# optimization finished, #iter = 1015
# obj = -3724.158268, rho = 0.676151
# nSV = 532, nBSV = 327
# .*
# optimization finished, #iter = 988
# obj = -3704.394569, rho = -0.563276
# nSV = 436, nBSV = 274
# Total nSV = 1437
# [CV] END .................................................... total time= 5.7min
# Training duration for C=10, kernel=rbf, gamma=auto: 1018.8664572238922 seconds

# %%
run_metrics = {}

for run_id in run_ids:
    client = mlflow.tracking.MlflowClient(ML_FLOW_DIRECTORY)
    run = client.get_run(run_id)
    metrics = run.data.metrics
    run_metrics[run_id] = metrics

for run_id, metrics in run_metrics.items():
    print(f"Run ID: {run_id}")
    for metric, value in metrics.items():
        print(f"\t{metric}: {value}")
# Out:
# Run ID: bcf3d811341a4a01a4c79a5cc36dadf4
# 	mean_f1_weighted: 0.8047625046491292
# 	mean_accuracy: 0.8065092989985695
# 	mean_recall: 0.8065092989985695
# 	mean_precision: 0.8045501982916231
# Run ID: f2048ec06f324fb4938416124f694c43
# 	mean_f1_weighted: 0.31760977436605303
# 	mean_accuracy: 0.3758941344778255
# 	mean_recall: 0.3758941344778255
# 	mean_precision: 0.46745896353895006
# Run ID: 137e9db0e44241cea2ff791ee35388b8
# 	mean_f1_weighted: 0.8047625046491292
# 	mean_accuracy: 0.8065092989985695
# 	mean_recall: 0.8065092989985695
# 	mean_precision: 0.8045501982916231
# Run ID: 6783e97d3bad4ddfb1b6d703ea8bb29c
# 	mean_f1_weighted: 0.8364481220648057
# 	mean_accuracy: 0.8376251788268956
# 	mean_recall: 0.8376251788268956
# 	mean_precision: 0.8358215197593659
# Run ID: b25e739433be4709895e7545e01bb8e6
# 	mean_f1_weighted: 0.8078734926798968
# 	mean_accuracy: 0.8104434907010014
# 	mean_recall: 0.8104434907010014
# 	mean_precision: 0.8077360245207114
# Run ID: 5602976e36c04bc6b7095f1dafc2a37d
# 	mean_f1_weighted: 0.7673151517777246
# 	mean_accuracy: 0.7682403433476396
# 	mean_recall: 0.7682403433476396
# 	mean_precision: 0.7684960116440774
# Run ID: e8875c4783db4a8eadc96088a76902d6
# 	mean_f1_weighted: 0.8047625046491292
# 	mean_accuracy: 0.8065092989985695
# 	mean_recall: 0.8065092989985695
# 	mean_precision: 0.8045501982916231
# Run ID: 642379948ee94ef1b67093ad3d59e696
# 	mean_f1_weighted: 0.8047625046491292
# 	mean_accuracy: 0.8065092989985695
# 	mean_recall: 0.8065092989985695
# 	mean_precision: 0.8045501982916231
# Run ID: 8be2f6d1f6284051a2e096121faca36f
# 	mean_f1_weighted: 0.6156079509997001
# 	mean_accuracy: 0.6155221745350501
# 	mean_recall: 0.6155221745350501
# 	mean_precision: 0.6207340946793816
# Run ID: 64162369829b4ec98698e8ea67b14da2
# 	mean_f1_weighted: 0.8047625046491292
# 	mean_accuracy: 0.8065092989985695
# 	mean_recall: 0.8065092989985695
# 	mean_precision: 0.8045501982916231
# Run ID: 33a9996462974f8db4c13fe38e174e02
# 	mean_f1_weighted: 0.8047625046491292
# 	mean_accuracy: 0.8065092989985695
# 	mean_recall: 0.8065092989985695
# 	mean_precision: 0.8045501982916231
# Run ID: ef8fd4f933854ce9b69d1769d4a6ab7c
# 	mean_f1_weighted: 0.6497533666821181
# 	mean_accuracy: 0.6512875536480687
# 	mean_recall: 0.6512875536480687
# 	mean_precision: 0.652959410059842

# %%
best_run_id = max(run_metrics, key=lambda x: run_metrics[x]["mean_f1_weighted"])
best_params = client.get_run(best_run_id).data.params

print(f"\nBest Run ID: {best_run_id}")
print("Best Parameters:")
for key, value in best_params.items():
    print(f"\t{key}: {value}")
# Out:
# Best Run ID: 6783e97d3bad4ddfb1b6d703ea8bb29c
# Best Parameters:
# 	gamma: scale
# 	C: 10
# 	kernel: rbf
