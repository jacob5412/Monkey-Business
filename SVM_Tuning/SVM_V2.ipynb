# %% [markdown]
# # SVM: Version 2
#
# ## SVM with PCA (BGR)

# %%
import cv2
import os
import glob
import time
import mlflow
import random
import shutil
import itertools

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from PIL import Image
from sklearn.decomposition import PCA
from sklearn import svm
from sklearn.model_selection import cross_validate, StratifiedKFold
from sklearn.metrics import (
    make_scorer,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
)

# %%
TRAIN_DIR = "../data/train"
CLASS_FOLDERS = ["Class A", "Class B", "Class C", "Class D"]
ML_FLOW_DIRECTORY = "SVM_Logs"

# %%
mlflow.set_tracking_uri(ML_FLOW_DIRECTORY)
mlflow.set_experiment("SVM_PCA")
# Out:
# <Experiment: artifact_location='/Users/jacob/Code/Monkey-Business/SVM/SVM_Logs/216794599421195463', creation_time=1701926432685, experiment_id='216794599421195463', last_update_time=1701926432685, lifecycle_stage='active', name='SVM_PCA', tags={}>

# %%
pca_components = [40 * 40, 45 * 45, 50 * 50]
C_values = [0.1, 1, 10]
kernel_types = ["linear", "rbf"]
gamma_values = ["scale", "auto"]

# %%
hyperparameter_combinations = list(
    itertools.product(pca_components, C_values, kernel_types, gamma_values)
)
print(
    f"Total number of hyperparameter combinations: {len(hyperparameter_combinations)}"
)
# Out:
# Total number of hyperparameter combinations: 36

# %%
pca_models_dict = {}

# %%
def train_with_params(pca_components, C, kernel, gamma, train_images, train_labels):
    # Check if PCA model for pca_components already exists
    if pca_components in pca_models_dict:
        pca = pca_models_dict[pca_components]
        print(f"Using existing PCA model for {pca_components} components")
    else:
        # Apply PCA
        pca = PCA(n_components=pca_components)
        pca.fit(train_images)
        pca_models_dict[pca_components] = pca

    # Transform images with PCA
    train_images_pca = pca.transform(train_images)

    with mlflow.start_run() as run:
        start_time = time.time()

        # Initialize SVM model
        svm_model = svm.SVC(
            C=C, kernel=kernel, gamma=gamma, class_weight="balanced", verbose=True
        )

        # Perform cross-validation
        skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
        scoring = {
            "f1_weighted": make_scorer(f1_score, average="weighted"),
            "accuracy": "accuracy",
            "precision": make_scorer(precision_score, average="weighted"),
            "recall": make_scorer(recall_score, average="weighted"),
        }
        cv_results = cross_validate(
            svm_model,
            train_images_pca,
            train_labels,
            cv=skf,
            scoring=scoring,
            verbose=2,
        )

        # Log hyperparameters and metrics
        mlflow.log_params(
            {"pca_components": pca_components, "C": C, "kernel": kernel, "gamma": gamma}
        )
        mlflow.log_metrics(
            {
                "mean_f1_weighted": cv_results["test_f1_weighted"].mean(),
                "mean_accuracy": cv_results["test_accuracy"].mean(),
                "mean_precision": cv_results["test_precision"].mean(),
                "mean_recall": cv_results["test_recall"].mean(),
            }
        )
        end_time = time.time()
        duration = end_time - start_time
        param_details = f"PCA={pca_components}, C={C}, kernel={kernel}, gamma={gamma}"
        duration_details = f"Training duration for {param_details}: {duration} seconds"
        print(duration_details)
        run_id = run.info.run_id
        return run_id

# %%
def load_images_from_folder(folder):
    images = []
    labels = []
    for class_folder in CLASS_FOLDERS:
        start_time = time.time()
        class_path = os.path.join(folder, class_folder)
        image_files = glob.glob(os.path.join(class_path, "*.png"))
        for img_file in image_files:
            processed_image = cv2.imread(img_file)
            flattened_image = processed_image.flatten()
            images.append(flattened_image)
            labels.append(class_folder)
        end_time = time.time()
        duration = end_time - start_time
        print(f"Processing {class_folder} took {duration} seconds")
    return np.array(images), np.array(labels)

# %%
train_images, train_labels = load_images_from_folder(TRAIN_DIR)
# Out:
# Processing Class A took 1.5078959465026855 seconds
# Processing Class B took 0.8401908874511719 seconds
# Processing Class C took 0.5691571235656738 seconds
# Processing Class D took 0.6987409591674805 seconds

# %%
print(
    f"Shape of train_images: {train_images.shape}, Shape of train_labels: {train_labels.shape}"
)
# Out:
# Shape of train_images: (2796, 150528), Shape of train_labels: (2796,)

# %%
random_indices = random.sample(range(len(train_images)), 3)
fig, axs = plt.subplots(1, 3, figsize=(12, 4))
for i, idx in enumerate(random_indices):
    image = train_images[idx].reshape(
        224, 224, 3
    )
    label = train_labels[idx]

    axs[i].imshow(image)
    axs[i].set_title(f"Label: {label}")
    axs[i].axis("off")

plt.tight_layout()
plt.show()

# %%
run_ids = []

for params in hyperparameter_combinations:
    pca_components, C, kernel, gamma = params
    run_id = train_with_params(pca_components, C, kernel, gamma, train_images, train_labels)
    run_ids.append(run_id)
# Out:
# [LibSVM]........*....*
# optimization finished, #iter = 12701
# obj = -0.000012, rho = 0.708561
# nSV = 416, nBSV = 0
# .*.*
# optimization finished, #iter = 2031
# obj = -0.000001, rho = -0.509828
# nSV = 198, nBSV = 0
# ..*.*
# optimization finished, #iter = 3777
# obj = -0.000002, rho = -0.437183
# nSV = 248, nBSV = 0
# ....*..*
# optimization finished, #iter = 4609
# obj = -0.000005, rho = -1.388771
# nSV = 321, nBSV = 0
# ....*..*
# optimization finished, #iter = 5362
# obj = -0.000003, rho = -1.096337
# nSV = 331, nBSV = 0
# ....*..*
# optimization finished, #iter = 4048
# obj = -0.000003, rho = -0.112510
# nSV = 339, nBSV = 0
# Total nSV = 1135
# [CV] END .................................................... total time=   2.4s
# [LibSVM]...........*...*
# optimization finished, #iter = 14645
# obj = -0.000010, rho = 0.612378
# nSV = 405, nBSV = 0
# .*
# optimization finished, #iter = 1573
# obj = -0.000001, rho = -0.495450
# nSV = 186, nBSV = 0
# ...*.*
# optimization finished, #iter = 4460
# obj = -0.000002, rho = -0.529545
# nSV = 251, nBSV = 0
# ...*..*
# optimization finished, #iter = 4090
# obj = -0.000003, rho = -1.104964
# nSV = 324, nBSV = 0
# ....*...*
# optimization finished, #iter = 5640
# obj = -0.000003, rho = -1.047384
# nSV = 329, nBSV = 0
# ....*.*
# optimization finished, #iter = 3963
# obj = -0.000003, rho = -0.412658
# nSV = 337, nBSV = 0
# Total nSV = 1121
# [CV] END .................................................... total time=   2.3s
# [LibSVM]........*....*
# optimization finished, #iter = 12439
# obj = -0.000010, rho = 0.461674
# nSV = 412, nBSV = 0
# .*.*
# optimization finished, #iter = 2268
# obj = -0.000001, rho = -0.476972
# nSV = 217, nBSV = 0
# ...*.*
# optimization finished, #iter = 4593
# obj = -0.000002, rho = -0.454652
# nSV = 264, nBSV = 0
# ....*..*
# optimization finished, #iter = 4710
# obj = -0.000003, rho = -1.267984
# nSV = 346, nBSV = 0
# ....*...*
# optimization finished, #iter = 5806
# obj = -0.000003, rho = -1.147302
# nSV = 331, nBSV = 0
# ....*..*
# optimization finished, #iter = 4268
# obj = -0.000002, rho = -0.323149
# nSV = 361, nBSV = 0
# Total nSV = 1140
# [CV] END .................................................... total time=   2.3s
# Training duration for PCA=1600, C=0.1, kernel=linear, gamma=scale: 7.068368196487427 seconds
# Using existing PCA model for 1600 components
# [LibSVM]........*....*
# optimization finished, #iter = 12701
# obj = -0.000012, rho = 0.708561
# nSV = 416, nBSV = 0
# .*.*
# optimization finished, #iter = 2031
# obj = -0.000001, rho = -0.509828
# nSV = 198, nBSV = 0
# ..*.*
# optimization finished, #iter = 3777
# obj = -0.000002, rho = -0.437183
# nSV = 248, nBSV = 0
# ....*..*
# optimization finished, #iter = 4609
# obj = -0.000005, rho = -1.388771
# nSV = 321, nBSV = 0
# ....*..*
# optimization finished, #iter = 5362
# obj = -0.000003, rho = -1.096337
# nSV = 331, nBSV = 0
# ....*..*
# optimization finished, #iter = 4048
# obj = -0.000003, rho = -0.112510
# nSV = 339, nBSV = 0
# Total nSV = 1135
# [CV] END .................................................... total time=   2.3s
# [LibSVM]...........*...*
# optimization finished, #iter = 14645
# obj = -0.000010, rho = 0.612378
# nSV = 405, nBSV = 0
# .*
# optimization finished, #iter = 1573
# obj = -0.000001, rho = -0.495450
# nSV = 186, nBSV = 0
# ...*.*
# optimization finished, #iter = 4460
# obj = -0.000002, rho = -0.529545
# nSV = 251, nBSV = 0
# ...*..*
# optimization finished, #iter = 4090
# obj = -0.000003, rho = -1.104964
# nSV = 324, nBSV = 0
# ....*...*
# optimization finished, #iter = 5640
# obj = -0.000003, rho = -1.047384
# nSV = 329, nBSV = 0
# ....*.*
# optimization finished, #iter = 3963
# obj = -0.000003, rho = -0.412658
# nSV = 337, nBSV = 0
# Total nSV = 1121
# [CV] END .................................................... total time=   2.2s
# [LibSVM]........*....*
# optimization finished, #iter = 12439
# obj = -0.000010, rho = 0.461674
# nSV = 412, nBSV = 0
# .*.*
# optimization finished, #iter = 2268
# obj = -0.000001, rho = -0.476972
# nSV = 217, nBSV = 0
# ...*.*
# optimization finished, #iter = 4593
# obj = -0.000002, rho = -0.454652
# nSV = 264, nBSV = 0
# ....*..*
# optimization finished, #iter = 4710
# obj = -0.000003, rho = -1.267984
# nSV = 346, nBSV = 0
# ....*...*
# optimization finished, #iter = 5806
# obj = -0.000003, rho = -1.147302
# nSV = 331, nBSV = 0
# ....*..*
# optimization finished, #iter = 4268
# obj = -0.000002, rho = -0.323149
# nSV = 361, nBSV = 0
# Total nSV = 1140
# [CV] END .................................................... total time=   2.3s
# Training duration for PCA=1600, C=0.1, kernel=linear, gamma=auto: 6.8166069984436035 seconds
# Using existing PCA model for 1600 components
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1059
# obj = -64.691996, rho = 0.263053
# nSV = 1031, nBSV = 935
# *
# optimization finished, #iter = 702
# obj = -40.641787, rho = 0.380666
# nSV = 669, nBSV = 608
# *
# optimization finished, #iter = 945
# obj = -51.686126, rho = 0.574649
# nSV = 887, nBSV = 803
# *
# optimization finished, #iter = 665
# obj = -66.667129, rho = 0.618480
# nSV = 636, nBSV = 587
# *
# optimization finished, #iter = 797
# obj = -71.645579, rho = 0.728711
# nSV = 755, nBSV = 702
# *
# optimization finished, #iter = 645
# obj = -70.320430, rho = 0.186104
# nSV = 620, nBSV = 593
# Total nSV = 1763
# [CV] END .................................................... total time=   5.0s
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1065
# obj = -65.248731, rho = 0.289358
# nSV = 1034, nBSV = 936
# *
# optimization finished, #iter = 668
# obj = -38.789489, rho = 0.415498
# nSV = 645, nBSV = 585
# *
# optimization finished, #iter = 930
# obj = -49.629176, rho = 0.673116
# nSV = 866, nBSV = 759
# *
# optimization finished, #iter = 640
# obj = -62.370960, rho = 0.644542
# nSV = 608, nBSV = 553
# *
# optimization finished, #iter = 779
# obj = -66.384654, rho = 0.787709
# nSV = 714, nBSV = 650
# *
# optimization finished, #iter = 639
# obj = -68.257600, rho = 0.234352
# nSV = 612, nBSV = 579
# Total nSV = 1765
# [CV] END .................................................... total time=   4.8s
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1074
# obj = -66.167569, rho = 0.197321
# nSV = 1057, nBSV = 943
# *
# optimization finished, #iter = 710
# obj = -41.353043, rho = 0.414362
# nSV = 683, nBSV = 626
# *
# optimization finished, #iter = 936
# obj = -51.761260, rho = 0.616675
# nSV = 889, nBSV = 812
# *
# optimization finished, #iter = 655
# obj = -64.098272, rho = 0.580985
# nSV = 615, nBSV = 564
# *
# optimization finished, #iter = 793
# obj = -69.677555, rho = 0.762408
# nSV = 737, nBSV = 681
# *
# optimization finished, #iter = 644
# obj = -70.440753, rho = 0.266646
# nSV = 618, nBSV = 591
# Total nSV = 1778
# [CV] END .................................................... total time=   4.9s
# Training duration for PCA=1600, C=0.1, kernel=rbf, gamma=scale: 14.695831060409546 seconds
# Using existing PCA model for 1600 components
# [LibSVM].*
# optimization finished, #iter = 1195
# obj = -89.262075, rho = -0.877690
# nSV = 1196, nBSV = 1195
# .*
# optimization finished, #iter = 1059
# obj = -88.095862, rho = 0.687248
# nSV = 1060, nBSV = 1059
# .*
# optimization finished, #iter = 1130
# obj = -88.829332, rho = 0.874054
# nSV = 1132, nBSV = 1130
# *
# optimization finished, #iter = 731
# obj = -87.030192, rho = 0.687248
# nSV = 732, nBSV = 731
# *
# optimization finished, #iter = 802
# obj = -87.763662, rho = 0.874054
# nSV = 804, nBSV = 802
# *
# optimization finished, #iter = 667
# obj = -86.597449, rho = 0.874054
# nSV = 668, nBSV = 667
# Total nSV = 1864
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   5.7s
# [LibSVM].*
# optimization finished, #iter = 1194
# obj = -89.260346, rho = 0.892874
# nSV = 1197, nBSV = 1194
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1058
# obj = -88.112835, rho = 0.843624
# nSV = 1060, nBSV = 762
# .*
# optimization finished, #iter = 1130
# obj = -88.797951, rho = 0.747425
# nSV = 1131, nBSV = 1130
# *
# optimization finished, #iter = 732
# obj = -87.060397, rho = -0.892874
# nSV = 733, nBSV = 732
# *
# optimization finished, #iter = 803
# obj = -87.745512, rho = -0.892874
# nSV = 804, nBSV = 803
# *
# optimization finished, #iter = 666
# obj = -86.598001, rho = -0.843624
# nSV = 667, nBSV = 666
# Total nSV = 1864
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   5.5s
# [LibSVM].*
# optimization finished, #iter = 1196
# obj = -89.275306, rho = 0.892874
# nSV = 1197, nBSV = 1196
# .*
# optimization finished, #iter = 1059
# obj = -88.103341, rho = 0.687248
# nSV = 1060, nBSV = 1059
# .*
# optimization finished, #iter = 1130
# obj = -88.812910, rho = 0.747425
# nSV = 1131, nBSV = 1130
# *
# optimization finished, #iter = 732
# obj = -87.035944, rho = -0.892874
# nSV = 733, nBSV = 732
# *
# optimization finished, #iter = 803
# obj = -87.745512, rho = -0.892874
# nSV = 804, nBSV = 803
# *
# optimization finished, #iter = 666
# obj = -86.573548, rho = -0.687248
# nSV = 667, nBSV = 666
# Total nSV = 1864
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   5.5s
# Training duration for PCA=1600, C=0.1, kernel=rbf, gamma=auto: 16.75189471244812 seconds
# Using existing PCA model for 1600 components
# [LibSVM]........*....*
# optimization finished, #iter = 12701
# obj = -0.000012, rho = 0.708561
# nSV = 416, nBSV = 0
# .*.*
# optimization finished, #iter = 2031
# obj = -0.000001, rho = -0.509828
# nSV = 198, nBSV = 0
# ..*.*
# optimization finished, #iter = 3777
# obj = -0.000002, rho = -0.437183
# nSV = 248, nBSV = 0
# ....*..*
# optimization finished, #iter = 4609
# obj = -0.000005, rho = -1.388771
# nSV = 321, nBSV = 0
# ....*..*
# optimization finished, #iter = 5362
# obj = -0.000003, rho = -1.096337
# nSV = 331, nBSV = 0
# ....*..*
# optimization finished, #iter = 4048
# obj = -0.000003, rho = -0.112510
# nSV = 339, nBSV = 0
# Total nSV = 1135
# [CV] END .................................................... total time=   2.3s
# [LibSVM]...........*...*
# optimization finished, #iter = 14645
# obj = -0.000010, rho = 0.612378
# nSV = 405, nBSV = 0
# .*
# optimization finished, #iter = 1573
# obj = -0.000001, rho = -0.495450
# nSV = 186, nBSV = 0
# ...*.*
# optimization finished, #iter = 4460
# obj = -0.000002, rho = -0.529545
# nSV = 251, nBSV = 0
# ...*..*
# optimization finished, #iter = 4090
# obj = -0.000003, rho = -1.104964
# nSV = 324, nBSV = 0
# ....*...*
# optimization finished, #iter = 5640
# obj = -0.000003, rho = -1.047384
# nSV = 329, nBSV = 0
# ....*.*
# optimization finished, #iter = 3963
# obj = -0.000003, rho = -0.412658
# nSV = 337, nBSV = 0
# Total nSV = 1121
# [CV] END .................................................... total time=   2.2s
# [LibSVM]........*....*
# optimization finished, #iter = 12439
# obj = -0.000010, rho = 0.461674
# nSV = 412, nBSV = 0
# .*.*
# optimization finished, #iter = 2268
# obj = -0.000001, rho = -0.476972
# nSV = 217, nBSV = 0
# ...*.*
# optimization finished, #iter = 4593
# obj = -0.000002, rho = -0.454652
# nSV = 264, nBSV = 0
# ....*..*
# optimization finished, #iter = 4710
# obj = -0.000003, rho = -1.267984
# nSV = 346, nBSV = 0
# ....*...*
# optimization finished, #iter = 5806
# obj = -0.000003, rho = -1.147302
# nSV = 331, nBSV = 0
# ....*..*
# optimization finished, #iter = 4268
# obj = -0.000002, rho = -0.323149
# nSV = 361, nBSV = 0
# Total nSV = 1140
# [CV] END .................................................... total time=   2.2s
# Training duration for PCA=1600, C=1, kernel=linear, gamma=scale: 6.696165084838867 seconds
# Using existing PCA model for 1600 components
# [LibSVM]........*....*
# optimization finished, #iter = 12701
# obj = -0.000012, rho = 0.708561
# nSV = 416, nBSV = 0
# .*.*
# optimization finished, #iter = 2031
# obj = -0.000001, rho = -0.509828
# nSV = 198, nBSV = 0
# ..*.*
# optimization finished, #iter = 3777
# obj = -0.000002, rho = -0.437183
# nSV = 248, nBSV = 0
# ....*..*
# optimization finished, #iter = 4609
# obj = -0.000005, rho = -1.388771
# nSV = 321, nBSV = 0
# ....*..*
# optimization finished, #iter = 5362
# obj = -0.000003, rho = -1.096337
# nSV = 331, nBSV = 0
# ....*..*
# optimization finished, #iter = 4048
# obj = -0.000003, rho = -0.112510
# nSV = 339, nBSV = 0
# Total nSV = 1135
# [CV] END .................................................... total time=   2.3s
# [LibSVM]...........*...*
# optimization finished, #iter = 14645
# obj = -0.000010, rho = 0.612378
# nSV = 405, nBSV = 0
# .*
# optimization finished, #iter = 1573
# obj = -0.000001, rho = -0.495450
# nSV = 186, nBSV = 0
# ...*.*
# optimization finished, #iter = 4460
# obj = -0.000002, rho = -0.529545
# nSV = 251, nBSV = 0
# ...*..*
# optimization finished, #iter = 4090
# obj = -0.000003, rho = -1.104964
# nSV = 324, nBSV = 0
# ....*...*
# optimization finished, #iter = 5640
# obj = -0.000003, rho = -1.047384
# nSV = 329, nBSV = 0
# ....*.*
# optimization finished, #iter = 3963
# obj = -0.000003, rho = -0.412658
# nSV = 337, nBSV = 0
# Total nSV = 1121
# [CV] END .................................................... total time=   2.2s
# [LibSVM]........*....*
# optimization finished, #iter = 12439
# obj = -0.000010, rho = 0.461674
# nSV = 412, nBSV = 0
# .*.*
# optimization finished, #iter = 2268
# obj = -0.000001, rho = -0.476972
# nSV = 217, nBSV = 0
# ...*.*
# optimization finished, #iter = 4593
# obj = -0.000002, rho = -0.454652
# nSV = 264, nBSV = 0
# ....*..*
# optimization finished, #iter = 4710
# obj = -0.000003, rho = -1.267984
# nSV = 346, nBSV = 0
# ....*...*
# optimization finished, #iter = 5806
# obj = -0.000003, rho = -1.147302
# nSV = 331, nBSV = 0
# ....*..*
# optimization finished, #iter = 4268
# obj = -0.000002, rho = -0.323149
# nSV = 361, nBSV = 0
# Total nSV = 1140
# [CV] END .................................................... total time=   2.3s
# Training duration for PCA=1600, C=1, kernel=linear, gamma=auto: 6.764859199523926 seconds
# Using existing PCA model for 1600 components
# [LibSVM]*.*
# optimization finished, #iter = 1064
# obj = -327.918467, rho = -0.056489
# nSV = 737, nBSV = 450
# *
# optimization finished, #iter = 709
# obj = -120.287300, rho = -0.118403
# nSV = 402, nBSV = 122
# *
# optimization finished, #iter = 893
# obj = -164.545310, rho = -0.133025
# nSV = 533, nBSV = 193
# .*
# optimization finished, #iter = 999
# obj = -314.320809, rho = 0.230239
# nSV = 579, nBSV = 158
# .*
# optimization finished, #iter = 1120
# obj = -303.347328, rho = 0.294457
# nSV = 629, nBSV = 149
# .*
# optimization finished, #iter = 967
# obj = -299.340893, rho = 0.142821
# nSV = 543, nBSV = 182
# Total nSV = 1527
# [CV] END .................................................... total time=   3.8s
# [LibSVM]*.*
# optimization finished, #iter = 1077
# obj = -330.819454, rho = 0.189124
# nSV = 748, nBSV = 448
# *
# optimization finished, #iter = 703
# obj = -110.692452, rho = 0.053620
# nSV = 383, nBSV = 105
# *
# optimization finished, #iter = 929
# obj = -160.442988, rho = 0.009770
# nSV = 533, nBSV = 191
# *.*
# optimization finished, #iter = 938
# obj = -282.533641, rho = 0.307624
# nSV = 541, nBSV = 152
# .*
# optimization finished, #iter = 1141
# obj = -293.462925, rho = 0.365538
# nSV = 631, nBSV = 141
# .*
# optimization finished, #iter = 971
# obj = -286.224033, rho = 0.199207
# nSV = 528, nBSV = 167
# Total nSV = 1529
# [CV] END .................................................... total time=   3.7s
# [LibSVM]*.*
# optimization finished, #iter = 1129
# obj = -330.929716, rho = -0.014213
# nSV = 763, nBSV = 436
# *
# optimization finished, #iter = 713
# obj = -121.325265, rho = -0.057622
# nSV = 409, nBSV = 122
# *
# optimization finished, #iter = 920
# obj = -162.208595, rho = -0.105859
# nSV = 532, nBSV = 194
# *.*
# optimization finished, #iter = 952
# obj = -312.254124, rho = 0.370832
# nSV = 568, nBSV = 184
# .*
# optimization finished, #iter = 1090
# obj = -308.661363, rho = 0.413356
# nSV = 633, nBSV = 154
# .*
# optimization finished, #iter = 979
# obj = -296.628137, rho = 0.179747
# nSV = 557, nBSV = 185
# Total nSV = 1541
# [CV] END .................................................... total time=   3.7s
# Training duration for PCA=1600, C=1, kernel=rbf, gamma=scale: 11.252304077148438 seconds
# Using existing PCA model for 1600 components
# [LibSVM].*
# optimization finished, #iter = 1567
# obj = -538.338707, rho = -0.071694
# nSV = 1196, nBSV = 758
# .*.*
# optimization finished, #iter = 2673
# obj = -426.937500, rho = -0.437500
# nSV = 1056, nBSV = 0
# .*
# optimization finished, #iter = 1625
# obj = -495.279631, rho = -0.255576
# nSV = 1132, nBSV = 756
# .*
# optimization finished, #iter = 1319
# obj = -352.662079, rho = -0.187415
# nSV = 731, nBSV = 0
# ..*.*
# optimization finished, #iter = 2422
# obj = -399.452710, rho = -0.079602
# nSV = 804, nBSV = 0
# ..*
# optimization finished, #iter = 1434
# obj = -329.505226, rho = 0.109445
# nSV = 667, nBSV = 0
# Total nSV = 1863
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   5.5s
# [LibSVM].*
# optimization finished, #iter = 1666
# obj = -538.248782, rho = -0.067917
# nSV = 1197, nBSV = 752
# .*.*
# optimization finished, #iter = 2733
# obj = -427.651130, rho = -0.435071
# nSV = 1055, nBSV = 0
# .*
# optimization finished, #iter = 1543
# obj = -493.181068, rho = -0.259741
# nSV = 1130, nBSV = 752
# .*.*
# optimization finished, #iter = 1698
# obj = -353.697052, rho = -0.186903
# nSV = 733, nBSV = 0
# ..*.*
# optimization finished, #iter = 2674
# obj = -398.704789, rho = -0.083437
# nSV = 803, nBSV = 0
# ..*.*
# optimization finished, #iter = 2018
# obj = -329.321247, rho = 0.105105
# nSV = 666, nBSV = 0
# Total nSV = 1863
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   5.5s
# [LibSVM].*
# optimization finished, #iter = 1492
# obj = -539.573810, rho = -0.070589
# nSV = 1197, nBSV = 760
# ..*
# optimization finished, #iter = 2463
# obj = -427.253254, rho = -0.438563
# nSV = 1058, nBSV = 0
# .*
# optimization finished, #iter = 1691
# obj = -494.124509, rho = -0.389316
# nSV = 1130, nBSV = 521
# .*.*
# optimization finished, #iter = 1971
# obj = -352.991787, rho = -0.188525
# nSV = 732, nBSV = 0
# ..*.*
# optimization finished, #iter = 2674
# obj = -398.704789, rho = -0.083437
# nSV = 803, nBSV = 0
# ..*.*
# optimization finished, #iter = 2139
# obj = -328.709704, rho = 0.106767
# nSV = 665, nBSV = 0
# Total nSV = 1863
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   5.5s
# Training duration for PCA=1600, C=1, kernel=rbf, gamma=auto: 16.507373094558716 seconds
# Using existing PCA model for 1600 components
# [LibSVM]........*....*
# optimization finished, #iter = 12701
# obj = -0.000012, rho = 0.708561
# nSV = 416, nBSV = 0
# .*.*
# optimization finished, #iter = 2031
# obj = -0.000001, rho = -0.509828
# nSV = 198, nBSV = 0
# ..*.*
# optimization finished, #iter = 3777
# obj = -0.000002, rho = -0.437183
# nSV = 248, nBSV = 0
# ....*..*
# optimization finished, #iter = 4609
# obj = -0.000005, rho = -1.388771
# nSV = 321, nBSV = 0
# ....*..*
# optimization finished, #iter = 5362
# obj = -0.000003, rho = -1.096337
# nSV = 331, nBSV = 0
# ....*..*
# optimization finished, #iter = 4048
# obj = -0.000003, rho = -0.112510
# nSV = 339, nBSV = 0
# Total nSV = 1135
# [CV] END .................................................... total time=   2.3s
# [LibSVM]...........*...*
# optimization finished, #iter = 14645
# obj = -0.000010, rho = 0.612378
# nSV = 405, nBSV = 0
# .*
# optimization finished, #iter = 1573
# obj = -0.000001, rho = -0.495450
# nSV = 186, nBSV = 0
# ...*.*
# optimization finished, #iter = 4460
# obj = -0.000002, rho = -0.529545
# nSV = 251, nBSV = 0
# ...*..*
# optimization finished, #iter = 4090
# obj = -0.000003, rho = -1.104964
# nSV = 324, nBSV = 0
# ....*...*
# optimization finished, #iter = 5640
# obj = -0.000003, rho = -1.047384
# nSV = 329, nBSV = 0
# ....*.*
# optimization finished, #iter = 3963
# obj = -0.000003, rho = -0.412658
# nSV = 337, nBSV = 0
# Total nSV = 1121
# [CV] END .................................................... total time=   2.2s
# [LibSVM]........*....*
# optimization finished, #iter = 12439
# obj = -0.000010, rho = 0.461674
# nSV = 412, nBSV = 0
# .*.*
# optimization finished, #iter = 2268
# obj = -0.000001, rho = -0.476972
# nSV = 217, nBSV = 0
# ...*.*
# optimization finished, #iter = 4593
# obj = -0.000002, rho = -0.454652
# nSV = 264, nBSV = 0
# ....*..*
# optimization finished, #iter = 4710
# obj = -0.000003, rho = -1.267984
# nSV = 346, nBSV = 0
# ....*...*
# optimization finished, #iter = 5806
# obj = -0.000003, rho = -1.147302
# nSV = 331, nBSV = 0
# ....*..*
# optimization finished, #iter = 4268
# obj = -0.000002, rho = -0.323149
# nSV = 361, nBSV = 0
# Total nSV = 1140
# [CV] END .................................................... total time=   2.2s
# Training duration for PCA=1600, C=10, kernel=linear, gamma=scale: 6.7204039096832275 seconds
# Using existing PCA model for 1600 components
# [LibSVM]........*....*
# optimization finished, #iter = 12701
# obj = -0.000012, rho = 0.708561
# nSV = 416, nBSV = 0
# .*.*
# optimization finished, #iter = 2031
# obj = -0.000001, rho = -0.509828
# nSV = 198, nBSV = 0
# ..*.*
# optimization finished, #iter = 3777
# obj = -0.000002, rho = -0.437183
# nSV = 248, nBSV = 0
# ....*..*
# optimization finished, #iter = 4609
# obj = -0.000005, rho = -1.388771
# nSV = 321, nBSV = 0
# ....*..*
# optimization finished, #iter = 5362
# obj = -0.000003, rho = -1.096337
# nSV = 331, nBSV = 0
# ....*..*
# optimization finished, #iter = 4048
# obj = -0.000003, rho = -0.112510
# nSV = 339, nBSV = 0
# Total nSV = 1135
# [CV] END .................................................... total time=   2.3s
# [LibSVM]...........*...*
# optimization finished, #iter = 14645
# obj = -0.000010, rho = 0.612378
# nSV = 405, nBSV = 0
# .*
# optimization finished, #iter = 1573
# obj = -0.000001, rho = -0.495450
# nSV = 186, nBSV = 0
# ...*.*
# optimization finished, #iter = 4460
# obj = -0.000002, rho = -0.529545
# nSV = 251, nBSV = 0
# ...*..*
# optimization finished, #iter = 4090
# obj = -0.000003, rho = -1.104964
# nSV = 324, nBSV = 0
# ....*...*
# optimization finished, #iter = 5640
# obj = -0.000003, rho = -1.047384
# nSV = 329, nBSV = 0
# ....*.*
# optimization finished, #iter = 3963
# obj = -0.000003, rho = -0.412658
# nSV = 337, nBSV = 0
# Total nSV = 1121
# [CV] END .................................................... total time=   2.2s
# [LibSVM]........*....*
# optimization finished, #iter = 12439
# obj = -0.000010, rho = 0.461674
# nSV = 412, nBSV = 0
# .*.*
# optimization finished, #iter = 2268
# obj = -0.000001, rho = -0.476972
# nSV = 217, nBSV = 0
# ...*.*
# optimization finished, #iter = 4593
# obj = -0.000002, rho = -0.454652
# nSV = 264, nBSV = 0
# ....*..*
# optimization finished, #iter = 4710
# obj = -0.000003, rho = -1.267984
# nSV = 346, nBSV = 0
# ....*...*
# optimization finished, #iter = 5806
# obj = -0.000003, rho = -1.147302
# nSV = 331, nBSV = 0
# ....*..*
# optimization finished, #iter = 4268
# obj = -0.000002, rho = -0.323149
# nSV = 361, nBSV = 0
# Total nSV = 1140
# [CV] END .................................................... total time=   2.3s
# Training duration for PCA=1600, C=10, kernel=linear, gamma=auto: 6.7796971797943115 seconds
# Using existing PCA model for 1600 components
# [LibSVM].*
# optimization finished, #iter = 1985
# obj = -855.458443, rho = 0.043646
# nSV = 653, nBSV = 44
# *
# optimization finished, #iter = 920
# obj = -162.489823, rho = -0.089846
# nSV = 387, nBSV = 1
# *.*
# optimization finished, #iter = 1258
# obj = -253.946129, rho = -0.065976
# nSV = 472, nBSV = 11
# .*.*
# optimization finished, #iter = 1582
# obj = -543.128729, rho = 0.143900
# nSV = 584, nBSV = 4
# .*.*
# optimization finished, #iter = 1658
# obj = -437.600187, rho = 0.223680
# nSV = 608, nBSV = 2
# .*
# optimization finished, #iter = 1334
# obj = -400.376189, rho = 0.112465
# nSV = 546, nBSV = 2
# Total nSV = 1455
# [CV] END .................................................... total time=   3.9s
# [LibSVM].*
# optimization finished, #iter = 1942
# obj = -832.253249, rho = 0.086005
# nSV = 637, nBSV = 55
# *
# optimization finished, #iter = 942
# obj = -155.997419, rho = 0.019340
# nSV = 376, nBSV = 0
# *.*
# optimization finished, #iter = 1228
# obj = -225.015216, rho = 0.027437
# nSV = 466, nBSV = 6
# .*
# optimization finished, #iter = 1419
# obj = -435.118744, rho = 0.347026
# nSV = 534, nBSV = 1
# .*.*
# optimization finished, #iter = 1659
# obj = -429.510041, rho = 0.330314
# nSV = 598, nBSV = 0
# .*.*
# optimization finished, #iter = 1346
# obj = -409.897454, rho = 0.238781
# nSV = 535, nBSV = 3
# Total nSV = 1448
# [CV] END .................................................... total time=   3.6s
# [LibSVM].*
# optimization finished, #iter = 1970
# obj = -785.293899, rho = 0.052171
# nSV = 638, nBSV = 48
# *
# optimization finished, #iter = 932
# obj = -156.645202, rho = -0.101213
# nSV = 384, nBSV = 0
# *.*
# optimization finished, #iter = 1320
# obj = -237.472506, rho = -0.138983
# nSV = 473, nBSV = 9
# .*.*
# optimization finished, #iter = 1616
# obj = -479.383730, rho = 0.204610
# nSV = 570, nBSV = 3
# .*.*
# optimization finished, #iter = 1687
# obj = -454.826815, rho = 0.367112
# nSV = 606, nBSV = 1
# .*.*
# optimization finished, #iter = 1412
# obj = -379.809275, rho = 0.257498
# nSV = 549, nBSV = 1
# Total nSV = 1453
# [CV] END .................................................... total time=   3.8s
# Training duration for PCA=1600, C=10, kernel=rbf, gamma=scale: 11.283824682235718 seconds
# Using existing PCA model for 1600 components
# [LibSVM]..*.*
# optimization finished, #iter = 3945
# obj = -552.231328, rho = -0.272422
# nSV = 1193, nBSV = 0
# .*
# optimization finished, #iter = 1683
# obj = -426.937500, rho = -0.437500
# nSV = 1056, nBSV = 0
# ..*.*
# optimization finished, #iter = 3261
# obj = -497.484421, rho = -0.344553
# nSV = 1129, nBSV = 0
# .*
# optimization finished, #iter = 1319
# obj = -352.662079, rho = -0.187415
# nSV = 731, nBSV = 0
# ..*.*
# optimization finished, #iter = 2422
# obj = -399.452641, rho = -0.079602
# nSV = 804, nBSV = 0
# ..*
# optimization finished, #iter = 1434
# obj = -329.505226, rho = 0.109445
# nSV = 667, nBSV = 0
# Total nSV = 1860
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   5.6s
# [LibSVM]..*.*
# optimization finished, #iter = 3801
# obj = -552.508255, rho = -0.270134
# nSV = 1192, nBSV = 0
# .*.*
# optimization finished, #iter = 2946
# obj = -427.651059, rho = -0.435071
# nSV = 1055, nBSV = 0
# ..*.*
# optimization finished, #iter = 3419
# obj = -495.246184, rho = -0.345778
# nSV = 1125, nBSV = 0
# .*.*
# optimization finished, #iter = 1698
# obj = -353.697052, rho = -0.186903
# nSV = 733, nBSV = 0
# ..*.*
# optimization finished, #iter = 2682
# obj = -398.704762, rho = -0.083437
# nSV = 803, nBSV = 0
# ..*.*
# optimization finished, #iter = 2018
# obj = -329.321247, rho = 0.105105
# nSV = 666, nBSV = 0
# Total nSV = 1858
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   5.5s
# [LibSVM]..*.*
# optimization finished, #iter = 3849
# obj = -553.570175, rho = -0.272575
# nSV = 1196, nBSV = 0
# .*.*
# optimization finished, #iter = 2711
# obj = -427.253267, rho = -0.438563
# nSV = 1058, nBSV = 0
# ..*.*
# optimization finished, #iter = 3629
# obj = -496.099070, rho = -0.348096
# nSV = 1129, nBSV = 0
# .*.*
# optimization finished, #iter = 1971
# obj = -352.991787, rho = -0.188525
# nSV = 732, nBSV = 0
# ..*.*
# optimization finished, #iter = 2682
# obj = -398.704762, rho = -0.083437
# nSV = 803, nBSV = 0
# ..*.*
# optimization finished, #iter = 2139
# obj = -328.709704, rho = 0.106767
# nSV = 665, nBSV = 0
# Total nSV = 1861
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   5.4s
# Training duration for PCA=1600, C=10, kernel=rbf, gamma=auto: 16.443915843963623 seconds
# [LibSVM].......*...*
# optimization finished, #iter = 10778
# obj = -0.000010, rho = 0.631943
# nSV = 444, nBSV = 0
# .*
# optimization finished, #iter = 1963
# obj = -0.000001, rho = -0.496670
# nSV = 214, nBSV = 0
# ..*.*
# optimization finished, #iter = 3802
# obj = -0.000002, rho = -0.429697
# nSV = 265, nBSV = 0
# ....*.*
# optimization finished, #iter = 4250
# obj = -0.000004, rho = -1.180689
# nSV = 359, nBSV = 0
# ....*.*
# optimization finished, #iter = 4771
# obj = -0.000003, rho = -1.024811
# nSV = 350, nBSV = 0
# ....*.*
# optimization finished, #iter = 3740
# obj = -0.000002, rho = -0.033208
# nSV = 362, nBSV = 0
# Total nSV = 1180
# [CV] END .................................................... total time=   3.1s
# [LibSVM]........*...*
# optimization finished, #iter = 11547
# obj = -0.000008, rho = 0.556664
# nSV = 421, nBSV = 0
# .*
# optimization finished, #iter = 1693
# obj = -0.000001, rho = -0.485727
# nSV = 194, nBSV = 0
# ..*.*
# optimization finished, #iter = 3886
# obj = -0.000002, rho = -0.501085
# nSV = 261, nBSV = 0
# ...*.*
# optimization finished, #iter = 3615
# obj = -0.000003, rho = -1.036172
# nSV = 342, nBSV = 0
# ....*..*
# optimization finished, #iter = 5050
# obj = -0.000003, rho = -0.992047
# nSV = 341, nBSV = 0
# ...*..*
# optimization finished, #iter = 3792
# obj = -0.000003, rho = -0.287728
# nSV = 360, nBSV = 0
# Total nSV = 1145
# [CV] END .................................................... total time=   3.0s
# [LibSVM]........*...*
# optimization finished, #iter = 11024
# obj = -0.000008, rho = 0.400225
# nSV = 447, nBSV = 0
# .*.*
# optimization finished, #iter = 2146
# obj = -0.000001, rho = -0.460906
# nSV = 220, nBSV = 0
# ..*..*
# optimization finished, #iter = 4325
# obj = -0.000002, rho = -0.445009
# nSV = 271, nBSV = 0
# ....*.*
# optimization finished, #iter = 4306
# obj = -0.000003, rho = -1.146219
# nSV = 371, nBSV = 0
# ....*..*
# optimization finished, #iter = 5278
# obj = -0.000003, rho = -1.072532
# nSV = 355, nBSV = 0
# ...*..*
# optimization finished, #iter = 3733
# obj = -0.000002, rho = -0.254086
# nSV = 368, nBSV = 0
# Total nSV = 1171
# [CV] END .................................................... total time=   3.2s
# Training duration for PCA=2025, C=0.1, kernel=linear, gamma=scale: 9.365202903747559 seconds
# Using existing PCA model for 2025 components
# [LibSVM].......*...*
# optimization finished, #iter = 10778
# obj = -0.000010, rho = 0.631943
# nSV = 444, nBSV = 0
# .*
# optimization finished, #iter = 1963
# obj = -0.000001, rho = -0.496670
# nSV = 214, nBSV = 0
# ..*.*
# optimization finished, #iter = 3802
# obj = -0.000002, rho = -0.429697
# nSV = 265, nBSV = 0
# ....*.*
# optimization finished, #iter = 4250
# obj = -0.000004, rho = -1.180689
# nSV = 359, nBSV = 0
# ....*.*
# optimization finished, #iter = 4771
# obj = -0.000003, rho = -1.024811
# nSV = 350, nBSV = 0
# ....*.*
# optimization finished, #iter = 3740
# obj = -0.000002, rho = -0.033208
# nSV = 362, nBSV = 0
# Total nSV = 1180
# [CV] END .................................................... total time=   3.1s
# [LibSVM]........*...*
# optimization finished, #iter = 11547
# obj = -0.000008, rho = 0.556664
# nSV = 421, nBSV = 0
# .*
# optimization finished, #iter = 1693
# obj = -0.000001, rho = -0.485727
# nSV = 194, nBSV = 0
# ..*.*
# optimization finished, #iter = 3886
# obj = -0.000002, rho = -0.501085
# nSV = 261, nBSV = 0
# ...*.*
# optimization finished, #iter = 3615
# obj = -0.000003, rho = -1.036172
# nSV = 342, nBSV = 0
# ....*..*
# optimization finished, #iter = 5050
# obj = -0.000003, rho = -0.992047
# nSV = 341, nBSV = 0
# ...*..*
# optimization finished, #iter = 3792
# obj = -0.000003, rho = -0.287728
# nSV = 360, nBSV = 0
# Total nSV = 1145
# [CV] END .................................................... total time=   3.0s
# [LibSVM]........*...*
# optimization finished, #iter = 11024
# obj = -0.000008, rho = 0.400225
# nSV = 447, nBSV = 0
# .*.*
# optimization finished, #iter = 2146
# obj = -0.000001, rho = -0.460906
# nSV = 220, nBSV = 0
# ..*..*
# optimization finished, #iter = 4325
# obj = -0.000002, rho = -0.445009
# nSV = 271, nBSV = 0
# ....*.*
# optimization finished, #iter = 4306
# obj = -0.000003, rho = -1.146219
# nSV = 371, nBSV = 0
# ....*..*
# optimization finished, #iter = 5278
# obj = -0.000003, rho = -1.072532
# nSV = 355, nBSV = 0
# ...*..*
# optimization finished, #iter = 3733
# obj = -0.000002, rho = -0.254086
# nSV = 368, nBSV = 0
# Total nSV = 1171
# [CV] END .................................................... total time=   3.3s
# Training duration for PCA=2025, C=0.1, kernel=linear, gamma=auto: 9.393073320388794 seconds
# Using existing PCA model for 2025 components
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1064
# obj = -64.812564, rho = 0.257232
# nSV = 1036, nBSV = 932
# *
# optimization finished, #iter = 702
# obj = -40.765680, rho = 0.373424
# nSV = 671, nBSV = 608
# *
# optimization finished, #iter = 945
# obj = -51.853542, rho = 0.570263
# nSV = 890, nBSV = 807
# *
# optimization finished, #iter = 674
# obj = -66.733824, rho = 0.613115
# nSV = 636, nBSV = 587
# *
# optimization finished, #iter = 799
# obj = -71.735451, rho = 0.725842
# nSV = 755, nBSV = 700
# *
# optimization finished, #iter = 648
# obj = -70.375076, rho = 0.190912
# nSV = 620, nBSV = 592
# Total nSV = 1765
# [CV] END .................................................... total time=   6.5s
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1065
# obj = -65.366216, rho = 0.286498
# nSV = 1040, nBSV = 935
# *
# optimization finished, #iter = 672
# obj = -38.912200, rho = 0.409620
# nSV = 649, nBSV = 584
# *
# optimization finished, #iter = 926
# obj = -49.795029, rho = 0.669887
# nSV = 864, nBSV = 760
# *
# optimization finished, #iter = 637
# obj = -62.448803, rho = 0.638028
# nSV = 608, nBSV = 554
# *
# optimization finished, #iter = 782
# obj = -66.480150, rho = 0.782531
# nSV = 713, nBSV = 653
# *
# optimization finished, #iter = 632
# obj = -68.310647, rho = 0.240029
# nSV = 613, nBSV = 580
# Total nSV = 1767
# [CV] END .................................................... total time=   6.3s
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1081
# obj = -66.297041, rho = 0.193365
# nSV = 1057, nBSV = 944
# *
# optimization finished, #iter = 713
# obj = -41.485150, rho = 0.407983
# nSV = 684, nBSV = 630
# *
# optimization finished, #iter = 939
# obj = -51.946307, rho = 0.613256
# nSV = 889, nBSV = 813
# *
# optimization finished, #iter = 649
# obj = -64.165127, rho = 0.575419
# nSV = 615, nBSV = 564
# *
# optimization finished, #iter = 786
# obj = -69.770747, rho = 0.758417
# nSV = 738, nBSV = 677
# *
# optimization finished, #iter = 648
# obj = -70.495533, rho = 0.268734
# nSV = 618, nBSV = 593
# Total nSV = 1777
# [CV] END .................................................... total time=   6.3s
# Training duration for PCA=2025, C=0.1, kernel=rbf, gamma=scale: 19.078423976898193 seconds
# Using existing PCA model for 2025 components
# [LibSVM].*
# optimization finished, #iter = 1195
# obj = -89.262075, rho = -0.877690
# nSV = 1196, nBSV = 1195
# .*
# optimization finished, #iter = 1059
# obj = -88.095862, rho = 0.687248
# nSV = 1060, nBSV = 1059
# .*
# optimization finished, #iter = 1130
# obj = -88.829332, rho = 0.874054
# nSV = 1132, nBSV = 1130
# *
# optimization finished, #iter = 731
# obj = -87.030192, rho = 0.687248
# nSV = 732, nBSV = 731
# *
# optimization finished, #iter = 802
# obj = -87.763662, rho = 0.874054
# nSV = 804, nBSV = 802
# *
# optimization finished, #iter = 667
# obj = -86.597449, rho = 0.874054
# nSV = 668, nBSV = 667
# Total nSV = 1864
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   7.2s
# [LibSVM].*
# optimization finished, #iter = 1194
# obj = -89.260346, rho = 0.892874
# nSV = 1197, nBSV = 1194
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1058
# obj = -88.112835, rho = 0.843624
# nSV = 1060, nBSV = 762
# .*
# optimization finished, #iter = 1130
# obj = -88.797951, rho = 0.747425
# nSV = 1131, nBSV = 1130
# *
# optimization finished, #iter = 732
# obj = -87.060397, rho = -0.892874
# nSV = 733, nBSV = 732
# *
# optimization finished, #iter = 803
# obj = -87.745512, rho = -0.892874
# nSV = 804, nBSV = 803
# *
# optimization finished, #iter = 666
# obj = -86.598001, rho = -0.843624
# nSV = 667, nBSV = 666
# Total nSV = 1864
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   7.0s
# [LibSVM].*
# optimization finished, #iter = 1196
# obj = -89.275306, rho = 0.892874
# nSV = 1197, nBSV = 1196
# .*
# optimization finished, #iter = 1059
# obj = -88.103341, rho = 0.687248
# nSV = 1060, nBSV = 1059
# .*
# optimization finished, #iter = 1130
# obj = -88.812910, rho = 0.747425
# nSV = 1131, nBSV = 1130
# *
# optimization finished, #iter = 732
# obj = -87.035944, rho = -0.892874
# nSV = 733, nBSV = 732
# *
# optimization finished, #iter = 803
# obj = -87.745512, rho = -0.892874
# nSV = 804, nBSV = 803
# *
# optimization finished, #iter = 666
# obj = -86.573548, rho = -0.687248
# nSV = 667, nBSV = 666
# Total nSV = 1864
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   6.9s
# Training duration for PCA=2025, C=0.1, kernel=rbf, gamma=auto: 21.04748797416687 seconds
# Using existing PCA model for 2025 components
# [LibSVM].......*...*
# optimization finished, #iter = 10778
# obj = -0.000010, rho = 0.631943
# nSV = 444, nBSV = 0
# .*
# optimization finished, #iter = 1963
# obj = -0.000001, rho = -0.496670
# nSV = 214, nBSV = 0
# ..*.*
# optimization finished, #iter = 3802
# obj = -0.000002, rho = -0.429697
# nSV = 265, nBSV = 0
# ....*.*
# optimization finished, #iter = 4250
# obj = -0.000004, rho = -1.180689
# nSV = 359, nBSV = 0
# ....*.*
# optimization finished, #iter = 4771
# obj = -0.000003, rho = -1.024811
# nSV = 350, nBSV = 0
# ....*.*
# optimization finished, #iter = 3740
# obj = -0.000002, rho = -0.033208
# nSV = 362, nBSV = 0
# Total nSV = 1180
# [CV] END .................................................... total time=   3.1s
# [LibSVM]........*...*
# optimization finished, #iter = 11547
# obj = -0.000008, rho = 0.556664
# nSV = 421, nBSV = 0
# .*
# optimization finished, #iter = 1693
# obj = -0.000001, rho = -0.485727
# nSV = 194, nBSV = 0
# ..*.*
# optimization finished, #iter = 3886
# obj = -0.000002, rho = -0.501085
# nSV = 261, nBSV = 0
# ...*.*
# optimization finished, #iter = 3615
# obj = -0.000003, rho = -1.036172
# nSV = 342, nBSV = 0
# ....*..*
# optimization finished, #iter = 5050
# obj = -0.000003, rho = -0.992047
# nSV = 341, nBSV = 0
# ...*..*
# optimization finished, #iter = 3792
# obj = -0.000003, rho = -0.287728
# nSV = 360, nBSV = 0
# Total nSV = 1145
# [CV] END .................................................... total time=   3.0s
# [LibSVM]........*...*
# optimization finished, #iter = 11024
# obj = -0.000008, rho = 0.400225
# nSV = 447, nBSV = 0
# .*.*
# optimization finished, #iter = 2146
# obj = -0.000001, rho = -0.460906
# nSV = 220, nBSV = 0
# ..*..*
# optimization finished, #iter = 4325
# obj = -0.000002, rho = -0.445009
# nSV = 271, nBSV = 0
# ....*.*
# optimization finished, #iter = 4306
# obj = -0.000003, rho = -1.146219
# nSV = 371, nBSV = 0
# ....*..*
# optimization finished, #iter = 5278
# obj = -0.000003, rho = -1.072532
# nSV = 355, nBSV = 0
# ...*..*
# optimization finished, #iter = 3733
# obj = -0.000002, rho = -0.254086
# nSV = 368, nBSV = 0
# Total nSV = 1171
# [CV] END .................................................... total time=   3.2s
# Training duration for PCA=2025, C=1, kernel=linear, gamma=scale: 9.292149066925049 seconds
# Using existing PCA model for 2025 components
# [LibSVM].......*...*
# optimization finished, #iter = 10778
# obj = -0.000010, rho = 0.631943
# nSV = 444, nBSV = 0
# .*
# optimization finished, #iter = 1963
# obj = -0.000001, rho = -0.496670
# nSV = 214, nBSV = 0
# ..*.*
# optimization finished, #iter = 3802
# obj = -0.000002, rho = -0.429697
# nSV = 265, nBSV = 0
# ....*.*
# optimization finished, #iter = 4250
# obj = -0.000004, rho = -1.180689
# nSV = 359, nBSV = 0
# ....*.*
# optimization finished, #iter = 4771
# obj = -0.000003, rho = -1.024811
# nSV = 350, nBSV = 0
# ....*.*
# optimization finished, #iter = 3740
# obj = -0.000002, rho = -0.033208
# nSV = 362, nBSV = 0
# Total nSV = 1180
# [CV] END .................................................... total time=   3.1s
# [LibSVM]........*...*
# optimization finished, #iter = 11547
# obj = -0.000008, rho = 0.556664
# nSV = 421, nBSV = 0
# .*
# optimization finished, #iter = 1693
# obj = -0.000001, rho = -0.485727
# nSV = 194, nBSV = 0
# ..*.*
# optimization finished, #iter = 3886
# obj = -0.000002, rho = -0.501085
# nSV = 261, nBSV = 0
# ...*.*
# optimization finished, #iter = 3615
# obj = -0.000003, rho = -1.036172
# nSV = 342, nBSV = 0
# ....*..*
# optimization finished, #iter = 5050
# obj = -0.000003, rho = -0.992047
# nSV = 341, nBSV = 0
# ...*..*
# optimization finished, #iter = 3792
# obj = -0.000003, rho = -0.287728
# nSV = 360, nBSV = 0
# Total nSV = 1145
# [CV] END .................................................... total time=   2.9s
# [LibSVM]........*...*
# optimization finished, #iter = 11024
# obj = -0.000008, rho = 0.400225
# nSV = 447, nBSV = 0
# .*.*
# optimization finished, #iter = 2146
# obj = -0.000001, rho = -0.460906
# nSV = 220, nBSV = 0
# ..*..*
# optimization finished, #iter = 4325
# obj = -0.000002, rho = -0.445009
# nSV = 271, nBSV = 0
# ....*.*
# optimization finished, #iter = 4306
# obj = -0.000003, rho = -1.146219
# nSV = 371, nBSV = 0
# ....*..*
# optimization finished, #iter = 5278
# obj = -0.000003, rho = -1.072532
# nSV = 355, nBSV = 0
# ...*..*
# optimization finished, #iter = 3733
# obj = -0.000002, rho = -0.254086
# nSV = 368, nBSV = 0
# Total nSV = 1171
# [CV] END .................................................... total time=   3.1s
# Training duration for PCA=2025, C=1, kernel=linear, gamma=auto: 9.165841102600098 seconds
# Using existing PCA model for 2025 components
# [LibSVM]*.*
# optimization finished, #iter = 1050
# obj = -327.929660, rho = -0.062670
# nSV = 741, nBSV = 451
# *
# optimization finished, #iter = 709
# obj = -120.327830, rho = -0.123680
# nSV = 406, nBSV = 123
# *
# optimization finished, #iter = 912
# obj = -164.729364, rho = -0.138266
# nSV = 543, nBSV = 191
# .*
# optimization finished, #iter = 1010
# obj = -313.840114, rho = 0.225830
# nSV = 583, nBSV = 157
# .*
# optimization finished, #iter = 1126
# obj = -303.206318, rho = 0.295481
# nSV = 633, nBSV = 144
# .*
# optimization finished, #iter = 972
# obj = -299.024733, rho = 0.146846
# nSV = 547, nBSV = 181
# Total nSV = 1528
# [CV] END .................................................... total time=   5.0s
# [LibSVM]*.*
# optimization finished, #iter = 1112
# obj = -330.783186, rho = 0.190001
# nSV = 754, nBSV = 445
# *
# optimization finished, #iter = 719
# obj = -110.825323, rho = 0.048729
# nSV = 389, nBSV = 104
# *
# optimization finished, #iter = 913
# obj = -160.659276, rho = 0.005416
# nSV = 543, nBSV = 190
# *.*
# optimization finished, #iter = 946
# obj = -282.250605, rho = 0.302004
# nSV = 546, nBSV = 150
# .*
# optimization finished, #iter = 1127
# obj = -293.308199, rho = 0.361530
# nSV = 634, nBSV = 137
# .*
# optimization finished, #iter = 976
# obj = -285.917191, rho = 0.201237
# nSV = 532, nBSV = 165
# Total nSV = 1536
# [CV] END .................................................... total time=   4.9s
# [LibSVM]*.*
# optimization finished, #iter = 1131
# obj = -330.964086, rho = -0.018642
# nSV = 769, nBSV = 433
# *
# optimization finished, #iter = 752
# obj = -121.428166, rho = -0.061654
# nSV = 411, nBSV = 119
# *
# optimization finished, #iter = 889
# obj = -162.511514, rho = -0.111771
# nSV = 541, nBSV = 192
# .*
# optimization finished, #iter = 990
# obj = -311.875582, rho = 0.363294
# nSV = 574, nBSV = 179
# .*
# optimization finished, #iter = 1095
# obj = -308.548011, rho = 0.408500
# nSV = 637, nBSV = 148
# .*
# optimization finished, #iter = 1039
# obj = -296.357146, rho = 0.187166
# nSV = 558, nBSV = 183
# Total nSV = 1548
# [CV] END .................................................... total time=   4.7s
# Training duration for PCA=2025, C=1, kernel=rbf, gamma=scale: 14.53200101852417 seconds
# Using existing PCA model for 2025 components
# [LibSVM].*
# optimization finished, #iter = 1567
# obj = -538.338707, rho = -0.071694
# nSV = 1196, nBSV = 758
# .*.*
# optimization finished, #iter = 2673
# obj = -426.937500, rho = -0.437500
# nSV = 1056, nBSV = 0
# .*
# optimization finished, #iter = 1625
# obj = -495.279631, rho = -0.255576
# nSV = 1132, nBSV = 756
# .*
# optimization finished, #iter = 1319
# obj = -352.662079, rho = -0.187415
# nSV = 731, nBSV = 0
# ..*.*
# optimization finished, #iter = 2422
# obj = -399.452710, rho = -0.079602
# nSV = 804, nBSV = 0
# ..*
# optimization finished, #iter = 1434
# obj = -329.505226, rho = 0.109445
# nSV = 667, nBSV = 0
# Total nSV = 1863
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   7.2s
# [LibSVM].*
# optimization finished, #iter = 1666
# obj = -538.248782, rho = -0.067917
# nSV = 1197, nBSV = 752
# .*.*
# optimization finished, #iter = 2733
# obj = -427.651130, rho = -0.435071
# nSV = 1055, nBSV = 0
# .*
# optimization finished, #iter = 1543
# obj = -493.181068, rho = -0.259741
# nSV = 1130, nBSV = 752
# .*.*
# optimization finished, #iter = 1698
# obj = -353.697052, rho = -0.186903
# nSV = 733, nBSV = 0
# ..*.*
# optimization finished, #iter = 2674
# obj = -398.704789, rho = -0.083437
# nSV = 803, nBSV = 0
# ..*.*
# optimization finished, #iter = 2018
# obj = -329.321247, rho = 0.105105
# nSV = 666, nBSV = 0
# Total nSV = 1863
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
# [LibSVM]......*...*
# optimization finished, #iter = 9120
# obj = -0.000007, rho = 0.362874
# nSV = 476, nBSV = 0
# .*.*
# optimization finished, #iter = 2003
# obj = -0.000001, rho = -0.452740
# nSV = 223, nBSV = 0
# ..*.*
# optimization finished, #iter = 3975
# obj = -0.000002, rho = -0.411723
# nSV = 282, nBSV = 0
# ...*..*
# optimization finished, #iter = 4340
# obj = -0.000002, rho = -1.087195
# nSV = 393, nBSV = 0
# ...*...*
# optimization finished, #iter = 4949
# obj = -0.000003, rho = -1.022763
# nSV = 381, nBSV = 0
# ...*..*
# optimization finished, #iter = 3585
# obj = -0.000002, rho = -0.226257
# nSV = 386, nBSV = 0
# Total nSV = 1211
# [CV] END .................................................... total time=   3.9s
# Training duration for PCA=2500, C=1, kernel=linear, gamma=auto: 11.647035121917725 seconds
# Using existing PCA model for 2500 components
# [LibSVM]*.*
# optimization finished, #iter = 1067
# obj = -327.959437, rho = -0.069765
# nSV = 744, nBSV = 445
# *
# optimization finished, #iter = 678
# obj = -120.421623, rho = -0.127270
# nSV = 410, nBSV = 121
# *
# optimization finished, #iter = 932
# obj = -164.838932, rho = -0.142467
# nSV = 549, nBSV = 189
# .*
# optimization finished, #iter = 1022
# obj = -313.664712, rho = 0.220255
# nSV = 584, nBSV = 154
# .*
# optimization finished, #iter = 1103
# obj = -303.295763, rho = 0.288654
# nSV = 636, nBSV = 140
# .*
# optimization finished, #iter = 939
# obj = -299.096343, rho = 0.145956
# nSV = 550, nBSV = 180
# Total nSV = 1533
# [CV] END .................................................... total time=   6.0s
# [LibSVM]*.*
# optimization finished, #iter = 1130
# obj = -330.866919, rho = 0.181737
# nSV = 759, nBSV = 443
# *
# optimization finished, #iter = 699
# obj = -110.958416, rho = 0.046054
# nSV = 391, nBSV = 104
# *
# optimization finished, #iter = 947
# obj = -160.823353, rho = 0.001410
# nSV = 546, nBSV = 190
# *.*
# optimization finished, #iter = 939
# obj = -282.231829, rho = 0.298743
# nSV = 548, nBSV = 147
# .*
# optimization finished, #iter = 1117
# obj = -293.312636, rho = 0.351725
# nSV = 638, nBSV = 137
# .*
# optimization finished, #iter = 964
# obj = -285.940889, rho = 0.196107
# nSV = 536, nBSV = 165
# Total nSV = 1541
# [CV] END .................................................... total time=   5.9s
# [LibSVM]*.*
# optimization finished, #iter = 1125
# obj = -331.113195, rho = -0.026706
# nSV = 772, nBSV = 434
# *
# optimization finished, #iter = 740
# obj = -121.567541, rho = -0.065403
# nSV = 413, nBSV = 119
# *
# optimization finished, #iter = 923
# obj = -162.664450, rho = -0.115969
# nSV = 545, nBSV = 192
# *.*
# optimization finished, #iter = 950
# obj = -311.754272, rho = 0.360648
# nSV = 577, nBSV = 175
# *.*
# optimization finished, #iter = 1066
# obj = -308.562439, rho = 0.404514
# nSV = 640, nBSV = 148
# .*
# optimization finished, #iter = 1021
# obj = -296.441068, rho = 0.185975
# nSV = 563, nBSV = 182
# Total nSV = 1552
# [CV] END .................................................... total time=   5.9s
# Training duration for PCA=2500, C=1, kernel=rbf, gamma=scale: 17.77680206298828 seconds
# Using existing PCA model for 2500 components
# [LibSVM].*
# optimization finished, #iter = 1567
# obj = -538.338707, rho = -0.071694
# nSV = 1196, nBSV = 758
# .*.*
# optimization finished, #iter = 2673
# obj = -426.937500, rho = -0.437500
# nSV = 1056, nBSV = 0
# .*
# optimization finished, #iter = 1625
# obj = -495.279631, rho = -0.255576
# nSV = 1132, nBSV = 756
# .*
# optimization finished, #iter = 1319
# obj = -352.662079, rho = -0.187415
# nSV = 731, nBSV = 0
# ..*.*
# optimization finished, #iter = 2422
# obj = -399.452710, rho = -0.079602
# nSV = 804, nBSV = 0
# ..*
# optimization finished, #iter = 1434
# obj = -329.505226, rho = 0.109445
# nSV = 667, nBSV = 0
# Total nSV = 1863
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   8.6s
# [LibSVM].*
# optimization finished, #iter = 1666
# obj = -538.248782, rho = -0.067917
# nSV = 1197, nBSV = 752
# .*.*
# optimization finished, #iter = 2733
# obj = -427.651130, rho = -0.435071
# nSV = 1055, nBSV = 0
# .*
# optimization finished, #iter = 1543
# obj = -493.181068, rho = -0.259741
# nSV = 1130, nBSV = 752
# .*.*
# optimization finished, #iter = 1698
# obj = -353.697052, rho = -0.186903
# nSV = 733, nBSV = 0
# ..*.*
# optimization finished, #iter = 2674
# obj = -398.704789, rho = -0.083437
# nSV = 803, nBSV = 0
# ..*.*
# optimization finished, #iter = 2018
# obj = -329.321247, rho = 0.105105
# nSV = 666, nBSV = 0
# Total nSV = 1863
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   8.5s
# [LibSVM].*
# optimization finished, #iter = 1492
# obj = -539.573810, rho = -0.070589
# nSV = 1197, nBSV = 760
# ..*
# optimization finished, #iter = 2463
# obj = -427.253254, rho = -0.438563
# nSV = 1058, nBSV = 0
# .*
# optimization finished, #iter = 1691
# obj = -494.124509, rho = -0.389316
# nSV = 1130, nBSV = 521
# .*.*
# optimization finished, #iter = 1971
# obj = -352.991787, rho = -0.188525
# nSV = 732, nBSV = 0
# ..*.*
# optimization finished, #iter = 2674
# obj = -398.704789, rho = -0.083437
# nSV = 803, nBSV = 0
# ..*.*
# optimization finished, #iter = 2139
# obj = -328.709704, rho = 0.106767
# nSV = 665, nBSV = 0
# Total nSV = 1863
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   8.5s
# Training duration for PCA=2500, C=1, kernel=rbf, gamma=auto: 25.65928888320923 seconds
# Using existing PCA model for 2500 components
# [LibSVM]......*...*
# optimization finished, #iter = 9132
# obj = -0.000008, rho = 0.542182
# nSV = 478, nBSV = 0
# .*
# optimization finished, #iter = 1879
# obj = -0.000001, rho = -0.486964
# nSV = 216, nBSV = 0
# ..*.*
# optimization finished, #iter = 3443
# obj = -0.000002, rho = -0.416777
# nSV = 280, nBSV = 0
# ....*.*
# optimization finished, #iter = 4241
# obj = -0.000003, rho = -1.089980
# nSV = 386, nBSV = 0
# ...*..*
# optimization finished, #iter = 4599
# obj = -0.000002, rho = -0.977058
# nSV = 377, nBSV = 0
# ...*..*
# optimization finished, #iter = 3589
# obj = -0.000002, rho = -0.040001
# nSV = 383, nBSV = 0
# Total nSV = 1229
# [CV] END .................................................... total time=   4.1s
# [LibSVM]......*...*
# optimization finished, #iter = 9682
# obj = -0.000007, rho = 0.483535
# nSV = 473, nBSV = 0
# *.*
# optimization finished, #iter = 1567
# obj = -0.000001, rho = -0.480233
# nSV = 204, nBSV = 0
# ..*.*
# optimization finished, #iter = 3596
# obj = -0.000002, rho = -0.467904
# nSV = 272, nBSV = 0
# ...*.*
# optimization finished, #iter = 3472
# obj = -0.000002, rho = -1.006773
# nSV = 363, nBSV = 0
# ...*..*
# optimization finished, #iter = 4811
# obj = -0.000002, rho = -0.940425
# nSV = 363, nBSV = 0
# ...*..*
# optimization finished, #iter = 3491
# obj = -0.000002, rho = -0.202779
# nSV = 372, nBSV = 0
# Total nSV = 1205
# [CV] END .................................................... total time=   3.7s
# [LibSVM]......*...*
# optimization finished, #iter = 9120
# obj = -0.000007, rho = 0.362874
# nSV = 476, nBSV = 0
# .*.*
# optimization finished, #iter = 2003
# obj = -0.000001, rho = -0.452740
# nSV = 223, nBSV = 0
# ..*.*
# optimization finished, #iter = 3975
# obj = -0.000002, rho = -0.411723
# nSV = 282, nBSV = 0
# ...*..*
# optimization finished, #iter = 4340
# obj = -0.000002, rho = -1.087195
# nSV = 393, nBSV = 0
# ...*...*
# optimization finished, #iter = 4949
# obj = -0.000003, rho = -1.022763
# nSV = 381, nBSV = 0
# ...*..*
# optimization finished, #iter = 3585
# obj = -0.000002, rho = -0.226257
# nSV = 386, nBSV = 0
# Total nSV = 1211
# [CV] END .................................................... total time=   3.9s
# Training duration for PCA=2500, C=10, kernel=linear, gamma=scale: 11.646730899810791 seconds
# Using existing PCA model for 2500 components
# [LibSVM]......*...*
# optimization finished, #iter = 9132
# obj = -0.000008, rho = 0.542182
# nSV = 478, nBSV = 0
# .*
# optimization finished, #iter = 1879
# obj = -0.000001, rho = -0.486964
# nSV = 216, nBSV = 0
# ..*.*
# optimization finished, #iter = 3443
# obj = -0.000002, rho = -0.416777
# nSV = 280, nBSV = 0
# ....*.*
# optimization finished, #iter = 4241
# obj = -0.000003, rho = -1.089980
# nSV = 386, nBSV = 0
# ...*..*
# optimization finished, #iter = 4599
# obj = -0.000002, rho = -0.977058
# nSV = 377, nBSV = 0
# ...*..*
# optimization finished, #iter = 3589
# obj = -0.000002, rho = -0.040001
# nSV = 383, nBSV = 0
# Total nSV = 1229
# [CV] END .................................................... total time=   4.0s
# [LibSVM]......*...*
# optimization finished, #iter = 9682
# obj = -0.000007, rho = 0.483535
# nSV = 473, nBSV = 0
# *.*
# optimization finished, #iter = 1567
# obj = -0.000001, rho = -0.480233
# nSV = 204, nBSV = 0
# ..*.*
# optimization finished, #iter = 3596
# obj = -0.000002, rho = -0.467904
# nSV = 272, nBSV = 0
# ...*.*
# optimization finished, #iter = 3472
# obj = -0.000002, rho = -1.006773
# nSV = 363, nBSV = 0
# ...*..*
# optimization finished, #iter = 4811
# obj = -0.000002, rho = -0.940425
# nSV = 363, nBSV = 0
# ...*..*
# optimization finished, #iter = 3491
# obj = -0.000002, rho = -0.202779
# nSV = 372, nBSV = 0
# Total nSV = 1205
# [CV] END .................................................... total time=   3.7s
# [LibSVM]......*...*
# optimization finished, #iter = 9120
# obj = -0.000007, rho = 0.362874
# nSV = 476, nBSV = 0
# .*.*
# optimization finished, #iter = 2003
# obj = -0.000001, rho = -0.452740
# nSV = 223, nBSV = 0
# ..*.*
# optimization finished, #iter = 3975
# obj = -0.000002, rho = -0.411723
# nSV = 282, nBSV = 0
# ...*..*
# optimization finished, #iter = 4340
# obj = -0.000002, rho = -1.087195
# nSV = 393, nBSV = 0
# ...*...*
# optimization finished, #iter = 4949
# obj = -0.000003, rho = -1.022763
# nSV = 381, nBSV = 0
# ...*..*
# optimization finished, #iter = 3585
# obj = -0.000002, rho = -0.226257
# nSV = 386, nBSV = 0
# Total nSV = 1211
# [CV] END .................................................... total time=   4.0s
# Training duration for PCA=2500, C=10, kernel=linear, gamma=auto: 11.687710285186768 seconds
# Using existing PCA model for 2500 components
# [LibSVM].*.*
# optimization finished, #iter = 2081
# obj = -795.548735, rho = 0.027326
# nSV = 684, nBSV = 36
# *
# optimization finished, #iter = 950
# obj = -157.749421, rho = -0.098741
# nSV = 402, nBSV = 0
# *.*
# optimization finished, #iter = 1266
# obj = -243.443669, rho = -0.070677
# nSV = 494, nBSV = 7
# .*.*
# optimization finished, #iter = 1558
# obj = -500.496569, rho = 0.126864
# nSV = 603, nBSV = 3
# .*.*
# optimization finished, #iter = 1704
# obj = -421.632481, rho = 0.219834
# nSV = 628, nBSV = 2
# .*.*
# optimization finished, #iter = 1372
# obj = -384.711472, rho = 0.135148
# nSV = 557, nBSV = 2
# Total nSV = 1483
# [CV] END .................................................... total time=   6.7s
# [LibSVM].*
# optimization finished, #iter = 1924
# obj = -775.557652, rho = 0.070908
# nSV = 666, nBSV = 35
# *
# optimization finished, #iter = 933
# obj = -150.605257, rho = 0.014266
# nSV = 389, nBSV = 0
# *.*
# optimization finished, #iter = 1198
# obj = -219.946886, rho = 0.023259
# nSV = 481, nBSV = 5
# .*
# optimization finished, #iter = 1426
# obj = -409.901638, rho = 0.335479
# nSV = 556, nBSV = 0
# .*.*
# optimization finished, #iter = 1634
# obj = -414.338328, rho = 0.315573
# nSV = 622, nBSV = 0
# .*
# optimization finished, #iter = 1328
# obj = -390.800001, rho = 0.239364
# nSV = 545, nBSV = 3
# Total nSV = 1471
# [CV] END .................................................... total time=   6.2s
# [LibSVM].*
# optimization finished, #iter = 1971
# obj = -731.866592, rho = 0.035499
# nSV = 668, nBSV = 31
# *
# optimization finished, #iter = 935
# obj = -152.724614, rho = -0.104071
# nSV = 406, nBSV = 0
# *.*
# optimization finished, #iter = 1269
# obj = -228.707738, rho = -0.144342
# nSV = 496, nBSV = 6
# .*.*
# optimization finished, #iter = 1562
# obj = -451.958800, rho = 0.206142
# nSV = 587, nBSV = 3
# .*.*
# optimization finished, #iter = 1712
# obj = -433.234589, rho = 0.362138
# nSV = 616, nBSV = 1
# .*.*
# optimization finished, #iter = 1420
# obj = -367.185638, rho = 0.268487
# nSV = 564, nBSV = 1
# Total nSV = 1486
# [CV] END .................................................... total time=   6.8s
# Training duration for PCA=2500, C=10, kernel=rbf, gamma=scale: 19.742658853530884 seconds
# Using existing PCA model for 2500 components
# [LibSVM]..*.*
# optimization finished, #iter = 3945
# obj = -552.231328, rho = -0.272422
# nSV = 1193, nBSV = 0
# .*
# optimization finished, #iter = 1683
# obj = -426.937500, rho = -0.437500
# nSV = 1056, nBSV = 0
# ..*.*
# optimization finished, #iter = 3261
# obj = -497.484421, rho = -0.344553
# nSV = 1129, nBSV = 0
# .*
# optimization finished, #iter = 1319
# obj = -352.662079, rho = -0.187415
# nSV = 731, nBSV = 0
# ..*.*
# optimization finished, #iter = 2422
# obj = -399.452641, rho = -0.079602
# nSV = 804, nBSV = 0
# ..*
# optimization finished, #iter = 1434
# obj = -329.505226, rho = 0.109445
# nSV = 667, nBSV = 0
# Total nSV = 1860
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   8.7s
# [LibSVM]..*.*
# optimization finished, #iter = 3801
# obj = -552.508255, rho = -0.270134
# nSV = 1192, nBSV = 0
# .*.*
# optimization finished, #iter = 2946
# obj = -427.651059, rho = -0.435071
# nSV = 1055, nBSV = 0
# ..*.*
# optimization finished, #iter = 3419
# obj = -495.246184, rho = -0.345778
# nSV = 1125, nBSV = 0
# .*.*
# optimization finished, #iter = 1698
# obj = -353.697052, rho = -0.186903
# nSV = 733, nBSV = 0
# ..*.*
# optimization finished, #iter = 2682
# obj = -398.704762, rho = -0.083437
# nSV = 803, nBSV = 0
# ..*.*
# optimization finished, #iter = 2018
# obj = -329.321247, rho = 0.105105
# nSV = 666, nBSV = 0
# Total nSV = 1858
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   8.5s
# [LibSVM]..*.*
# optimization finished, #iter = 3849
# obj = -553.570175, rho = -0.272575
# nSV = 1196, nBSV = 0
# .*.*
# optimization finished, #iter = 2711
# obj = -427.253267, rho = -0.438563
# nSV = 1058, nBSV = 0
# ..*.*
# optimization finished, #iter = 3629
# obj = -496.099070, rho = -0.348096
# nSV = 1129, nBSV = 0
# .*.*
# optimization finished, #iter = 1971
# obj = -352.991787, rho = -0.188525
# nSV = 732, nBSV = 0
# ..*.*
# optimization finished, #iter = 2682
# obj = -398.704762, rho = -0.083437
# nSV = 803, nBSV = 0
# ..*.*
# optimization finished, #iter = 2139
# obj = -328.709704, rho = 0.106767
# nSV = 665, nBSV = 0
# Total nSV = 1861
# [CV] END .................................................... total time=   8.7s
# Training duration for PCA=2500, C=10, kernel=rbf, gamma=auto: 25.95921492576599 seconds
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
run_metrics = {}
run_params = {}

for run_id in run_ids:
    client = mlflow.tracking.MlflowClient(ML_FLOW_DIRECTORY)
    run = client.get_run(run_id)
    metrics = run.data.metrics
    params = run.data.params
    run_metrics[run_id] = metrics
    run_params[run_id] = params

for run_id in run_ids:
    print(f"Run ID: {run_id}")
    print("Metrics:")
    metrics = run_metrics[run_id]
    for metric, value in metrics.items():
        print(f"\t{metric}: {value}")

    print("Parameters:")
    params = run_params[run_id]
    for param, value in params.items():
        print(f"\t{param}: {value}")
# Out:
# Run ID: f856e8c263064e45ac219ac2bc96b068
# Metrics:
# 	mean_f1_weighted: 0.7865371424274419
# 	mean_accuracy: 0.7879113018597996
# 	mean_recall: 0.7879113018597996
# 	mean_precision: 0.786487178346798
# Parameters:
# 	gamma: scale
# 	pca_components: 1600
# 	C: 0.1
# 	kernel: linear
# Run ID: bb6176ebb1f94841b42290f781294d98
# Metrics:
# 	mean_f1_weighted: 0.7865371424274419
# 	mean_accuracy: 0.7879113018597996
# 	mean_recall: 0.7879113018597996
# 	mean_precision: 0.786487178346798
# Parameters:
# 	gamma: auto
# 	pca_components: 1600
# 	C: 0.1
# 	kernel: linear
# Run ID: a8e9c30929374c66a31e04b15b2ecee8
# Metrics:
# 	mean_f1_weighted: 0.6136776175878488
# 	mean_accuracy: 0.6133762517882689
# 	mean_recall: 0.6133762517882689
# 	mean_precision: 0.6202479873572102
# Parameters:
# 	gamma: scale
# 	pca_components: 1600
# 	C: 0.1
# 	kernel: rbf
# Run ID: 62b217cf3a1d4ecdbecd0b476e623635
# Metrics:
# 	mean_f1_weighted: 0.08033054698280266
# 	mean_accuracy: 0.22103004291845493
# 	mean_recall: 0.22103004291845493
# 	mean_precision: 0.04913288143086076
# Parameters:
# 	gamma: auto
# 	pca_components: 1600
# 	C: 0.1
# 	kernel: rbf
# Run ID: e28678a0a7974347aa023f6e9d3eedf3
# Metrics:
# 	mean_f1_weighted: 0.7865371424274419
# 	mean_accuracy: 0.7879113018597996
# 	mean_recall: 0.7879113018597996
# 	mean_precision: 0.786487178346798
# Parameters:
# 	gamma: scale
# 	pca_components: 1600
# 	C: 1
# 	kernel: linear
# Run ID: fa27627152d44feb85fccb95784adb0d
# Metrics:
# 	mean_f1_weighted: 0.7865371424274419
# 	mean_accuracy: 0.7879113018597996
# 	mean_recall: 0.7879113018597996
# 	mean_precision: 0.786487178346798
# Parameters:
# 	gamma: auto
# 	pca_components: 1600
# 	C: 1
# 	kernel: linear
# Run ID: df19739ff9b143559d1cf398ea0835b9
# Metrics:
# 	mean_f1_weighted: 0.8100680511382533
# 	mean_accuracy: 0.8125894134477826
# 	mean_recall: 0.8125894134477826
# 	mean_precision: 0.8097951673248476
# Parameters:
# 	gamma: scale
# 	pca_components: 1600
# 	C: 1
# 	kernel: rbf
# Run ID: 990f5b1d305d43d9b57d29ea603af79e
# Metrics:
# 	mean_f1_weighted: 0.23724622379702479
# 	mean_accuracy: 0.4087982832618026
# 	mean_recall: 0.4087982832618026
# 	mean_precision: 0.16711603639779696
# Parameters:
# 	gamma: auto
# 	pca_components: 1600
# 	C: 1
# 	kernel: rbf
# Run ID: 415d14ec1bcc4800a3fd24b969cab49b
# Metrics:
# 	mean_f1_weighted: 0.7865371424274419
# 	mean_accuracy: 0.7879113018597996
# 	mean_recall: 0.7879113018597996
# 	mean_precision: 0.786487178346798
# Parameters:
# 	gamma: scale
# 	pca_components: 1600
# 	C: 10
# 	kernel: linear
# Run ID: 9c694dbec19d4d18bfc451b310c58bd1
# Metrics:
# 	mean_f1_weighted: 0.7865371424274419
# 	mean_accuracy: 0.7879113018597996
# 	mean_recall: 0.7879113018597996
# 	mean_precision: 0.786487178346798
# Parameters:
# 	gamma: auto
# 	pca_components: 1600
# 	C: 10
# 	kernel: linear
# Run ID: bec0ec38b1ae410389b1c7a5a878422f
# Metrics:
# 	mean_f1_weighted: 0.8373405981420549
# 	mean_accuracy: 0.8386981402002861
# 	mean_recall: 0.8386981402002861
# 	mean_precision: 0.8365690019537823
# Parameters:
# 	gamma: scale
# 	pca_components: 1600
# 	C: 10
# 	kernel: rbf
# Run ID: d961b70a4c7e4c538789e2a3a16a3f99
# Metrics:
# 	mean_f1_weighted: 0.23724622379702479
# 	mean_accuracy: 0.4087982832618026
# 	mean_recall: 0.4087982832618026
# 	mean_precision: 0.16711603639779696
# Parameters:
# 	gamma: auto
# 	pca_components: 1600
# 	C: 10
# 	kernel: rbf
# Run ID: 47da99f3d5284b77bea9e75269494cef
# Metrics:
# 	mean_f1_weighted: 0.7959320843060681
# 	mean_accuracy: 0.7972103004291845
# 	mean_recall: 0.7972103004291845
# 	mean_precision: 0.7958838622270897
# Parameters:
# 	gamma: scale
# 	pca_components: 2025
# 	C: 0.1
# 	kernel: linear
# Run ID: 7bcb9252566445cbbdce4562904616b4
# Metrics:
# 	mean_f1_weighted: 0.7959320843060681
# 	mean_accuracy: 0.7972103004291845
# 	mean_recall: 0.7972103004291845
# 	mean_precision: 0.7958838622270897
# Parameters:
# 	gamma: auto
# 	pca_components: 2025
# 	C: 0.1
# 	kernel: linear
# Run ID: 7b4639037c564cd59204dcb58d87f4e2
# Metrics:
# 	mean_f1_weighted: 0.6140274868742179
# 	mean_accuracy: 0.6137339055793992
# 	mean_recall: 0.6137339055793992
# 	mean_precision: 0.6203766706752983
# Parameters:
# 	gamma: scale
# 	pca_components: 2025
# 	C: 0.1
# 	kernel: rbf
# Run ID: 114162471ff54a51845cbfb064742f39
# Metrics:
# 	mean_f1_weighted: 0.08033054698280266
# 	mean_accuracy: 0.22103004291845493
# 	mean_recall: 0.22103004291845493
# 	mean_precision: 0.04913288143086076
# Parameters:
# 	gamma: auto
# 	pca_components: 2025
# 	C: 0.1
# 	kernel: rbf
# Run ID: ebe705d0e9bb466ea8941c937173d863
# Metrics:
# 	mean_f1_weighted: 0.7959320843060681
# 	mean_accuracy: 0.7972103004291845
# 	mean_recall: 0.7972103004291845
# 	mean_precision: 0.7958838622270897
# Parameters:
# 	gamma: scale
# 	pca_components: 2025
# 	C: 1
# 	kernel: linear
# Run ID: 77abf23dac384d8cae65f71220a8a329
# Metrics:
# 	mean_f1_weighted: 0.7959320843060681
# 	mean_accuracy: 0.7972103004291845
# 	mean_recall: 0.7972103004291845
# 	mean_precision: 0.7958838622270897
# Parameters:
# 	gamma: auto
# 	pca_components: 2025
# 	C: 1
# 	kernel: linear
# Run ID: 643101a0600f401f85dc89371decb721
# Metrics:
# 	mean_f1_weighted: 0.8100680511382533
# 	mean_accuracy: 0.8125894134477826
# 	mean_recall: 0.8125894134477826
# 	mean_precision: 0.8097951673248476
# Parameters:
# 	gamma: scale
# 	pca_components: 2025
# 	C: 1
# 	kernel: rbf
# Run ID: 081a2f1d893f482e950a1b06313d81b4
# Metrics:
# 	mean_f1_weighted: 0.23724622379702479
# 	mean_accuracy: 0.4087982832618026
# 	mean_recall: 0.4087982832618026
# 	mean_precision: 0.16711603639779696
# Parameters:
# 	gamma: auto
# 	pca_components: 2025
# 	C: 1
# 	kernel: rbf
# Run ID: afb4805ecdd94d4b86d7da0c1f1f4ccf
# Metrics:
# 	mean_f1_weighted: 0.7959320843060681
# 	mean_accuracy: 0.7972103004291845
# 	mean_recall: 0.7972103004291845
# 	mean_precision: 0.7958838622270897
# Parameters:
# 	gamma: scale
# 	pca_components: 2025
# 	C: 10
# 	kernel: linear
# Run ID: c21ed47fdda64cbf830a16dae98a4fe6
# Metrics:
# 	mean_f1_weighted: 0.7959320843060681
# 	mean_accuracy: 0.7972103004291845
# 	mean_recall: 0.7972103004291845
# 	mean_precision: 0.7958838622270897
# Parameters:
# 	gamma: auto
# 	pca_components: 2025
# 	C: 10
# 	kernel: linear
# Run ID: 1994aa71633b41898d7a65b45659180e
# Metrics:
# 	mean_f1_weighted: 0.8376076489548224
# 	mean_accuracy: 0.8390557939914164
# 	mean_recall: 0.8390557939914164
# 	mean_precision: 0.8368479247103006
# Parameters:
# 	gamma: scale
# 	pca_components: 2025
# 	C: 10
# 	kernel: rbf
# Run ID: 886e1539a5d440bfb9f3cd41d3c1ae36
# Metrics:
# 	mean_f1_weighted: 0.23724622379702479
# 	mean_accuracy: 0.4087982832618026
# 	mean_recall: 0.4087982832618026
# 	mean_precision: 0.16711603639779696
# Parameters:
# 	gamma: auto
# 	pca_components: 2025
# 	C: 10
# 	kernel: rbf
# Run ID: 123fbfcb19954b35b3bf5584f391d49a
# Metrics:
# 	mean_f1_weighted: 0.8049952487599411
# 	mean_accuracy: 0.8065092989985695
# 	mean_recall: 0.8065092989985695
# 	mean_precision: 0.8051015848260729
# Parameters:
# 	gamma: scale
# 	pca_components: 2500
# 	C: 0.1
# 	kernel: linear
# Run ID: c537ac296ccb48ad8ce270fb10610cec
# Metrics:
# 	mean_f1_weighted: 0.8049952487599411
# 	mean_accuracy: 0.8065092989985695
# 	mean_recall: 0.8065092989985695
# 	mean_precision: 0.8051015848260729
# Parameters:
# 	gamma: auto
# 	pca_components: 2500
# 	C: 0.1
# 	kernel: linear
# Run ID: 44be7b12aa3d4eb3a840734443523aea
# Metrics:
# 	mean_f1_weighted: 0.6133458380095286
# 	mean_accuracy: 0.6130185979971388
# 	mean_recall: 0.6130185979971388
# 	mean_precision: 0.619591771626081
# Parameters:
# 	gamma: scale
# 	pca_components: 2500
# 	C: 0.1
# 	kernel: rbf
# Run ID: 708b1f675f604d3482777d9b94cac782
# Metrics:
# 	mean_f1_weighted: 0.08033054698280266
# 	mean_accuracy: 0.22103004291845493
# 	mean_recall: 0.22103004291845493
# 	mean_precision: 0.04913288143086076
# Parameters:
# 	gamma: auto
# 	pca_components: 2500
# 	C: 0.1
# 	kernel: rbf
# Run ID: 8a8d9a95153b450ab267bd90489426f0
# Metrics:
# 	mean_f1_weighted: 0.8049952487599411
# 	mean_accuracy: 0.8065092989985695
# 	mean_recall: 0.8065092989985695
# 	mean_precision: 0.8051015848260729
# Parameters:
# 	gamma: scale
# 	pca_components: 2500
# 	C: 1
# 	kernel: linear
# Run ID: c170a157f8fa48ac93459d7a47b3f370
# Metrics:
# 	mean_f1_weighted: 0.8049952487599411
# 	mean_accuracy: 0.8065092989985695
# 	mean_recall: 0.8065092989985695
# 	mean_precision: 0.8051015848260729
# Parameters:
# 	gamma: auto
# 	pca_components: 2500
# 	C: 1
# 	kernel: linear
# Run ID: 77aee0d6996149c9924237d2e9751a73
# Metrics:
# 	mean_f1_weighted: 0.8107774320868485
# 	mean_accuracy: 0.8133047210300429
# 	mean_recall: 0.8133047210300429
# 	mean_precision: 0.8104893664493921
# Parameters:
# 	gamma: scale
# 	pca_components: 2500
# 	C: 1
# 	kernel: rbf
# Run ID: e5f3361041614a4caaa6647350d11f52
# Metrics:
# 	mean_f1_weighted: 0.23724622379702479
# 	mean_accuracy: 0.4087982832618026
# 	mean_recall: 0.4087982832618026
# 	mean_precision: 0.16711603639779696
# Parameters:
# 	gamma: auto
# 	pca_components: 2500
# 	C: 1
# 	kernel: rbf
# Run ID: b0fefc299fea4314b22d1fb5359acfc0
# Metrics:
# 	mean_f1_weighted: 0.8049952487599411
# 	mean_accuracy: 0.8065092989985695
# 	mean_recall: 0.8065092989985695
# 	mean_precision: 0.8051015848260729
# Parameters:
# 	gamma: scale
# 	pca_components: 2500
# 	C: 10
# 	kernel: linear
# Run ID: 178ae0b320f64c09b328b967d52111ac
# Metrics:
# 	mean_f1_weighted: 0.8049952487599411
# 	mean_accuracy: 0.8065092989985695
# 	mean_recall: 0.8065092989985695
# 	mean_precision: 0.8051015848260729
# Parameters:
# 	gamma: auto
# 	pca_components: 2500
# 	C: 10
# 	kernel: linear
# Run ID: 6b0c4f4931744a80aaf140aa9454b3d7
# Metrics:
# 	mean_f1_weighted: 0.8375532254258272
# 	mean_accuracy: 0.8390557939914164
# 	mean_recall: 0.8390557939914164
# 	mean_precision: 0.8367832923504993
# Parameters:
# 	gamma: scale
# 	pca_components: 2500
# 	C: 10
# 	kernel: rbf
# Run ID: ab1211ac16b94ef6a1f2325fc99761f9
# Metrics:
# 	mean_f1_weighted: 0.23724622379702479
# 	mean_accuracy: 0.4087982832618026
# 	mean_recall: 0.4087982832618026
# 	mean_precision: 0.16711603639779696
# Parameters:
# 	gamma: auto
# 	pca_components: 2500
# 	C: 10
# 	kernel: rbf

# %%
best_run_id = max(run_metrics, key=lambda x: run_metrics[x]["mean_f1_weighted"])
best_run_params = run_params[best_run_id]
best_run_metrics = run_metrics[best_run_id]

print(f"\nBest Run ID: {best_run_id}")
print("Best Parameters:")
for key, value in best_run_params.items():
    print(f"\t{key}: {value}")

print("\nBest Run Metrics:")
for metric, value in best_run_metrics.items():
    print(f"\t{metric}: {value}")
# Out:
# Best Run ID: 1994aa71633b41898d7a65b45659180e
# Best Parameters:
# 	gamma: scale
# 	pca_components: 2025
# 	C: 10
# 	kernel: rbf
#
# Best Run Metrics:
# 	mean_f1_weighted: 0.8376076489548224
# 	mean_accuracy: 0.8390557939914164
# 	mean_recall: 0.8390557939914164
# 	mean_precision: 0.8368479247103006
