# %% [markdown]
# # SVM: Version 3
#
# ## SVM with PCA and Heuristic-Based color thresholding

# %%
import cv2
import os
import glob
import time
import mlflow
import shutil
import itertools

import numpy as np
import pandas as pd

from PIL import Image
from sklearn.decomposition import PCA
from sklearn import svm
from sklearn.model_selection import cross_validate, StratifiedKFold
from sklearn.metrics import (
    make_scorer,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
)

# %%
TRAIN_DIR = "../data/train"
CLASS_FOLDERS = ["Class A", "Class B", "Class C", "Class D"]
ML_FLOW_DIRECTORY = "SVM_Logs"

# %%
mlflow.set_tracking_uri(ML_FLOW_DIRECTORY)
mlflow.set_experiment("SVM_PCA_heuristic_color_thresholding")
# Out:
# 2023/12/07 00:20:39 INFO mlflow.tracking.fluent: Experiment with name 'SVM_PCA_heuristic_color_thresholding' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/Users/jacob/Code/Monkey-Business/SVM/SVM_Logs/725068244323799849', creation_time=1701930039088, experiment_id='725068244323799849', last_update_time=1701930039088, lifecycle_stage='active', name='SVM_PCA_heuristic_color_thresholding', tags={}>

# %%
pca_components = [40 * 40, 45 * 45, 50 * 50]
C_values = [0.1, 1, 10]
kernel_types = ["linear", "rbf"]
gamma_values = ["scale", "auto"]

# %%
hyperparameter_combinations = list(
    itertools.product(pca_components, C_values, kernel_types, gamma_values)
)
print(
    f"Total number of hyperparameter combinations: {len(hyperparameter_combinations)}"
)
# Out:
# Total number of hyperparameter combinations: 36

# %%
pca_models_dict = {}

# %%
def train_with_params(pca_components, C, kernel, gamma, train_images, train_labels):
    # Check if PCA model for pca_components already exists
    if pca_components in pca_models_dict:
        pca = pca_models_dict[pca_components]
        print(f"Using existing PCA model for {pca_components} components")
    else:
        # Apply PCA
        pca = PCA(n_components=pca_components)
        pca.fit(train_images)
        pca_models_dict[pca_components] = pca

    # Transform images with PCA
    train_images_pca = pca.transform(train_images)

    with mlflow.start_run() as run:
        start_time = time.time()

        # Initialize SVM model
        svm_model = svm.SVC(
            C=C, kernel=kernel, gamma=gamma, class_weight="balanced", verbose=True
        )

        # Perform cross-validation
        skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
        scoring = {
            "f1_weighted": make_scorer(f1_score, average="weighted"),
            "accuracy": "accuracy",
            "precision": make_scorer(precision_score, average="weighted"),
            "recall": make_scorer(recall_score, average="weighted"),
        }
        cv_results = cross_validate(
            svm_model,
            train_images_pca,
            train_labels,
            cv=skf,
            scoring=scoring,
            verbose=2,
        )

        # Log hyperparameters and metrics
        mlflow.log_params(
            {"pca_components": pca_components, "C": C, "kernel": kernel, "gamma": gamma}
        )
        mlflow.log_metrics(
            {
                "mean_f1_weighted": cv_results["test_f1_weighted"].mean(),
                "mean_accuracy": cv_results["test_accuracy"].mean(),
                "mean_precision": cv_results["test_precision"].mean(),
                "mean_recall": cv_results["test_recall"].mean(),
            }
        )
        end_time = time.time()
        duration = end_time - start_time
        param_details = f"PCA={pca_components}, C={C}, kernel={kernel}, gamma={gamma}"
        duration_details = f"Training duration for {param_details}: {duration} seconds"
        print(duration_details)
        run_id = run.info.run_id
        return run_id

# %%
def load_image(img_path):
    img = Image.open(img_path)
    img = img.resize((224, 224))
    img = np.array(img)
    img = img.astype("float32") / 255.0
    return img

# %%
def heuristic_color_thresholding(image_path):
    lower_yellow = np.array([20, 100, 100])
    upper_yellow = np.array([40, 255, 255])
    lower_green = np.array([40, 40, 40])
    upper_green = np.array([80, 255, 255])
    lower_brown = np.array([10, 60, 60])
    upper_brown = np.array([30, 255, 200])

    image = cv2.imread(image_path)
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mask_yellow = cv2.inRange(hsv, lower_yellow, upper_yellow)
    mask_green = cv2.inRange(hsv, lower_green, upper_green)
    mask_brown = cv2.inRange(hsv, lower_brown, upper_brown)
    final_mask = cv2.bitwise_or(mask_yellow, mask_green)
    final_mask = cv2.bitwise_or(final_mask, mask_brown)
    result = cv2.bitwise_and(image, image, mask=final_mask)

    return result

# %%
def load_images_from_folder(folder):
    images = []
    labels = []
    for class_folder in CLASS_FOLDERS:
        start_time = time.time()
        class_path = os.path.join(folder, class_folder)
        image_files = glob.glob(os.path.join(class_path, "*.png"))
        for img_file in image_files:
            processed_image = heuristic_color_thresholding(img_file)
            flattened_image = processed_image.flatten()
            images.append(flattened_image)
            labels.append(class_folder)
        end_time = time.time()
        duration = end_time - start_time
        print(f"Processing {class_folder} took {duration} seconds")
    return np.array(images), np.array(labels)

# %%
train_images, train_labels = load_images_from_folder(TRAIN_DIR)
# Out:
# Processing Class A took 1.8958618640899658 seconds
# Processing Class B took 1.0603289604187012 seconds
# Processing Class C took 0.7121992111206055 seconds
# Processing Class D took 0.8621330261230469 seconds

# %%
print(
    f"Shape of train_images: {train_images.shape}, Shape of train_labels: {train_labels.shape}"
)
# Out:
# Shape of train_images: (2796, 150528), Shape of train_labels: (2796,)

# %%
run_ids = []

for params in hyperparameter_combinations:
    pca_components, C, kernel, gamma = params
    run_id = train_with_params(
        pca_components, C, kernel, gamma, train_images, train_labels
    )
    run_ids.append(run_id)
# Out:
# [LibSVM]...*..*
# optimization finished, #iter = 5460
# obj = -0.000005, rho = 0.793179
# nSV = 429, nBSV = 0
# *.*
# optimization finished, #iter = 1198
# obj = -0.000001, rho = -0.252242
# nSV = 210, nBSV = 0
# .*
# optimization finished, #iter = 1866
# obj = -0.000001, rho = -0.202404
# nSV = 268, nBSV = 0
# ....*.*
# optimization finished, #iter = 4303
# obj = -0.000002, rho = -0.945566
# nSV = 388, nBSV = 0
# ...*.*
# optimization finished, #iter = 3580
# obj = -0.000002, rho = -0.817248
# nSV = 391, nBSV = 0
# ...*.*
# optimization finished, #iter = 3313
# obj = -0.000002, rho = -0.057044
# nSV = 378, nBSV = 0
# Total nSV = 1200
# [CV] END .................................................... total time=   2.6s
# [LibSVM]...*..*
# optimization finished, #iter = 5067
# obj = -0.000004, rho = 0.698972
# nSV = 428, nBSV = 0
# *.*
# optimization finished, #iter = 1268
# obj = -0.000000, rho = -0.257093
# nSV = 225, nBSV = 0
# .*
# optimization finished, #iter = 1903
# obj = -0.000001, rho = -0.379932
# nSV = 291, nBSV = 0
# ...*.*
# optimization finished, #iter = 3461
# obj = -0.000002, rho = -0.907973
# nSV = 366, nBSV = 0
# ..*..*
# optimization finished, #iter = 3332
# obj = -0.000002, rho = -0.791502
# nSV = 362, nBSV = 0
# ...*.*
# optimization finished, #iter = 3099
# obj = -0.000002, rho = 0.009760
# nSV = 367, nBSV = 0
# Total nSV = 1190
# [CV] END .................................................... total time=   2.5s
# [LibSVM]...*.*
# optimization finished, #iter = 4488
# obj = -0.000004, rho = 0.971557
# nSV = 421, nBSV = 0
# *.*
# optimization finished, #iter = 1281
# obj = -0.000001, rho = -0.158096
# nSV = 230, nBSV = 0
# .*
# optimization finished, #iter = 1723
# obj = -0.000001, rho = -0.257482
# nSV = 264, nBSV = 0
# ...*..*
# optimization finished, #iter = 3766
# obj = -0.000002, rho = -0.962174
# nSV = 379, nBSV = 0
# ...*.*
# optimization finished, #iter = 3801
# obj = -0.000002, rho = -0.810280
# nSV = 391, nBSV = 0
# ...*.*
# optimization finished, #iter = 3235
# obj = -0.000002, rho = -0.114219
# nSV = 387, nBSV = 0
# Total nSV = 1185
# [CV] END .................................................... total time=   2.5s
# Training duration for PCA=1600, C=0.1, kernel=linear, gamma=scale: 7.643505811691284 seconds
# Using existing PCA model for 1600 components
# [LibSVM]...*..*
# optimization finished, #iter = 5460
# obj = -0.000005, rho = 0.793179
# nSV = 429, nBSV = 0
# *.*
# optimization finished, #iter = 1198
# obj = -0.000001, rho = -0.252242
# nSV = 210, nBSV = 0
# .*
# optimization finished, #iter = 1866
# obj = -0.000001, rho = -0.202404
# nSV = 268, nBSV = 0
# ....*.*
# optimization finished, #iter = 4303
# obj = -0.000002, rho = -0.945566
# nSV = 388, nBSV = 0
# ...*.*
# optimization finished, #iter = 3580
# obj = -0.000002, rho = -0.817248
# nSV = 391, nBSV = 0
# ...*.*
# optimization finished, #iter = 3313
# obj = -0.000002, rho = -0.057044
# nSV = 378, nBSV = 0
# Total nSV = 1200
# [CV] END .................................................... total time=   2.5s
# [LibSVM]...*..*
# optimization finished, #iter = 5067
# obj = -0.000004, rho = 0.698972
# nSV = 428, nBSV = 0
# *.*
# optimization finished, #iter = 1268
# obj = -0.000000, rho = -0.257093
# nSV = 225, nBSV = 0
# .*
# optimization finished, #iter = 1903
# obj = -0.000001, rho = -0.379932
# nSV = 291, nBSV = 0
# ...*.*
# optimization finished, #iter = 3461
# obj = -0.000002, rho = -0.907973
# nSV = 366, nBSV = 0
# ..*..*
# optimization finished, #iter = 3332
# obj = -0.000002, rho = -0.791502
# nSV = 362, nBSV = 0
# ...*.*
# optimization finished, #iter = 3099
# obj = -0.000002, rho = 0.009760
# nSV = 367, nBSV = 0
# Total nSV = 1190
# [CV] END .................................................... total time=   2.4s
# [LibSVM]...*.*
# optimization finished, #iter = 4488
# obj = -0.000004, rho = 0.971557
# nSV = 421, nBSV = 0
# *.*
# optimization finished, #iter = 1281
# obj = -0.000001, rho = -0.158096
# nSV = 230, nBSV = 0
# .*
# optimization finished, #iter = 1723
# obj = -0.000001, rho = -0.257482
# nSV = 264, nBSV = 0
# ...*..*
# optimization finished, #iter = 3766
# obj = -0.000002, rho = -0.962174
# nSV = 379, nBSV = 0
# ...*.*
# optimization finished, #iter = 3801
# obj = -0.000002, rho = -0.810280
# nSV = 391, nBSV = 0
# ...*.*
# optimization finished, #iter = 3235
# obj = -0.000002, rho = -0.114219
# nSV = 387, nBSV = 0
# Total nSV = 1185
# [CV] END .................................................... total time=   2.4s
# Training duration for PCA=1600, C=0.1, kernel=linear, gamma=auto: 7.262310028076172 seconds
# Using existing PCA model for 1600 components
# [LibSVM].*
# optimization finished, #iter = 1055
# obj = -63.145499, rho = 0.869980
# nSV = 962, nBSV = 865
# *
# optimization finished, #iter = 632
# obj = -35.833822, rho = 0.744571
# nSV = 565, nBSV = 512
# *
# optimization finished, #iter = 904
# obj = -51.915046, rho = 0.958435
# nSV = 811, nBSV = 755
# *
# optimization finished, #iter = 658
# obj = -65.726811, rho = 0.526652
# nSV = 617, nBSV = 569
# *
# optimization finished, #iter = 797
# obj = -78.175725, rho = 0.433037
# nSV = 783, nBSV = 765
# *
# optimization finished, #iter = 630
# obj = -69.961737, rho = -0.167666
# nSV = 599, nBSV = 573
# Total nSV = 1694
# [CV] END .................................................... total time=   4.7s
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1069
# obj = -63.502465, rho = 0.876026
# nSV = 969, nBSV = 857
# *
# optimization finished, #iter = 619
# obj = -34.791261, rho = 0.861630
# nSV = 553, nBSV = 505
# *
# optimization finished, #iter = 873
# obj = -50.011703, rho = 1.025732
# nSV = 785, nBSV = 729
# *
# optimization finished, #iter = 644
# obj = -63.648105, rho = 0.616456
# nSV = 603, nBSV = 566
# *
# optimization finished, #iter = 793
# obj = -73.999418, rho = 0.556259
# nSV = 758, nBSV = 730
# *
# optimization finished, #iter = 639
# obj = -69.381017, rho = -0.080817
# nSV = 612, nBSV = 588
# Total nSV = 1693
# [CV] END .................................................... total time=   4.7s
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1064
# obj = -64.671281, rho = 0.814987
# nSV = 991, nBSV = 883
# *
# optimization finished, #iter = 624
# obj = -35.882650, rho = 0.757301
# nSV = 563, nBSV = 514
# *
# optimization finished, #iter = 887
# obj = -50.094906, rho = 0.909268
# nSV = 795, nBSV = 730
# *
# optimization finished, #iter = 654
# obj = -63.173934, rho = 0.616697
# nSV = 597, nBSV = 548
# *
# optimization finished, #iter = 790
# obj = -74.632875, rho = 0.569079
# nSV = 753, nBSV = 724
# *
# optimization finished, #iter = 642
# obj = -70.531521, rho = -0.083894
# nSV = 613, nBSV = 586
# Total nSV = 1706
# [CV] END .................................................... total time=   4.7s
# Training duration for PCA=1600, C=0.1, kernel=rbf, gamma=scale: 14.158001899719238 seconds
# Using existing PCA model for 1600 components
# [LibSVM].*
# optimization finished, #iter = 1195
# obj = -89.262075, rho = -0.877690
# nSV = 1196, nBSV = 1195
# .*
# optimization finished, #iter = 1059
# obj = -88.095862, rho = 0.687248
# nSV = 1060, nBSV = 1059
# .*
# optimization finished, #iter = 1130
# obj = -88.829332, rho = 0.874054
# nSV = 1132, nBSV = 1130
# *
# optimization finished, #iter = 731
# obj = -87.030192, rho = 0.687248
# nSV = 732, nBSV = 731
# *
# optimization finished, #iter = 802
# obj = -87.763662, rho = 0.874054
# nSV = 804, nBSV = 802
# *
# optimization finished, #iter = 667
# obj = -86.597449, rho = 0.874054
# nSV = 668, nBSV = 667
# Total nSV = 1864
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   5.7s
# [LibSVM].*
# optimization finished, #iter = 1194
# obj = -89.260346, rho = 0.892874
# nSV = 1197, nBSV = 1194
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1058
# obj = -88.112835, rho = 0.843624
# nSV = 1060, nBSV = 762
# .*
# optimization finished, #iter = 1130
# obj = -88.797951, rho = 0.747425
# nSV = 1131, nBSV = 1130
# *
# optimization finished, #iter = 732
# obj = -87.060397, rho = -0.892874
# nSV = 733, nBSV = 732
# *
# optimization finished, #iter = 803
# obj = -87.745512, rho = -0.892874
# nSV = 804, nBSV = 803
# *
# optimization finished, #iter = 666
# obj = -86.598001, rho = -0.843624
# nSV = 667, nBSV = 666
# Total nSV = 1864
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   5.7s
# [LibSVM].*
# optimization finished, #iter = 1196
# obj = -89.275306, rho = 0.892874
# nSV = 1197, nBSV = 1196
# .*
# optimization finished, #iter = 1059
# obj = -88.103341, rho = 0.687248
# nSV = 1060, nBSV = 1059
# .*
# optimization finished, #iter = 1130
# obj = -88.812910, rho = 0.747425
# nSV = 1131, nBSV = 1130
# *
# optimization finished, #iter = 732
# obj = -87.035944, rho = -0.892874
# nSV = 733, nBSV = 732
# *
# optimization finished, #iter = 803
# obj = -87.745512, rho = -0.892874
# nSV = 804, nBSV = 803
# *
# optimization finished, #iter = 666
# obj = -86.573548, rho = -0.687248
# nSV = 667, nBSV = 666
# Total nSV = 1864
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   5.6s
# Training duration for PCA=1600, C=0.1, kernel=rbf, gamma=auto: 16.971483945846558 seconds
# Using existing PCA model for 1600 components
# [LibSVM]...*..*
# optimization finished, #iter = 5460
# obj = -0.000005, rho = 0.793179
# nSV = 429, nBSV = 0
# *.*
# optimization finished, #iter = 1198
# obj = -0.000001, rho = -0.252242
# nSV = 210, nBSV = 0
# .*
# optimization finished, #iter = 1866
# obj = -0.000001, rho = -0.202404
# nSV = 268, nBSV = 0
# ....*.*
# optimization finished, #iter = 4303
# obj = -0.000002, rho = -0.945566
# nSV = 388, nBSV = 0
# ...*.*
# optimization finished, #iter = 3580
# obj = -0.000002, rho = -0.817248
# nSV = 391, nBSV = 0
# ...*.*
# optimization finished, #iter = 3313
# obj = -0.000002, rho = -0.057044
# nSV = 378, nBSV = 0
# Total nSV = 1200
# [CV] END .................................................... total time=   2.5s
# [LibSVM]...*..*
# optimization finished, #iter = 5067
# obj = -0.000004, rho = 0.698972
# nSV = 428, nBSV = 0
# *.*
# optimization finished, #iter = 1268
# obj = -0.000000, rho = -0.257093
# nSV = 225, nBSV = 0
# .*
# optimization finished, #iter = 1903
# obj = -0.000001, rho = -0.379932
# nSV = 291, nBSV = 0
# ...*.*
# optimization finished, #iter = 3461
# obj = -0.000002, rho = -0.907973
# nSV = 366, nBSV = 0
# ..*..*
# optimization finished, #iter = 3332
# obj = -0.000002, rho = -0.791502
# nSV = 362, nBSV = 0
# ...*.*
# optimization finished, #iter = 3099
# obj = -0.000002, rho = 0.009760
# nSV = 367, nBSV = 0
# Total nSV = 1190
# [CV] END .................................................... total time=   2.5s
# [LibSVM]...*.*
# optimization finished, #iter = 4488
# obj = -0.000004, rho = 0.971557
# nSV = 421, nBSV = 0
# *.*
# optimization finished, #iter = 1281
# obj = -0.000001, rho = -0.158096
# nSV = 230, nBSV = 0
# .*
# optimization finished, #iter = 1723
# obj = -0.000001, rho = -0.257482
# nSV = 264, nBSV = 0
# ...*..*
# optimization finished, #iter = 3766
# obj = -0.000002, rho = -0.962174
# nSV = 379, nBSV = 0
# ...*.*
# optimization finished, #iter = 3801
# obj = -0.000002, rho = -0.810280
# nSV = 391, nBSV = 0
# ...*.*
# optimization finished, #iter = 3235
# obj = -0.000002, rho = -0.114219
# nSV = 387, nBSV = 0
# Total nSV = 1185
# [CV] END .................................................... total time=   2.4s
# Training duration for PCA=1600, C=1, kernel=linear, gamma=scale: 7.349045753479004 seconds
# Using existing PCA model for 1600 components
# [LibSVM]...*..*
# optimization finished, #iter = 5460
# obj = -0.000005, rho = 0.793179
# nSV = 429, nBSV = 0
# *.*
# optimization finished, #iter = 1198
# obj = -0.000001, rho = -0.252242
# nSV = 210, nBSV = 0
# .*
# optimization finished, #iter = 1866
# obj = -0.000001, rho = -0.202404
# nSV = 268, nBSV = 0
# ....*.*
# optimization finished, #iter = 4303
# obj = -0.000002, rho = -0.945566
# nSV = 388, nBSV = 0
# ...*.*
# optimization finished, #iter = 3580
# obj = -0.000002, rho = -0.817248
# nSV = 391, nBSV = 0
# ...*.*
# optimization finished, #iter = 3313
# obj = -0.000002, rho = -0.057044
# nSV = 378, nBSV = 0
# Total nSV = 1200
# [CV] END .................................................... total time=   2.5s
# [LibSVM]...*..*
# optimization finished, #iter = 5067
# obj = -0.000004, rho = 0.698972
# nSV = 428, nBSV = 0
# *.*
# optimization finished, #iter = 1268
# obj = -0.000000, rho = -0.257093
# nSV = 225, nBSV = 0
# .*
# optimization finished, #iter = 1903
# obj = -0.000001, rho = -0.379932
# nSV = 291, nBSV = 0
# ...*.*
# optimization finished, #iter = 3461
# obj = -0.000002, rho = -0.907973
# nSV = 366, nBSV = 0
# ..*..*
# optimization finished, #iter = 3332
# obj = -0.000002, rho = -0.791502
# nSV = 362, nBSV = 0
# ...*.*
# optimization finished, #iter = 3099
# obj = -0.000002, rho = 0.009760
# nSV = 367, nBSV = 0
# Total nSV = 1190
# [CV] END .................................................... total time=   2.4s
# [LibSVM]...*.*
# optimization finished, #iter = 4488
# obj = -0.000004, rho = 0.971557
# nSV = 421, nBSV = 0
# *.*
# optimization finished, #iter = 1281
# obj = -0.000001, rho = -0.158096
# nSV = 230, nBSV = 0
# .*
# optimization finished, #iter = 1723
# obj = -0.000001, rho = -0.257482
# nSV = 264, nBSV = 0
# ...*..*
# optimization finished, #iter = 3766
# obj = -0.000002, rho = -0.962174
# nSV = 379, nBSV = 0
# ...*.*
# optimization finished, #iter = 3801
# obj = -0.000002, rho = -0.810280
# nSV = 391, nBSV = 0
# ...*.*
# optimization finished, #iter = 3235
# obj = -0.000002, rho = -0.114219
# nSV = 387, nBSV = 0
# Total nSV = 1185
# [CV] END .................................................... total time=   2.4s
# Training duration for PCA=1600, C=1, kernel=linear, gamma=auto: 7.299662828445435 seconds
# Using existing PCA model for 1600 components
# [LibSVM]*.*
# optimization finished, #iter = 1205
# obj = -348.273470, rho = 0.591570
# nSV = 883, nBSV = 404
# *
# optimization finished, #iter = 735
# obj = -128.934609, rho = 0.306970
# nSV = 472, nBSV = 114
# *.*
# optimization finished, #iter = 1010
# obj = -201.115676, rho = 0.579155
# nSV = 648, nBSV = 209
# .*
# optimization finished, #iter = 1033
# obj = -298.111474, rho = -0.127196
# nSV = 620, nBSV = 95
# .*
# optimization finished, #iter = 1179
# obj = -325.806093, rho = 0.129168
# nSV = 710, nBSV = 125
# .*
# optimization finished, #iter = 978
# obj = -271.983807, rho = 0.153624
# nSV = 577, nBSV = 132
# Total nSV = 1616
# [CV] END .................................................... total time=   4.3s
# [LibSVM]*.*
# optimization finished, #iter = 1153
# obj = -346.620084, rho = 0.562038
# nSV = 869, nBSV = 442
# *
# optimization finished, #iter = 705
# obj = -119.197952, rho = 0.404378
# nSV = 445, nBSV = 110
# *
# optimization finished, #iter = 984
# obj = -194.851017, rho = 0.633640
# nSV = 631, nBSV = 221
# .*
# optimization finished, #iter = 1033
# obj = -272.411234, rho = 0.010829
# nSV = 604, nBSV = 86
# .*
# optimization finished, #iter = 1185
# obj = -316.986438, rho = 0.246143
# nSV = 706, nBSV = 118
# .*
# optimization finished, #iter = 983
# obj = -255.187675, rho = 0.100596
# nSV = 566, nBSV = 113
# Total nSV = 1602
# [CV] END .................................................... total time=   4.2s
# [LibSVM]*.*
# optimization finished, #iter = 1125
# obj = -346.464165, rho = 0.540509
# nSV = 851, nBSV = 445
# *
# optimization finished, #iter = 762
# obj = -125.899279, rho = 0.353277
# nSV = 475, nBSV = 111
# *.*
# optimization finished, #iter = 1003
# obj = -189.783062, rho = 0.528923
# nSV = 639, nBSV = 202
# .*
# optimization finished, #iter = 1017
# obj = -293.226337, rho = -0.010637
# nSV = 612, nBSV = 105
# .*
# optimization finished, #iter = 1164
# obj = -325.776639, rho = 0.171856
# nSV = 710, nBSV = 133
# .*
# optimization finished, #iter = 1008
# obj = -269.498571, rho = 0.123635
# nSV = 578, nBSV = 132
# Total nSV = 1597
# [CV] END .................................................... total time=   4.2s
# Training duration for PCA=1600, C=1, kernel=rbf, gamma=scale: 12.810351133346558 seconds
# Using existing PCA model for 1600 components
# [LibSVM].*
# optimization finished, #iter = 1567
# obj = -538.338707, rho = -0.071694
# nSV = 1196, nBSV = 758
# .*.*
# optimization finished, #iter = 2673
# obj = -426.937500, rho = -0.437500
# nSV = 1056, nBSV = 0
# .*
# optimization finished, #iter = 1625
# obj = -495.279631, rho = -0.255576
# nSV = 1132, nBSV = 756
# .*
# optimization finished, #iter = 1319
# obj = -352.662079, rho = -0.187415
# nSV = 731, nBSV = 0
# ..*.*
# optimization finished, #iter = 2422
# obj = -399.452710, rho = -0.079602
# nSV = 804, nBSV = 0
# ..*
# optimization finished, #iter = 1434
# obj = -329.505226, rho = 0.109445
# nSV = 667, nBSV = 0
# Total nSV = 1863
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   5.6s
# [LibSVM].*
# optimization finished, #iter = 1666
# obj = -538.248782, rho = -0.067917
# nSV = 1197, nBSV = 752
# .*.*
# optimization finished, #iter = 2733
# obj = -427.651130, rho = -0.435071
# nSV = 1055, nBSV = 0
# .*
# optimization finished, #iter = 1543
# obj = -493.181068, rho = -0.259741
# nSV = 1130, nBSV = 752
# .*.*
# optimization finished, #iter = 1698
# obj = -353.697052, rho = -0.186903
# nSV = 733, nBSV = 0
# ..*.*
# optimization finished, #iter = 2674
# obj = -398.704789, rho = -0.083437
# nSV = 803, nBSV = 0
# ..*.*
# optimization finished, #iter = 2018
# obj = -329.321247, rho = 0.105105
# nSV = 666, nBSV = 0
# Total nSV = 1863
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   5.6s
# [LibSVM].*
# optimization finished, #iter = 1492
# obj = -539.573810, rho = -0.070589
# nSV = 1197, nBSV = 760
# ..*
# optimization finished, #iter = 2463
# obj = -427.253254, rho = -0.438563
# nSV = 1058, nBSV = 0
# .*
# optimization finished, #iter = 1691
# obj = -494.124509, rho = -0.389316
# nSV = 1130, nBSV = 521
# .*.*
# optimization finished, #iter = 1971
# obj = -352.991787, rho = -0.188525
# nSV = 732, nBSV = 0
# ..*.*
# optimization finished, #iter = 2674
# obj = -398.704789, rho = -0.083437
# nSV = 803, nBSV = 0
# ..*.*
# optimization finished, #iter = 2139
# obj = -328.709704, rho = 0.106767
# nSV = 665, nBSV = 0
# Total nSV = 1863
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   5.6s
# Training duration for PCA=1600, C=1, kernel=rbf, gamma=auto: 16.874788761138916 seconds
# Using existing PCA model for 1600 components
# [LibSVM]...*..*
# optimization finished, #iter = 5460
# obj = -0.000005, rho = 0.793179
# nSV = 429, nBSV = 0
# *.*
# optimization finished, #iter = 1198
# obj = -0.000001, rho = -0.252242
# nSV = 210, nBSV = 0
# .*
# optimization finished, #iter = 1866
# obj = -0.000001, rho = -0.202404
# nSV = 268, nBSV = 0
# ....*.*
# optimization finished, #iter = 4303
# obj = -0.000002, rho = -0.945566
# nSV = 388, nBSV = 0
# ...*.*
# optimization finished, #iter = 3580
# obj = -0.000002, rho = -0.817248
# nSV = 391, nBSV = 0
# ...*.*
# optimization finished, #iter = 3313
# obj = -0.000002, rho = -0.057044
# nSV = 378, nBSV = 0
# Total nSV = 1200
# [CV] END .................................................... total time=   2.5s
# [LibSVM]...*..*
# optimization finished, #iter = 5067
# obj = -0.000004, rho = 0.698972
# nSV = 428, nBSV = 0
# *.*
# optimization finished, #iter = 1268
# obj = -0.000000, rho = -0.257093
# nSV = 225, nBSV = 0
# .*
# optimization finished, #iter = 1903
# obj = -0.000001, rho = -0.379932
# nSV = 291, nBSV = 0
# ...*.*
# optimization finished, #iter = 3461
# obj = -0.000002, rho = -0.907973
# nSV = 366, nBSV = 0
# ..*..*
# optimization finished, #iter = 3332
# obj = -0.000002, rho = -0.791502
# nSV = 362, nBSV = 0
# ...*.*
# optimization finished, #iter = 3099
# obj = -0.000002, rho = 0.009760
# nSV = 367, nBSV = 0
# Total nSV = 1190
# [CV] END .................................................... total time=   2.4s
# [LibSVM]...*.*
# optimization finished, #iter = 4488
# obj = -0.000004, rho = 0.971557
# nSV = 421, nBSV = 0
# *.*
# optimization finished, #iter = 1281
# obj = -0.000001, rho = -0.158096
# nSV = 230, nBSV = 0
# .*
# optimization finished, #iter = 1723
# obj = -0.000001, rho = -0.257482
# nSV = 264, nBSV = 0
# ...*..*
# optimization finished, #iter = 3766
# obj = -0.000002, rho = -0.962174
# nSV = 379, nBSV = 0
# ...*.*
# optimization finished, #iter = 3801
# obj = -0.000002, rho = -0.810280
# nSV = 391, nBSV = 0
# ...*.*
# optimization finished, #iter = 3235
# obj = -0.000002, rho = -0.114219
# nSV = 387, nBSV = 0
# Total nSV = 1185
# [CV] END .................................................... total time=   2.4s
# Training duration for PCA=1600, C=10, kernel=linear, gamma=scale: 7.2930169105529785 seconds
# Using existing PCA model for 1600 components
# [LibSVM]...*..*
# optimization finished, #iter = 5460
# obj = -0.000005, rho = 0.793179
# nSV = 429, nBSV = 0
# *.*
# optimization finished, #iter = 1198
# obj = -0.000001, rho = -0.252242
# nSV = 210, nBSV = 0
# .*
# optimization finished, #iter = 1866
# obj = -0.000001, rho = -0.202404
# nSV = 268, nBSV = 0
# ....*.*
# optimization finished, #iter = 4303
# obj = -0.000002, rho = -0.945566
# nSV = 388, nBSV = 0
# ...*.*
# optimization finished, #iter = 3580
# obj = -0.000002, rho = -0.817248
# nSV = 391, nBSV = 0
# ...*.*
# optimization finished, #iter = 3313
# obj = -0.000002, rho = -0.057044
# nSV = 378, nBSV = 0
# Total nSV = 1200
# [CV] END .................................................... total time=   2.4s
# [LibSVM]...*..*
# optimization finished, #iter = 5067
# obj = -0.000004, rho = 0.698972
# nSV = 428, nBSV = 0
# *.*
# optimization finished, #iter = 1268
# obj = -0.000000, rho = -0.257093
# nSV = 225, nBSV = 0
# .*
# optimization finished, #iter = 1903
# obj = -0.000001, rho = -0.379932
# nSV = 291, nBSV = 0
# ...*.*
# optimization finished, #iter = 3461
# obj = -0.000002, rho = -0.907973
# nSV = 366, nBSV = 0
# ..*..*
# optimization finished, #iter = 3332
# obj = -0.000002, rho = -0.791502
# nSV = 362, nBSV = 0
# ...*.*
# optimization finished, #iter = 3099
# obj = -0.000002, rho = 0.009760
# nSV = 367, nBSV = 0
# Total nSV = 1190
# [CV] END .................................................... total time=   2.5s
# [LibSVM]...*.*
# optimization finished, #iter = 4488
# obj = -0.000004, rho = 0.971557
# nSV = 421, nBSV = 0
# *.*
# optimization finished, #iter = 1281
# obj = -0.000001, rho = -0.158096
# nSV = 230, nBSV = 0
# .*
# optimization finished, #iter = 1723
# obj = -0.000001, rho = -0.257482
# nSV = 264, nBSV = 0
# ...*..*
# optimization finished, #iter = 3766
# obj = -0.000002, rho = -0.962174
# nSV = 379, nBSV = 0
# ...*.*
# optimization finished, #iter = 3801
# obj = -0.000002, rho = -0.810280
# nSV = 391, nBSV = 0
# ...*.*
# optimization finished, #iter = 3235
# obj = -0.000002, rho = -0.114219
# nSV = 387, nBSV = 0
# Total nSV = 1185
# [CV] END .................................................... total time=   2.4s
# Training duration for PCA=1600, C=10, kernel=linear, gamma=auto: 7.34001612663269 seconds
# Using existing PCA model for 1600 components
# [LibSVM].*.*
# optimization finished, #iter = 2240
# obj = -646.436666, rho = 0.554634
# nSV = 843, nBSV = 16
# *.*
# optimization finished, #iter = 1020
# obj = -163.796359, rho = 0.116948
# nSV = 483, nBSV = 3
# *.*
# optimization finished, #iter = 1314
# obj = -306.908488, rho = 0.368077
# nSV = 577, nBSV = 10
# .*
# optimization finished, #iter = 1431
# obj = -403.545294, rho = -0.223879
# nSV = 629, nBSV = 1
# .*.*
# optimization finished, #iter = 1609
# obj = -429.709036, rho = 0.080307
# nSV = 694, nBSV = 0
# .*
# optimization finished, #iter = 1245
# obj = -319.872460, rho = 0.220803
# nSV = 579, nBSV = 1
# Total nSV = 1571
# [CV] END .................................................... total time=   4.7s
# [LibSVM].*.*
# optimization finished, #iter = 2034
# obj = -646.479388, rho = 0.454687
# nSV = 771, nBSV = 20
# *
# optimization finished, #iter = 974
# obj = -149.484842, rho = 0.176764
# nSV = 487, nBSV = 0
# *.*
# optimization finished, #iter = 1184
# obj = -293.389348, rho = 0.497073
# nSV = 559, nBSV = 13
# .*
# optimization finished, #iter = 1376
# obj = -335.911212, rho = -0.096701
# nSV = 610, nBSV = 0
# .*
# optimization finished, #iter = 1570
# obj = -437.683754, rho = 0.189332
# nSV = 689, nBSV = 0
# .*
# optimization finished, #iter = 1221
# obj = -297.825411, rho = 0.174527
# nSV = 568, nBSV = 0
# Total nSV = 1529
# [CV] END .................................................... total time=   4.3s
# [LibSVM].*.*
# optimization finished, #iter = 2104
# obj = -621.481015, rho = 0.465442
# nSV = 790, nBSV = 17
# *.*
# optimization finished, #iter = 1011
# obj = -159.114310, rho = 0.157697
# nSV = 479, nBSV = 2
# *.*
# optimization finished, #iter = 1265
# obj = -293.972601, rho = 0.378344
# nSV = 569, nBSV = 14
# .*
# optimization finished, #iter = 1443
# obj = -375.600026, rho = -0.067730
# nSV = 626, nBSV = 1
# .*
# optimization finished, #iter = 1569
# obj = -443.192602, rho = 0.110342
# nSV = 684, nBSV = 0
# .*
# optimization finished, #iter = 1253
# obj = -307.956736, rho = 0.172623
# nSV = 583, nBSV = 0
# Total nSV = 1540
# [CV] END .................................................... total time=   4.4s
# Training duration for PCA=1600, C=10, kernel=rbf, gamma=scale: 13.416416883468628 seconds
# Using existing PCA model for 1600 components
# [LibSVM]..*.*
# optimization finished, #iter = 3945
# obj = -552.231328, rho = -0.272422
# nSV = 1193, nBSV = 0
# .*
# optimization finished, #iter = 1683
# obj = -426.937500, rho = -0.437500
# nSV = 1056, nBSV = 0
# ..*.*
# optimization finished, #iter = 3261
# obj = -497.484421, rho = -0.344553
# nSV = 1129, nBSV = 0
# .*
# optimization finished, #iter = 1319
# obj = -352.662079, rho = -0.187415
# nSV = 731, nBSV = 0
# ..*.*
# optimization finished, #iter = 2422
# obj = -399.452641, rho = -0.079602
# nSV = 804, nBSV = 0
# ..*
# optimization finished, #iter = 1434
# obj = -329.505226, rho = 0.109445
# nSV = 667, nBSV = 0
# Total nSV = 1860
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   5.7s
# [LibSVM]..*.*
# optimization finished, #iter = 3801
# obj = -552.508255, rho = -0.270134
# nSV = 1192, nBSV = 0
# .*.*
# optimization finished, #iter = 2946
# obj = -427.651059, rho = -0.435071
# nSV = 1055, nBSV = 0
# ..*.*
# optimization finished, #iter = 3419
# obj = -495.246184, rho = -0.345778
# nSV = 1125, nBSV = 0
# .*.*
# optimization finished, #iter = 1698
# obj = -353.697052, rho = -0.186903
# nSV = 733, nBSV = 0
# ..*.*
# optimization finished, #iter = 2682
# obj = -398.704762, rho = -0.083437
# nSV = 803, nBSV = 0
# ..*.*
# optimization finished, #iter = 2018
# obj = -329.321247, rho = 0.105105
# nSV = 666, nBSV = 0
# Total nSV = 1858
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   5.7s
# [LibSVM]..*.*
# optimization finished, #iter = 3849
# obj = -553.570175, rho = -0.272575
# nSV = 1196, nBSV = 0
# .*.*
# optimization finished, #iter = 2711
# obj = -427.253267, rho = -0.438563
# nSV = 1058, nBSV = 0
# ..*.*
# optimization finished, #iter = 3629
# obj = -496.099070, rho = -0.348096
# nSV = 1129, nBSV = 0
# .*.*
# optimization finished, #iter = 1971
# obj = -352.991787, rho = -0.188525
# nSV = 732, nBSV = 0
# ..*.*
# optimization finished, #iter = 2682
# obj = -398.704762, rho = -0.083437
# nSV = 803, nBSV = 0
# ..*.*
# optimization finished, #iter = 2139
# obj = -328.709704, rho = 0.106767
# nSV = 665, nBSV = 0
# Total nSV = 1861
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   5.5s
# Training duration for PCA=1600, C=10, kernel=rbf, gamma=auto: 16.944263219833374 seconds
# [LibSVM]..*..*
# optimization finished, #iter = 4316
# obj = -0.000003, rho = 0.682827
# nSV = 494, nBSV = 0
# *.*
# optimization finished, #iter = 1099
# obj = -0.000000, rho = -0.245354
# nSV = 233, nBSV = 0
# .*
# optimization finished, #iter = 1692
# obj = -0.000001, rho = -0.195550
# nSV = 310, nBSV = 0
# ...*.*
# optimization finished, #iter = 3169
# obj = -0.000002, rho = -0.841212
# nSV = 427, nBSV = 0
# ..*.*
# optimization finished, #iter = 2960
# obj = -0.000002, rho = -0.705133
# nSV = 456, nBSV = 0
# ..*.*
# optimization finished, #iter = 2512
# obj = -0.000001, rho = 0.029997
# nSV = 418, nBSV = 0
# Total nSV = 1284
# [CV] END .................................................... total time=   3.6s
# [LibSVM]..*.*
# optimization finished, #iter = 3616
# obj = -0.000003, rho = 0.589701
# nSV = 475, nBSV = 0
# *.*
# optimization finished, #iter = 1132
# obj = -0.000000, rho = -0.247659
# nSV = 259, nBSV = 0
# .*
# optimization finished, #iter = 1597
# obj = -0.000001, rho = -0.316204
# nSV = 322, nBSV = 0
# ..*.*
# optimization finished, #iter = 2677
# obj = -0.000001, rho = -0.820629
# nSV = 404, nBSV = 0
# ..*.*
# optimization finished, #iter = 2936
# obj = -0.000002, rho = -0.670329
# nSV = 409, nBSV = 0
# ..*.*
# optimization finished, #iter = 2611
# obj = -0.000001, rho = 0.048090
# nSV = 409, nBSV = 0
# Total nSV = 1269
# [CV] END .................................................... total time=   3.4s
# [LibSVM]..*.*
# optimization finished, #iter = 3546
# obj = -0.000003, rho = 0.805158
# nSV = 454, nBSV = 0
# *.*
# optimization finished, #iter = 1118
# obj = -0.000000, rho = -0.157387
# nSV = 252, nBSV = 0
# .*
# optimization finished, #iter = 1492
# obj = -0.000001, rho = -0.208499
# nSV = 308, nBSV = 0
# ..*..*
# optimization finished, #iter = 2994
# obj = -0.000002, rho = -0.879520
# nSV = 424, nBSV = 0
# ..*.*
# optimization finished, #iter = 3031
# obj = -0.000002, rho = -0.697672
# nSV = 434, nBSV = 0
# ..*..*
# optimization finished, #iter = 2729
# obj = -0.000001, rho = -0.037001
# nSV = 419, nBSV = 0
# Total nSV = 1252
# [CV] END .................................................... total time=   3.4s
# Training duration for PCA=2025, C=0.1, kernel=linear, gamma=scale: 10.38563084602356 seconds
# Using existing PCA model for 2025 components
# [LibSVM]..*..*
# optimization finished, #iter = 4316
# obj = -0.000003, rho = 0.682827
# nSV = 494, nBSV = 0
# *.*
# optimization finished, #iter = 1099
# obj = -0.000000, rho = -0.245354
# nSV = 233, nBSV = 0
# .*
# optimization finished, #iter = 1692
# obj = -0.000001, rho = -0.195550
# nSV = 310, nBSV = 0
# ...*.*
# optimization finished, #iter = 3169
# obj = -0.000002, rho = -0.841212
# nSV = 427, nBSV = 0
# ..*.*
# optimization finished, #iter = 2960
# obj = -0.000002, rho = -0.705133
# nSV = 456, nBSV = 0
# ..*.*
# optimization finished, #iter = 2512
# obj = -0.000001, rho = 0.029997
# nSV = 418, nBSV = 0
# Total nSV = 1284
# [CV] END .................................................... total time=   3.6s
# [LibSVM]..*.*
# optimization finished, #iter = 3616
# obj = -0.000003, rho = 0.589701
# nSV = 475, nBSV = 0
# *.*
# optimization finished, #iter = 1132
# obj = -0.000000, rho = -0.247659
# nSV = 259, nBSV = 0
# .*
# optimization finished, #iter = 1597
# obj = -0.000001, rho = -0.316204
# nSV = 322, nBSV = 0
# ..*.*
# optimization finished, #iter = 2677
# obj = -0.000001, rho = -0.820629
# nSV = 404, nBSV = 0
# ..*.*
# optimization finished, #iter = 2936
# obj = -0.000002, rho = -0.670329
# nSV = 409, nBSV = 0
# ..*.*
# optimization finished, #iter = 2611
# obj = -0.000001, rho = 0.048090
# nSV = 409, nBSV = 0
# Total nSV = 1269
# [CV] END .................................................... total time=   3.4s
# [LibSVM]..*.*
# optimization finished, #iter = 3546
# obj = -0.000003, rho = 0.805158
# nSV = 454, nBSV = 0
# *.*
# optimization finished, #iter = 1118
# obj = -0.000000, rho = -0.157387
# nSV = 252, nBSV = 0
# .*
# optimization finished, #iter = 1492
# obj = -0.000001, rho = -0.208499
# nSV = 308, nBSV = 0
# ..*..*
# optimization finished, #iter = 2994
# obj = -0.000002, rho = -0.879520
# nSV = 424, nBSV = 0
# ..*.*
# optimization finished, #iter = 3031
# obj = -0.000002, rho = -0.697672
# nSV = 434, nBSV = 0
# ..*..*
# optimization finished, #iter = 2729
# obj = -0.000001, rho = -0.037001
# nSV = 419, nBSV = 0
# Total nSV = 1252
# [CV] END .................................................... total time=   3.3s
# Training duration for PCA=2025, C=0.1, kernel=linear, gamma=auto: 10.318043947219849 seconds
# Using existing PCA model for 2025 components
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1073
# obj = -63.473721, rho = 0.861561
# nSV = 968, nBSV = 852
# *
# optimization finished, #iter = 635
# obj = -36.041973, rho = 0.753524
# nSV = 574, nBSV = 518
# *
# optimization finished, #iter = 907
# obj = -52.410762, rho = 0.960825
# nSV = 822, nBSV = 760
# *
# optimization finished, #iter = 670
# obj = -65.903467, rho = 0.525570
# nSV = 625, nBSV = 572
# *
# optimization finished, #iter = 801
# obj = -78.541011, rho = 0.411100
# nSV = 788, nBSV = 771
# *
# optimization finished, #iter = 632
# obj = -70.116796, rho = -0.181555
# nSV = 606, nBSV = 574
# Total nSV = 1698
# [CV] END .................................................... total time=   6.2s
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1078
# obj = -63.848421, rho = 0.875644
# nSV = 978, nBSV = 845
# *
# optimization finished, #iter = 621
# obj = -35.079820, rho = 0.870232
# nSV = 561, nBSV = 505
# *
# optimization finished, #iter = 883
# obj = -50.573590, rho = 1.027592
# nSV = 792, nBSV = 740
# *
# optimization finished, #iter = 656
# obj = -63.943512, rho = 0.603995
# nSV = 611, nBSV = 566
# *
# optimization finished, #iter = 796
# obj = -74.400112, rho = 0.523635
# nSV = 765, nBSV = 733
# *
# optimization finished, #iter = 637
# obj = -69.593577, rho = -0.084602
# nSV = 612, nBSV = 590
# Total nSV = 1699
# [CV] END .................................................... total time=   6.2s
# [LibSVM].
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1080
# obj = -64.992105, rho = 0.806917
# nSV = 994, nBSV = 862
# *
# optimization finished, #iter = 626
# obj = -36.094465, rho = 0.761483
# nSV = 567, nBSV = 514
# *
# optimization finished, #iter = 923
# obj = -50.577175, rho = 0.907720
# nSV = 808, nBSV = 734
# *
# optimization finished, #iter = 667
# obj = -63.416649, rho = 0.604046
# nSV = 604, nBSV = 549
# *
# optimization finished, #iter = 798
# obj = -75.005894, rho = 0.542055
# nSV = 759, nBSV = 727
# *
# optimization finished, #iter = 638
# obj = -70.726048, rho = -0.087862
# nSV = 614, nBSV = 587
# Total nSV = 1705
# [CV] END .................................................... total time=   6.1s
# Training duration for PCA=2025, C=0.1, kernel=rbf, gamma=scale: 18.442875862121582 seconds
# Using existing PCA model for 2025 components
# [LibSVM].*
# optimization finished, #iter = 1195
# obj = -89.262075, rho = -0.877690
# nSV = 1196, nBSV = 1195
# .*
# optimization finished, #iter = 1059
# obj = -88.095862, rho = 0.687248
# nSV = 1060, nBSV = 1059
# .*
# optimization finished, #iter = 1130
# obj = -88.829332, rho = 0.874054
# nSV = 1132, nBSV = 1130
# *
# optimization finished, #iter = 731
# obj = -87.030192, rho = 0.687248
# nSV = 732, nBSV = 731
# *
# optimization finished, #iter = 802
# obj = -87.763662, rho = 0.874054
# nSV = 804, nBSV = 802
# *
# optimization finished, #iter = 667
# obj = -86.597449, rho = 0.874054
# nSV = 668, nBSV = 667
# Total nSV = 1864
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   7.2s
# [LibSVM].*
# optimization finished, #iter = 1194
# obj = -89.260346, rho = 0.892874
# nSV = 1197, nBSV = 1194
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1058
# obj = -88.112835, rho = 0.843624
# nSV = 1060, nBSV = 762
# .*
# optimization finished, #iter = 1130
# obj = -88.797951, rho = 0.747425
# nSV = 1131, nBSV = 1130
# *
# optimization finished, #iter = 732
# obj = -87.060397, rho = -0.892874
# nSV = 733, nBSV = 732
# *
# optimization finished, #iter = 803
# obj = -87.745512, rho = -0.892874
# nSV = 804, nBSV = 803
# *
# optimization finished, #iter = 666
# obj = -86.598001, rho = -0.843624
# nSV = 667, nBSV = 666
# Total nSV = 1864
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   7.1s
# [LibSVM].*
# optimization finished, #iter = 1196
# obj = -89.275306, rho = 0.892874
# nSV = 1197, nBSV = 1196
# .*
# optimization finished, #iter = 1059
# obj = -88.103341, rho = 0.687248
# nSV = 1060, nBSV = 1059
# .*
# optimization finished, #iter = 1130
# obj = -88.812910, rho = 0.747425
# nSV = 1131, nBSV = 1130
# *
# optimization finished, #iter = 732
# obj = -87.035944, rho = -0.892874
# nSV = 733, nBSV = 732
# *
# optimization finished, #iter = 803
# obj = -87.745512, rho = -0.892874
# nSV = 804, nBSV = 803
# *
# optimization finished, #iter = 666
# obj = -86.573548, rho = -0.687248
# nSV = 667, nBSV = 666
# Total nSV = 1864
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   7.1s
# Training duration for PCA=2025, C=0.1, kernel=rbf, gamma=auto: 21.433531999588013 seconds
# Using existing PCA model for 2025 components
# [LibSVM]..*..*
# optimization finished, #iter = 4316
# obj = -0.000003, rho = 0.682827
# nSV = 494, nBSV = 0
# *.*
# optimization finished, #iter = 1099
# obj = -0.000000, rho = -0.245354
# nSV = 233, nBSV = 0
# .*
# optimization finished, #iter = 1692
# obj = -0.000001, rho = -0.195550
# nSV = 310, nBSV = 0
# ...*.*
# optimization finished, #iter = 3169
# obj = -0.000002, rho = -0.841212
# nSV = 427, nBSV = 0
# ..*.*
# optimization finished, #iter = 2960
# obj = -0.000002, rho = -0.705133
# nSV = 456, nBSV = 0
# ..*.*
# optimization finished, #iter = 2512
# obj = -0.000001, rho = 0.029997
# nSV = 418, nBSV = 0
# Total nSV = 1284
# [CV] END .................................................... total time=   3.6s
# [LibSVM]..*.*
# optimization finished, #iter = 3616
# obj = -0.000003, rho = 0.589701
# nSV = 475, nBSV = 0
# *.*
# optimization finished, #iter = 1132
# obj = -0.000000, rho = -0.247659
# nSV = 259, nBSV = 0
# .*
# optimization finished, #iter = 1597
# obj = -0.000001, rho = -0.316204
# nSV = 322, nBSV = 0
# ..*.*
# optimization finished, #iter = 2677
# obj = -0.000001, rho = -0.820629
# nSV = 404, nBSV = 0
# ..*.*
# optimization finished, #iter = 2936
# obj = -0.000002, rho = -0.670329
# nSV = 409, nBSV = 0
# ..*.*
# optimization finished, #iter = 2611
# obj = -0.000001, rho = 0.048090
# nSV = 409, nBSV = 0
# Total nSV = 1269
# [CV] END .................................................... total time=   3.5s
# [LibSVM]..*.*
# optimization finished, #iter = 3546
# obj = -0.000003, rho = 0.805158
# nSV = 454, nBSV = 0
# *.*
# optimization finished, #iter = 1118
# obj = -0.000000, rho = -0.157387
# nSV = 252, nBSV = 0
# .*
# optimization finished, #iter = 1492
# obj = -0.000001, rho = -0.208499
# nSV = 308, nBSV = 0
# ..*..*
# optimization finished, #iter = 2994
# obj = -0.000002, rho = -0.879520
# nSV = 424, nBSV = 0
# ..*.*
# optimization finished, #iter = 3031
# obj = -0.000002, rho = -0.697672
# nSV = 434, nBSV = 0
# ..*..*
# optimization finished, #iter = 2729
# obj = -0.000001, rho = -0.037001
# nSV = 419, nBSV = 0
# Total nSV = 1252
# [CV] END .................................................... total time=   3.4s
# Training duration for PCA=2025, C=1, kernel=linear, gamma=scale: 10.516963005065918 seconds
# Using existing PCA model for 2025 components
# [LibSVM]..*..*
# optimization finished, #iter = 4316
# obj = -0.000003, rho = 0.682827
# nSV = 494, nBSV = 0
# *.*
# optimization finished, #iter = 1099
# obj = -0.000000, rho = -0.245354
# nSV = 233, nBSV = 0
# .*
# optimization finished, #iter = 1692
# obj = -0.000001, rho = -0.195550
# nSV = 310, nBSV = 0
# ...*.*
# optimization finished, #iter = 3169
# obj = -0.000002, rho = -0.841212
# nSV = 427, nBSV = 0
# ..*.*
# optimization finished, #iter = 2960
# obj = -0.000002, rho = -0.705133
# nSV = 456, nBSV = 0
# ..*.*
# optimization finished, #iter = 2512
# obj = -0.000001, rho = 0.029997
# nSV = 418, nBSV = 0
# Total nSV = 1284
# [CV] END .................................................... total time=   3.6s
# [LibSVM]..*.*
# optimization finished, #iter = 3616
# obj = -0.000003, rho = 0.589701
# nSV = 475, nBSV = 0
# *.*
# optimization finished, #iter = 1132
# obj = -0.000000, rho = -0.247659
# nSV = 259, nBSV = 0
# .*
# optimization finished, #iter = 1597
# obj = -0.000001, rho = -0.316204
# nSV = 322, nBSV = 0
# ..*.*
# optimization finished, #iter = 2677
# obj = -0.000001, rho = -0.820629
# nSV = 404, nBSV = 0
# ..*.*
# optimization finished, #iter = 2936
# obj = -0.000002, rho = -0.670329
# nSV = 409, nBSV = 0
# ..*.*
# optimization finished, #iter = 2611
# obj = -0.000001, rho = 0.048090
# nSV = 409, nBSV = 0
# Total nSV = 1269
# [CV] END .................................................... total time=   3.5s
# [LibSVM]..*.*
# optimization finished, #iter = 3546
# obj = -0.000003, rho = 0.805158
# nSV = 454, nBSV = 0
# *.*
# optimization finished, #iter = 1118
# obj = -0.000000, rho = -0.157387
# nSV = 252, nBSV = 0
# .*
# optimization finished, #iter = 1492
# obj = -0.000001, rho = -0.208499
# nSV = 308, nBSV = 0
# ..*..*
# optimization finished, #iter = 2994
# obj = -0.000002, rho = -0.879520
# nSV = 424, nBSV = 0
# ..*.*
# optimization finished, #iter = 3031
# obj = -0.000002, rho = -0.697672
# nSV = 434, nBSV = 0
# ..*..*
# optimization finished, #iter = 2729
# obj = -0.000001, rho = -0.037001
# nSV = 419, nBSV = 0
# Total nSV = 1252
# [CV] END .................................................... total time=   3.5s
# Training duration for PCA=2025, C=1, kernel=linear, gamma=auto: 10.527465105056763 seconds
# Using existing PCA model for 2025 components
# [LibSVM]*.*
# optimization finished, #iter = 1199
# obj = -346.314526, rho = 0.647535
# nSV = 893, nBSV = 397
# *
# optimization finished, #iter = 762
# obj = -128.715615, rho = 0.333164
# nSV = 490, nBSV = 114
# *.*
# optimization finished, #iter = 1019
# obj = -201.195928, rho = 0.616089
# nSV = 662, nBSV = 206
# .*
# optimization finished, #iter = 1088
# obj = -295.865526, rho = -0.113204
# nSV = 638, nBSV = 88
# .*
# optimization finished, #iter = 1156
# obj = -324.791504, rho = 0.130643
# nSV = 722, nBSV = 119
# .*
# optimization finished, #iter = 1007
# obj = -269.658500, rho = 0.147939
# nSV = 587, nBSV = 128
# Total nSV = 1633
# [CV] END .................................................... total time=   5.6s
# [LibSVM]*.*
# optimization finished, #iter = 1147
# obj = -344.523084, rho = 0.642650
# nSV = 867, nBSV = 431
# *
# optimization finished, #iter = 697
# obj = -119.465169, rho = 0.421314
# nSV = 458, nBSV = 110
# *
# optimization finished, #iter = 948
# obj = -195.438305, rho = 0.670601
# nSV = 635, nBSV = 219
# .*
# optimization finished, #iter = 1048
# obj = -271.663054, rho = 0.014488
# nSV = 617, nBSV = 85
# .*
# optimization finished, #iter = 1198
# obj = -315.530906, rho = 0.240318
# nSV = 725, nBSV = 113
# .*
# optimization finished, #iter = 980
# obj = -253.902993, rho = 0.102177
# nSV = 571, nBSV = 108
# Total nSV = 1605
# [CV] END .................................................... total time=   5.4s
# [LibSVM]*.*
# optimization finished, #iter = 1150
# obj = -344.712181, rho = 0.588843
# nSV = 868, nBSV = 439
# *
# optimization finished, #iter = 763
# obj = -126.038278, rho = 0.378865
# nSV = 490, nBSV = 109
# *.*
# optimization finished, #iter = 1024
# obj = -190.668993, rho = 0.557527
# nSV = 654, nBSV = 197
# .*
# optimization finished, #iter = 1065
# obj = -291.712561, rho = 0.002060
# nSV = 629, nBSV = 103
# .*
# optimization finished, #iter = 1191
# obj = -324.761845, rho = 0.176355
# nSV = 728, nBSV = 126
# .*
# optimization finished, #iter = 1004
# obj = -268.038628, rho = 0.118698
# nSV = 588, nBSV = 124
# Total nSV = 1613
# [CV] END .................................................... total time=   5.5s
# Training duration for PCA=2025, C=1, kernel=rbf, gamma=scale: 16.492382049560547 seconds
# Using existing PCA model for 2025 components
# [LibSVM].*
# optimization finished, #iter = 1567
# obj = -538.338707, rho = -0.071694
# nSV = 1196, nBSV = 758
# .*.*
# optimization finished, #iter = 2673
# obj = -426.937500, rho = -0.437500
# nSV = 1056, nBSV = 0
# .*
# optimization finished, #iter = 1625
# obj = -495.279631, rho = -0.255576
# nSV = 1132, nBSV = 756
# .*
# optimization finished, #iter = 1319
# obj = -352.662079, rho = -0.187415
# nSV = 731, nBSV = 0
# ..*.*
# optimization finished, #iter = 2422
# obj = -399.452710, rho = -0.079602
# nSV = 804, nBSV = 0
# ..*
# optimization finished, #iter = 1434
# obj = -329.505226, rho = 0.109445
# nSV = 667, nBSV = 0
# Total nSV = 1863
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   7.2s
# [LibSVM].*
# optimization finished, #iter = 1666
# obj = -538.248782, rho = -0.067917
# nSV = 1197, nBSV = 752
# .*.*
# optimization finished, #iter = 2733
# obj = -427.651130, rho = -0.435071
# nSV = 1055, nBSV = 0
# .*
# optimization finished, #iter = 1543
# obj = -493.181068, rho = -0.259741
# nSV = 1130, nBSV = 752
# .*.*
# optimization finished, #iter = 1698
# obj = -353.697052, rho = -0.186903
# nSV = 733, nBSV = 0
# ..*.*
# optimization finished, #iter = 2674
# obj = -398.704789, rho = -0.083437
# nSV = 803, nBSV = 0
# ..*.*
# optimization finished, #iter = 2018
# obj = -329.321247, rho = 0.105105
# nSV = 666, nBSV = 0
# Total nSV = 1863
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   7.0s
# [LibSVM].*
# optimization finished, #iter = 1492
# obj = -539.573810, rho = -0.070589
# nSV = 1197, nBSV = 760
# ..*
# optimization finished, #iter = 2463
# obj = -427.253254, rho = -0.438563
# nSV = 1058, nBSV = 0
# .*
# optimization finished, #iter = 1691
# obj = -494.124509, rho = -0.389316
# nSV = 1130, nBSV = 521
# .*.*
# optimization finished, #iter = 1971
# obj = -352.991787, rho = -0.188525
# nSV = 732, nBSV = 0
# ..*.*
# optimization finished, #iter = 2674
# obj = -398.704789, rho = -0.083437
# nSV = 803, nBSV = 0
# ..*.*
# ...
# obj = -0.000001, rho = 0.111206
# nSV = 444, nBSV = 0
# Total nSV = 1354
# [CV] END .................................................... total time=   4.6s
# [LibSVM]..*.*
# optimization finished, #iter = 3011
# obj = -0.000002, rho = 0.677138
# nSV = 534, nBSV = 0
# *.*
# optimization finished, #iter = 1032
# obj = -0.000000, rho = -0.157667
# nSV = 295, nBSV = 0
# .*
# optimization finished, #iter = 1464
# obj = -0.000001, rho = -0.162948
# nSV = 361, nBSV = 0
# ..*.*
# optimization finished, #iter = 2536
# obj = -0.000001, rho = -0.783067
# nSV = 473, nBSV = 0
# ..*.*
# optimization finished, #iter = 2657
# obj = -0.000002, rho = -0.653947
# nSV = 501, nBSV = 0
# ..*.*
# optimization finished, #iter = 2185
# obj = -0.000001, rho = 0.016671
# nSV = 468, nBSV = 0
# Total nSV = 1356
# [CV] END .................................................... total time=   4.5s
# Training duration for PCA=2500, C=1, kernel=linear, gamma=auto: 13.751309633255005 seconds
# Using existing PCA model for 2500 components
# [LibSVM]*.*
# optimization finished, #iter = 1194
# obj = -344.754122, rho = 0.703995
# nSV = 898, nBSV = 396
# *
# optimization finished, #iter = 749
# obj = -127.846602, rho = 0.360464
# nSV = 493, nBSV = 116
# *.*
# optimization finished, #iter = 1006
# obj = -200.219430, rho = 0.675045
# nSV = 671, nBSV = 206
# .*
# optimization finished, #iter = 1055
# obj = -294.069628, rho = -0.095417
# nSV = 650, nBSV = 87
# .*
# optimization finished, #iter = 1171
# obj = -323.769754, rho = 0.148957
# nSV = 736, nBSV = 117
# .*
# optimization finished, #iter = 996
# obj = -267.898242, rho = 0.142674
# nSV = 600, nBSV = 122
# Total nSV = 1643
# [CV] END .................................................... total time=   6.9s
# [LibSVM]*.*
# optimization finished, #iter = 1107
# obj = -342.516885, rho = 0.711049
# nSV = 876, nBSV = 425
# *
# optimization finished, #iter = 718
# obj = -118.887249, rho = 0.454461
# nSV = 465, nBSV = 109
# *
# optimization finished, #iter = 942
# obj = -194.394761, rho = 0.731732
# nSV = 644, nBSV = 216
# .*
# optimization finished, #iter = 1059
# obj = -270.260314, rho = 0.046802
# nSV = 629, nBSV = 83
# .*
# optimization finished, #iter = 1218
# obj = -313.657154, rho = 0.272602
# nSV = 732, nBSV = 111
# .*
# optimization finished, #iter = 982
# obj = -252.075207, rho = 0.087082
# nSV = 583, nBSV = 104
# Total nSV = 1613
# [CV] END .................................................... total time=   6.6s
# [LibSVM]*.*
# optimization finished, #iter = 1130
# obj = -343.052310, rho = 0.661321
# nSV = 878, nBSV = 435
# *
# optimization finished, #iter = 760
# obj = -125.145559, rho = 0.418744
# nSV = 493, nBSV = 113
# *.*
# optimization finished, #iter = 1014
# obj = -189.950428, rho = 0.622564
# nSV = 664, nBSV = 197
# .*
# optimization finished, #iter = 1018
# obj = -290.007108, rho = 0.024043
# nSV = 644, nBSV = 99
# .*
# optimization finished, #iter = 1185
# obj = -323.809437, rho = 0.205105
# nSV = 738, nBSV = 123
# .*
# optimization finished, #iter = 1024
# obj = -266.176350, rho = 0.111626
# nSV = 598, nBSV = 120
# Total nSV = 1619
# [CV] END .................................................... total time=   6.7s
# Training duration for PCA=2500, C=1, kernel=rbf, gamma=scale: 20.123727083206177 seconds
# Using existing PCA model for 2500 components
# [LibSVM].*
# optimization finished, #iter = 1567
# obj = -538.338707, rho = -0.071694
# nSV = 1196, nBSV = 758
# .*.*
# optimization finished, #iter = 2673
# obj = -426.937500, rho = -0.437500
# nSV = 1056, nBSV = 0
# .*
# optimization finished, #iter = 1625
# obj = -495.279631, rho = -0.255576
# nSV = 1132, nBSV = 756
# .*
# optimization finished, #iter = 1319
# obj = -352.662079, rho = -0.187415
# nSV = 731, nBSV = 0
# ..*.*
# optimization finished, #iter = 2422
# obj = -399.452710, rho = -0.079602
# nSV = 804, nBSV = 0
# ..*
# optimization finished, #iter = 1434
# obj = -329.505226, rho = 0.109445
# nSV = 667, nBSV = 0
# Total nSV = 1863
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   8.7s
# [LibSVM].*
# optimization finished, #iter = 1666
# obj = -538.248782, rho = -0.067917
# nSV = 1197, nBSV = 752
# .*.*
# optimization finished, #iter = 2733
# obj = -427.651130, rho = -0.435071
# nSV = 1055, nBSV = 0
# .*
# optimization finished, #iter = 1543
# obj = -493.181068, rho = -0.259741
# nSV = 1130, nBSV = 752
# .*.*
# optimization finished, #iter = 1698
# obj = -353.697052, rho = -0.186903
# nSV = 733, nBSV = 0
# ..*.*
# optimization finished, #iter = 2674
# obj = -398.704789, rho = -0.083437
# nSV = 803, nBSV = 0
# ..*.*
# optimization finished, #iter = 2018
# obj = -329.321247, rho = 0.105105
# nSV = 666, nBSV = 0
# Total nSV = 1863
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   8.7s
# [LibSVM].*
# optimization finished, #iter = 1492
# obj = -539.573810, rho = -0.070589
# nSV = 1197, nBSV = 760
# ..*
# optimization finished, #iter = 2463
# obj = -427.253254, rho = -0.438563
# nSV = 1058, nBSV = 0
# .*
# optimization finished, #iter = 1691
# obj = -494.124509, rho = -0.389316
# nSV = 1130, nBSV = 521
# .*.*
# optimization finished, #iter = 1971
# obj = -352.991787, rho = -0.188525
# nSV = 732, nBSV = 0
# ..*.*
# optimization finished, #iter = 2674
# obj = -398.704789, rho = -0.083437
# nSV = 803, nBSV = 0
# ..*.*
# optimization finished, #iter = 2139
# obj = -328.709704, rho = 0.106767
# nSV = 665, nBSV = 0
# Total nSV = 1863
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   8.6s
# Training duration for PCA=2500, C=1, kernel=rbf, gamma=auto: 26.03443717956543 seconds
# Using existing PCA model for 2500 components
# [LibSVM]..*.*
# optimization finished, #iter = 3207
# obj = -0.000002, rho = 0.606467
# nSV = 551, nBSV = 0
# *.*
# optimization finished, #iter = 1016
# obj = -0.000000, rho = -0.232999
# nSV = 288, nBSV = 0
# .*
# optimization finished, #iter = 1506
# obj = -0.000001, rho = -0.156949
# nSV = 368, nBSV = 0
# ...*
# optimization finished, #iter = 2843
# obj = -0.000001, rho = -0.765990
# nSV = 495, nBSV = 0
# ..*.*
# optimization finished, #iter = 2506
# obj = -0.000001, rho = -0.645169
# nSV = 514, nBSV = 0
# ..*.*
# optimization finished, #iter = 2101
# obj = -0.000001, rho = 0.073528
# nSV = 453, nBSV = 0
# Total nSV = 1382
# [CV] END .................................................... total time=   4.7s
# [LibSVM]..*.*
# optimization finished, #iter = 3100
# obj = -0.000002, rho = 0.524276
# nSV = 542, nBSV = 0
# *.*
# optimization finished, #iter = 1060
# obj = -0.000000, rho = -0.257520
# nSV = 303, nBSV = 0
# .*
# optimization finished, #iter = 1602
# obj = -0.000001, rho = -0.240842
# nSV = 392, nBSV = 0
# ..*.*
# optimization finished, #iter = 2345
# obj = -0.000001, rho = -0.760955
# nSV = 453, nBSV = 0
# ..*.*
# optimization finished, #iter = 2502
# obj = -0.000001, rho = -0.604934
# nSV = 479, nBSV = 0
# ..*.*
# optimization finished, #iter = 2228
# obj = -0.000001, rho = 0.111206
# nSV = 444, nBSV = 0
# Total nSV = 1354
# [CV] END .................................................... total time=   4.5s
# [LibSVM]..*.*
# optimization finished, #iter = 3011
# obj = -0.000002, rho = 0.677138
# nSV = 534, nBSV = 0
# *.*
# optimization finished, #iter = 1032
# obj = -0.000000, rho = -0.157667
# nSV = 295, nBSV = 0
# .*
# optimization finished, #iter = 1464
# obj = -0.000001, rho = -0.162948
# nSV = 361, nBSV = 0
# ..*.*
# optimization finished, #iter = 2536
# obj = -0.000001, rho = -0.783067
# nSV = 473, nBSV = 0
# ..*.*
# optimization finished, #iter = 2657
# obj = -0.000002, rho = -0.653947
# nSV = 501, nBSV = 0
# ..*.*
# optimization finished, #iter = 2185
# obj = -0.000001, rho = 0.016671
# nSV = 468, nBSV = 0
# Total nSV = 1356
# [CV] END .................................................... total time=   4.5s
# Training duration for PCA=2500, C=10, kernel=linear, gamma=scale: 13.789795875549316 seconds
# Using existing PCA model for 2500 components
# [LibSVM]..*.*
# optimization finished, #iter = 3207
# obj = -0.000002, rho = 0.606467
# nSV = 551, nBSV = 0
# *.*
# optimization finished, #iter = 1016
# obj = -0.000000, rho = -0.232999
# nSV = 288, nBSV = 0
# .*
# optimization finished, #iter = 1506
# obj = -0.000001, rho = -0.156949
# nSV = 368, nBSV = 0
# ...*
# optimization finished, #iter = 2843
# obj = -0.000001, rho = -0.765990
# nSV = 495, nBSV = 0
# ..*.*
# optimization finished, #iter = 2506
# obj = -0.000001, rho = -0.645169
# nSV = 514, nBSV = 0
# ..*.*
# optimization finished, #iter = 2101
# obj = -0.000001, rho = 0.073528
# nSV = 453, nBSV = 0
# Total nSV = 1382
# [CV] END .................................................... total time=   4.6s
# [LibSVM]..*.*
# optimization finished, #iter = 3100
# obj = -0.000002, rho = 0.524276
# nSV = 542, nBSV = 0
# *.*
# optimization finished, #iter = 1060
# obj = -0.000000, rho = -0.257520
# nSV = 303, nBSV = 0
# .*
# optimization finished, #iter = 1602
# obj = -0.000001, rho = -0.240842
# nSV = 392, nBSV = 0
# ..*.*
# optimization finished, #iter = 2345
# obj = -0.000001, rho = -0.760955
# nSV = 453, nBSV = 0
# ..*.*
# optimization finished, #iter = 2502
# obj = -0.000001, rho = -0.604934
# nSV = 479, nBSV = 0
# ..*.*
# optimization finished, #iter = 2228
# obj = -0.000001, rho = 0.111206
# nSV = 444, nBSV = 0
# Total nSV = 1354
# [CV] END .................................................... total time=   4.6s
# [LibSVM]..*.*
# optimization finished, #iter = 3011
# obj = -0.000002, rho = 0.677138
# nSV = 534, nBSV = 0
# *.*
# optimization finished, #iter = 1032
# obj = -0.000000, rho = -0.157667
# nSV = 295, nBSV = 0
# .*
# optimization finished, #iter = 1464
# obj = -0.000001, rho = -0.162948
# nSV = 361, nBSV = 0
# ..*.*
# optimization finished, #iter = 2536
# obj = -0.000001, rho = -0.783067
# nSV = 473, nBSV = 0
# ..*.*
# optimization finished, #iter = 2657
# obj = -0.000002, rho = -0.653947
# nSV = 501, nBSV = 0
# ..*.*
# optimization finished, #iter = 2185
# obj = -0.000001, rho = 0.016671
# nSV = 468, nBSV = 0
# Total nSV = 1356
# [CV] END .................................................... total time=   4.5s
# Training duration for PCA=2500, C=10, kernel=linear, gamma=auto: 13.765891075134277 seconds
# Using existing PCA model for 2500 components
# [LibSVM].*
# optimization finished, #iter = 1977
# obj = -532.893320, rho = 0.604195
# nSV = 901, nBSV = 8
# *
# optimization finished, #iter = 996
# obj = -149.163290, rho = 0.183617
# nSV = 510, nBSV = 0
# *.*
# optimization finished, #iter = 1342
# obj = -259.139110, rho = 0.528686
# nSV = 650, nBSV = 0
# .*
# optimization finished, #iter = 1430
# obj = -353.793358, rho = -0.159340
# nSV = 670, nBSV = 0
# .*
# optimization finished, #iter = 1509
# obj = -379.018339, rho = 0.152714
# nSV = 735, nBSV = 0
# .*
# optimization finished, #iter = 1223
# obj = -289.662323, rho = 0.192439
# nSV = 603, nBSV = 0
# Total nSV = 1613
# [CV] END .................................................... total time=   7.3s
# [LibSVM].*
# optimization finished, #iter = 1853
# obj = -532.435863, rho = 0.561975
# nSV = 849, nBSV = 4
# *
# optimization finished, #iter = 952
# obj = -139.558861, rho = 0.240875
# nSV = 512, nBSV = 0
# *.*
# optimization finished, #iter = 1229
# obj = -258.749241, rho = 0.606974
# nSV = 604, nBSV = 3
# .*
# optimization finished, #iter = 1319
# obj = -303.511095, rho = -0.024444
# nSV = 644, nBSV = 0
# .*
# optimization finished, #iter = 1528
# obj = -385.974950, rho = 0.271990
# nSV = 724, nBSV = 0
# .*
# optimization finished, #iter = 1193
# obj = -274.851164, rho = 0.152189
# nSV = 597, nBSV = 0
# Total nSV = 1581
# [CV] END .................................................... total time=   7.2s
# [LibSVM].*
# optimization finished, #iter = 1930
# obj = -527.404095, rho = 0.564626
# nSV = 864, nBSV = 6
# *
# optimization finished, #iter = 976
# obj = -146.141856, rho = 0.239827
# nSV = 507, nBSV = 0
# *.*
# optimization finished, #iter = 1277
# obj = -254.442316, rho = 0.483972
# nSV = 640, nBSV = 4
# .*
# optimization finished, #iter = 1359
# obj = -338.756862, rho = -0.041146
# nSV = 656, nBSV = 1
# .*
# optimization finished, #iter = 1557
# obj = -392.441667, rho = 0.199004
# nSV = 734, nBSV = 1
# .*
# optimization finished, #iter = 1243
# obj = -286.856371, rho = 0.155689
# nSV = 614, nBSV = 0
# Total nSV = 1585
# [CV] END .................................................... total time=   7.2s
# Training duration for PCA=2500, C=10, kernel=rbf, gamma=scale: 21.78554081916809 seconds
# Using existing PCA model for 2500 components
# [LibSVM]..*.*
# optimization finished, #iter = 3945
# obj = -552.231328, rho = -0.272422
# nSV = 1193, nBSV = 0
# .*
# optimization finished, #iter = 1683
# obj = -426.937500, rho = -0.437500
# nSV = 1056, nBSV = 0
# ..*.*
# optimization finished, #iter = 3261
# obj = -497.484421, rho = -0.344553
# nSV = 1129, nBSV = 0
# .*
# optimization finished, #iter = 1319
# obj = -352.662079, rho = -0.187415
# nSV = 731, nBSV = 0
# ..*.*
# optimization finished, #iter = 2422
# obj = -399.452641, rho = -0.079602
# nSV = 804, nBSV = 0
# ..*
# optimization finished, #iter = 1434
# obj = -329.505226, rho = 0.109445
# nSV = 667, nBSV = 0
# Total nSV = 1860
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   8.8s
# [LibSVM]..*.*
# optimization finished, #iter = 3801
# obj = -552.508255, rho = -0.270134
# nSV = 1192, nBSV = 0
# .*.*
# optimization finished, #iter = 2946
# obj = -427.651059, rho = -0.435071
# nSV = 1055, nBSV = 0
# ..*.*
# optimization finished, #iter = 3419
# obj = -495.246184, rho = -0.345778
# nSV = 1125, nBSV = 0
# .*.*
# optimization finished, #iter = 1698
# obj = -353.697052, rho = -0.186903
# nSV = 733, nBSV = 0
# ..*.*
# optimization finished, #iter = 2682
# obj = -398.704762, rho = -0.083437
# nSV = 803, nBSV = 0
# ..*.*
# optimization finished, #iter = 2018
# obj = -329.321247, rho = 0.105105
# nSV = 666, nBSV = 0
# Total nSV = 1858
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [CV] END .................................................... total time=   8.8s
# [LibSVM]..*.*
# optimization finished, #iter = 3849
# obj = -553.570175, rho = -0.272575
# nSV = 1196, nBSV = 0
# .*.*
# optimization finished, #iter = 2711
# obj = -427.253267, rho = -0.438563
# nSV = 1058, nBSV = 0
# ..*.*
# optimization finished, #iter = 3629
# obj = -496.099070, rho = -0.348096
# nSV = 1129, nBSV = 0
# .*.*
# optimization finished, #iter = 1971
# obj = -352.991787, rho = -0.188525
# nSV = 732, nBSV = 0
# ..*.*
# optimization finished, #iter = 2682
# obj = -398.704762, rho = -0.083437
# nSV = 803, nBSV = 0
# ..*.*
# optimization finished, #iter = 2139
# obj = -328.709704, rho = 0.106767
# nSV = 665, nBSV = 0
# Total nSV = 1861
# [CV] END .................................................... total time=   9.0s
# Training duration for PCA=2500, C=10, kernel=rbf, gamma=auto: 26.652085065841675 seconds
# /Users/jacob/.pyenv/versions/anaconda3-2022.10/envs/monkey-business/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
run_metrics = {}

for run_id in run_ids:
    client = mlflow.tracking.MlflowClient(ML_FLOW_DIRECTORY)
    run = client.get_run(run_id)
    metrics = run.data.metrics
    run_metrics[run_id] = metrics

for run_id, metrics in run_metrics.items():
    print(f"Run ID: {run_id}")
    for metric, value in metrics.items():
        print(f"\t{metric}: {value}")
# Out:
# Run ID: 880325a203664a49b26f385e828e8d9a
# 	mean_f1_weighted: 0.7709596949649072
# 	mean_accuracy: 0.772889842632332
# 	mean_recall: 0.772889842632332
# 	mean_precision: 0.7704984181750968
# Run ID: 6fd50341c5a94a7d8d647f6a4930fb42
# 	mean_f1_weighted: 0.7709596949649072
# 	mean_accuracy: 0.772889842632332
# 	mean_recall: 0.772889842632332
# 	mean_precision: 0.7704984181750968
# Run ID: 7bdbce01131c4cd29112b966fc3e9d20
# 	mean_f1_weighted: 0.5508562954690585
# 	mean_accuracy: 0.5815450643776824
# 	mean_recall: 0.5815450643776824
# 	mean_precision: 0.6082632026754454
# Run ID: 89ed5beb4f3c4f48adeb88c1b0724bc6
# 	mean_f1_weighted: 0.08033054698280266
# 	mean_accuracy: 0.22103004291845493
# 	mean_recall: 0.22103004291845493
# 	mean_precision: 0.04913288143086076
# Run ID: 336206d63da14b46bcbd8f30f964a713
# 	mean_f1_weighted: 0.7709596949649072
# 	mean_accuracy: 0.772889842632332
# 	mean_recall: 0.772889842632332
# 	mean_precision: 0.7704984181750968
# Run ID: 204a86ec54c24105aa2bac982e446b52
# 	mean_f1_weighted: 0.7709596949649072
# 	mean_accuracy: 0.772889842632332
# 	mean_recall: 0.772889842632332
# 	mean_precision: 0.7704984181750968
# Run ID: 379ed9f87c704619ac545fb77a102fb1
# 	mean_f1_weighted: 0.7843077133285913
# 	mean_accuracy: 0.7882689556509299
# 	mean_recall: 0.7882689556509299
# 	mean_precision: 0.7851101514276632
# Run ID: ffe3b0b5888d4db8b49dc0ebea5ac48e
# 	mean_f1_weighted: 0.23724622379702479
# 	mean_accuracy: 0.4087982832618026
# 	mean_recall: 0.4087982832618026
# 	mean_precision: 0.16711603639779696
# Run ID: ff575bfda258411d9a58df819651c34d
# 	mean_f1_weighted: 0.7709596949649072
# 	mean_accuracy: 0.772889842632332
# 	mean_recall: 0.772889842632332
# 	mean_precision: 0.7704984181750968
# Run ID: 3701a4015c134105b73f0e14836bbf04
# 	mean_f1_weighted: 0.7709596949649072
# 	mean_accuracy: 0.772889842632332
# 	mean_recall: 0.772889842632332
# 	mean_precision: 0.7704984181750968
# Run ID: 70c67528ab4c40a9af491238eec96afa
# 	mean_f1_weighted: 0.8192517945784673
# 	mean_accuracy: 0.8204577968526466
# 	mean_recall: 0.8204577968526466
# 	mean_precision: 0.8191830019961214
# Run ID: e676b45befcb42359e829f7dbb444a7c
# 	mean_f1_weighted: 0.23724622379702479
# 	mean_accuracy: 0.4087982832618026
# 	mean_recall: 0.4087982832618026
# 	mean_precision: 0.16711603639779696
# Run ID: 10338865d72f4a75a9f04921dde22c49
# 	mean_f1_weighted: 0.7815111867499319
# 	mean_accuracy: 0.7836194563662375
# 	mean_recall: 0.7836194563662375
# 	mean_precision: 0.7808264242770396
# Run ID: b47c2dc9ae004036b657f7c79269e889
# 	mean_f1_weighted: 0.7815111867499319
# 	mean_accuracy: 0.7836194563662375
# 	mean_recall: 0.7836194563662375
# 	mean_precision: 0.7808264242770396
# Run ID: a61af237d083407abcf3e31ee0feed20
# 	mean_f1_weighted: 0.5507348782538425
# 	mean_accuracy: 0.5833333333333334
# 	mean_recall: 0.5833333333333334
# 	mean_precision: 0.6109857004910804
# Run ID: e850aef9b152435294e05826230ba79a
# 	mean_f1_weighted: 0.08033054698280266
# 	mean_accuracy: 0.22103004291845493
# 	mean_recall: 0.22103004291845493
# 	mean_precision: 0.04913288143086076
# Run ID: 46de0a7b40304b3299847560a8a82b82
# 	mean_f1_weighted: 0.7815111867499319
# 	mean_accuracy: 0.7836194563662375
# 	mean_recall: 0.7836194563662375
# 	mean_precision: 0.7808264242770396
# Run ID: 94640f5852ff46adbe45a4357c82dc0d
# 	mean_f1_weighted: 0.7815111867499319
# 	mean_accuracy: 0.7836194563662375
# 	mean_recall: 0.7836194563662375
# 	mean_precision: 0.7808264242770396
# Run ID: 36d83914f9bb4c79b0043dd9bcf3699e
# 	mean_f1_weighted: 0.7802314451544522
# 	mean_accuracy: 0.7843347639484978
# 	mean_recall: 0.7843347639484978
# 	mean_precision: 0.7811653900414764
# Run ID: 899405b34a614c9a8f63b0296b6d59b4
# 	mean_f1_weighted: 0.23724622379702479
# 	mean_accuracy: 0.4087982832618026
# 	mean_recall: 0.4087982832618026
# 	mean_precision: 0.16711603639779696
# Run ID: ebcf7da4fa9547879d46a222e16a271d
# 	mean_f1_weighted: 0.7815111867499319
# 	mean_accuracy: 0.7836194563662375
# 	mean_recall: 0.7836194563662375
# 	mean_precision: 0.7808264242770396
# Run ID: 6e0c23200937402aa2354d21aa0d1395
# 	mean_f1_weighted: 0.7815111867499319
# 	mean_accuracy: 0.7836194563662375
# 	mean_recall: 0.7836194563662375
# 	mean_precision: 0.7808264242770396
# Run ID: c61f43383a904906b116410832bd475d
# 	mean_f1_weighted: 0.8189838811916124
# 	mean_accuracy: 0.8204577968526466
# 	mean_recall: 0.8204577968526466
# 	mean_precision: 0.8187976962424827
# Run ID: 30b875b575344278b3416a091985e9c3
# 	mean_f1_weighted: 0.23724622379702479
# 	mean_accuracy: 0.4087982832618026
# 	mean_recall: 0.4087982832618026
# 	mean_precision: 0.16711603639779696
# Run ID: 1c53655aa8e047d090f0533776783734
# 	mean_f1_weighted: 0.7887414620684577
# 	mean_accuracy: 0.7907725321888411
# 	mean_recall: 0.7907725321888411
# 	mean_precision: 0.788399734398553
# Run ID: 67c3bc8fbc974d3bac45e865b966728d
# 	mean_f1_weighted: 0.7887414620684577
# 	mean_accuracy: 0.7907725321888411
# 	mean_recall: 0.7907725321888411
# 	mean_precision: 0.788399734398553
# Run ID: ef72ce6f7c1943f7ab0857b7aa07a35f
# 	mean_f1_weighted: 0.5446120998736055
# 	mean_accuracy: 0.5804721030042919
# 	mean_recall: 0.5804721030042919
# 	mean_precision: 0.608954291826801
# Run ID: 2a83dff8b2b441efb236d1d46120dc09
# 	mean_f1_weighted: 0.08033054698280266
# 	mean_accuracy: 0.22103004291845493
# 	mean_recall: 0.22103004291845493
# 	mean_precision: 0.04913288143086076
# Run ID: 2ff76a114f474cdeaec351f33a6a6f53
# 	mean_f1_weighted: 0.7887414620684577
# 	mean_accuracy: 0.7907725321888411
# 	mean_recall: 0.7907725321888411
# 	mean_precision: 0.788399734398553
# Run ID: 97c8428f90ca4899ac66b0000fc8c24d
# 	mean_f1_weighted: 0.7887414620684577
# 	mean_accuracy: 0.7907725321888411
# 	mean_recall: 0.7907725321888411
# 	mean_precision: 0.788399734398553
# Run ID: 45bdcaf351014da59bbbc19a8f844449
# 	mean_f1_weighted: 0.7779190916634383
# 	mean_accuracy: 0.7818311874105865
# 	mean_recall: 0.7818311874105865
# 	mean_precision: 0.7784211286996623
# Run ID: 293e9fb26b3f4d57883fb09af3b080f4
# 	mean_f1_weighted: 0.23724622379702479
# 	mean_accuracy: 0.4087982832618026
# 	mean_recall: 0.4087982832618026
# 	mean_precision: 0.16711603639779696
# Run ID: 18fa86154c53491f8ca601453a399cc5
# 	mean_f1_weighted: 0.7887414620684577
# 	mean_accuracy: 0.7907725321888411
# 	mean_recall: 0.7907725321888411
# 	mean_precision: 0.788399734398553
# Run ID: 84dff47f508048c08e4b5b33b6dc0541
# 	mean_f1_weighted: 0.7887414620684577
# 	mean_accuracy: 0.7907725321888411
# 	mean_recall: 0.7907725321888411
# 	mean_precision: 0.788399734398553
# Run ID: 25a1bddb806345dbbd772a649b75febc
# 	mean_f1_weighted: 0.8128253046431723
# 	mean_accuracy: 0.8147353361945636
# 	mean_recall: 0.8147353361945636
# 	mean_precision: 0.8125924305723983
# Run ID: 4367787af50f47b294a7f3dcdb30f8ee
# 	mean_f1_weighted: 0.23724622379702479
# 	mean_accuracy: 0.4087982832618026
# 	mean_recall: 0.4087982832618026
# 	mean_precision: 0.16711603639779696

# %%
best_run_id = max(run_metrics, key=lambda x: run_metrics[x]["mean_f1_weighted"])
best_params = client.get_run(best_run_id).data.params
best_run_metrics = run_metrics[best_run_id]

print(f"\nBest Run ID: {best_run_id}")
print("Best Parameters:")
for key, value in best_params.items():
    print(f"\t{key}: {value}")

print("\nBest Run Metrics:")
for metric, value in best_run_metrics.items():
    print(f"\t{metric}: {value}")
# Out:
# Best Run ID: 70c67528ab4c40a9af491238eec96afa
# Best Parameters:
# 	gamma: scale
# 	pca_components: 1600
# 	C: 10
# 	kernel: rbf
#
# Best Run Metrics:
# 	mean_f1_weighted: 0.8192517945784673
# 	mean_accuracy: 0.8204577968526466
# 	mean_recall: 0.8204577968526466
# 	mean_precision: 0.8191830019961214
