# %% [markdown]
# # SVM with PCA (BGR)

# %%
import cv2
import os
import glob
import time
import mlflow
import itertools

import numpy as np

from sklearn.decomposition import PCA
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
)

# %%
TRAIN_DIR = "../data/train"
CLASS_FOLDERS = ["Class A", "Class B", "Class C", "Class D"]
ML_FLOW_DIRECTORY = "SVM_Logs"

# %%
mlflow.set_tracking_uri(ML_FLOW_DIRECTORY)
mlflow.set_experiment("SVM_PCA_BGR")
# Out:
# 2023/12/08 00:31:50 INFO mlflow.tracking.fluent: Experiment with name 'SVM_PCA_BGR' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/Users/jacob/Code/Monkey-Business/SVM_Final_Models/SVM_Logs/910507522813637421', creation_time=1702017110382, experiment_id='910507522813637421', last_update_time=1702017110382, lifecycle_stage='active', name='SVM_PCA_BGR', tags={}>

# %%
pca_components = [40 * 40, 45 * 45, 50 * 50]
C_values = [9, 10, 10.5]
kernel_types = ["rbf"]
gamma_values = ["scale"]

# %%
hyperparameter_combinations = list(
    itertools.product(pca_components, C_values, kernel_types, gamma_values)
)
print(
    f"Total number of hyperparameter combinations: {len(hyperparameter_combinations)}"
)
# Out:
# Total number of hyperparameter combinations: 9

# %%
def train_with_params(pca_components, C, kernel, gamma, train_images, train_labels):
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    with mlflow.start_run() as run:
        start_time = time.time()

        scores = []
        for train_index, valid_index in skf.split(train_images, train_labels):
            train_images_fold, valid_images_fold = (
                train_images[train_index],
                train_images[valid_index],
            )
            train_labels_fold, valid_labels_fold = (
                train_labels[train_index],
                train_labels[valid_index],
            )

            pca = PCA(n_components=pca_components)
            pca.fit(train_images_fold)

            train_images_pca = pca.transform(train_images_fold)
            valid_images_pca = pca.transform(valid_images_fold)

            clf = svm.SVC(
                C=C, kernel=kernel, gamma=gamma, class_weight="balanced", verbose=True
            )
            clf.fit(train_images_pca, train_labels_fold)
            valid_predictions = clf.predict(valid_images_pca)

            scores.append(
                {
                    "f1_weighted": f1_score(
                        valid_labels_fold, valid_predictions, average="weighted"
                    ),
                    "accuracy": accuracy_score(valid_labels_fold, valid_predictions),
                    "precision": precision_score(
                        valid_labels_fold, valid_predictions, average="weighted"
                    ),
                    "recall": recall_score(
                        valid_labels_fold, valid_predictions, average="weighted"
                    ),
                }
            )

        mean_scores = {
            "mean_f1_weighted": np.mean([s["f1_weighted"] for s in scores]),
            "mean_accuracy": np.mean([s["accuracy"] for s in scores]),
            "mean_precision": np.mean([s["precision"] for s in scores]),
            "mean_recall": np.mean([s["recall"] for s in scores]),
        }

        # Log hyperparameters and metrics
        mlflow.log_params(
            {"pca_components": pca_components, "C": C, "kernel": kernel, "gamma": gamma}
        )
        mlflow.log_metrics(mean_scores)

        end_time = time.time()
        duration = end_time - start_time
        param_details = f"PCA={pca_components}, C={C}, kernel={kernel}, gamma={gamma}"
        duration_details = f"Training duration for {param_details}: {duration} seconds"
        print(duration_details)
        run_id = run.info.run_id
        return run_id

# %%
def load_images_from_folder(folder):
    images = []
    labels = []
    for class_folder in CLASS_FOLDERS:
        start_time = time.time()
        class_path = os.path.join(folder, class_folder)
        image_files = glob.glob(os.path.join(class_path, "*.png"))
        for img_file in image_files:
            processed_image = cv2.imread(img_file)
            flattened_image = processed_image.flatten()
            images.append(flattened_image)
            labels.append(class_folder)
        end_time = time.time()
        duration = end_time - start_time
        print(f"Processing {class_folder} took {duration} seconds")
    return np.array(images), np.array(labels)

# %%
train_images, train_labels = load_images_from_folder(TRAIN_DIR)
# Out:
# Processing Class A took 1.5296101570129395 seconds
# Processing Class B took 0.8514950275421143 seconds
# Processing Class C took 0.5740070343017578 seconds
# Processing Class D took 0.6946301460266113 seconds

# %%
print(
    f"Shape of train_images: {train_images.shape}, Shape of train_labels: {train_labels.shape}"
)
# Out:
# Shape of train_images: (2796, 150528), Shape of train_labels: (2796,)

# %%
run_ids = []

for params in hyperparameter_combinations:
    pca_components, C, kernel, gamma = params
    run_id = train_with_params(pca_components, C, kernel, gamma, train_images, train_labels)
    run_ids.append(run_id)
# Out:
# [LibSVM].*.*
# optimization finished, #iter = 2543
# obj = -1062.287663, rho = -0.045514
# nSV = 811, nBSV = 84
# *.*
# optimization finished, #iter = 1185
# obj = -193.994882, rho = -0.119254
# nSV = 469, nBSV = 2
# .*
# optimization finished, #iter = 1582
# obj = -294.669116, rho = -0.101244
# nSV = 590, nBSV = 16
# .*.*
# optimization finished, #iter = 2014
# obj = -693.834513, rho = 0.189757
# nSV = 725, nBSV = 7
# .*.*
# optimization finished, #iter = 2152
# obj = -532.779218, rho = 0.226326
# nSV = 757, nBSV = 1
# .*
# optimization finished, #iter = 1798
# obj = -528.303971, rho = 0.159033
# nSV = 692, nBSV = 4
# Total nSV = 1892
# [LibSVM].*.*
# optimization finished, #iter = 2574
# obj = -1055.627906, rho = -0.013558
# nSV = 809, nBSV = 86
# *.*
# optimization finished, #iter = 1168
# obj = -183.513711, rho = -0.036922
# nSV = 459, nBSV = 2
# .*
# optimization finished, #iter = 1541
# obj = -279.011941, rho = -0.075708
# nSV = 569, nBSV = 13
# .*.*
# optimization finished, #iter = 1993
# obj = -648.621021, rho = 0.250778
# nSV = 716, nBSV = 8
# .*.*
# optimization finished, #iter = 2071
# obj = -537.496688, rho = 0.300275
# nSV = 744, nBSV = 2
# .*
# optimization finished, #iter = 1778
# obj = -486.357700, rho = 0.175827
# nSV = 690, nBSV = 2
# Total nSV = 1886
# [LibSVM].*.*
# optimization finished, #iter = 2557
# obj = -1064.287781, rho = 0.064545
# nSV = 824, nBSV = 82
# *.*
# optimization finished, #iter = 1134
# obj = -192.462260, rho = -0.079998
# nSV = 455, nBSV = 2
# .*
# optimization finished, #iter = 1550
# obj = -296.012034, rho = -0.084501
# nSV = 566, nBSV = 15
# .*.*
# optimization finished, #iter = 2025
# obj = -721.938650, rho = 0.236500
# nSV = 735, nBSV = 10
# .*.*
# optimization finished, #iter = 2117
# obj = -539.084064, rho = 0.216845
# nSV = 750, nBSV = 2
# .*.*
# optimization finished, #iter = 1816
# obj = -519.663623, rho = 0.185017
# nSV = 698, nBSV = 3
# Total nSV = 1901
# [LibSVM].*.*
# optimization finished, #iter = 2524
# obj = -1039.555677, rho = 0.024914
# nSV = 810, nBSV = 88
# *.*
# optimization finished, #iter = 1231
# obj = -195.599935, rho = -0.085556
# nSV = 482, nBSV = 2
# .*
# optimization finished, #iter = 1581
# obj = -265.905799, rho = -0.111277
# nSV = 580, nBSV = 11
# .*.*
# optimization finished, #iter = 2024
# obj = -688.420424, rho = 0.186446
# nSV = 727, nBSV = 7
# .*.*
# optimization finished, #iter = 2015
# obj = -515.363448, rho = 0.279493
# nSV = 736, nBSV = 0
# .*.*
# optimization finished, #iter = 1817
# obj = -532.026671, rho = 0.265784
# nSV = 692, nBSV = 4
# Total nSV = 1892
# [LibSVM].*.*
# optimization finished, #iter = 2533
# obj = -1083.856628, rho = -0.019153
# nSV = 812, nBSV = 92
# *.*
# optimization finished, #iter = 1150
# obj = -188.680266, rho = -0.065078
# nSV = 457, nBSV = 2
# .*
# optimization finished, #iter = 1568
# obj = -296.254265, rho = -0.069472
# nSV = 587, nBSV = 15
# .*.*
# optimization finished, #iter = 2039
# obj = -699.036823, rho = 0.263490
# nSV = 722, nBSV = 8
# .*.*
# optimization finished, #iter = 2120
# obj = -562.323576, rho = 0.276693
# nSV = 754, nBSV = 1
# .*
# optimization finished, #iter = 1756
# obj = -541.567147, rho = 0.276894
# nSV = 689, nBSV = 4
# Total nSV = 1890
# [LibSVM].*.*
# optimization finished, #iter = 2505
# obj = -1076.038535, rho = -0.054398
# nSV = 808, nBSV = 82
# *.*
# optimization finished, #iter = 1106
# obj = -184.942906, rho = -0.069804
# nSV = 458, nBSV = 3
# .*
# optimization finished, #iter = 1629
# obj = -292.890161, rho = -0.047452
# nSV = 591, nBSV = 15
# .*
# optimization finished, #iter = 1889
# obj = -634.698493, rho = 0.285966
# nSV = 708, nBSV = 6
# .*.*
# optimization finished, #iter = 2118
# obj = -539.185064, rho = 0.304533
# nSV = 760, nBSV = 1
# .*
# optimization finished, #iter = 1783
# obj = -529.238307, rho = 0.169458
# nSV = 694, nBSV = 4
# Total nSV = 1908
# [LibSVM].*.*
# optimization finished, #iter = 2522
# obj = -1028.353914, rho = -0.058616
# nSV = 812, nBSV = 80
# *.*
# optimization finished, #iter = 1190
# obj = -190.269496, rho = -0.054980
# nSV = 470, nBSV = 3
# *.*
# optimization finished, #iter = 1428
# obj = -273.144780, rho = -0.107539
# nSV = 554, nBSV = 15
# .*.*
# optimization finished, #iter = 2023
# obj = -679.249387, rho = 0.313993
# nSV = 737, nBSV = 8
# .*.*
# optimization finished, #iter = 2121
# obj = -537.992421, rho = 0.264979
# nSV = 755, nBSV = 1
# .*
# optimization finished, #iter = 1745
# obj = -501.350116, rho = 0.115557
# nSV = 677, nBSV = 3
# Total nSV = 1891
# [LibSVM].*.*
# optimization finished, #iter = 2590
# obj = -1034.974024, rho = -0.027011
# nSV = 822, nBSV = 82
# *.*
# optimization finished, #iter = 1184
# obj = -191.958748, rho = -0.086840
# nSV = 468, nBSV = 2
# .*
# optimization finished, #iter = 1594
# obj = -285.911940, rho = -0.077977
# nSV = 583, nBSV = 13
# .*.*
# optimization finished, #iter = 1995
# obj = -696.802311, rho = 0.318217
# nSV = 719, nBSV = 10
# .*.*
# optimization finished, #iter = 2136
# obj = -546.783811, rho = 0.328722
# nSV = 757, nBSV = 2
# .*.*
# optimization finished, #iter = 1823
# obj = -519.774700, rho = 0.257765
# nSV = 700, nBSV = 3
# Total nSV = 1913
# [LibSVM].*.*
# optimization finished, #iter = 2514
# obj = -1059.228034, rho = 0.016236
# nSV = 818, nBSV = 81
# *.*
# optimization finished, #iter = 1159
# obj = -179.547196, rho = -0.085003
# nSV = 462, nBSV = 2
# .*
# optimization finished, #iter = 1527
# obj = -279.927058, rho = -0.138550
# nSV = 569, nBSV = 14
# .*.*
# optimization finished, #iter = 2024
# obj = -696.798134, rho = 0.213735
# nSV = 729, nBSV = 10
# .*.*
# optimization finished, #iter = 2114
# obj = -537.512470, rho = 0.281497
# nSV = 751, nBSV = 1
# .*
# optimization finished, #iter = 1786
# obj = -515.692366, rho = 0.230824
# nSV = 681, nBSV = 3
# Total nSV = 1903
# [LibSVM].*.*
# optimization finished, #iter = 2557
# obj = -1032.939839, rho = 0.049968
# nSV = 810, nBSV = 82
# *.*
# optimization finished, #iter = 1205
# obj = -192.286741, rho = -0.061415
# nSV = 475, nBSV = 4
# .*
# optimization finished, #iter = 1553
# obj = -294.548049, rho = -0.082913
# nSV = 586, nBSV = 14
# .*.*
# optimization finished, #iter = 2019
# obj = -660.532989, rho = 0.187397
# nSV = 728, nBSV = 6
# .*.*
# optimization finished, #iter = 2156
# obj = -554.811976, rho = 0.278576
# nSV = 763, nBSV = 2
# .*.*
# optimization finished, #iter = 1847
# obj = -506.346752, rho = 0.207735
# nSV = 707, nBSV = 3
# Total nSV = 1898
# Training duration for PCA=1600, C=9, kernel=rbf, gamma=scale: 1800.93754196167 seconds
# [LibSVM].*.*
# optimization finished, #iter = 2544
# obj = -1086.684327, rho = -0.037806
# nSV = 800, nBSV = 68
# *.*
# optimization finished, #iter = 1164
# obj = -193.868783, rho = -0.119039
# nSV = 467, nBSV = 2
# .*
# optimization finished, #iter = 1493
# obj = -295.251794, rho = -0.098637
# nSV = 586, nBSV = 13
# .*.*
# optimization finished, #iter = 2020
# obj = -706.816363, rho = 0.196575
# nSV = 724, nBSV = 7
# .*.*
# optimization finished, #iter = 2117
# obj = -536.009785, rho = 0.224726
# nSV = 756, nBSV = 1
# .*
# optimization finished, #iter = 1794
# obj = -534.428840, rho = 0.158906
# nSV = 688, nBSV = 4
# Total nSV = 1884
# [LibSVM].*.*
# optimization finished, #iter = 2524
# obj = -1077.978511, rho = -0.010597
# nSV = 805, nBSV = 69
# *.*
# optimization finished, #iter = 1143
# obj = -183.508811, rho = -0.036801
# nSV = 462, nBSV = 2
# .*
# optimization finished, #iter = 1530
# obj = -280.469311, rho = -0.076373
# nSV = 565, nBSV = 9
# .*
# optimization finished, #iter = 1963
# obj = -657.903319, rho = 0.255705
# nSV = 723, nBSV = 7
# .*.*
# optimization finished, #iter = 2132
# obj = -541.379477, rho = 0.298976
# nSV = 740, nBSV = 2
# .*
# optimization finished, #iter = 1790
# obj = -489.061414, rho = 0.176199
# nSV = 693, nBSV = 2
# Total nSV = 1883
# [LibSVM].*.*
# optimization finished, #iter = 2590
# obj = -1087.648341, rho = 0.074632
# nSV = 822, nBSV = 61
# *.*
# optimization finished, #iter = 1128
# obj = -192.516913, rho = -0.080444
# nSV = 458, nBSV = 2
# .*
# optimization finished, #iter = 1541
# obj = -297.001400, rho = -0.080476
# nSV = 566, nBSV = 13
# .*.*
# optimization finished, #iter = 1982
# obj = -737.413666, rho = 0.238170
# nSV = 726, nBSV = 9
# .*.*
# optimization finished, #iter = 2177
# obj = -543.319364, rho = 0.216841
# nSV = 751, nBSV = 1
# .*
# optimization finished, #iter = 1782
# obj = -524.155146, rho = 0.187491
# nSV = 695, nBSV = 3
# Total nSV = 1891
# [LibSVM].*.*
# optimization finished, #iter = 2565
# obj = -1061.200820, rho = 0.031960
# nSV = 810, nBSV = 70
# *.*
# optimization finished, #iter = 1213
# obj = -195.520189, rho = -0.084809
# nSV = 482, nBSV = 2
# .*
# optimization finished, #iter = 1516
# obj = -265.954741, rho = -0.112229
# nSV = 581, nBSV = 8
# .*.*
# optimization finished, #iter = 2087
# obj = -701.949970, rho = 0.185584
# nSV = 724, nBSV = 6
# .*.*
# optimization finished, #iter = 2066
# obj = -517.674933, rho = 0.277494
# nSV = 737, nBSV = 0
# .*
# optimization finished, #iter = 1794
# obj = -538.405982, rho = 0.260970
# nSV = 691, nBSV = 4
# Total nSV = 1896
# [LibSVM].*.*
# optimization finished, #iter = 2548
# obj = -1108.882397, rho = -0.017525
# nSV = 807, nBSV = 79
# *.*
# optimization finished, #iter = 1126
# obj = -188.617592, rho = -0.065300
# nSV = 458, nBSV = 2
# .*
# optimization finished, #iter = 1592
# obj = -296.957586, rho = -0.065904
# nSV = 583, nBSV = 9
# .*
# optimization finished, #iter = 1939
# obj = -711.055256, rho = 0.264928
# nSV = 718, nBSV = 8
# .*.*
# optimization finished, #iter = 2172
# obj = -564.799150, rho = 0.279098
# nSV = 755, nBSV = 1
# .*
# optimization finished, #iter = 1789
# obj = -547.149007, rho = 0.279065
# nSV = 688, nBSV = 4
# Total nSV = 1888
# [LibSVM].*.*
# optimization finished, #iter = 2564
# obj = -1099.161392, rho = -0.053672
# nSV = 799, nBSV = 73
# *.*
# optimization finished, #iter = 1144
# obj = -184.939287, rho = -0.067591
# nSV = 460, nBSV = 2
# .*
# optimization finished, #iter = 1612
# obj = -293.781324, rho = -0.043674
# nSV = 590, nBSV = 13
# .*
# optimization finished, #iter = 1917
# obj = -643.476809, rho = 0.290243
# nSV = 705, nBSV = 6
# .*.*
# optimization finished, #iter = 2159
# obj = -542.542515, rho = 0.305890
# nSV = 759, nBSV = 1
# .*
# optimization finished, #iter = 1779
# obj = -535.281773, rho = 0.172317
# nSV = 694, nBSV = 4
# Total nSV = 1900
# [LibSVM].*.*
# optimization finished, #iter = 2549
# obj = -1049.980175, rho = -0.049552
# nSV = 796, nBSV = 66
# *.*
# optimization finished, #iter = 1165
# obj = -190.758004, rho = -0.054218
# nSV = 469, nBSV = 3
# .*
# optimization finished, #iter = 1477
# obj = -274.323082, rho = -0.104146
# nSV = 550, nBSV = 9
# .*.*
# optimization finished, #iter = 2038
# obj = -692.069039, rho = 0.320692
# nSV = 734, nBSV = 7
# .*.*
# optimization finished, #iter = 2165
# obj = -541.387617, rho = 0.265052
# nSV = 750, nBSV = 1
# .*
# optimization finished, #iter = 1733
# obj = -505.874792, rho = 0.115343
# nSV = 681, nBSV = 3
# Total nSV = 1879
# [LibSVM].*.*
# optimization finished, #iter = 2594
# obj = -1055.448311, rho = -0.022569
# nSV = 816, nBSV = 63
# *.*
# optimization finished, #iter = 1173
# obj = -191.938247, rho = -0.086932
# nSV = 470, nBSV = 2
# .*
# optimization finished, #iter = 1584
# obj = -286.685884, rho = -0.073464
# nSV = 584, nBSV = 10
# .*
# optimization finished, #iter = 1957
# obj = -710.263218, rho = 0.322602
# nSV = 717, nBSV = 9
# .*.*
# optimization finished, #iter = 2168
# obj = -550.359251, rho = 0.326283
# nSV = 759, nBSV = 1
# .*.*
# optimization finished, #iter = 1848
# obj = -524.455552, rho = 0.258350
# nSV = 701, nBSV = 3
# Total nSV = 1913
# [LibSVM].*.*
# optimization finished, #iter = 2584
# obj = -1084.604025, rho = 0.018640
# nSV = 815, nBSV = 73
# *.*
# optimization finished, #iter = 1145
# obj = -179.595810, rho = -0.085059
# nSV = 463, nBSV = 2
# .*
# optimization finished, #iter = 1534
# obj = -281.155475, rho = -0.138161
# nSV = 564, nBSV = 14
# .*.*
# optimization finished, #iter = 1997
# obj = -709.319191, rho = 0.221870
# nSV = 726, nBSV = 9
# .*.*
# optimization finished, #iter = 2115
# obj = -540.026036, rho = 0.277011
# nSV = 750, nBSV = 1
# .*
# optimization finished, #iter = 1743
# obj = -520.556067, rho = 0.229477
# nSV = 681, nBSV = 3
# Total nSV = 1905
# [LibSVM].*.*
# optimization finished, #iter = 2571
# obj = -1054.304909, rho = 0.054442
# nSV = 811, nBSV = 71
# *.*
# optimization finished, #iter = 1209
# obj = -192.253978, rho = -0.060832
# nSV = 470, nBSV = 2
# .*
# optimization finished, #iter = 1541
# obj = -295.222519, rho = -0.077522
# nSV = 582, nBSV = 12
# .*.*
# optimization finished, #iter = 2034
# obj = -667.444350, rho = 0.191374
# nSV = 725, nBSV = 6
# .*.*
# optimization finished, #iter = 2186
# obj = -557.613451, rho = 0.279442
# nSV = 765, nBSV = 2
# .*.*
# optimization finished, #iter = 1832
# obj = -510.688882, rho = 0.207636
# nSV = 706, nBSV = 3
# Total nSV = 1897
# Training duration for PCA=1600, C=10, kernel=rbf, gamma=scale: 1811.3305716514587 seconds
# [LibSVM].*.*
# optimization finished, #iter = 2512
# obj = -1098.743407, rho = -0.037028
# nSV = 800, nBSV = 62
# *.*
# optimization finished, #iter = 1130
# obj = -193.937838, rho = -0.118970
# nSV = 468, nBSV = 2
# .*
# optimization finished, #iter = 1581
# obj = -295.605137, rho = -0.096401
# nSV = 587, nBSV = 10
# .*.*
# optimization finished, #iter = 2002
# obj = -712.840289, rho = 0.195968
# nSV = 716, nBSV = 7
# .*.*
# optimization finished, #iter = 2145
# obj = -538.212800, rho = 0.224673
# nSV = 757, nBSV = 1
# .*
# optimization finished, #iter = 1797
# obj = -537.303399, rho = 0.160325
# nSV = 688, nBSV = 4
# Total nSV = 1877
# [LibSVM].*.*
# optimization finished, #iter = 2618
# obj = -1088.129670, rho = -0.008977
# nSV = 802, nBSV = 57
# *.*
# optimization finished, #iter = 1155
# obj = -183.400966, rho = -0.037496
# nSV = 464, nBSV = 2
# .*
# optimization finished, #iter = 1524
# obj = -281.003856, rho = -0.072681
# nSV = 563, nBSV = 9
# .*
# optimization finished, #iter = 1947
# obj = -662.380568, rho = 0.254992
# nSV = 719, nBSV = 7
# .*.*
# optimization finished, #iter = 2113
# obj = -542.749536, rho = 0.300245
# nSV = 747, nBSV = 2
# .*
# optimization finished, #iter = 1755
# obj = -490.729610, rho = 0.173507
# nSV = 690, nBSV = 2
# Total nSV = 1886
# [LibSVM].*.*
# optimization finished, #iter = 2620
# obj = -1095.647658, rho = 0.088668
# nSV = 821, nBSV = 58
# *.*
# optimization finished, #iter = 1151
# obj = -192.657244, rho = -0.079001
# nSV = 457, nBSV = 2
# .*
# optimization finished, #iter = 1528
# obj = -297.375283, rho = -0.078053
# nSV = 567, nBSV = 11
# .*.*
# optimization finished, #iter = 2013
# obj = -744.512234, rho = 0.241412
# nSV = 730, nBSV = 8
# .*.*
# optimization finished, #iter = 2126
# obj = -544.349696, rho = 0.216205
# nSV = 750, nBSV = 1
# .*
# optimization finished, #iter = 1800
# obj = -526.439255, rho = 0.186092
# nSV = 694, nBSV = 3
# Total nSV = 1895
# [LibSVM].*.*
# optimization finished, #iter = 2594
# obj = -1069.416300, rho = 0.027075
# nSV = 809, nBSV = 69
# *.*
# optimization finished, #iter = 1192
# obj = -195.416578, rho = -0.085749
# nSV = 482, nBSV = 2
# .*
# optimization finished, #iter = 1542
# obj = -266.026801, rho = -0.110401
# nSV = 577, nBSV = 5
# .*.*
# optimization finished, #iter = 2053
# obj = -707.472777, rho = 0.188108
# nSV = 721, nBSV = 4
# .*.*
# optimization finished, #iter = 2055
# obj = -518.554851, rho = 0.277046
# nSV = 737, nBSV = 0
# .*.*
# optimization finished, #iter = 1812
# obj = -540.970447, rho = 0.265697
# nSV = 693, nBSV = 4
# Total nSV = 1898
# [LibSVM].*.*
# optimization finished, #iter = 2640
# obj = -1118.585145, rho = -0.015236
# nSV = 807, nBSV = 70
# *.*
# optimization finished, #iter = 1134
# obj = -188.863519, rho = -0.064195
# nSV = 461, nBSV = 2
# .*
# optimization finished, #iter = 1602
# obj = -297.648925, rho = -0.065193
# nSV = 580, nBSV = 9
# .*
# optimization finished, #iter = 1962
# obj = -717.326507, rho = 0.268159
# nSV = 720, nBSV = 7
# .*.*
# optimization finished, #iter = 2182
# obj = -567.154118, rho = 0.277859
# nSV = 754, nBSV = 1
# .*
# optimization finished, #iter = 1770
# obj = -550.127689, rho = 0.278019
# nSV = 687, nBSV = 4
# Total nSV = 1888
# [LibSVM].*.*
# optimization finished, #iter = 2608
# obj = -1108.628159, rho = -0.049916
# nSV = 800, nBSV = 66
# *.*
# optimization finished, #iter = 1136
# obj = -184.615316, rho = -0.068068
# nSV = 463, nBSV = 2
# .*
# optimization finished, #iter = 1578
# obj = -294.130111, rho = -0.043189
# nSV = 589, nBSV = 12
# .*
# optimization finished, #iter = 1901
# obj = -647.495134, rho = 0.296760
# nSV = 704, nBSV = 6
# .*.*
# optimization finished, #iter = 2128
# obj = -544.688448, rho = 0.305763
# nSV = 760, nBSV = 1
# .*.*
# optimization finished, #iter = 1812
# obj = -537.978378, rho = 0.173574
# nSV = 694, nBSV = 4
# Total nSV = 1897
# [LibSVM].*.*
# optimization finished, #iter = 2531
# obj = -1062.021050, rho = -0.046826
# nSV = 798, nBSV = 58
# *.*
# optimization finished, #iter = 1171
# obj = -190.699330, rho = -0.054331
# nSV = 465, nBSV = 3
# .*
# optimization finished, #iter = 1489
# obj = -274.817487, rho = -0.104191
# nSV = 548, nBSV = 7
# .*.*
# optimization finished, #iter = 1996
# obj = -697.007575, rho = 0.321683
# nSV = 730, nBSV = 7
# .*.*
# optimization finished, #iter = 2129
# obj = -543.399504, rho = 0.263183
# nSV = 754, nBSV = 1
# .*
# optimization finished, #iter = 1721
# obj = -508.446784, rho = 0.114184
# nSV = 677, nBSV = 3
# Total nSV = 1875
# [LibSVM].*.*
# optimization finished, #iter = 2626
# obj = -1065.119666, rho = -0.019927
# nSV = 815, nBSV = 61
# *.*
# optimization finished, #iter = 1157
# obj = -191.952562, rho = -0.086884
# nSV = 466, nBSV = 2
# .*
# optimization finished, #iter = 1523
# obj = -287.056853, rho = -0.070425
# nSV = 583, nBSV = 9
# .*.*
# optimization finished, #iter = 2000
# obj = -715.162723, rho = 0.327700
# nSV = 716, nBSV = 8
# .*.*
# optimization finished, #iter = 2112
# obj = -551.546263, rho = 0.326310
# nSV = 757, nBSV = 1
# .*.*
# optimization finished, #iter = 1826
# obj = -526.126672, rho = 0.258477
# nSV = 698, nBSV = 3
# Total nSV = 1902
# [LibSVM].*.*
# optimization finished, #iter = 2637
# obj = -1095.026755, rho = 0.023812
# nSV = 809, nBSV = 62
# *.*
# optimization finished, #iter = 1169
# obj = -179.534160, rho = -0.085262
# nSV = 462, nBSV = 1
# .*
# optimization finished, #iter = 1549
# obj = -281.283969, rho = -0.135319
# nSV = 563, nBSV = 12
# .*.*
# optimization finished, #iter = 2022
# obj = -714.277514, rho = 0.222730
# nSV = 726, nBSV = 9
# .*.*
# optimization finished, #iter = 2149
# obj = -540.401185, rho = 0.279907
# nSV = 751, nBSV = 1
# .*
# optimization finished, #iter = 1797
# obj = -522.902147, rho = 0.229699
# nSV = 686, nBSV = 3
# Total nSV = 1901
# [LibSVM].*.*
# optimization finished, #iter = 2591
# obj = -1065.174124, rho = 0.056712
# nSV = 799, nBSV = 65
# *.*
# optimization finished, #iter = 1189
# obj = -192.233156, rho = -0.061870
# nSV = 471, nBSV = 2
# .*
# optimization finished, #iter = 1632
# obj = -295.674031, rho = -0.077532
# nSV = 584, nBSV = 11
# .*.*
# optimization finished, #iter = 2012
# obj = -672.833251, rho = 0.187631
# nSV = 724, nBSV = 6
# .*.*
# optimization finished, #iter = 2129
# obj = -559.010901, rho = 0.273499
# nSV = 761, nBSV = 2
# .*
# optimization finished, #iter = 1800
# obj = -512.758611, rho = 0.206406
# nSV = 707, nBSV = 3
# Total nSV = 1889
# Training duration for PCA=1600, C=10.5, kernel=rbf, gamma=scale: 1830.0931041240692 seconds
# [LibSVM].*.*
# optimization finished, #iter = 2499
# obj = -1022.043241, rho = -0.039859
# nSV = 823, nBSV = 76
# *.*
# optimization finished, #iter = 1179
# obj = -190.427159, rho = -0.122322
# nSV = 483, nBSV = 2
# .*
# optimization finished, #iter = 1585
# obj = -288.603922, rho = -0.107443
# nSV = 599, nBSV = 13
# .*.*
# optimization finished, #iter = 2011
# obj = -656.777632, rho = 0.178969
# nSV = 748, nBSV = 4
# .*.*
# optimization finished, #iter = 2139
# obj = -522.164980, rho = 0.225659
# nSV = 771, nBSV = 1
# .*.*
# optimization finished, #iter = 1802
# obj = -513.193536, rho = 0.166280
# nSV = 706, nBSV = 4
# Total nSV = 1916
# [LibSVM].*.*
# optimization finished, #iter = 2527
# obj = -1012.865733, rho = -0.012012
# nSV = 822, nBSV = 68
# *.*
# optimization finished, #iter = 1153
# obj = -180.446149, rho = -0.046019
# nSV = 473, nBSV = 2
# .*
# optimization finished, #iter = 1501
# obj = -273.686948, rho = -0.082697
# nSV = 578, nBSV = 11
# .*
# optimization finished, #iter = 1974
# obj = -618.079142, rho = 0.240041
# nSV = 740, nBSV = 5
# .*.*
# optimization finished, #iter = 2132
# obj = -524.774946, rho = 0.296587
# nSV = 762, nBSV = 2
# .*
# optimization finished, #iter = 1764
# obj = -476.687566, rho = 0.181301
# nSV = 702, nBSV = 2
# Total nSV = 1903
# [LibSVM].*.*
# optimization finished, #iter = 2497
# obj = -1022.336218, rho = 0.064682
# nSV = 842, nBSV = 67
# *.*
# optimization finished, #iter = 1128
# obj = -189.020052, rho = -0.081971
# nSV = 471, nBSV = 2
# *.*
# optimization finished, #iter = 1513
# obj = -289.693697, rho = -0.089388
# nSV = 581, nBSV = 13
# .*.*
# optimization finished, #iter = 2001
# obj = -680.044764, rho = 0.222718
# nSV = 749, nBSV = 6
# .*.*
# optimization finished, #iter = 2158
# obj = -527.533641, rho = 0.218560
# nSV = 762, nBSV = 1
# .*.*
# optimization finished, #iter = 1819
# obj = -508.574091, rho = 0.193815
# nSV = 710, nBSV = 3
# Total nSV = 1919
# [LibSVM].*.*
# optimization finished, #iter = 2515
# obj = -1002.192860, rho = 0.017577
# nSV = 825, nBSV = 76
# *.*
# optimization finished, #iter = 1223
# obj = -192.267163, rho = -0.090893
# nSV = 495, nBSV = 2
# .*
# optimization finished, #iter = 1522
# obj = -262.284592, rho = -0.116518
# nSV = 588, nBSV = 8
# .*.*
# optimization finished, #iter = 2025
# obj = -651.450918, rho = 0.172345
# nSV = 741, nBSV = 4
# .*.*
# optimization finished, #iter = 2076
# obj = -505.533028, rho = 0.274403
# nSV = 753, nBSV = 0
# .*.*
# optimization finished, #iter = 1810
# obj = -518.579577, rho = 0.270134
# nSV = 706, nBSV = 4
# Total nSV = 1912
# [LibSVM].*.*
# optimization finished, #iter = 2551
# obj = -1040.814890, rho = -0.023394
# nSV = 834, nBSV = 76
# *.*
# optimization finished, #iter = 1155
# obj = -185.506022, rho = -0.068514
# nSV = 469, nBSV = 2
# .*
# optimization finished, #iter = 1580
# obj = -289.807376, rho = -0.073993
# nSV = 596, nBSV = 11
# .*.*
# optimization finished, #iter = 1979
# obj = -660.137785, rho = 0.252361
# nSV = 745, nBSV = 5
# .*.*
# optimization finished, #iter = 2141
# obj = -547.208607, rho = 0.277270
# nSV = 776, nBSV = 1
# .*
# optimization finished, #iter = 1788
# obj = -526.026466, rho = 0.280021
# nSV = 702, nBSV = 4
# Total nSV = 1919
# [LibSVM].*.*
# optimization finished, #iter = 2498
# obj = -1034.479245, rho = -0.063005
# nSV = 820, nBSV = 81
# *.*
# optimization finished, #iter = 1158
# obj = -180.736770, rho = -0.070692
# nSV = 476, nBSV = 2
# .*
# optimization finished, #iter = 1582
# obj = -287.093467, rho = -0.053704
# nSV = 602, nBSV = 14
# .*
# optimization finished, #iter = 1872
# obj = -603.687989, rho = 0.283706
# nSV = 720, nBSV = 5
# .*.*
# optimization finished, #iter = 2213
# obj = -526.736043, rho = 0.306892
# nSV = 774, nBSV = 1
# .*
# optimization finished, #iter = 1786
# obj = -513.891153, rho = 0.175158
# nSV = 702, nBSV = 4
# Total nSV = 1926
# [LibSVM].*.*
# optimization finished, #iter = 2485
# obj = -989.113070, rho = -0.053973
# nSV = 827, nBSV = 68
# *.*
# optimization finished, #iter = 1167
# obj = -187.235400, rho = -0.059218
# nSV = 478, nBSV = 3
# .*
# optimization finished, #iter = 1476
# obj = -267.431964, rho = -0.111660
# nSV = 566, nBSV = 11
# .*.*
# optimization finished, #iter = 2015
# obj = -641.006450, rho = 0.300480
# nSV = 753, nBSV = 5
# .*.*
# optimization finished, #iter = 2115
# obj = -525.099516, rho = 0.260042
# nSV = 766, nBSV = 1
# .*
# optimization finished, #iter = 1747
# obj = -488.972051, rho = 0.122715
# nSV = 691, nBSV = 3
# Total nSV = 1913
# [LibSVM].*.*
# optimization finished, #iter = 2609
# obj = -996.630135, rho = -0.030638
# nSV = 838, nBSV = 74
# *.*
# optimization finished, #iter = 1120
# obj = -188.902439, rho = -0.089459
# nSV = 479, nBSV = 2
# .*
# optimization finished, #iter = 1576
# obj = -280.698314, rho = -0.084514
# nSV = 592, nBSV = 11
# .*.*
# optimization finished, #iter = 2011
# obj = -657.090934, rho = 0.303309
# nSV = 741, nBSV = 6
# .*.*
# optimization finished, #iter = 2083
# obj = -533.612034, rho = 0.327287
# nSV = 769, nBSV = 2
# .*.*
# optimization finished, #iter = 1840
# obj = -506.531147, rho = 0.263845
# nSV = 710, nBSV = 3
# Total nSV = 1930
# [LibSVM].*.*
# optimization finished, #iter = 2571
# obj = -1017.153389, rho = 0.014234
# nSV = 842, nBSV = 68
# *.*
# optimization finished, #iter = 1111
# obj = -176.858288, rho = -0.089199
# nSV = 471, nBSV = 2
# .*
# optimization finished, #iter = 1496
# obj = -274.493485, rho = -0.147717
# nSV = 581, nBSV = 13
# .*.*
# optimization finished, #iter = 1986
# obj = -659.683928, rho = 0.204364
# nSV = 740, nBSV = 7
# .*.*
# optimization finished, #iter = 2133
# obj = -524.340980, rho = 0.283923
# nSV = 768, nBSV = 1
# .*
# optimization finished, #iter = 1790
# obj = -502.545477, rho = 0.237014
# nSV = 698, nBSV = 3
# Total nSV = 1930
# [LibSVM].*.*
# optimization finished, #iter = 2535
# obj = -992.832462, rho = 0.051407
# nSV = 825, nBSV = 71
# *.*
# optimization finished, #iter = 1135
# obj = -188.664529, rho = -0.064865
# nSV = 484, nBSV = 2
# .*
# optimization finished, #iter = 1566
# obj = -288.500524, rho = -0.086671
# nSV = 598, nBSV = 14
# .*.*
# optimization finished, #iter = 2036
# obj = -629.342043, rho = 0.186709
# nSV = 741, nBSV = 4
# .*.*
# optimization finished, #iter = 2148
# obj = -540.637941, rho = 0.279994
# nSV = 780, nBSV = 2
# .*.*
# optimization finished, #iter = 1826
# obj = -494.425441, rho = 0.213165
# nSV = 715, nBSV = 3
# Total nSV = 1913
# Training duration for PCA=2025, C=9, kernel=rbf, gamma=scale: 1922.8323838710785 seconds
# [LibSVM].*.*
# optimization finished, #iter = 2589
# obj = -1040.788759, rho = -0.038107
# nSV = 822, nBSV = 58
# *.*
# optimization finished, #iter = 1179
# obj = -190.427159, rho = -0.122322
# nSV = 483, nBSV = 2
# .*
# optimization finished, #iter = 1572
# obj = -288.967341, rho = -0.104078
# nSV = 601, nBSV = 10
# .*.*
# optimization finished, #iter = 2027
# obj = -663.948164, rho = 0.182609
# nSV = 748, nBSV = 3
# .*.*
# optimization finished, #iter = 2071
# obj = -524.555285, rho = 0.224599
# nSV = 766, nBSV = 1
# .*
# optimization finished, #iter = 1731
# obj = -517.024101, rho = 0.167414
# nSV = 704, nBSV = 4
# Total nSV = 1910
# [LibSVM].*.*
# optimization finished, #iter = 2583
# obj = -1031.358262, rho = -0.009744
# nSV = 820, nBSV = 59
# *.*
# optimization finished, #iter = 1146
# obj = -180.509451, rho = -0.044956
# nSV = 471, nBSV = 2
# .*
# optimization finished, #iter = 1532
# obj = -274.599746, rho = -0.080991
# nSV = 579, nBSV = 8
# .*.*
# optimization finished, #iter = 2008
# obj = -623.258212, rho = 0.240703
# nSV = 739, nBSV = 4
# .*.*
# optimization finished, #iter = 2115
# obj = -527.067821, rho = 0.297446
# nSV = 765, nBSV = 2
# .*
# optimization finished, #iter = 1749
# obj = -478.798817, rho = 0.181376
# nSV = 702, nBSV = 2
# Total nSV = 1901
# [LibSVM].*.*
# optimization finished, #iter = 2579
# obj = -1040.452472, rho = 0.068796
# nSV = 844, nBSV = 52
# *.*
# optimization finished, #iter = 1128
# obj = -189.020052, rho = -0.081971
# nSV = 471, nBSV = 2
# .*
# optimization finished, #iter = 1567
# obj = -290.092571, rho = -0.085809
# nSV = 579, nBSV = 10
# .*
# optimization finished, #iter = 1968
# obj = -688.161867, rho = 0.226184
# nSV = 746, nBSV = 6
# .*.*
# optimization finished, #iter = 2107
# obj = -529.901053, rho = 0.218207
# nSV = 762, nBSV = 1
# .*.*
# optimization finished, #iter = 1828
# obj = -511.863197, rho = 0.195403
# nSV = 708, nBSV = 3
# Total nSV = 1917
# [LibSVM].*.*
# optimization finished, #iter = 2574
# obj = -1018.646931, rho = 0.019363
# nSV = 824, nBSV = 59
# *.*
# optimization finished, #iter = 1223
# obj = -192.267163, rho = -0.090893
# nSV = 495, nBSV = 2
# .*
# optimization finished, #iter = 1544
# obj = -262.300652, rho = -0.115527
# nSV = 588, nBSV = 6
# .*.*
# optimization finished, #iter = 1980
# obj = -658.533380, rho = 0.170817
# nSV = 737, nBSV = 4
# .*.*
# optimization finished, #iter = 2069
# obj = -506.861160, rho = 0.273124
# nSV = 753, nBSV = 0
# .*.*
# optimization finished, #iter = 1850
# obj = -522.623107, rho = 0.270696
# nSV = 704, nBSV = 4
# Total nSV = 1911
# [LibSVM].*.*
# optimization finished, #iter = 2568
# obj = -1058.829744, rho = -0.021929
# nSV = 832, nBSV = 69
# *.*
# optimization finished, #iter = 1130
# obj = -185.506022, rho = -0.068486
# nSV = 469, nBSV = 2
# .*
# optimization finished, #iter = 1587
# obj = -290.374935, rho = -0.070981
# nSV = 593, nBSV = 8
# .*.*
# optimization finished, #iter = 1981
# obj = -666.911342, rho = 0.254025
# nSV = 745, nBSV = 4
# .*.*
# optimization finished, #iter = 2158
# obj = -549.707584, rho = 0.276748
# nSV = 775, nBSV = 1
# .*
# optimization finished, #iter = 1787
# obj = -529.967300, rho = 0.281202
# nSV = 702, nBSV = 4
# Total nSV = 1919
# [LibSVM].*.*
# optimization finished, #iter = 2535
# obj = -1053.417605, rho = -0.062782
# nSV = 820, nBSV = 62
# *.*
# optimization finished, #iter = 1158
# obj = -180.736770, rho = -0.070692
# nSV = 476, nBSV = 2
# .*
# optimization finished, #iter = 1607
# obj = -287.444783, rho = -0.049969
# nSV = 601, nBSV = 12
# .*
# optimization finished, #iter = 1951
# obj = -608.432200, rho = 0.289407
# nSV = 718, nBSV = 3
# .*.*
# optimization finished, #iter = 2105
# obj = -529.260483, rho = 0.306321
# nSV = 774, nBSV = 1
# .*
# optimization finished, #iter = 1793
# obj = -517.714288, rho = 0.176904
# nSV = 702, nBSV = 4
# Total nSV = 1922
# [LibSVM].*.*
# optimization finished, #iter = 2539
# obj = -1006.528973, rho = -0.054080
# nSV = 819, nBSV = 66
# *.*
# optimization finished, #iter = 1170
# obj = -187.321144, rho = -0.058470
# nSV = 480, nBSV = 3
# *.*
# optimization finished, #iter = 1431
# obj = -268.108449, rho = -0.109995
# nSV = 562, nBSV = 8
# .*.*
# optimization finished, #iter = 1992
# obj = -647.659159, rho = 0.304395
# nSV = 751, nBSV = 3
# .*.*
# optimization finished, #iter = 2082
# obj = -527.497089, rho = 0.259678
# nSV = 772, nBSV = 1
# .*
# optimization finished, #iter = 1753
# obj = -492.049598, rho = 0.122787
# nSV = 692, nBSV = 3
# Total nSV = 1912
# [LibSVM].*.*
# optimization finished, #iter = 2583
# obj = -1014.040835, rho = -0.027287
# nSV = 832, nBSV = 59
# *.*
# optimization finished, #iter = 1120
# obj = -188.902439, rho = -0.089459
# nSV = 479, nBSV = 2
# .*
# optimization finished, #iter = 1555
# obj = -280.951969, rho = -0.082356
# nSV = 591, nBSV = 9
# .*.*
# optimization finished, #iter = 2048
# obj = -664.379110, rho = 0.308018
# nSV = 740, nBSV = 5
# .*.*
# optimization finished, #iter = 2106
# obj = -536.034294, rho = 0.326696
# nSV = 767, nBSV = 1
# .*.*
# optimization finished, #iter = 1815
# obj = -509.167524, rho = 0.265461
# nSV = 711, nBSV = 3
# Total nSV = 1929
# [LibSVM].*.*
# optimization finished, #iter = 2547
# obj = -1035.604028, rho = 0.017429
# nSV = 831, nBSV = 66
# *.*
# optimization finished, #iter = 1111
# obj = -176.858288, rho = -0.089199
# nSV = 471, nBSV = 2
# .*
# optimization finished, #iter = 1516
# obj = -274.971440, rho = -0.144226
# nSV = 580, nBSV = 11
# .*
# optimization finished, #iter = 1967
# obj = -666.618427, rho = 0.209289
# nSV = 736, nBSV = 6
# .*.*
# optimization finished, #iter = 2153
# obj = -525.532385, rho = 0.282585
# nSV = 767, nBSV = 1
# .*
# optimization finished, #iter = 1757
# obj = -505.438890, rho = 0.236715
# nSV = 700, nBSV = 3
# Total nSV = 1922
# [LibSVM].*.*
# optimization finished, #iter = 2506
# obj = -1009.008462, rho = 0.053622
# nSV = 821, nBSV = 54
# *.*
# optimization finished, #iter = 1135
# obj = -188.664529, rho = -0.064865
# nSV = 484, nBSV = 2
# .*
# optimization finished, #iter = 1582
# obj = -288.878199, rho = -0.084212
# nSV = 594, nBSV = 10
# .*.*
# optimization finished, #iter = 1996
# obj = -632.838951, rho = 0.183755
# nSV = 740, nBSV = 3
# .*.*
# optimization finished, #iter = 2146
# obj = -542.608223, rho = 0.278775
# nSV = 779, nBSV = 2
# .*.*
# optimization finished, #iter = 1816
# obj = -497.121239, rho = 0.215407
# nSV = 713, nBSV = 3
# Total nSV = 1911
# Training duration for PCA=2025, C=10, kernel=rbf, gamma=scale: 1983.0524098873138 seconds
# [LibSVM].*.*
# optimization finished, #iter = 2527
# obj = -1048.966264, rho = -0.036493
# nSV = 819, nBSV = 51
# *.*
# optimization finished, #iter = 1179
# obj = -190.427159, rho = -0.122322
# nSV = 483, nBSV = 2
# .*
# optimization finished, #iter = 1584
# obj = -289.023572, rho = -0.102466
# nSV = 602, nBSV = 9
# .*.*
# optimization finished, #iter = 2041
# obj = -667.024155, rho = 0.184297
# nSV = 746, nBSV = 3
# .*.*
# optimization finished, #iter = 2136
# obj = -525.597658, rho = 0.224037
# nSV = 767, nBSV = 1
# .*
# optimization finished, #iter = 1729
# obj = -518.709350, rho = 0.168071
# nSV = 704, nBSV = 4
# Total nSV = 1909
# [LibSVM].*.*
# optimization finished, #iter = 2551
# obj = -1039.439832, rho = -0.009075
# nSV = 820, nBSV = 54
# *.*
# optimization finished, #iter = 1108
# obj = -180.510515, rho = -0.044957
# nSV = 472, nBSV = 2
# .*
# optimization finished, #iter = 1554
# obj = -274.905489, rho = -0.080217
# nSV = 580, nBSV = 9
# .*.*
# optimization finished, #iter = 1987
# obj = -625.523779, rho = 0.241011
# nSV = 740, nBSV = 4
# .*.*
# optimization finished, #iter = 2072
# obj = -528.066388, rho = 0.297671
# nSV = 766, nBSV = 2
# .*
# optimization finished, #iter = 1745
# obj = -479.745818, rho = 0.181415
# nSV = 701, nBSV = 2
# Total nSV = 1901
# [LibSVM].*.*
# optimization finished, #iter = 2575
# obj = -1048.204939, rho = 0.071732
# nSV = 840, nBSV = 50
# *.*
# optimization finished, #iter = 1128
# obj = -189.020052, rho = -0.081971
# nSV = 471, nBSV = 2
# .*
# optimization finished, #iter = 1579
# obj = -290.161419, rho = -0.084685
# nSV = 581, nBSV = 9
# .*.*
# optimization finished, #iter = 2011
# obj = -691.703437, rho = 0.227390
# nSV = 746, nBSV = 4
# .*.*
# optimization finished, #iter = 2091
# obj = -530.932318, rho = 0.218191
# nSV = 763, nBSV = 1
# .*
# optimization finished, #iter = 1799
# obj = -513.347633, rho = 0.196188
# nSV = 708, nBSV = 3
# Total nSV = 1918
# [LibSVM].*.*
# optimization finished, #iter = 2583
# obj = -1025.699334, rho = 0.021764
# nSV = 823, nBSV = 55
# *.*
# optimization finished, #iter = 1223
# obj = -192.267163, rho = -0.090893
# nSV = 495, nBSV = 2
# .*
# optimization finished, #iter = 1545
# obj = -262.300921, rho = -0.115383
# nSV = 588, nBSV = 5
# .*.*
# optimization finished, #iter = 2024
# obj = -661.559446, rho = 0.169869
# nSV = 738, nBSV = 4
# .*.*
# optimization finished, #iter = 2043
# obj = -507.448619, rho = 0.273097
# nSV = 753, nBSV = 0
# .*.*
# optimization finished, #iter = 1830
# obj = -524.422930, rho = 0.271070
# nSV = 705, nBSV = 4
# Total nSV = 1909
# [LibSVM].*.*
# optimization finished, #iter = 2610
# obj = -1066.547794, rho = -0.018902
# nSV = 830, nBSV = 56
# *.*
# optimization finished, #iter = 1130
# obj = -185.506022, rho = -0.068486
# nSV = 469, nBSV = 2
# .*
# optimization finished, #iter = 1546
# obj = -290.556746, rho = -0.069963
# nSV = 591, nBSV = 8
# .*.*
# optimization finished, #iter = 1978
# obj = -669.816457, rho = 0.255033
# nSV = 745, nBSV = 4
# .*.*
# optimization finished, #iter = 2161
# obj = -550.819787, rho = 0.276799
# nSV = 773, nBSV = 1
# .*
# optimization finished, #iter = 1779
# obj = -531.711610, rho = 0.281674
# nSV = 703, nBSV = 4
# Total nSV = 1917
# [LibSVM].*.*
# optimization finished, #iter = 2546
# obj = -1061.550420, rho = -0.060861
# nSV = 816, nBSV = 64
# *.*
# optimization finished, #iter = 1158
# obj = -180.736770, rho = -0.070692
# nSV = 476, nBSV = 2
# .*
# optimization finished, #iter = 1605
# obj = -287.493421, rho = -0.048396
# nSV = 601, nBSV = 10
# .*
# optimization finished, #iter = 1926
# obj = -610.422387, rho = 0.292110
# nSV = 717, nBSV = 2
# .*.*
# optimization finished, #iter = 2139
# obj = -530.375558, rho = 0.306056
# nSV = 774, nBSV = 1
# .*
# optimization finished, #iter = 1781
# obj = -519.395042, rho = 0.177787
# nSV = 701, nBSV = 4
# Total nSV = 1917
# [LibSVM].*.*
# optimization finished, #iter = 2480
# obj = -1014.024141, rho = -0.052277
# nSV = 817, nBSV = 55
# *.*
# optimization finished, #iter = 1150
# obj = -187.326451, rho = -0.058636
# nSV = 478, nBSV = 2
# .*
# optimization finished, #iter = 1501
# obj = -268.284870, rho = -0.109318
# nSV = 560, nBSV = 7
# .*.*
# optimization finished, #iter = 2011
# obj = -650.559504, rho = 0.305883
# nSV = 749, nBSV = 3
# .*.*
# optimization finished, #iter = 2095
# obj = -528.557856, rho = 0.260019
# nSV = 772, nBSV = 1
# .*
# optimization finished, #iter = 1741
# obj = -493.419558, rho = 0.122821
# nSV = 692, nBSV = 3
# Total nSV = 1908
# [LibSVM].*.*
# optimization finished, #iter = 2590
# obj = -1021.479086, rho = -0.025300
# nSV = 838, nBSV = 53
# *.*
# optimization finished, #iter = 1120
# obj = -188.902439, rho = -0.089459
# nSV = 479, nBSV = 2
# .*
# optimization finished, #iter = 1588
# obj = -281.046079, rho = -0.081564
# nSV = 590, nBSV = 8
# .*.*
# optimization finished, #iter = 1989
# obj = -667.538048, rho = 0.309702
# nSV = 739, nBSV = 4
# .*.*
# optimization finished, #iter = 2120
# obj = -537.091397, rho = 0.326818
# nSV = 767, nBSV = 1
# .*.*
# optimization finished, #iter = 1819
# obj = -510.308816, rho = 0.266306
# nSV = 710, nBSV = 3
# Total nSV = 1930
# [LibSVM].*.*
# optimization finished, #iter = 2578
# obj = -1043.495174, rho = 0.018684
# nSV = 829, nBSV = 53
# *.*
# optimization finished, #iter = 1111
# obj = -176.858288, rho = -0.089199
# nSV = 471, nBSV = 1
# .*
# optimization finished, #iter = 1493
# obj = -275.078149, rho = -0.142646
# nSV = 579, nBSV = 9
# .*.*
# optimization finished, #iter = 2018
# obj = -669.597860, rho = 0.211527
# nSV = 736, nBSV = 5
# .*.*
# optimization finished, #iter = 2134
# obj = -525.981656, rho = 0.282387
# nSV = 766, nBSV = 1
# .*.*
# optimization finished, #iter = 1806
# obj = -506.716328, rho = 0.236478
# nSV = 700, nBSV = 3
# Total nSV = 1922
# [LibSVM].*.*
# optimization finished, #iter = 2568
# obj = -1015.921188, rho = 0.056772
# nSV = 820, nBSV = 51
# *.*
# optimization finished, #iter = 1135
# obj = -188.664529, rho = -0.064865
# nSV = 484, nBSV = 2
# .*
# optimization finished, #iter = 1595
# obj = -288.935751, rho = -0.083857
# nSV = 593, nBSV = 7
# .*.*
# optimization finished, #iter = 1998
# obj = -634.259177, rho = 0.181514
# nSV = 739, nBSV = 3
# .*.*
# optimization finished, #iter = 2161
# obj = -543.447317, rho = 0.278736
# nSV = 778, nBSV = 2
# .*.*
# optimization finished, #iter = 1822
# obj = -498.293310, rho = 0.216406
# nSV = 714, nBSV = 3
# Total nSV = 1911
# Training duration for PCA=2025, C=10.5, kernel=rbf, gamma=scale: 2010.557846069336 seconds
# [LibSVM].*.*
# optimization finished, #iter = 2514
# obj = -984.552793, rho = -0.042225
# nSV = 850, nBSV = 58
# *.*
# optimization finished, #iter = 1218
# obj = -189.576799, rho = -0.132584
# nSV = 490, nBSV = 2
# .*
# optimization finished, #iter = 1588
# obj = -282.825235, rho = -0.113785
# nSV = 615, nBSV = 11
# .*.*
# optimization finished, #iter = 2002
# obj = -642.570557, rho = 0.167486
# nSV = 760, nBSV = 4
# .*.*
# optimization finished, #iter = 2162
# obj = -513.455285, rho = 0.211799
# nSV = 786, nBSV = 1
# .*
# optimization finished, #iter = 1751
# obj = -505.056063, rho = 0.171617
# nSV = 710, nBSV = 4
# Total nSV = 1938
# [LibSVM].*.*
# optimization finished, #iter = 2480
# obj = -977.469121, rho = -0.022732
# nSV = 847, nBSV = 62
# *.*
# optimization finished, #iter = 1143
# obj = -179.777127, rho = -0.057534
# nSV = 479, nBSV = 2
# .*
# optimization finished, #iter = 1499
# obj = -268.436360, rho = -0.087849
# nSV = 592, nBSV = 8
# .*.*
# optimization finished, #iter = 1978
# obj = -606.407744, rho = 0.227482
# nSV = 750, nBSV = 4
# .*.*
# optimization finished, #iter = 2082
# obj = -515.581588, rho = 0.286565
# nSV = 783, nBSV = 2
# .*
# optimization finished, #iter = 1784
# obj = -471.905908, rho = 0.184819
# nSV = 707, nBSV = 2
# Total nSV = 1935
# [LibSVM].*.*
# optimization finished, #iter = 2510
# obj = -987.615848, rho = 0.056707
# nSV = 869, nBSV = 55
# *.*
# optimization finished, #iter = 1104
# obj = -188.291239, rho = -0.091933
# nSV = 472, nBSV = 2
# .*
# optimization finished, #iter = 1540
# obj = -283.767034, rho = -0.095660
# nSV = 602, nBSV = 9
# .*
# optimization finished, #iter = 1972
# obj = -664.775612, rho = 0.211122
# nSV = 755, nBSV = 5
# .*.*
# optimization finished, #iter = 2122
# obj = -518.667967, rho = 0.202937
# nSV = 777, nBSV = 1
# .*
# optimization finished, #iter = 1788
# obj = -500.974462, rho = 0.196048
# nSV = 717, nBSV = 3
# Total nSV = 1949
# [LibSVM].*.*
# optimization finished, #iter = 2543
# obj = -967.089597, rho = 0.014419
# nSV = 848, nBSV = 69
# *.*
# optimization finished, #iter = 1223
# obj = -191.556380, rho = -0.103110
# nSV = 500, nBSV = 3
# .*
# optimization finished, #iter = 1542
# obj = -257.559000, rho = -0.121288
# nSV = 599, nBSV = 7
# .*.*
# optimization finished, #iter = 1985
# obj = -638.845751, rho = 0.153684
# nSV = 758, nBSV = 4
# .*.*
# optimization finished, #iter = 2017
# obj = -497.764207, rho = 0.263352
# nSV = 767, nBSV = 0
# .*
# optimization finished, #iter = 1792
# obj = -510.211579, rho = 0.277238
# nSV = 712, nBSV = 4
# Total nSV = 1941
# [LibSVM].*.*
# optimization finished, #iter = 2470
# obj = -1003.974003, rho = -0.029420
# nSV = 856, nBSV = 72
# *.*
# optimization finished, #iter = 1136
# obj = -184.624286, rho = -0.080508
# nSV = 471, nBSV = 2
# .*
# optimization finished, #iter = 1576
# obj = -284.247271, rho = -0.080446
# nSV = 609, nBSV = 10
# .*.*
# optimization finished, #iter = 2002
# obj = -644.936330, rho = 0.241958
# nSV = 754, nBSV = 4
# .*.*
# optimization finished, #iter = 2207
# obj = -538.265453, rho = 0.265635
# nSV = 789, nBSV = 1
# .*
# optimization finished, #iter = 1781
# obj = -517.443923, rho = 0.278186
# nSV = 710, nBSV = 4
# Total nSV = 1941
# [LibSVM].*.*
# optimization finished, #iter = 2491
# obj = -995.861993, rho = -0.066444
# nSV = 849, nBSV = 62
# *.*
# optimization finished, #iter = 1162
# obj = -179.759558, rho = -0.080992
# nSV = 481, nBSV = 2
# .*
# optimization finished, #iter = 1574
# obj = -281.135302, rho = -0.059525
# nSV = 614, nBSV = 12
# .*
# optimization finished, #iter = 1901
# obj = -591.152922, rho = 0.269702
# nSV = 729, nBSV = 3
# .*.*
# optimization finished, #iter = 2116
# obj = -518.257070, rho = 0.291959
# nSV = 789, nBSV = 1
# .*
# optimization finished, #iter = 1795
# obj = -505.979369, rho = 0.176871
# nSV = 706, nBSV = 4
# Total nSV = 1942
# [LibSVM].*.*
# optimization finished, #iter = 2470
# obj = -955.431602, rho = -0.058433
# nSV = 847, nBSV = 67
# *.*
# optimization finished, #iter = 1165
# obj = -186.206349, rho = -0.069816
# nSV = 488, nBSV = 3
# *.*
# optimization finished, #iter = 1461
# obj = -262.873129, rho = -0.115275
# nSV = 581, nBSV = 7
# .*.*
# optimization finished, #iter = 2005
# obj = -627.968621, rho = 0.285386
# nSV = 766, nBSV = 5
# .*.*
# optimization finished, #iter = 2066
# obj = -516.667134, rho = 0.244734
# nSV = 780, nBSV = 1
# .*
# optimization finished, #iter = 1689
# obj = -483.174668, rho = 0.129586
# nSV = 696, nBSV = 3
# Total nSV = 1940
# [LibSVM].*.*
# optimization finished, #iter = 2548
# obj = -962.154472, rho = -0.032941
# nSV = 853, nBSV = 72
# *.*
# optimization finished, #iter = 1136
# obj = -188.045400, rho = -0.098721
# nSV = 483, nBSV = 2
# .*
# optimization finished, #iter = 1587
# obj = -275.219889, rho = -0.095889
# nSV = 600, nBSV = 9
# .*
# optimization finished, #iter = 1967
# obj = -641.420777, rho = 0.291779
# nSV = 752, nBSV = 5
# .*.*
# optimization finished, #iter = 2100
# obj = -523.557319, rho = 0.310715
# nSV = 782, nBSV = 1
# .*
# optimization finished, #iter = 1784
# obj = -499.788804, rho = 0.263156
# nSV = 716, nBSV = 3
# Total nSV = 1944
# [LibSVM].*.*
# optimization finished, #iter = 2502
# obj = -981.190078, rho = 0.015537
# nSV = 855, nBSV = 65
# *.*
# optimization finished, #iter = 1144
# obj = -176.270485, rho = -0.100690
# nSV = 476, nBSV = 2
# .*
# optimization finished, #iter = 1487
# obj = -269.239548, rho = -0.152742
# nSV = 594, nBSV = 11
# .*.*
# optimization finished, #iter = 2039
# obj = -644.781626, rho = 0.194445
# nSV = 747, nBSV = 5
# .*.*
# optimization finished, #iter = 2106
# obj = -517.095148, rho = 0.267651
# nSV = 788, nBSV = 1
# .*
# optimization finished, #iter = 1786
# obj = -495.943155, rho = 0.237302
# nSV = 708, nBSV = 3
# Total nSV = 1941
# [LibSVM].*.*
# optimization finished, #iter = 2520
# obj = -962.549463, rho = 0.043214
# nSV = 848, nBSV = 62
# *.*
# optimization finished, #iter = 1173
# obj = -187.762145, rho = -0.076319
# nSV = 491, nBSV = 2
# .*
# optimization finished, #iter = 1548
# obj = -283.103456, rho = -0.091908
# nSV = 614, nBSV = 10
# .*.*
# optimization finished, #iter = 1992
# obj = -619.029843, rho = 0.175087
# nSV = 754, nBSV = 3
# .*.*
# optimization finished, #iter = 2150
# obj = -531.033166, rho = 0.263209
# nSV = 793, nBSV = 2
# .*.*
# optimization finished, #iter = 1834
# obj = -488.091567, rho = 0.214984
# nSV = 724, nBSV = 3
# Total nSV = 1942
# Training duration for PCA=2500, C=9, kernel=rbf, gamma=scale: 2150.440050125122 seconds
# [LibSVM].*.*
# optimization finished, #iter = 2612
# obj = -998.038479, rho = -0.043387
# nSV = 848, nBSV = 52
# *.*
# optimization finished, #iter = 1218
# obj = -189.576799, rho = -0.132584
# nSV = 490, nBSV = 2
# .*
# optimization finished, #iter = 1603
# obj = -282.901886, rho = -0.112768
# nSV = 614, nBSV = 8
# .*.*
# optimization finished, #iter = 1989
# obj = -647.794014, rho = 0.171264
# nSV = 754, nBSV = 3
# .*.*
# optimization finished, #iter = 2073
# obj = -515.139498, rho = 0.211127
# nSV = 781, nBSV = 1
# .*
# optimization finished, #iter = 1777
# obj = -507.390638, rho = 0.173417
# nSV = 710, nBSV = 4
# Total nSV = 1936
# [LibSVM].*.*
# optimization finished, #iter = 2561
# obj = -990.937919, rho = -0.019408
# nSV = 843, nBSV = 52
# *.*
# optimization finished, #iter = 1149
# obj = -179.807573, rho = -0.056915
# nSV = 478, nBSV = 2
# .*
# optimization finished, #iter = 1509
# obj = -269.071219, rho = -0.087788
# nSV = 591, nBSV = 7
# .*
# optimization finished, #iter = 1962
# obj = -609.845334, rho = 0.229096
# nSV = 752, nBSV = 4
# .*.*
# optimization finished, #iter = 2076
# obj = -517.228781, rho = 0.287010
# nSV = 784, nBSV = 2
# .*
# optimization finished, #iter = 1776
# obj = -473.178645, rho = 0.184976
# nSV = 707, nBSV = 2
# Total nSV = 1934
# [LibSVM].*.*
# optimization finished, #iter = 2608
# obj = -1000.583018, rho = 0.058145
# nSV = 866, nBSV = 48
# *.*
# optimization finished, #iter = 1104
# obj = -188.291239, rho = -0.091933
# nSV = 472, nBSV = 2
# .*
# optimization finished, #iter = 1576
# obj = -283.888045, rho = -0.094472
# nSV = 604, nBSV = 8
# .*
# optimization finished, #iter = 1972
# obj = -670.589323, rho = 0.214581
# nSV = 758, nBSV = 5
# .*.*
# optimization finished, #iter = 2062
# obj = -520.348771, rho = 0.202935
# nSV = 778, nBSV = 1
# .*
# optimization finished, #iter = 1798
# obj = -502.911701, rho = 0.198021
# nSV = 715, nBSV = 3
# Total nSV = 1947
# [LibSVM].*.*
# optimization finished, #iter = 2557
# obj = -978.558149, rho = 0.018217
# nSV = 849, nBSV = 53
# *.*
# optimization finished, #iter = 1223
# obj = -191.556380, rho = -0.103110
# nSV = 500, nBSV = 2
# .*
# optimization finished, #iter = 1542
# obj = -257.559000, rho = -0.121288
# nSV = 599, nBSV = 5
# .*.*
# optimization finished, #iter = 2054
# obj = -644.079882, rho = 0.152304
# nSV = 754, nBSV = 4
# .*.*
# optimization finished, #iter = 2022
# obj = -498.618668, rho = 0.263120
# nSV = 767, nBSV = 0
# .*
# optimization finished, #iter = 1801
# obj = -512.609404, rho = 0.278585
# nSV = 712, nBSV = 4
# Total nSV = 1939
# [LibSVM].*.*
# optimization finished, #iter = 2566
# obj = -1016.874257, rho = -0.025485
# nSV = 859, nBSV = 51
# *.*
# optimization finished, #iter = 1136
# obj = -184.624286, rho = -0.080508
# nSV = 471, nBSV = 2
# .*
# optimization finished, #iter = 1569
# obj = -284.598810, rho = -0.078971
# nSV = 607, nBSV = 8
# .*.*
# optimization finished, #iter = 2034
# obj = -649.910495, rho = 0.245106
# nSV = 754, nBSV = 4
# .*.*
# optimization finished, #iter = 2101
# obj = -540.131894, rho = 0.265855
# nSV = 789, nBSV = 1
# .*
# optimization finished, #iter = 1798
# obj = -519.898299, rho = 0.279860
# nSV = 709, nBSV = 4
# Total nSV = 1942
# [LibSVM].*.*
# optimization finished, #iter = 2525
# obj = -1008.988686, rho = -0.064803
# nSV = 846, nBSV = 59
# *.*
# optimization finished, #iter = 1162
# obj = -179.759558, rho = -0.080992
# nSV = 481, nBSV = 2
# .*
# optimization finished, #iter = 1597
# obj = -281.215893, rho = -0.058184
# nSV = 615, nBSV = 7
# .*
# optimization finished, #iter = 1928
# obj = -594.368472, rho = 0.275198
# nSV = 730, nBSV = 4
# .*.*
# optimization finished, #iter = 2071
# obj = -520.133716, rho = 0.291352
# nSV = 786, nBSV = 1
# .*
# optimization finished, #iter = 1782
# obj = -508.360471, rho = 0.179212
# nSV = 706, nBSV = 4
# Total nSV = 1942
# [LibSVM].*.*
# optimization finished, #iter = 2553
# obj = -967.904827, rho = -0.058238
# nSV = 845, nBSV = 54
# *.*
# optimization finished, #iter = 1171
# obj = -186.247850, rho = -0.069159
# nSV = 487, nBSV = 2
# .*
# optimization finished, #iter = 1491
# obj = -263.252409, rho = -0.115884
# nSV = 577, nBSV = 4
# .*.*
# optimization finished, #iter = 1993
# obj = -633.012679, rho = 0.288865
# nSV = 764, nBSV = 3
# .*.*
# optimization finished, #iter = 2109
# obj = -518.418640, rho = 0.245180
# nSV = 780, nBSV = 1
# .*
# optimization finished, #iter = 1735
# obj = -485.178303, rho = 0.130333
# nSV = 697, nBSV = 3
# Total nSV = 1936
# [LibSVM].*.*
# optimization finished, #iter = 2629
# obj = -974.248403, rho = -0.026973
# nSV = 857, nBSV = 53
# *.*
# optimization finished, #iter = 1136
# obj = -188.045400, rho = -0.098721
# nSV = 483, nBSV = 2
# .*
# optimization finished, #iter = 1551
# obj = -275.326485, rho = -0.094697
# nSV = 600, nBSV = 9
# .*.*
# optimization finished, #iter = 1995
# obj = -646.530133, rho = 0.296890
# nSV = 752, nBSV = 5
# .*.*
# optimization finished, #iter = 2114
# obj = -525.307156, rho = 0.310897
# nSV = 784, nBSV = 1
# .*.*
# optimization finished, #iter = 1806
# obj = -501.330089, rho = 0.265114
# nSV = 716, nBSV = 3
# Total nSV = 1946
# [LibSVM].*.*
# optimization finished, #iter = 2544
# obj = -993.846584, rho = 0.019764
# nSV = 854, nBSV = 62
# *.*
# optimization finished, #iter = 1144
# obj = -176.270485, rho = -0.100690
# nSV = 476, nBSV = 2
# .*
# optimization finished, #iter = 1525
# obj = -269.435478, rho = -0.151891
# nSV = 590, nBSV = 9
# .*.*
# optimization finished, #iter = 2009
# obj = -649.510035, rho = 0.199755
# nSV = 749, nBSV = 5
# .*.*
# optimization finished, #iter = 2095
# obj = -517.967588, rho = 0.267136
# nSV = 788, nBSV = 1
# .*
# optimization finished, #iter = 1796
# obj = -497.705907, rho = 0.237257
# nSV = 708, nBSV = 3
# Total nSV = 1937
# [LibSVM].*.*
# optimization finished, #iter = 2582
# obj = -974.125034, rho = 0.046805
# nSV = 845, nBSV = 51
# *.*
# optimization finished, #iter = 1173
# obj = -187.762145, rho = -0.076319
# nSV = 491, nBSV = 2
# .*
# optimization finished, #iter = 1575
# obj = -283.274415, rho = -0.091007
# nSV = 614, nBSV = 7
# .*.*
# optimization finished, #iter = 2005
# obj = -621.430061, rho = 0.172290
# nSV = 755, nBSV = 3
# .*.*
# optimization finished, #iter = 2122
# obj = -532.303476, rho = 0.263654
# nSV = 794, nBSV = 2
# .*.*
# optimization finished, #iter = 1837
# obj = -489.696869, rho = 0.217342
# nSV = 721, nBSV = 3
# Total nSV = 1939
# Training duration for PCA=2500, C=10, kernel=rbf, gamma=scale: 2146.60870885849 seconds
# [LibSVM].*.*
# optimization finished, #iter = 2617
# obj = -1003.647380, rho = -0.044315
# nSV = 842, nBSV = 45
# *.*
# optimization finished, #iter = 1218
# obj = -189.576799, rho = -0.132584
# nSV = 490, nBSV = 2
# .*
# optimization finished, #iter = 1584
# obj = -282.903030, rho = -0.112463
# nSV = 614, nBSV = 5
# .*
# optimization finished, #iter = 1955
# obj = -649.919888, rho = 0.172855
# nSV = 754, nBSV = 3
# .*.*
# optimization finished, #iter = 2081
# obj = -515.829224, rho = 0.211110
# nSV = 781, nBSV = 1
# .*
# optimization finished, #iter = 1786
# obj = -508.272581, rho = 0.174401
# nSV = 710, nBSV = 4
# Total nSV = 1931
# [LibSVM].*.*
# optimization finished, #iter = 2522
# obj = -996.574905, rho = -0.018074
# nSV = 844, nBSV = 50
# *.*
# optimization finished, #iter = 1149
# obj = -179.807573, rho = -0.056915
# nSV = 478, nBSV = 2
# .*
# optimization finished, #iter = 1535
# obj = -269.251745, rho = -0.087927
# nSV = 589, nBSV = 7
# .*
# optimization finished, #iter = 1950
# obj = -611.237937, rho = 0.229877
# nSV = 752, nBSV = 4
# .*.*
# optimization finished, #iter = 2091
# obj = -517.927311, rho = 0.287277
# nSV = 784, nBSV = 1
# .*
# optimization finished, #iter = 1800
# obj = -473.674721, rho = 0.185077
# nSV = 708, nBSV = 2
# Total nSV = 1933
# [LibSVM].*.*
# optimization finished, #iter = 2613
# obj = -1005.988600, rho = 0.058476
# nSV = 863, nBSV = 48
# *.*
# optimization finished, #iter = 1104
# obj = -188.291239, rho = -0.091933
# nSV = 472, nBSV = 2
# .*
# optimization finished, #iter = 1569
# obj = -283.888250, rho = -0.094417
# nSV = 604, nBSV = 5
# .*.*
# optimization finished, #iter = 2030
# obj = -672.974906, rho = 0.215865
# nSV = 757, nBSV = 4
# .*.*
# optimization finished, #iter = 2035
# obj = -521.055974, rho = 0.202990
# nSV = 777, nBSV = 1
# .*
# optimization finished, #iter = 1790
# obj = -503.670990, rho = 0.198979
# nSV = 714, nBSV = 3
# Total nSV = 1944
# [LibSVM].*.*
# optimization finished, #iter = 2584
# obj = -983.230891, rho = 0.018754
# nSV = 848, nBSV = 48
# *.*
# optimization finished, #iter = 1223
# obj = -191.556380, rho = -0.103110
# nSV = 500, nBSV = 2
# .*
# optimization finished, #iter = 1542
# obj = -257.559000, rho = -0.121288
# nSV = 599, nBSV = 4
# .*.*
# optimization finished, #iter = 2048
# obj = -646.195318, rho = 0.151356
# nSV = 755, nBSV = 3
# .*.*
# optimization finished, #iter = 2010
# obj = -499.006720, rho = 0.263177
# nSV = 767, nBSV = 0
# .*.*
# optimization finished, #iter = 1818
# obj = -513.525691, rho = 0.279299
# nSV = 712, nBSV = 4
# Total nSV = 1937
# [LibSVM].*.*
# optimization finished, #iter = 2604
# obj = -1022.209766, rho = -0.023510
# nSV = 858, nBSV = 55
# *.*
# optimization finished, #iter = 1136
# obj = -184.624286, rho = -0.080508
# nSV = 471, nBSV = 2
# .*
# optimization finished, #iter = 1577
# obj = -284.675669, rho = -0.078075
# nSV = 606, nBSV = 7
# .*.*
# optimization finished, #iter = 1978
# obj = -651.963420, rho = 0.246618
# nSV = 754, nBSV = 4
# .*.*
# optimization finished, #iter = 2139
# obj = -540.944843, rho = 0.265936
# nSV = 789, nBSV = 1
# .*.*
# optimization finished, #iter = 1819
# obj = -520.844322, rho = 0.280812
# nSV = 709, nBSV = 4
# Total nSV = 1941
# [LibSVM].*.*
# optimization finished, #iter = 2556
# obj = -1014.389771, rho = -0.063599
# nSV = 846, nBSV = 51
# *.*
# optimization finished, #iter = 1162
# obj = -179.759558, rho = -0.080992
# nSV = 481, nBSV = 2
# .*
# optimization finished, #iter = 1645
# obj = -281.216300, rho = -0.058008
# nSV = 615, nBSV = 6
# .*
# optimization finished, #iter = 1919
# obj = -595.665752, rho = 0.277478
# nSV = 730, nBSV = 2
# .*.*
# optimization finished, #iter = 2110
# obj = -520.906094, rho = 0.291358
# nSV = 786, nBSV = 1
# .*
# optimization finished, #iter = 1779
# obj = -509.266466, rho = 0.180400
# nSV = 707, nBSV = 4
# Total nSV = 1942
# [LibSVM].*.*
# optimization finished, #iter = 2507
# obj = -973.041446, rho = -0.058345
# nSV = 840, nBSV = 49
# *.*
# optimization finished, #iter = 1171
# obj = -186.247850, rho = -0.069159
# nSV = 487, nBSV = 2
# .*
# optimization finished, #iter = 1480
# obj = -263.344451, rho = -0.116811
# nSV = 576, nBSV = 4
# .*.*
# optimization finished, #iter = 2024
# obj = -635.070343, rho = 0.289973
# nSV = 763, nBSV = 3
# .*.*
# optimization finished, #iter = 2100
# obj = -519.170088, rho = 0.245448
# nSV = 780, nBSV = 1
# .*
# optimization finished, #iter = 1735
# obj = -485.971549, rho = 0.130846
# nSV = 698, nBSV = 3
# Total nSV = 1933
# [LibSVM].*.*
# optimization finished, #iter = 2628
# obj = -979.207916, rho = -0.026555
# nSV = 855, nBSV = 43
# *.*
# optimization finished, #iter = 1136
# obj = -188.045400, rho = -0.098721
# nSV = 483, nBSV = 2
# .*
# optimization finished, #iter = 1578
# obj = -275.363144, rho = -0.094209
# nSV = 600, nBSV = 7
# .*
# optimization finished, #iter = 1975
# obj = -648.616498, rho = 0.298921
# nSV = 752, nBSV = 4
# .*.*
# optimization finished, #iter = 2100
# obj = -526.055480, rho = 0.311111
# nSV = 783, nBSV = 1
# .*.*
# optimization finished, #iter = 1807
# obj = -501.884646, rho = 0.266086
# nSV = 714, nBSV = 3
# Total nSV = 1946
# [LibSVM].*.*
# optimization finished, #iter = 2554
# obj = -998.937160, rho = 0.020799
# nSV = 850, nBSV = 55
# *.*
# optimization finished, #iter = 1144
# obj = -176.270485, rho = -0.100690
# nSV = 476, nBSV = 1
# .*
# optimization finished, #iter = 1527
# obj = -269.446443, rho = -0.151477
# nSV = 590, nBSV = 7
# .*.*
# optimization finished, #iter = 1987
# obj = -651.419182, rho = 0.202071
# nSV = 750, nBSV = 4
# .*.*
# optimization finished, #iter = 2097
# obj = -518.313667, rho = 0.267099
# nSV = 788, nBSV = 1
# .*
# optimization finished, #iter = 1798
# obj = -498.375216, rho = 0.237178
# nSV = 708, nBSV = 3
# Total nSV = 1935
# [LibSVM].*.*
# optimization finished, #iter = 2579
# obj = -978.779506, rho = 0.048741
# nSV = 844, nBSV = 47
# *.*
# optimization finished, #iter = 1173
# obj = -187.762145, rho = -0.076319
# nSV = 491, nBSV = 2
# .*
# optimization finished, #iter = 1620
# obj = -283.276161, rho = -0.090781
# nSV = 615, nBSV = 6
# .*.*
# optimization finished, #iter = 2002
# obj = -622.376276, rho = 0.170649
# nSV = 756, nBSV = 2
# .*.*
# optimization finished, #iter = 2185
# obj = -532.815666, rho = 0.263961
# nSV = 793, nBSV = 2
# .*.*
# optimization finished, #iter = 1819
# obj = -490.283134, rho = 0.218618
# nSV = 721, nBSV = 3
# Total nSV = 1940
# Training duration for PCA=2500, C=10.5, kernel=rbf, gamma=scale: 1676.2611141204834 seconds

# %%
run_metrics = {}
run_params = {}

for run_id in run_ids:
    client = mlflow.tracking.MlflowClient(ML_FLOW_DIRECTORY)
    run = client.get_run(run_id)
    metrics = run.data.metrics
    params = run.data.params
    run_metrics[run_id] = metrics
    run_params[run_id] = params

for run_id in run_ids:
    print(f"Run ID: {run_id}")
    print("Metrics:")
    metrics = run_metrics[run_id]
    for metric, value in metrics.items():
        print(f"\t{metric}: {value}")

    print("Parameters:")
    params = run_params[run_id]
    for param, value in params.items():
        print(f"\t{param}: {value}")
# Out:
# Run ID: 2c5e0889a25d4f6198011c3f1c940674
# Metrics:
# 	mean_f1_weighted: 0.858136518892557
# 	mean_accuracy: 0.8587045570916538
# 	mean_recall: 0.8587045570916538
# 	mean_precision: 0.859396922731795
# Parameters:
# 	gamma: scale
# 	pca_components: 1600
# 	C: 9
# 	kernel: rbf
# Run ID: 48928baac2144e85b8ef021edabcbbc0
# Metrics:
# 	mean_f1_weighted: 0.8588437866954063
# 	mean_accuracy: 0.8594226830517153
# 	mean_recall: 0.8594226830517153
# 	mean_precision: 0.8601183763650667
# Parameters:
# 	gamma: scale
# 	pca_components: 1600
# 	C: 10
# 	kernel: rbf
# Run ID: 1607c9810d9a43fdbe31847e79b7da53
# Metrics:
# 	mean_f1_weighted: 0.8581366597704709
# 	mean_accuracy: 0.8587083973374297
# 	mean_recall: 0.8587083973374297
# 	mean_precision: 0.8594076881137994
# Parameters:
# 	gamma: scale
# 	pca_components: 1600
# 	C: 10.5
# 	kernel: rbf
# Run ID: 5e04c83533d5462fa994ab4ee02e06ce
# Metrics:
# 	mean_f1_weighted: 0.8588472464951025
# 	mean_accuracy: 0.8594188428059395
# 	mean_recall: 0.8594188428059395
# 	mean_precision: 0.8603170575935852
# Parameters:
# 	gamma: scale
# 	pca_components: 2025
# 	C: 9
# 	kernel: rbf
# Run ID: f149f79c351b439881f45776d47f11c4
# Metrics:
# 	mean_f1_weighted: 0.8584977018394648
# 	mean_accuracy: 0.8590642601126472
# 	mean_recall: 0.8590642601126472
# 	mean_precision: 0.8599139085634174
# Parameters:
# 	gamma: scale
# 	pca_components: 2025
# 	C: 10
# 	kernel: rbf
# Run ID: 4e8a7518cd1a400880f1d9655c7ef7e1
# Metrics:
# 	mean_f1_weighted: 0.8584679138412602
# 	mean_accuracy: 0.8590642601126472
# 	mean_recall: 0.8590642601126472
# 	mean_precision: 0.8598418970316143
# Parameters:
# 	gamma: scale
# 	pca_components: 2025
# 	C: 10.5
# 	kernel: rbf
# Run ID: c3b0c7ddbe66406d9a01c744de9894a9
# Metrics:
# 	mean_f1_weighted: 0.8595412904504144
# 	mean_accuracy: 0.8601369687660011
# 	mean_recall: 0.8601369687660011
# 	mean_precision: 0.8610459586099418
# Parameters:
# 	gamma: scale
# 	pca_components: 2500
# 	C: 9
# 	kernel: rbf
# Run ID: ceab38cde7f747ea84dd62390950896a
# Metrics:
# 	mean_f1_weighted: 0.858103319218014
# 	mean_accuracy: 0.8587045570916538
# 	mean_recall: 0.8587045570916538
# 	mean_precision: 0.8595310637380982
# Parameters:
# 	gamma: scale
# 	pca_components: 2500
# 	C: 10
# 	kernel: rbf
# Run ID: f3292752954c44588be03a2cc3157977
# Metrics:
# 	mean_f1_weighted: 0.85739032813078
# 	mean_accuracy: 0.8579877112135177
# 	mean_recall: 0.8579877112135177
# 	mean_precision: 0.8587622672394388
# Parameters:
# 	gamma: scale
# 	pca_components: 2500
# 	C: 10.5
# 	kernel: rbf

# %%
best_run_id = max(run_metrics, key=lambda x: run_metrics[x]["mean_f1_weighted"])
best_run_params = run_params[best_run_id]
best_run_metrics = run_metrics[best_run_id]

print(f"\nBest Run ID: {best_run_id}")
print("Best Parameters:")
for key, value in best_run_params.items():
    print(f"\t{key}: {value}")

print("\nBest Run Metrics:")
for metric, value in best_run_metrics.items():
    print(f"\t{metric}: {value}")
# Out:
# Best Run ID: c3b0c7ddbe66406d9a01c744de9894a9
# Best Parameters:
# 	gamma: scale
# 	pca_components: 2500
# 	C: 9
# 	kernel: rbf
#
# Best Run Metrics:
# 	mean_f1_weighted: 0.8595412904504144
# 	mean_accuracy: 0.8601369687660011
# 	mean_recall: 0.8601369687660011
# 	mean_precision: 0.8610459586099418
