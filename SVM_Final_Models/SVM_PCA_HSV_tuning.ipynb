# %% [markdown]
# # SVM with PCA (HSV)

# %%
import re
import cv2
import os
import glob
import time
import mlflow
import random
import shutil
import itertools

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from PIL import Image
from sklearn.decomposition import PCA
from sklearn import svm
from sklearn.model_selection import cross_validate, StratifiedKFold
from sklearn.metrics import (
    make_scorer,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
)

# %%
TRAIN_DIR = "../data/train"
CLASS_FOLDERS = ["Class A", "Class B", "Class C", "Class D"]
ML_FLOW_DIRECTORY = "SVM_Logs"

# %%
mlflow.set_tracking_uri(ML_FLOW_DIRECTORY)
mlflow.set_experiment("SVM_PCA_HSV")
# Out:
# <Experiment: artifact_location='/Users/jacob/Code/Monkey-Business/SVM_Final_Models/SVM_Logs/460119513691526511', creation_time=1702029139080, experiment_id='460119513691526511', last_update_time=1702029139080, lifecycle_stage='active', name='SVM_PCA_HSV', tags={}>

# %%
pca_components = [40 * 40, 45 * 45, 50 * 50]
C_values = [9, 10, 10.5]
kernel_types = ["rbf"]
gamma_values = ["scale"]

# %%
hyperparameter_combinations = list(
    itertools.product(pca_components, C_values, kernel_types, gamma_values)
)
print(
    f"Total number of hyperparameter combinations: {len(hyperparameter_combinations)}"
)
# Out:
# Total number of hyperparameter combinations: 9

# %%
pca_models_dict = {}

# %%
def train_with_params(pca_components, C, kernel, gamma, train_images, train_labels):
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    with mlflow.start_run() as run:
        start_time = time.time()

        scores = []
        for train_index, valid_index in skf.split(train_images, train_labels):
            train_images_fold, valid_images_fold = (
                train_images[train_index],
                train_images[valid_index],
            )
            train_labels_fold, valid_labels_fold = (
                train_labels[train_index],
                train_labels[valid_index],
            )

            pca = PCA(n_components=pca_components)
            pca.fit(train_images_fold)

            train_images_pca = pca.transform(train_images_fold)
            valid_images_pca = pca.transform(valid_images_fold)

            clf = svm.SVC(
                C=C, kernel=kernel, gamma=gamma, class_weight="balanced", verbose=True
            )
            clf.fit(train_images_pca, train_labels_fold)
            valid_predictions = clf.predict(valid_images_pca)

            scores.append(
                {
                    "f1_weighted": f1_score(
                        valid_labels_fold, valid_predictions, average="weighted"
                    ),
                    "accuracy": accuracy_score(valid_labels_fold, valid_predictions),
                    "precision": precision_score(
                        valid_labels_fold, valid_predictions, average="weighted"
                    ),
                    "recall": recall_score(
                        valid_labels_fold, valid_predictions, average="weighted"
                    ),
                }
            )

        mean_scores = {
            "mean_f1_weighted": np.mean([s["f1_weighted"] for s in scores]),
            "mean_accuracy": np.mean([s["accuracy"] for s in scores]),
            "mean_precision": np.mean([s["precision"] for s in scores]),
            "mean_recall": np.mean([s["recall"] for s in scores]),
        }

        # Log hyperparameters and metrics
        mlflow.log_params(
            {"pca_components": pca_components, "C": C, "kernel": kernel, "gamma": gamma}
        )
        mlflow.log_metrics(mean_scores)

        end_time = time.time()
        duration = end_time - start_time
        param_details = f"PCA={pca_components}, C={C}, kernel={kernel}, gamma={gamma}"
        duration_details = f"Training duration for {param_details}: {duration} seconds"
        print(duration_details)
        run_id = run.info.run_id
        return run_id

# %%
def load_images_from_folder(folder):
    images = []
    labels = []
    for class_folder in CLASS_FOLDERS:
        start_time = time.time()
        class_path = os.path.join(folder, class_folder)
        image_files = glob.glob(os.path.join(class_path, "*.png"))
        for img_file in image_files:
            image = cv2.imread(img_file)
            hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
            flattened_image = hsv_image.flatten()
            images.append(flattened_image)
            labels.append(class_folder)
        end_time = time.time()
        duration = end_time - start_time
        print(f"Processing {class_folder} took {duration} seconds")
    return np.array(images), np.array(labels)

# %%
train_images, train_labels = load_images_from_folder(TRAIN_DIR)
# Out:
# Processing Class A took 1.6364998817443848 seconds
# Processing Class B took 0.9348328113555908 seconds
# Processing Class C took 0.6303431987762451 seconds
# Processing Class D took 0.7784278392791748 seconds

# %%
print(
    f"Shape of train_images: {train_images.shape}, Shape of train_labels: {train_labels.shape}"
)
# Out:
# Shape of train_images: (2796, 150528), Shape of train_labels: (2796,)

# %%
run_ids = []

for params in hyperparameter_combinations:
    pca_components, C, kernel, gamma = params
    run_id = train_with_params(
        pca_components, C, kernel, gamma, train_images, train_labels
    )
    run_ids.append(run_id)
# Out:
# [LibSVM].*.*
# optimization finished, #iter = 2668
# obj = -650.217640, rho = 0.398430
# nSV = 1080, nBSV = 14
# *.*
# optimization finished, #iter = 1178
# obj = -165.422474, rho = -0.009663
# nSV = 554, nBSV = 0
# *.*
# optimization finished, #iter = 1285
# obj = -172.061979, rho = 0.066480
# nSV = 612, nBSV = 0
# .*
# optimization finished, #iter = 1915
# obj = -686.553331, rho = 0.277605
# nSV = 764, nBSV = 4
# .*
# optimization finished, #iter = 1722
# obj = -379.041236, rho = 0.577439
# nSV = 730, nBSV = 0
# .*
# optimization finished, #iter = 1515
# obj = -446.963155, rho = 0.517614
# nSV = 616, nBSV = 5
# Total nSV = 2006
# [LibSVM].*.*
# optimization finished, #iter = 2695
# obj = -667.820591, rho = 0.380145
# nSV = 1092, nBSV = 16
# *.*
# optimization finished, #iter = 1154
# obj = -157.351241, rho = 0.024951
# nSV = 537, nBSV = 0
# *.*
# optimization finished, #iter = 1271
# obj = -166.626825, rho = 0.060058
# nSV = 599, nBSV = 0
# .*
# optimization finished, #iter = 1907
# obj = -632.861803, rho = 0.352312
# nSV = 759, nBSV = 5
# .*
# optimization finished, #iter = 1697
# obj = -376.139161, rho = 0.590025
# nSV = 710, nBSV = 0
# .*
# optimization finished, #iter = 1464
# obj = -399.435769, rho = 0.496052
# nSV = 605, nBSV = 2
# Total nSV = 2005
# [LibSVM].*.*
# optimization finished, #iter = 2677
# obj = -656.365444, rho = 0.414442
# nSV = 1086, nBSV = 12
# *.*
# optimization finished, #iter = 1189
# obj = -161.882575, rho = -0.012047
# nSV = 534, nBSV = 0
# *.*
# optimization finished, #iter = 1297
# obj = -171.537240, rho = 0.078888
# nSV = 608, nBSV = 0
# .*
# optimization finished, #iter = 1897
# obj = -703.876869, rho = 0.299666
# nSV = 759, nBSV = 8
# .*
# optimization finished, #iter = 1721
# obj = -373.862826, rho = 0.654709
# nSV = 727, nBSV = 0
# .*
# optimization finished, #iter = 1557
# obj = -434.677946, rho = 0.573765
# nSV = 619, nBSV = 4
# Total nSV = 2001
# [LibSVM].*.*
# optimization finished, #iter = 2646
# obj = -655.305698, rho = 0.347918
# nSV = 1074, nBSV = 15
# *.*
# optimization finished, #iter = 1235
# obj = -168.622163, rho = 0.005967
# nSV = 556, nBSV = 0
# *.*
# optimization finished, #iter = 1270
# obj = -164.985054, rho = 0.008067
# nSV = 591, nBSV = 0
# .*
# optimization finished, #iter = 1922
# obj = -660.557453, rho = 0.278424
# nSV = 764, nBSV = 8
# .*
# optimization finished, #iter = 1683
# obj = -369.124563, rho = 0.563197
# nSV = 700, nBSV = 0
# .*
# optimization finished, #iter = 1550
# obj = -450.937647, rho = 0.511924
# nSV = 626, nBSV = 5
# Total nSV = 2004
# [LibSVM].*.*
# optimization finished, #iter = 2644
# obj = -667.595619, rho = 0.402357
# nSV = 1080, nBSV = 16
# *.*
# optimization finished, #iter = 1226
# obj = -160.775556, rho = 0.003163
# nSV = 551, nBSV = 0
# *.*
# optimization finished, #iter = 1275
# obj = -171.556868, rho = 0.072571
# nSV = 596, nBSV = 0
# .*
# optimization finished, #iter = 1903
# obj = -673.655973, rho = 0.345390
# nSV = 767, nBSV = 6
# .*
# optimization finished, #iter = 1726
# obj = -389.454278, rho = 0.629096
# nSV = 723, nBSV = 0
# .*
# optimization finished, #iter = 1549
# obj = -458.273507, rho = 0.616634
# nSV = 611, nBSV = 5
# Total nSV = 2011
# [LibSVM].*.*
# optimization finished, #iter = 2620
# obj = -656.767222, rho = 0.313753
# nSV = 1083, nBSV = 13
# *.*
# optimization finished, #iter = 1151
# obj = -159.427244, rho = -0.015920
# nSV = 531, nBSV = 0
# *.*
# optimization finished, #iter = 1306
# obj = -172.230009, rho = 0.076167
# nSV = 607, nBSV = 0
# .*
# optimization finished, #iter = 1857
# obj = -608.738795, rho = 0.395339
# nSV = 745, nBSV = 3
# .*
# optimization finished, #iter = 1742
# obj = -374.339367, rho = 0.719484
# nSV = 728, nBSV = 0
# .*
# optimization finished, #iter = 1509
# obj = -446.216604, rho = 0.530465
# nSV = 602, nBSV = 5
# Total nSV = 2013
# [LibSVM].*.*
# optimization finished, #iter = 2687
# obj = -639.205187, rho = 0.391046
# nSV = 1088, nBSV = 13
# *.*
# optimization finished, #iter = 1201
# obj = -164.746617, rho = 0.005659
# nSV = 551, nBSV = 0
# *.*
# optimization finished, #iter = 1274
# obj = -163.836516, rho = 0.083953
# nSV = 608, nBSV = 0
# .*
# optimization finished, #iter = 1949
# obj = -655.001661, rho = 0.366143
# nSV = 778, nBSV = 5
# .*
# optimization finished, #iter = 1731
# obj = -376.878896, rho = 0.613086
# nSV = 725, nBSV = 0
# .*
# optimization finished, #iter = 1498
# obj = -418.414868, rho = 0.523536
# nSV = 602, nBSV = 4
# Total nSV = 2025
# [LibSVM].*.*
# optimization finished, #iter = 2682
# obj = -646.473288, rho = 0.334952
# nSV = 1074, nBSV = 14
# *.*
# optimization finished, #iter = 1160
# obj = -162.358041, rho = -0.011496
# nSV = 536, nBSV = 0
# *.*
# optimization finished, #iter = 1301
# obj = -167.813658, rho = 0.050958
# nSV = 613, nBSV = 0
# .*
# optimization finished, #iter = 1870
# obj = -669.171056, rho = 0.441201
# nSV = 759, nBSV = 3
# .*
# optimization finished, #iter = 1711
# obj = -383.076321, rho = 0.706661
# nSV = 728, nBSV = 0
# .*
# optimization finished, #iter = 1554
# obj = -432.058890, rho = 0.579112
# nSV = 619, nBSV = 3
# Total nSV = 2020
# [LibSVM].*.*
# optimization finished, #iter = 2657
# obj = -651.805738, rho = 0.380883
# nSV = 1092, nBSV = 13
# *.*
# optimization finished, #iter = 1166
# obj = -154.477536, rho = -0.002763
# nSV = 535, nBSV = 0
# *.*
# optimization finished, #iter = 1325
# obj = -165.240696, rho = 0.048031
# nSV = 614, nBSV = 0
# .*
# optimization finished, #iter = 1936
# obj = -676.292102, rho = 0.337620
# nSV = 763, nBSV = 6
# .*
# optimization finished, #iter = 1668
# obj = -367.171954, rho = 0.651478
# nSV = 713, nBSV = 0
# .*
# optimization finished, #iter = 1525
# obj = -426.649928, rho = 0.561116
# nSV = 606, nBSV = 4
# Total nSV = 2006
# [LibSVM].*.*
# optimization finished, #iter = 2615
# obj = -655.292554, rho = 0.403032
# nSV = 1073, nBSV = 12
# *.*
# optimization finished, #iter = 1155
# obj = -162.251397, rho = 0.011890
# nSV = 533, nBSV = 0
# *.*
# optimization finished, #iter = 1281
# obj = -170.914627, rho = 0.104671
# nSV = 608, nBSV = 0
# .*
# optimization finished, #iter = 1933
# obj = -642.583229, rho = 0.327715
# nSV = 767, nBSV = 3
# .*
# optimization finished, #iter = 1779
# obj = -390.181931, rho = 0.666283
# nSV = 731, nBSV = 0
# .*
# optimization finished, #iter = 1536
# obj = -432.205677, rho = 0.544086
# nSV = 618, nBSV = 4
# Total nSV = 2003
# Training duration for PCA=1600, C=9, kernel=rbf, gamma=scale: 1373.5374119281769 seconds
# [LibSVM].*.*
# optimization finished, #iter = 2595
# obj = -652.431007, rho = 0.398309
# nSV = 1078, nBSV = 12
# *.*
# optimization finished, #iter = 1222
# obj = -165.357579, rho = -0.010307
# nSV = 555, nBSV = 0
# *.*
# optimization finished, #iter = 1315
# obj = -171.599759, rho = 0.066154
# nSV = 618, nBSV = 0
# .*
# optimization finished, #iter = 1907
# obj = -698.634187, rho = 0.276963
# nSV = 761, nBSV = 4
# .*
# optimization finished, #iter = 1740
# obj = -380.638872, rho = 0.572676
# nSV = 728, nBSV = 0
# .*
# optimization finished, #iter = 1547
# obj = -455.788605, rho = 0.515725
# nSV = 614, nBSV = 5
# Total nSV = 2021
# [LibSVM].*.*
# optimization finished, #iter = 2674
# obj = -670.491977, rho = 0.384690
# nSV = 1084, nBSV = 13
# *.*
# optimization finished, #iter = 1175
# obj = -157.303165, rho = 0.023619
# nSV = 546, nBSV = 0
# *.*
# optimization finished, #iter = 1265
# obj = -166.415833, rho = 0.060198
# nSV = 600, nBSV = 0
# .*
# optimization finished, #iter = 1939
# obj = -642.124472, rho = 0.346052
# nSV = 758, nBSV = 4
# .*
# optimization finished, #iter = 1687
# obj = -377.209426, rho = 0.590164
# nSV = 711, nBSV = 0
# .*
# optimization finished, #iter = 1463
# obj = -401.806923, rho = 0.495160
# nSV = 600, nBSV = 2
# Total nSV = 2003
# [LibSVM].*.*
# optimization finished, #iter = 2664
# obj = -659.751972, rho = 0.427997
# nSV = 1082, nBSV = 11
# *.*
# optimization finished, #iter = 1188
# obj = -161.487801, rho = -0.015893
# nSV = 537, nBSV = 0
# *.*
# optimization finished, #iter = 1281
# obj = -171.290328, rho = 0.082114
# nSV = 607, nBSV = 0
# .*
# optimization finished, #iter = 1913
# obj = -715.206244, rho = 0.296466
# nSV = 762, nBSV = 7
# .*
# optimization finished, #iter = 1754
# obj = -375.934262, rho = 0.651655
# nSV = 725, nBSV = 0
# .*
# optimization finished, #iter = 1505
# obj = -440.983063, rho = 0.580962
# nSV = 615, nBSV = 4
# Total nSV = 2000
# [LibSVM].*.*
# optimization finished, #iter = 2706
# obj = -655.295751, rho = 0.355429
# nSV = 1073, nBSV = 11
# *.*
# optimization finished, #iter = 1210
# obj = -168.555243, rho = 0.004553
# nSV = 553, nBSV = 0
# *.*
# optimization finished, #iter = 1289
# obj = -164.904245, rho = 0.005084
# nSV = 591, nBSV = 0
# .*
# optimization finished, #iter = 1864
# obj = -675.161131, rho = 0.284729
# nSV = 760, nBSV = 7
# .*
# optimization finished, #iter = 1633
# obj = -370.494125, rho = 0.563766
# nSV = 697, nBSV = 0
# .*
# optimization finished, #iter = 1578
# obj = -458.995359, rho = 0.510899
# nSV = 622, nBSV = 5
# Total nSV = 1999
# [LibSVM].*.*
# optimization finished, #iter = 2663
# obj = -670.152745, rho = 0.402454
# nSV = 1076, nBSV = 13
# *.*
# optimization finished, #iter = 1205
# obj = -160.607432, rho = 0.002014
# nSV = 555, nBSV = 0
# *.*
# optimization finished, #iter = 1256
# obj = -171.317883, rho = 0.072496
# nSV = 596, nBSV = 0
# .*
# optimization finished, #iter = 1896
# obj = -684.618325, rho = 0.347480
# nSV = 767, nBSV = 6
# .*
# optimization finished, #iter = 1749
# obj = -390.695418, rho = 0.635949
# nSV = 723, nBSV = 0
# .*
# optimization finished, #iter = 1554
# obj = -465.772950, rho = 0.628232
# nSV = 610, nBSV = 5
# Total nSV = 2003
# [LibSVM].*.*
# optimization finished, #iter = 2670
# obj = -657.387438, rho = 0.323063
# nSV = 1078, nBSV = 11
# *.*
# optimization finished, #iter = 1167
# obj = -159.822788, rho = -0.012593
# nSV = 535, nBSV = 0
# *.*
# optimization finished, #iter = 1305
# obj = -172.028842, rho = 0.075493
# nSV = 609, nBSV = 0
# .*
# optimization finished, #iter = 1855
# obj = -618.077609, rho = 0.396160
# nSV = 753, nBSV = 3
# .*
# optimization finished, #iter = 1740
# obj = -375.878733, rho = 0.713435
# nSV = 726, nBSV = 0
# .*
# optimization finished, #iter = 1508
# obj = -452.351945, rho = 0.527492
# nSV = 597, nBSV = 5
# Total nSV = 2007
# [LibSVM].*.*
# optimization finished, #iter = 2648
# obj = -642.033998, rho = 0.398341
# nSV = 1085, nBSV = 10
# *.*
# optimization finished, #iter = 1225
# obj = -164.568599, rho = 0.005739
# nSV = 547, nBSV = 0
# *.*
# optimization finished, #iter = 1297
# obj = -163.769682, rho = 0.080869
# nSV = 606, nBSV = 0
# .*.*
# optimization finished, #iter = 2001
# obj = -669.596142, rho = 0.354603
# nSV = 784, nBSV = 4
# .*
# optimization finished, #iter = 1726
# obj = -377.964699, rho = 0.607441
# nSV = 730, nBSV = 0
# .*
# optimization finished, #iter = 1533
# obj = -424.951647, rho = 0.530608
# nSV = 607, nBSV = 4
# Total nSV = 2022
# [LibSVM].*.*
# optimization finished, #iter = 2660
# obj = -648.846218, rho = 0.344054
# nSV = 1080, nBSV = 14
# *.*
# optimization finished, #iter = 1172
# obj = -162.543608, rho = -0.006299
# nSV = 542, nBSV = 0
# *.*
# optimization finished, #iter = 1292
# obj = -167.785129, rho = 0.053676
# nSV = 614, nBSV = 0
# .*
# optimization finished, #iter = 1912
# obj = -684.881947, rho = 0.466733
# nSV = 755, nBSV = 6
# .*
# optimization finished, #iter = 1738
# obj = -384.875596, rho = 0.700511
# nSV = 726, nBSV = 0
# .*
# optimization finished, #iter = 1553
# obj = -437.716532, rho = 0.575240
# nSV = 613, nBSV = 3
# Total nSV = 2009
# [LibSVM].*.*
# optimization finished, #iter = 2653
# obj = -655.357672, rho = 0.374214
# nSV = 1092, nBSV = 11
# *.*
# optimization finished, #iter = 1170
# obj = -154.591393, rho = -0.005682
# nSV = 539, nBSV = 0
# *.*
# optimization finished, #iter = 1289
# obj = -165.142991, rho = 0.048336
# nSV = 612, nBSV = 0
# .*
# optimization finished, #iter = 1967
# obj = -690.596613, rho = 0.330074
# nSV = 766, nBSV = 7
# .*
# optimization finished, #iter = 1699
# obj = -367.866385, rho = 0.648713
# nSV = 710, nBSV = 0
# .*
# optimization finished, #iter = 1523
# obj = -431.693700, rho = 0.558384
# nSV = 610, nBSV = 4
# Total nSV = 2010
# [LibSVM].*.*
# optimization finished, #iter = 2580
# obj = -655.678757, rho = 0.410088
# nSV = 1077, nBSV = 12
# *.*
# optimization finished, #iter = 1158
# obj = -162.028143, rho = 0.011526
# nSV = 537, nBSV = 0
# *.*
# optimization finished, #iter = 1285
# obj = -170.900407, rho = 0.101497
# nSV = 607, nBSV = 0
# .*
# optimization finished, #iter = 1936
# obj = -651.124968, rho = 0.328073
# nSV = 767, nBSV = 3
# .*
# optimization finished, #iter = 1699
# obj = -392.454404, rho = 0.661432
# nSV = 732, nBSV = 0
# .*
# optimization finished, #iter = 1552
# obj = -438.776394, rho = 0.546280
# nSV = 623, nBSV = 4
# Total nSV = 2006
# Training duration for PCA=1600, C=10, kernel=rbf, gamma=scale: 1343.7988381385803 seconds
# [LibSVM].*.*
# optimization finished, #iter = 2665
# obj = -653.272766, rho = 0.413445
# nSV = 1084, nBSV = 10
# *.*
# optimization finished, #iter = 1223
# obj = -165.373293, rho = -0.009069
# nSV = 556, nBSV = 0
# *.*
# optimization finished, #iter = 1259
# obj = -172.015190, rho = 0.067131
# nSV = 613, nBSV = 0
# .*
# optimization finished, #iter = 1958
# obj = -706.709575, rho = 0.276624
# nSV = 763, nBSV = 4
# .*
# optimization finished, #iter = 1730
# obj = -381.802531, rho = 0.578535
# nSV = 728, nBSV = 0
# .*
# optimization finished, #iter = 1536
# obj = -457.719969, rho = 0.525707
# nSV = 611, nBSV = 5
# Total nSV = 2013
# [LibSVM].*.*
# optimization finished, #iter = 2720
# obj = -671.709191, rho = 0.377354
# nSV = 1084, nBSV = 13
# *.*
# optimization finished, #iter = 1194
# obj = -157.521066, rho = 0.020682
# nSV = 543, nBSV = 0
# *.*
# optimization finished, #iter = 1291
# obj = -166.664028, rho = 0.059788
# nSV = 602, nBSV = 0
# .*
# optimization finished, #iter = 1898
# obj = -647.743176, rho = 0.359171
# nSV = 757, nBSV = 4
# .*
# optimization finished, #iter = 1656
# obj = -378.427758, rho = 0.593765
# nSV = 709, nBSV = 0
# .*
# optimization finished, #iter = 1504
# obj = -404.557960, rho = 0.489880
# nSV = 607, nBSV = 2
# Total nSV = 2001
# [LibSVM].*.*
# optimization finished, #iter = 2692
# obj = -658.709137, rho = 0.418228
# nSV = 1086, nBSV = 10
# *.*
# optimization finished, #iter = 1193
# obj = -161.637578, rho = -0.018684
# nSV = 534, nBSV = 0
# *.*
# optimization finished, #iter = 1309
# obj = -171.144002, rho = 0.081106
# nSV = 605, nBSV = 0
# .*
# optimization finished, #iter = 1911
# obj = -725.243728, rho = 0.308669
# nSV = 754, nBSV = 7
# .*
# optimization finished, #iter = 1773
# obj = -376.005027, rho = 0.653381
# nSV = 730, nBSV = 0
# .*
# optimization finished, #iter = 1544
# obj = -442.016050, rho = 0.580636
# nSV = 616, nBSV = 4
# Total nSV = 2001
# [LibSVM].*.*
# optimization finished, #iter = 2631
# obj = -656.523222, rho = 0.357612
# nSV = 1071, nBSV = 12
# *.*
# optimization finished, #iter = 1238
# obj = -168.550251, rho = 0.008618
# nSV = 559, nBSV = 0
# *.*
# optimization finished, #iter = 1262
# obj = -165.106201, rho = 0.009240
# nSV = 593, nBSV = 0
# .*
# optimization finished, #iter = 1909
# obj = -679.343962, rho = 0.281786
# nSV = 756, nBSV = 7
# .*
# optimization finished, #iter = 1658
# obj = -370.563174, rho = 0.561892
# nSV = 698, nBSV = 0
# .*
# optimization finished, #iter = 1559
# obj = -464.189193, rho = 0.515584
# nSV = 622, nBSV = 5
# Total nSV = 1990
# [LibSVM].*.*
# optimization finished, #iter = 2628
# obj = -671.472326, rho = 0.408664
# nSV = 1078, nBSV = 13
# *.*
# optimization finished, #iter = 1162
# obj = -160.547811, rho = 0.002381
# nSV = 553, nBSV = 0
# *.*
# optimization finished, #iter = 1277
# obj = -171.513340, rho = 0.071494
# nSV = 597, nBSV = 0
# .*
# optimization finished, #iter = 1924
# obj = -693.565165, rho = 0.360752
# nSV = 763, nBSV = 6
# .*
# optimization finished, #iter = 1714
# obj = -391.554303, rho = 0.628797
# nSV = 721, nBSV = 0
# .*
# optimization finished, #iter = 1538
# obj = -469.633934, rho = 0.626730
# nSV = 604, nBSV = 5
# Total nSV = 2006
# [LibSVM].*.*
# optimization finished, #iter = 2718
# obj = -656.830754, rho = 0.313918
# nSV = 1079, nBSV = 10
# *.*
# optimization finished, #iter = 1154
# obj = -159.539641, rho = -0.014315
# nSV = 532, nBSV = 0
# *.*
# optimization finished, #iter = 1280
# obj = -172.179387, rho = 0.077328
# nSV = 609, nBSV = 0
# .*
# optimization finished, #iter = 1873
# obj = -624.307098, rho = 0.392968
# nSV = 748, nBSV = 2
# .*
# optimization finished, #iter = 1727
# obj = -375.899275, rho = 0.717708
# nSV = 728, nBSV = 0
# .*
# optimization finished, #iter = 1507
# obj = -456.945627, rho = 0.539803
# nSV = 601, nBSV = 5
# Total nSV = 2004
# [LibSVM].*.*
# optimization finished, #iter = 2683
# obj = -640.262639, rho = 0.395772
# nSV = 1102, nBSV = 9
# *.*
# optimization finished, #iter = 1199
# obj = -164.678932, rho = 0.004816
# nSV = 549, nBSV = 0
# *.*
# optimization finished, #iter = 1290
# obj = -163.570623, rho = 0.081923
# nSV = 609, nBSV = 0
# .*.*
# optimization finished, #iter = 1978
# obj = -676.976841, rho = 0.361536
# nSV = 781, nBSV = 4
# .*
# optimization finished, #iter = 1757
# obj = -378.523144, rho = 0.609922
# nSV = 727, nBSV = 0
# .*
# optimization finished, #iter = 1539
# obj = -428.441847, rho = 0.542091
# nSV = 607, nBSV = 4
# Total nSV = 2032
# [LibSVM].*.*
# optimization finished, #iter = 2588
# obj = -648.327560, rho = 0.343188
# nSV = 1064, nBSV = 15
# *.*
# optimization finished, #iter = 1167
# obj = -162.556761, rho = -0.008949
# nSV = 534, nBSV = 0
# *.*
# optimization finished, #iter = 1285
# obj = -167.744966, rho = 0.052768
# nSV = 601, nBSV = 0
# .*
# optimization finished, #iter = 1914
# obj = -692.780905, rho = 0.443544
# nSV = 755, nBSV = 5
# .*
# optimization finished, #iter = 1733
# obj = -385.144696, rho = 0.701341
# nSV = 727, nBSV = 0
# .*
# optimization finished, #iter = 1572
# obj = -440.023136, rho = 0.581725
# nSV = 614, nBSV = 3
# Total nSV = 2002
# [LibSVM].*.*
# optimization finished, #iter = 2701
# obj = -653.982194, rho = 0.379149
# nSV = 1087, nBSV = 12
# *.*
# optimization finished, #iter = 1206
# obj = -154.525117, rho = -0.000472
# nSV = 540, nBSV = 0
# *.*
# optimization finished, #iter = 1305
# obj = -165.255282, rho = 0.049355
# nSV = 611, nBSV = 0
# .*
# optimization finished, #iter = 1899
# obj = -698.522403, rho = 0.318087
# nSV = 763, nBSV = 6
# .*
# optimization finished, #iter = 1735
# obj = -367.209137, rho = 0.647490
# nSV = 717, nBSV = 0
# .*
# optimization finished, #iter = 1508
# obj = -434.482568, rho = 0.571785
# nSV = 609, nBSV = 4
# Total nSV = 2011
# [LibSVM].*.*
# optimization finished, #iter = 2603
# obj = -657.494598, rho = 0.408548
# nSV = 1067, nBSV = 11
# *.*
# optimization finished, #iter = 1140
# obj = -162.117968, rho = 0.014358
# nSV = 531, nBSV = 0
# *.*
# optimization finished, #iter = 1291
# obj = -170.687800, rho = 0.103050
# nSV = 611, nBSV = 0
# .*
# optimization finished, #iter = 1941
# obj = -654.207559, rho = 0.324933
# nSV = 765, nBSV = 3
# .*
# optimization finished, #iter = 1704
# obj = -390.379844, rho = 0.660679
# nSV = 734, nBSV = 0
# .*
# optimization finished, #iter = 1546
# obj = -440.116632, rho = 0.548963
# nSV = 618, nBSV = 4
# Total nSV = 1999
# Training duration for PCA=1600, C=10.5, kernel=rbf, gamma=scale: 1339.0201189517975 seconds
# [LibSVM].*.*
# optimization finished, #iter = 2634
# obj = -604.462790, rho = 0.354420
# nSV = 1145, nBSV = 7
# *.*
# optimization finished, #iter = 1187
# obj = -163.905972, rho = -0.020834
# nSV = 572, nBSV = 0
# *.*
# optimization finished, #iter = 1306
# obj = -172.148040, rho = 0.042397
# nSV = 644, nBSV = 0
# .*
# optimization finished, #iter = 1920
# obj = -633.399192, rho = 0.291999
# nSV = 798, nBSV = 3
# .*
# optimization finished, #iter = 1725
# obj = -369.874608, rho = 0.574688
# nSV = 762, nBSV = 0
# .*
# optimization finished, #iter = 1485
# obj = -425.940945, rho = 0.434606
# nSV = 629, nBSV = 4
# Total nSV = 2062
# [LibSVM].*.*
# optimization finished, #iter = 2668
# obj = -620.268591, rho = 0.339283
# nSV = 1130, nBSV = 9
# *.*
# optimization finished, #iter = 1170
# obj = -156.326066, rho = 0.021042
# nSV = 558, nBSV = 0
# *.*
# optimization finished, #iter = 1287
# obj = -166.875077, rho = 0.040436
# nSV = 639, nBSV = 0
# .*
# optimization finished, #iter = 1891
# obj = -585.147052, rho = 0.348850
# nSV = 798, nBSV = 3
# .*
# optimization finished, #iter = 1660
# obj = -364.584993, rho = 0.585994
# nSV = 739, nBSV = 0
# .*
# optimization finished, #iter = 1460
# obj = -384.030246, rho = 0.432606
# nSV = 623, nBSV = 2
# Total nSV = 2054
# [LibSVM].*.*
# optimization finished, #iter = 2635
# obj = -610.682601, rho = 0.377732
# nSV = 1133, nBSV = 7
# *.*
# optimization finished, #iter = 1150
# obj = -160.345981, rho = -0.025743
# nSV = 552, nBSV = 0
# *.*
# optimization finished, #iter = 1305
# obj = -171.521004, rho = 0.059500
# nSV = 639, nBSV = 0
# .*
# optimization finished, #iter = 1872
# obj = -643.490920, rho = 0.310322
# nSV = 804, nBSV = 4
# .*
# optimization finished, #iter = 1720
# obj = -363.063938, rho = 0.630708
# nSV = 766, nBSV = 0
# .*
# optimization finished, #iter = 1494
# obj = -410.339857, rho = 0.494412
# nSV = 636, nBSV = 3
# Total nSV = 2053
# [LibSVM].*.*
# optimization finished, #iter = 2616
# obj = -609.484254, rho = 0.311783
# nSV = 1130, nBSV = 9
# *.*
# optimization finished, #iter = 1209
# obj = -166.965916, rho = -0.003213
# nSV = 579, nBSV = 0
# *.*
# optimization finished, #iter = 1266
# obj = -165.488101, rho = -0.013394
# nSV = 615, nBSV = 0
# .*
# optimization finished, #iter = 1911
# obj = -605.678481, rho = 0.290973
# nSV = 801, nBSV = 3
# .*
# optimization finished, #iter = 1657
# obj = -358.139359, rho = 0.542330
# nSV = 737, nBSV = 0
# .*
# optimization finished, #iter = 1514
# obj = -430.629510, rho = 0.438779
# nSV = 639, nBSV = 4
# Total nSV = 2046
# [LibSVM].*.*
# optimization finished, #iter = 2568
# obj = -618.620147, rho = 0.356350
# nSV = 1120, nBSV = 11
# *.*
# optimization finished, #iter = 1196
# obj = -159.207554, rho = -0.010035
# nSV = 571, nBSV = 0
# *.*
# optimization finished, #iter = 1271
# obj = -171.795303, rho = 0.050973
# nSV = 626, nBSV = 0
# .*
# optimization finished, #iter = 1871
# obj = -620.463526, rho = 0.337067
# nSV = 801, nBSV = 4
# .*
# optimization finished, #iter = 1747
# obj = -377.022386, rho = 0.615132
# nSV = 755, nBSV = 0
# .*
# optimization finished, #iter = 1462
# obj = -436.765705, rho = 0.534978
# nSV = 622, nBSV = 4
# Total nSV = 2043
# [LibSVM].*.*
# optimization finished, #iter = 2644
# obj = -612.317132, rho = 0.271239
# nSV = 1131, nBSV = 6
# *.*
# optimization finished, #iter = 1135
# obj = -157.854385, rho = -0.016174
# nSV = 546, nBSV = 0
# *.*
# optimization finished, #iter = 1310
# obj = -172.455260, rho = 0.053000
# nSV = 636, nBSV = 0
# .*
# optimization finished, #iter = 1846
# obj = -559.656852, rho = 0.396332
# nSV = 779, nBSV = 2
# .*
# optimization finished, #iter = 1708
# obj = -364.221770, rho = 0.685936
# nSV = 759, nBSV = 0
# .*
# optimization finished, #iter = 1455
# obj = -425.130543, rho = 0.442952
# nSV = 624, nBSV = 4
# Total nSV = 2054
# [LibSVM].*.*
# optimization finished, #iter = 2609
# obj = -596.146797, rho = 0.343953
# nSV = 1133, nBSV = 7
# *.*
# optimization finished, #iter = 1178
# obj = -162.795497, rho = -0.000632
# nSV = 565, nBSV = 0
# *.*
# optimization finished, #iter = 1296
# obj = -164.167986, rho = 0.054617
# nSV = 640, nBSV = 0
# .*
# optimization finished, #iter = 1887
# obj = -607.229886, rho = 0.372614
# nSV = 810, nBSV = 4
# .*
# optimization finished, #iter = 1717
# obj = -365.331927, rho = 0.589001
# nSV = 756, nBSV = 0
# .*
# optimization finished, #iter = 1413
# obj = -399.368063, rho = 0.423853
# nSV = 620, nBSV = 3
# Total nSV = 2052
# [LibSVM].*.*
# optimization finished, #iter = 2622
# obj = -601.151145, rho = 0.294993
# nSV = 1120, nBSV = 10
# *.*
# optimization finished, #iter = 1150
# obj = -160.883859, rho = -0.020151
# nSV = 555, nBSV = 0
# *.*
# optimization finished, #iter = 1293
# obj = -168.298565, rho = 0.031491
# nSV = 641, nBSV = 0
# .*
# optimization finished, #iter = 1858
# obj = -621.630026, rho = 0.437719
# nSV = 790, nBSV = 2
# .*
# optimization finished, #iter = 1753
# obj = -370.420642, rho = 0.679814
# nSV = 758, nBSV = 0
# .*
# optimization finished, #iter = 1493
# obj = -415.995219, rho = 0.524726
# nSV = 635, nBSV = 3
# Total nSV = 2058
# [LibSVM].*.*
# optimization finished, #iter = 2645
# obj = -605.026240, rho = 0.337158
# nSV = 1147, nBSV = 6
# *.*
# optimization finished, #iter = 1150
# obj = -154.348863, rho = -0.008546
# nSV = 554, nBSV = 0
# *.*
# optimization finished, #iter = 1300
# obj = -166.254905, rho = 0.027474
# nSV = 642, nBSV = 0
# .*
# optimization finished, #iter = 1853
# obj = -620.980588, rho = 0.331054
# nSV = 801, nBSV = 5
# .*
# optimization finished, #iter = 1708
# obj = -357.817414, rho = 0.611062
# nSV = 747, nBSV = 0
# .*
# optimization finished, #iter = 1454
# obj = -406.415704, rho = 0.473922
# nSV = 624, nBSV = 3
# Total nSV = 2055
# [LibSVM].*.*
# optimization finished, #iter = 2613
# obj = -608.304242, rho = 0.372469
# nSV = 1126, nBSV = 6
# *.*
# optimization finished, #iter = 1174
# obj = -160.608858, rho = 0.011838
# nSV = 558, nBSV = 0
# *.*
# optimization finished, #iter = 1311
# obj = -171.181333, rho = 0.073392
# nSV = 639, nBSV = 0
# .*
# optimization finished, #iter = 1940
# obj = -580.520899, rho = 0.348388
# nSV = 805, nBSV = 2
# .*
# optimization finished, #iter = 1764
# obj = -376.901628, rho = 0.633728
# nSV = 768, nBSV = 0
# .*
# optimization finished, #iter = 1493
# obj = -410.260336, rho = 0.448550
# nSV = 640, nBSV = 3
# Total nSV = 2055
# Training duration for PCA=2025, C=9, kernel=rbf, gamma=scale: 1449.6184029579163 seconds
# [LibSVM].*.*
# optimization finished, #iter = 2656
# obj = -605.103817, rho = 0.355897
# nSV = 1142, nBSV = 5
# *.*
# optimization finished, #iter = 1187
# obj = -163.905972, rho = -0.020834
# nSV = 572, nBSV = 0
# *.*
# optimization finished, #iter = 1306
# obj = -172.148040, rho = 0.042397
# nSV = 644, nBSV = 0
# .*
# optimization finished, #iter = 1895
# obj = -646.669975, rho = 0.292999
# nSV = 794, nBSV = 3
# .*
# optimization finished, #iter = 1721
# obj = -370.672218, rho = 0.576000
# nSV = 761, nBSV = 0
# .*
# optimization finished, #iter = 1496
# obj = -433.119248, rho = 0.438212
# nSV = 628, nBSV = 4
# Total nSV = 2058
# [LibSVM].*.*
# optimization finished, #iter = 2641
# obj = -620.675483, rho = 0.339895
# nSV = 1131, nBSV = 6
# *.*
# optimization finished, #iter = 1170
# obj = -156.326066, rho = 0.021042
# nSV = 558, nBSV = 0
# *.*
# optimization finished, #iter = 1287
# obj = -166.875077, rho = 0.040436
# nSV = 639, nBSV = 0
# .*
# optimization finished, #iter = 1894
# obj = -594.880218, rho = 0.354067
# nSV = 796, nBSV = 3
# .*
# optimization finished, #iter = 1714
# obj = -365.269062, rho = 0.586771
# nSV = 740, nBSV = 0
# .*
# optimization finished, #iter = 1453
# obj = -387.593734, rho = 0.431957
# nSV = 622, nBSV = 2
# Total nSV = 2052
# [LibSVM].*.*
# optimization finished, #iter = 2651
# obj = -610.827015, rho = 0.378249
# nSV = 1133, nBSV = 4
# *.*
# optimization finished, #iter = 1150
# obj = -160.345981, rho = -0.025743
# nSV = 552, nBSV = 0
# *.*
# optimization finished, #iter = 1305
# obj = -171.521004, rho = 0.059500
# nSV = 639, nBSV = 0
# .*
# optimization finished, #iter = 1860
# obj = -658.028403, rho = 0.311275
# nSV = 800, nBSV = 3
# .*
# optimization finished, #iter = 1739
# obj = -363.881000, rho = 0.631937
# nSV = 765, nBSV = 0
# .*
# optimization finished, #iter = 1502
# obj = -415.699194, rho = 0.495945
# nSV = 634, nBSV = 3
# Total nSV = 2050
# [LibSVM].*.*
# optimization finished, #iter = 2607
# obj = -609.514730, rho = 0.312082
# nSV = 1129, nBSV = 6
# *.*
# optimization finished, #iter = 1209
# obj = -166.965916, rho = -0.003213
# nSV = 579, nBSV = 0
# *.*
# optimization finished, #iter = 1266
# obj = -165.488101, rho = -0.013394
# nSV = 615, nBSV = 0
# .*
# optimization finished, #iter = 1880
# obj = -617.381554, rho = 0.290791
# nSV = 800, nBSV = 3
# .*
# optimization finished, #iter = 1665
# obj = -358.804669, rho = 0.543176
# nSV = 737, nBSV = 0
# .*
# optimization finished, #iter = 1519
# obj = -437.800566, rho = 0.441123
# nSV = 636, nBSV = 4
# Total nSV = 2045
# [LibSVM].*.*
# optimization finished, #iter = 2625
# obj = -618.949746, rho = 0.357119
# nSV = 1119, nBSV = 6
# *.*
# optimization finished, #iter = 1196
# obj = -159.207554, rho = -0.010035
# nSV = 571, nBSV = 0
# *.*
# optimization finished, #iter = 1271
# obj = -171.795303, rho = 0.050973
# nSV = 626, nBSV = 0
# .*
# optimization finished, #iter = 1873
# obj = -633.143229, rho = 0.340825
# nSV = 797, nBSV = 2
# .*
# optimization finished, #iter = 1731
# obj = -377.815885, rho = 0.615958
# nSV = 758, nBSV = 0
# .*
# optimization finished, #iter = 1469
# obj = -443.961295, rho = 0.538199
# nSV = 623, nBSV = 4
# Total nSV = 2043
# [LibSVM].*.*
# optimization finished, #iter = 2632
# obj = -612.901594, rho = 0.272140
# nSV = 1130, nBSV = 5
# *.*
# optimization finished, #iter = 1135
# obj = -157.854385, rho = -0.016174
# nSV = 546, nBSV = 0
# *.*
# optimization finished, #iter = 1310
# obj = -172.455260, rho = 0.053000
# nSV = 636, nBSV = 0
# .*
# optimization finished, #iter = 1847
# obj = -568.432412, rho = 0.395351
# nSV = 778, nBSV = 1
# .*
# optimization finished, #iter = 1739
# obj = -365.021653, rho = 0.687111
# nSV = 762, nBSV = 0
# .*
# optimization finished, #iter = 1427
# obj = -432.250157, rho = 0.445462
# nSV = 624, nBSV = 4
# Total nSV = 2052
# [LibSVM].*.*
# optimization finished, #iter = 2626
# obj = -596.482628, rho = 0.344327
# nSV = 1132, nBSV = 4
# *.*
# optimization finished, #iter = 1178
# obj = -162.795497, rho = -0.000632
# nSV = 565, nBSV = 0
# *.*
# optimization finished, #iter = 1296
# obj = -164.167986, rho = 0.054617
# nSV = 640, nBSV = 0
# .*
# optimization finished, #iter = 1920
# obj = -619.403068, rho = 0.372449
# nSV = 809, nBSV = 3
# .*
# optimization finished, #iter = 1712
# obj = -366.142532, rho = 0.589659
# nSV = 757, nBSV = 0
# .*
# optimization finished, #iter = 1468
# obj = -404.799536, rho = 0.428432
# nSV = 618, nBSV = 3
# Total nSV = 2052
# [LibSVM].*.*
# optimization finished, #iter = 2618
# obj = -601.513060, rho = 0.295458
# nSV = 1118, nBSV = 8
# *.*
# optimization finished, #iter = 1150
# obj = -160.883859, rho = -0.020151
# nSV = 555, nBSV = 0
# *.*
# optimization finished, #iter = 1293
# obj = -168.298565, rho = 0.031491
# nSV = 641, nBSV = 0
# .*
# optimization finished, #iter = 1883
# obj = -634.679369, rho = 0.440358
# nSV = 791, nBSV = 2
# .*
# optimization finished, #iter = 1725
# obj = -371.182177, rho = 0.680915
# nSV = 758, nBSV = 0
# .*
# optimization finished, #iter = 1480
# obj = -421.287932, rho = 0.527126
# nSV = 637, nBSV = 3
# Total nSV = 2055
# [LibSVM].*.*
# optimization finished, #iter = 2662
# obj = -605.168104, rho = 0.338282
# nSV = 1146, nBSV = 6
# *.*
# optimization finished, #iter = 1150
# obj = -154.348863, rho = -0.008546
# nSV = 554, nBSV = 0
# *.*
# optimization finished, #iter = 1300
# obj = -166.254905, rho = 0.027474
# nSV = 642, nBSV = 0
# .*
# optimization finished, #iter = 1898
# obj = -632.993577, rho = 0.333697
# nSV = 801, nBSV = 4
# .*
# optimization finished, #iter = 1687
# obj = -357.817415, rho = 0.611133
# nSV = 747, nBSV = 0
# .*
# optimization finished, #iter = 1462
# obj = -411.859632, rho = 0.474292
# nSV = 624, nBSV = 3
# Total nSV = 2053
# [LibSVM].*.*
# optimization finished, #iter = 2613
# obj = -608.870377, rho = 0.373771
# nSV = 1127, nBSV = 7
# *.*
# optimization finished, #iter = 1174
# obj = -160.608858, rho = 0.011838
# nSV = 558, nBSV = 0
# *.*
# optimization finished, #iter = 1311
# obj = -171.181333, rho = 0.073392
# nSV = 639, nBSV = 0
# .*
# optimization finished, #iter = 1911
# obj = -587.559235, rho = 0.348898
# nSV = 800, nBSV = 2
# .*
# optimization finished, #iter = 1745
# obj = -377.351835, rho = 0.635423
# nSV = 768, nBSV = 0
# .*
# optimization finished, #iter = 1495
# obj = -415.532094, rho = 0.450492
# nSV = 639, nBSV = 3
# Total nSV = 2055
# Training duration for PCA=2025, C=10, kernel=rbf, gamma=scale: 1507.5816378593445 seconds
# [LibSVM].*.*
# optimization finished, #iter = 2620
# obj = -605.322637, rho = 0.356503
# nSV = 1143, nBSV = 5
# *.*
# optimization finished, #iter = 1187
# obj = -163.905972, rho = -0.020834
# nSV = 572, nBSV = 0
# *.*
# optimization finished, #iter = 1306
# obj = -172.148040, rho = 0.042397
# nSV = 644, nBSV = 0
# .*
# optimization finished, #iter = 1848
# obj = -653.009554, rho = 0.292994
# nSV = 793, nBSV = 2
# .*
# optimization finished, #iter = 1711
# obj = -371.022488, rho = 0.576591
# nSV = 760, nBSV = 0
# .*
# optimization finished, #iter = 1458
# obj = -436.597351, rho = 0.440159
# nSV = 629, nBSV = 4
# Total nSV = 2059
# [LibSVM].*.*
# optimization finished, #iter = 2628
# obj = -620.810638, rho = 0.340044
# nSV = 1131, nBSV = 4
# *.*
# optimization finished, #iter = 1170
# obj = -156.326066, rho = 0.021042
# nSV = 558, nBSV = 0
# *.*
# optimization finished, #iter = 1287
# obj = -166.875077, rho = 0.040436
# nSV = 639, nBSV = 0
# .*
# optimization finished, #iter = 1887
# obj = -599.497722, rho = 0.356752
# nSV = 796, nBSV = 2
# .*
# optimization finished, #iter = 1680
# obj = -365.556913, rho = 0.587138
# nSV = 739, nBSV = 0
# .*
# optimization finished, #iter = 1445
# obj = -389.322826, rho = 0.431450
# nSV = 623, nBSV = 2
# Total nSV = 2052
# [LibSVM].*.*
# optimization finished, #iter = 2616
# obj = -610.849827, rho = 0.378525
# nSV = 1133, nBSV = 4
# *.*
# optimization finished, #iter = 1150
# obj = -160.345981, rho = -0.025743
# nSV = 552, nBSV = 0
# *.*
# optimization finished, #iter = 1305
# obj = -171.521004, rho = 0.059500
# nSV = 639, nBSV = 0
# .*
# optimization finished, #iter = 1877
# obj = -664.995847, rho = 0.311396
# nSV = 800, nBSV = 2
# .*
# optimization finished, #iter = 1741
# obj = -364.241389, rho = 0.632563
# nSV = 764, nBSV = 0
# .*
# optimization finished, #iter = 1479
# obj = -418.297595, rho = 0.496694
# nSV = 634, nBSV = 3
# Total nSV = 2050
# [LibSVM].*.*
# optimization finished, #iter = 2607
# obj = -609.514730, rho = 0.312082
# nSV = 1129, nBSV = 5
# *.*
# optimization finished, #iter = 1209
# obj = -166.965916, rho = -0.003213
# nSV = 579, nBSV = 0
# *.*
# optimization finished, #iter = 1266
# obj = -165.488101, rho = -0.013394
# nSV = 615, nBSV = 0
# .*
# optimization finished, #iter = 1871
# obj = -622.941007, rho = 0.290529
# nSV = 797, nBSV = 1
# .*
# optimization finished, #iter = 1632
# obj = -359.087188, rho = 0.543425
# nSV = 737, nBSV = 0
# .*
# optimization finished, #iter = 1509
# obj = -441.278384, rho = 0.442323
# nSV = 637, nBSV = 4
# Total nSV = 2045
# [LibSVM].*.*
# optimization finished, #iter = 2594
# obj = -619.080136, rho = 0.357160
# nSV = 1119, nBSV = 4
# *.*
# optimization finished, #iter = 1196
# obj = -159.207554, rho = -0.010035
# nSV = 571, nBSV = 0
# *.*
# optimization finished, #iter = 1271
# obj = -171.795303, rho = 0.050973
# nSV = 626, nBSV = 0
# .*
# optimization finished, #iter = 1836
# obj = -639.193259, rho = 0.342156
# nSV = 794, nBSV = 2
# .*
# optimization finished, #iter = 1699
# obj = -378.161802, rho = 0.616348
# nSV = 757, nBSV = 0
# .*
# optimization finished, #iter = 1498
# obj = -447.450478, rho = 0.539688
# nSV = 623, nBSV = 4
# Total nSV = 2041
# [LibSVM].*.*
# optimization finished, #iter = 2676
# obj = -613.078507, rho = 0.272192
# nSV = 1128, nBSV = 3
# *.*
# optimization finished, #iter = 1135
# obj = -157.854385, rho = -0.016174
# nSV = 546, nBSV = 0
# *.*
# optimization finished, #iter = 1310
# obj = -172.455260, rho = 0.053000
# nSV = 636, nBSV = 0
# .*
# optimization finished, #iter = 1844
# obj = -572.617745, rho = 0.394428
# nSV = 776, nBSV = 1
# .*
# optimization finished, #iter = 1766
# obj = -365.373509, rho = 0.687833
# nSV = 761, nBSV = 0
# .*
# optimization finished, #iter = 1462
# obj = -435.699707, rho = 0.446835
# nSV = 623, nBSV = 4
# Total nSV = 2049
# [LibSVM].*.*
# optimization finished, #iter = 2640
# obj = -596.612633, rho = 0.344543
# nSV = 1133, nBSV = 2
# *.*
# optimization finished, #iter = 1178
# obj = -162.795497, rho = -0.000632
# nSV = 565, nBSV = 0
# *.*
# optimization finished, #iter = 1296
# obj = -164.167986, rho = 0.054617
# nSV = 640, nBSV = 0
# .*
# optimization finished, #iter = 1888
# obj = -625.233563, rho = 0.371885
# nSV = 807, nBSV = 3
# .*
# optimization finished, #iter = 1728
# obj = -366.499796, rho = 0.589960
# nSV = 757, nBSV = 0
# .*
# optimization finished, #iter = 1467
# obj = -407.427773, rho = 0.430745
# nSV = 620, nBSV = 3
# Total nSV = 2053
# [LibSVM].*.*
# optimization finished, #iter = 2620
# obj = -601.648563, rho = 0.295649
# nSV = 1118, nBSV = 4
# *.*
# optimization finished, #iter = 1150
# obj = -160.883859, rho = -0.020151
# nSV = 555, nBSV = 0
# *.*
# optimization finished, #iter = 1293
# obj = -168.298565, rho = 0.031491
# nSV = 641, nBSV = 0
# .*
# optimization finished, #iter = 1869
# obj = -640.927686, rho = 0.441573
# nSV = 791, nBSV = 2
# .*
# optimization finished, #iter = 1750
# obj = -371.513440, rho = 0.681553
# nSV = 760, nBSV = 0
# .*
# optimization finished, #iter = 1469
# obj = -423.850037, rho = 0.528152
# nSV = 638, nBSV = 3
# Total nSV = 2055
# [LibSVM].*.*
# optimization finished, #iter = 2649
# obj = -605.180816, rho = 0.338566
# nSV = 1146, nBSV = 5
# *.*
# optimization finished, #iter = 1150
# obj = -154.348863, rho = -0.008546
# nSV = 554, nBSV = 0
# *.*
# optimization finished, #iter = 1300
# obj = -166.254905, rho = 0.027474
# nSV = 642, nBSV = 0
# .*
# optimization finished, #iter = 1890
# obj = -638.754330, rho = 0.334956
# nSV = 801, nBSV = 3
# .*
# optimization finished, #iter = 1687
# obj = -357.817415, rho = 0.611133
# nSV = 747, nBSV = 0
# .*
# optimization finished, #iter = 1456
# obj = -414.504193, rho = 0.474518
# nSV = 624, nBSV = 3
# Total nSV = 2053
# [LibSVM].*.*
# optimization finished, #iter = 2603
# obj = -609.093762, rho = 0.373721
# nSV = 1127, nBSV = 5
# *.*
# optimization finished, #iter = 1174
# obj = -160.608858, rho = 0.011838
# nSV = 558, nBSV = 0
# *.*
# optimization finished, #iter = 1311
# obj = -171.181333, rho = 0.073392
# nSV = 639, nBSV = 0
# .*
# optimization finished, #iter = 1893
# obj = -590.883724, rho = 0.349091
# nSV = 798, nBSV = 1
# .*
# optimization finished, #iter = 1731
# obj = -377.515396, rho = 0.636224
# nSV = 766, nBSV = 0
# .*
# optimization finished, #iter = 1500
# obj = -418.085819, rho = 0.451377
# nSV = 638, nBSV = 3
# Total nSV = 2052
# Training duration for PCA=2025, C=10.5, kernel=rbf, gamma=scale: 1501.9653120040894 seconds
# [LibSVM].*.*
# optimization finished, #iter = 2570
# obj = -585.738789, rho = 0.337086
# nSV = 1176, nBSV = 3
# *.*
# optimization finished, #iter = 1204
# obj = -164.184265, rho = -0.029413
# nSV = 588, nBSV = 0
# *.*
# optimization finished, #iter = 1325
# obj = -172.947269, rho = 0.022883
# nSV = 656, nBSV = 0
# .*
# optimization finished, #iter = 1903
# obj = -564.074871, rho = 0.254255
# nSV = 825, nBSV = 1
# .*
# optimization finished, #iter = 1729
# obj = -358.844274, rho = 0.521988
# nSV = 786, nBSV = 0
# .*
# optimization finished, #iter = 1481
# obj = -392.205656, rho = 0.375136
# nSV = 658, nBSV = 4
# Total nSV = 2097
# [LibSVM].*.*
# optimization finished, #iter = 2596
# obj = -599.109204, rho = 0.317613
# nSV = 1163, nBSV = 3
# *.*
# optimization finished, #iter = 1158
# obj = -156.695203, rho = 0.008564
# nSV = 575, nBSV = 0
# *.*
# optimization finished, #iter = 1306
# obj = -167.672072, rho = 0.011960
# nSV = 655, nBSV = 0
# .*
# optimization finished, #iter = 1900
# obj = -527.443409, rho = 0.324633
# nSV = 834, nBSV = 1
# .*
# optimization finished, #iter = 1715
# obj = -353.152904, rho = 0.532221
# nSV = 778, nBSV = 0
# .*
# optimization finished, #iter = 1460
# obj = -362.774982, rho = 0.349117
# nSV = 649, nBSV = 2
# Total nSV = 2089
# [LibSVM].*.*
# optimization finished, #iter = 2617
# obj = -592.650126, rho = 0.345940
# nSV = 1168, nBSV = 3
# *.*
# optimization finished, #iter = 1158
# obj = -160.818013, rho = -0.036105
# nSV = 573, nBSV = 0
# *.*
# optimization finished, #iter = 1314
# obj = -172.434789, rho = 0.037365
# nSV = 660, nBSV = 0
# .*
# optimization finished, #iter = 1906
# obj = -570.071789, rho = 0.281251
# nSV = 829, nBSV = 1
# .*
# optimization finished, #iter = 1736
# obj = -356.211627, rho = 0.589726
# nSV = 793, nBSV = 0
# .*
# optimization finished, #iter = 1523
# obj = -386.233062, rho = 0.432170
# nSV = 660, nBSV = 3
# Total nSV = 2095
# [LibSVM].*.*
# optimization finished, #iter = 2595
# obj = -590.116926, rho = 0.311553
# nSV = 1162, nBSV = 0
# *.*
# optimization finished, #iter = 1173
# obj = -167.481432, rho = -0.006222
# nSV = 589, nBSV = 0
# *.*
# optimization finished, #iter = 1301
# obj = -166.277924, rho = -0.029611
# nSV = 636, nBSV = 0
# .*
# optimization finished, #iter = 1880
# obj = -539.722693, rho = 0.275762
# nSV = 834, nBSV = 0
# .*
# optimization finished, #iter = 1684
# obj = -347.134856, rho = 0.494359
# nSV = 771, nBSV = 0
# .*
# optimization finished, #iter = 1504
# obj = -397.420196, rho = 0.363546
# nSV = 664, nBSV = 4
# Total nSV = 2083
# [LibSVM].*.*
# optimization finished, #iter = 2578
# obj = -598.251575, rho = 0.342198
# nSV = 1155, nBSV = 3
# *.*
# optimization finished, #iter = 1191
# obj = -159.928370, rho = -0.010587
# nSV = 585, nBSV = 0
# *.*
# optimization finished, #iter = 1291
# obj = -172.642967, rho = 0.027850
# nSV = 651, nBSV = 0
# .*
# optimization finished, #iter = 1880
# obj = -556.193623, rho = 0.314551
# nSV = 834, nBSV = 1
# .*
# optimization finished, #iter = 1726
# obj = -365.923476, rho = 0.559713
# nSV = 795, nBSV = 0
# .*
# optimization finished, #iter = 1461
# obj = -402.362716, rho = 0.454807
# nSV = 661, nBSV = 4
# Total nSV = 2093
# [LibSVM].*.*
# optimization finished, #iter = 2610
# obj = -593.179582, rho = 0.266716
# nSV = 1161, nBSV = 3
# *.*
# optimization finished, #iter = 1132
# obj = -158.278542, rho = -0.019174
# nSV = 569, nBSV = 0
# *.*
# optimization finished, #iter = 1306
# obj = -173.186494, rho = 0.031601
# nSV = 658, nBSV = 0
# .*
# optimization finished, #iter = 1862
# obj = -512.508161, rho = 0.373000
# nSV = 815, nBSV = 1
# .*
# optimization finished, #iter = 1723
# obj = -354.079646, rho = 0.632896
# nSV = 794, nBSV = 0
# .*
# optimization finished, #iter = 1482
# obj = -391.956424, rho = 0.372690
# nSV = 646, nBSV = 4
# Total nSV = 2090
# [LibSVM].*.*
# optimization finished, #iter = 2566
# obj = -582.502483, rho = 0.333621
# nSV = 1162, nBSV = 2
# *.*
# optimization finished, #iter = 1159
# obj = -163.396631, rho = -0.002452
# nSV = 574, nBSV = 0
# *.*
# optimization finished, #iter = 1294
# obj = -165.099752, rho = 0.041332
# nSV = 653, nBSV = 0
# .*
# optimization finished, #iter = 1928
# obj = -547.026575, rho = 0.335160
# nSV = 844, nBSV = 1
# .*
# optimization finished, #iter = 1753
# obj = -354.380018, rho = 0.541194
# nSV = 788, nBSV = 0
# .*
# optimization finished, #iter = 1476
# obj = -375.458087, rho = 0.378888
# nSV = 646, nBSV = 3
# Total nSV = 2091
# [LibSVM].*.*
# optimization finished, #iter = 2606
# obj = -580.739068, rho = 0.289954
# nSV = 1152, nBSV = 1
# *.*
# optimization finished, #iter = 1150
# obj = -160.989515, rho = -0.026080
# nSV = 568, nBSV = 0
# *.*
# optimization finished, #iter = 1309
# obj = -169.171057, rho = 0.010823
# nSV = 657, nBSV = 0
# .*
# optimization finished, #iter = 1943
# obj = -552.547173, rho = 0.397346
# nSV = 832, nBSV = 1
# .*
# optimization finished, #iter = 1747
# obj = -359.837345, rho = 0.625668
# nSV = 789, nBSV = 0
# .*
# optimization finished, #iter = 1511
# obj = -387.953597, rho = 0.459802
# nSV = 668, nBSV = 3
# Total nSV = 2095
# [LibSVM].*.*
# optimization finished, #iter = 2604
# obj = -588.202006, rho = 0.332039
# nSV = 1175, nBSV = 3
# *.*
# optimization finished, #iter = 1138
# obj = -154.906022, rho = -0.015441
# nSV = 567, nBSV = 0
# *.*
# optimization finished, #iter = 1312
# obj = -167.122427, rho = 0.009266
# nSV = 662, nBSV = 0
# .*
# optimization finished, #iter = 1882
# obj = -562.354627, rho = 0.322072
# nSV = 832, nBSV = 1
# .*
# optimization finished, #iter = 1708
# obj = -353.277601, rho = 0.572259
# nSV = 776, nBSV = 0
# .*
# optimization finished, #iter = 1445
# obj = -381.780473, rho = 0.414917
# nSV = 652, nBSV = 3
# Total nSV = 2095
# [LibSVM].*.*
# optimization finished, #iter = 2595
# obj = -589.489886, rho = 0.360304
# nSV = 1154, nBSV = 1
# *.*
# optimization finished, #iter = 1182
# obj = -161.228221, rho = 0.010871
# nSV = 581, nBSV = 0
# *.*
# optimization finished, #iter = 1284
# obj = -172.132427, rho = 0.053342
# nSV = 658, nBSV = 0
# .*
# optimization finished, #iter = 1885
# obj = -518.004751, rho = 0.315762
# nSV = 830, nBSV = 0
# .*
# optimization finished, #iter = 1742
# obj = -366.363753, rho = 0.571119
# nSV = 809, nBSV = 0
# .*
# optimization finished, #iter = 1482
# obj = -383.801646, rho = 0.393328
# nSV = 662, nBSV = 3
# Total nSV = 2093
# Training duration for PCA=2500, C=9, kernel=rbf, gamma=scale: 1581.6211609840393 seconds
# [LibSVM].*.*
# optimization finished, #iter = 2591
# obj = -585.770659, rho = 0.337701
# nSV = 1176, nBSV = 1
# *.*
# optimization finished, #iter = 1204
# obj = -164.184265, rho = -0.029413
# nSV = 588, nBSV = 0
# *.*
# optimization finished, #iter = 1325
# obj = -172.947269, rho = 0.022883
# nSV = 656, nBSV = 0
# .*
# optimization finished, #iter = 1893
# obj = -569.391633, rho = 0.254289
# nSV = 824, nBSV = 1
# .*
# optimization finished, #iter = 1729
# obj = -358.844274, rho = 0.521988
# nSV = 786, nBSV = 0
# .*
# optimization finished, #iter = 1460
# obj = -393.992784, rho = 0.381029
# nSV = 659, nBSV = 4
# Total nSV = 2097
# [LibSVM].*.*
# optimization finished, #iter = 2608
# obj = -599.109473, rho = 0.317617
# nSV = 1163, nBSV = 1
# *.*
# optimization finished, #iter = 1158
# obj = -156.695203, rho = 0.008564
# nSV = 575, nBSV = 0
# *.*
# optimization finished, #iter = 1306
# obj = -167.672072, rho = 0.011960
# nSV = 655, nBSV = 0
# .*
# optimization finished, #iter = 1860
# obj = -530.978901, rho = 0.323885
# nSV = 834, nBSV = 1
# .*
# optimization finished, #iter = 1715
# obj = -353.152904, rho = 0.532221
# nSV = 778, nBSV = 0
# .*
# optimization finished, #iter = 1450
# obj = -363.751774, rho = 0.348532
# nSV = 648, nBSV = 2
# Total nSV = 2089
# [LibSVM].*.*
# optimization finished, #iter = 2617
# obj = -592.650126, rho = 0.345940
# nSV = 1168, nBSV = 2
# *.*
# optimization finished, #iter = 1158
# obj = -160.818013, rho = -0.036105
# nSV = 573, nBSV = 0
# *.*
# optimization finished, #iter = 1314
# obj = -172.434789, rho = 0.037365
# nSV = 660, nBSV = 0
# .*
# optimization finished, #iter = 1862
# obj = -575.600869, rho = 0.280316
# nSV = 825, nBSV = 1
# .*
# optimization finished, #iter = 1736
# obj = -356.211627, rho = 0.589726
# nSV = 793, nBSV = 0
# .*
# optimization finished, #iter = 1504
# obj = -387.549355, rho = 0.435200
# nSV = 658, nBSV = 3
# Total nSV = 2093
# [LibSVM].*.*
# optimization finished, #iter = 2595
# obj = -590.116926, rho = 0.311553
# nSV = 1162, nBSV = 0
# *.*
# optimization finished, #iter = 1173
# obj = -167.481432, rho = -0.006222
# nSV = 589, nBSV = 0
# *.*
# optimization finished, #iter = 1301
# obj = -166.277924, rho = -0.029611
# nSV = 636, nBSV = 0
# .*
# optimization finished, #iter = 1914
# obj = -543.314231, rho = 0.273935
# nSV = 833, nBSV = 0
# .*
# optimization finished, #iter = 1684
# obj = -347.134856, rho = 0.494359
# nSV = 771, nBSV = 0
# .*
# optimization finished, #iter = 1505
# obj = -399.248844, rho = 0.368112
# nSV = 665, nBSV = 4
# Total nSV = 2084
# [LibSVM].*.*
# optimization finished, #iter = 2578
# obj = -598.251575, rho = 0.342198
# nSV = 1155, nBSV = 1
# *.*
# optimization finished, #iter = 1191
# obj = -159.928370, rho = -0.010587
# nSV = 585, nBSV = 0
# *.*
# optimization finished, #iter = 1291
# obj = -172.642967, rho = 0.027850
# nSV = 651, nBSV = 0
# .*
# optimization finished, #iter = 1881
# obj = -561.421851, rho = 0.316227
# nSV = 832, nBSV = 1
# .*
# optimization finished, #iter = 1726
# obj = -365.923476, rho = 0.559713
# nSV = 795, nBSV = 0
# .*
# optimization finished, #iter = 1498
# obj = -404.206820, rho = 0.459734
# nSV = 659, nBSV = 4
# Total nSV = 2092
# [LibSVM].*.*
# optimization finished, #iter = 2610
# obj = -593.179582, rho = 0.266716
# nSV = 1161, nBSV = 1
# *.*
# optimization finished, #iter = 1132
# obj = -158.278542, rho = -0.019174
# nSV = 569, nBSV = 0
# *.*
# optimization finished, #iter = 1306
# obj = -173.186494, rho = 0.031601
# nSV = 658, nBSV = 0
# .*
# optimization finished, #iter = 1853
# obj = -516.450189, rho = 0.372553
# nSV = 815, nBSV = 1
# .*
# optimization finished, #iter = 1723
# obj = -354.079646, rho = 0.632896
# nSV = 794, nBSV = 0
# .*
# optimization finished, #iter = 1454
# obj = -393.769729, rho = 0.377264
# nSV = 646, nBSV = 4
# Total nSV = 2090
# [LibSVM].*.*
# optimization finished, #iter = 2578
# obj = -582.502485, rho = 0.333653
# nSV = 1162, nBSV = 1
# *.*
# optimization finished, #iter = 1159
# obj = -163.396631, rho = -0.002452
# nSV = 574, nBSV = 0
# *.*
# optimization finished, #iter = 1294
# obj = -165.099752, rho = 0.041332
# nSV = 653, nBSV = 0
# .*
# optimization finished, #iter = 1867
# obj = -551.624496, rho = 0.333021
# nSV = 840, nBSV = 1
# .*
# optimization finished, #iter = 1753
# obj = -354.380018, rho = 0.541194
# nSV = 788, nBSV = 0
# .*
# optimization finished, #iter = 1469
# obj = -376.912922, rho = 0.384644
# nSV = 648, nBSV = 3
# Total nSV = 2090
# [LibSVM].*.*
# optimization finished, #iter = 2593
# obj = -580.739201, rho = 0.289964
# nSV = 1152, nBSV = 1
# *.*
# optimization finished, #iter = 1150
# obj = -160.989515, rho = -0.026080
# nSV = 568, nBSV = 0
# *.*
# optimization finished, #iter = 1309
# obj = -169.171057, rho = 0.010823
# nSV = 657, nBSV = 0
# .*
# optimization finished, #iter = 1884
# obj = -557.811323, rho = 0.398258
# nSV = 832, nBSV = 1
# .*
# optimization finished, #iter = 1747
# obj = -359.837345, rho = 0.625668
# nSV = 789, nBSV = 0
# .*
# optimization finished, #iter = 1512
# obj = -389.115929, rho = 0.463308
# nSV = 668, nBSV = 3
# Total nSV = 2096
# [LibSVM].*.*
# optimization finished, #iter = 2604
# obj = -588.202006, rho = 0.332039
# nSV = 1175, nBSV = 0
# *.*
# optimization finished, #iter = 1138
# obj = -154.906022, rho = -0.015441
# nSV = 567, nBSV = 0
# *.*
# optimization finished, #iter = 1312
# obj = -167.122427, rho = 0.009266
# nSV = 662, nBSV = 0
# .*
# optimization finished, #iter = 1880
# obj = -567.677622, rho = 0.321937
# nSV = 830, nBSV = 2
# .*
# optimization finished, #iter = 1708
# obj = -353.277601, rho = 0.572259
# nSV = 776, nBSV = 0
# .*
# optimization finished, #iter = 1481
# obj = -383.268950, rho = 0.415912
# nSV = 651, nBSV = 3
# Total nSV = 2094
# [LibSVM].*.*
# optimization finished, #iter = 2574
# obj = -589.565084, rho = 0.360135
# nSV = 1155, nBSV = 0
# *.*
# optimization finished, #iter = 1182
# obj = -161.228221, rho = 0.010871
# nSV = 581, nBSV = 0
# *.*
# optimization finished, #iter = 1284
# obj = -172.132427, rho = 0.053342
# nSV = 658, nBSV = 0
# .*
# optimization finished, #iter = 1887
# obj = -518.918102, rho = 0.315430
# nSV = 830, nBSV = 0
# .*
# optimization finished, #iter = 1742
# obj = -366.363753, rho = 0.571119
# nSV = 809, nBSV = 0
# .*
# optimization finished, #iter = 1482
# obj = -385.071555, rho = 0.396504
# nSV = 663, nBSV = 3
# Total nSV = 2094
# Training duration for PCA=2500, C=10, kernel=rbf, gamma=scale: 1558.3642740249634 seconds
# [LibSVM].*.*
# optimization finished, #iter = 2591
# obj = -585.770659, rho = 0.337701
# nSV = 1176, nBSV = 0
# *.*
# optimization finished, #iter = 1204
# obj = -164.184265, rho = -0.029413
# nSV = 588, nBSV = 0
# *.*
# optimization finished, #iter = 1325
# obj = -172.947269, rho = 0.022883
# nSV = 656, nBSV = 0
# .*
# optimization finished, #iter = 1884
# obj = -571.813913, rho = 0.254636
# nSV = 823, nBSV = 2
# .*
# optimization finished, #iter = 1729
# obj = -358.844274, rho = 0.521988
# nSV = 786, nBSV = 0
# .*
# optimization finished, #iter = 1459
# obj = -394.572207, rho = 0.384017
# nSV = 660, nBSV = 3
# Total nSV = 2097
# [LibSVM].*.*
# optimization finished, #iter = 2608
# obj = -599.109473, rho = 0.317617
# nSV = 1163, nBSV = 1
# *.*
# optimization finished, #iter = 1158
# obj = -156.695203, rho = 0.008564
# nSV = 575, nBSV = 0
# *.*
# optimization finished, #iter = 1306
# obj = -167.672072, rho = 0.011960
# nSV = 655, nBSV = 0
# .*
# optimization finished, #iter = 1912
# obj = -532.561146, rho = 0.323672
# nSV = 830, nBSV = 1
# .*
# optimization finished, #iter = 1715
# obj = -353.152904, rho = 0.532221
# nSV = 778, nBSV = 0
# .*
# optimization finished, #iter = 1456
# obj = -364.092092, rho = 0.348106
# nSV = 646, nBSV = 2
# Total nSV = 2088
# [LibSVM].*.*
# optimization finished, #iter = 2617
# obj = -592.650126, rho = 0.345940
# nSV = 1168, nBSV = 0
# *.*
# optimization finished, #iter = 1158
# obj = -160.818013, rho = -0.036105
# nSV = 573, nBSV = 0
# *.*
# optimization finished, #iter = 1314
# obj = -172.434789, rho = 0.037365
# nSV = 660, nBSV = 0
# .*
# optimization finished, #iter = 1881
# obj = -578.105553, rho = 0.280406
# nSV = 825, nBSV = 1
# .*
# optimization finished, #iter = 1736
# obj = -356.211627, rho = 0.589726
# nSV = 793, nBSV = 0
# .*
# optimization finished, #iter = 1498
# obj = -387.977227, rho = 0.436819
# nSV = 659, nBSV = 3
# Total nSV = 2093
# [LibSVM].*.*
# optimization finished, #iter = 2595
# obj = -590.116926, rho = 0.311553
# nSV = 1162, nBSV = 0
# *.*
# optimization finished, #iter = 1173
# obj = -167.481432, rho = -0.006222
# nSV = 589, nBSV = 0
# *.*
# optimization finished, #iter = 1301
# obj = -166.277924, rho = -0.029611
# nSV = 636, nBSV = 0
# .*
# optimization finished, #iter = 1899
# obj = -544.883690, rho = 0.272910
# nSV = 833, nBSV = 1
# .*
# optimization finished, #iter = 1684
# obj = -347.134856, rho = 0.494359
# nSV = 771, nBSV = 0
# .*
# optimization finished, #iter = 1505
# obj = -399.852301, rho = 0.370395
# nSV = 664, nBSV = 4
# Total nSV = 2084
# [LibSVM].*.*
# optimization finished, #iter = 2578
# obj = -598.251575, rho = 0.342198
# nSV = 1155, nBSV = 1
# *.*
# optimization finished, #iter = 1191
# obj = -159.928370, rho = -0.010587
# nSV = 585, nBSV = 0
# *.*
# optimization finished, #iter = 1291
# obj = -172.642967, rho = 0.027850
# nSV = 651, nBSV = 0
# .*
# optimization finished, #iter = 1884
# obj = -563.841299, rho = 0.317295
# nSV = 832, nBSV = 1
# .*
# optimization finished, #iter = 1726
# obj = -365.923476, rho = 0.559713
# nSV = 795, nBSV = 0
# .*
# optimization finished, #iter = 1504
# obj = -404.818261, rho = 0.462114
# nSV = 659, nBSV = 4
# Total nSV = 2092
# [LibSVM].*.*
# optimization finished, #iter = 2610
# obj = -593.179582, rho = 0.266716
# nSV = 1161, nBSV = 1
# *.*
# optimization finished, #iter = 1132
# obj = -158.278542, rho = -0.019174
# nSV = 569, nBSV = 0
# *.*
# optimization finished, #iter = 1306
# obj = -173.186494, rho = 0.031601
# nSV = 658, nBSV = 0
# .*
# optimization finished, #iter = 1857
# obj = -518.268194, rho = 0.372704
# nSV = 815, nBSV = 1
# .*
# optimization finished, #iter = 1723
# obj = -354.079646, rho = 0.632896
# nSV = 794, nBSV = 0
# .*
# optimization finished, #iter = 1452
# obj = -394.364345, rho = 0.379323
# nSV = 646, nBSV = 4
# Total nSV = 2090
# [LibSVM].*.*
# optimization finished, #iter = 2578
# obj = -582.502485, rho = 0.333653
# nSV = 1162, nBSV = 1
# *.*
# optimization finished, #iter = 1159
# obj = -163.396631, rho = -0.002452
# nSV = 574, nBSV = 0
# *.*
# optimization finished, #iter = 1294
# obj = -165.099752, rho = 0.041332
# nSV = 653, nBSV = 0
# .*
# optimization finished, #iter = 1892
# obj = -553.712451, rho = 0.332224
# nSV = 840, nBSV = 1
# .*
# optimization finished, #iter = 1753
# obj = -354.380018, rho = 0.541194
# nSV = 788, nBSV = 0
# .*
# optimization finished, #iter = 1444
# obj = -377.402503, rho = 0.387761
# nSV = 647, nBSV = 3
# Total nSV = 2090
# [LibSVM].*.*
# optimization finished, #iter = 2593
# obj = -580.739201, rho = 0.289964
# nSV = 1152, nBSV = 1
# *.*
# optimization finished, #iter = 1150
# obj = -160.989515, rho = -0.026080
# nSV = 568, nBSV = 0
# *.*
# optimization finished, #iter = 1309
# obj = -169.171057, rho = 0.010823
# nSV = 657, nBSV = 0
# .*
# optimization finished, #iter = 1885
# obj = -560.253785, rho = 0.398857
# nSV = 832, nBSV = 1
# .*
# optimization finished, #iter = 1747
# obj = -359.837345, rho = 0.625668
# nSV = 789, nBSV = 0
# .*
# optimization finished, #iter = 1515
# obj = -389.460754, rho = 0.465097
# nSV = 668, nBSV = 3
# Total nSV = 2096
# [LibSVM].*.*
# optimization finished, #iter = 2604
# obj = -588.202006, rho = 0.332039
# nSV = 1175, nBSV = 0
# *.*
# optimization finished, #iter = 1138
# obj = -154.906022, rho = -0.015441
# nSV = 567, nBSV = 0
# *.*
# optimization finished, #iter = 1312
# obj = -167.122427, rho = 0.009266
# nSV = 662, nBSV = 0
# .*
# optimization finished, #iter = 1870
# obj = -570.090082, rho = 0.322205
# nSV = 831, nBSV = 1
# .*
# optimization finished, #iter = 1708
# obj = -353.277601, rho = 0.572259
# nSV = 776, nBSV = 0
# .*
# optimization finished, #iter = 1445
# obj = -383.786749, rho = 0.416490
# nSV = 652, nBSV = 3
# Total nSV = 2094
# [LibSVM].*.*
# optimization finished, #iter = 2550
# obj = -589.567187, rho = 0.360108
# nSV = 1155, nBSV = 0
# *.*
# optimization finished, #iter = 1182
# obj = -161.228221, rho = 0.010871
# nSV = 581, nBSV = 0
# *.*
# optimization finished, #iter = 1284
# obj = -172.132427, rho = 0.053342
# nSV = 658, nBSV = 0
# .*
# optimization finished, #iter = 1912
# obj = -519.251946, rho = 0.315590
# nSV = 831, nBSV = 0
# .*
# optimization finished, #iter = 1742
# obj = -366.363753, rho = 0.571119
# nSV = 809, nBSV = 0
# .*
# optimization finished, #iter = 1505
# obj = -385.472660, rho = 0.398087
# nSV = 663, nBSV = 3
# Total nSV = 2094
# Training duration for PCA=2500, C=10.5, kernel=rbf, gamma=scale: 1864.7711539268494 seconds

# %%
run_metrics = {}
run_params = {}

for run_id in run_ids:
    client = mlflow.tracking.MlflowClient(ML_FLOW_DIRECTORY)
    run = client.get_run(run_id)
    metrics = run.data.metrics
    params = run.data.params
    run_metrics[run_id] = metrics
    run_params[run_id] = params

for run_id in run_ids:
    print(f"Run ID: {run_id}")
    print("Metrics:")
    metrics = run_metrics[run_id]
    for metric, value in metrics.items():
        print(f"\t{metric}: {value}")

    print("Parameters:")
    params = run_params[run_id]
    for param, value in params.items():
        print(f"\t{param}: {value}")
# Out:
# Run ID: 4ad3076fcc2a4faf99c3ac498439cc9f
# Metrics:
# 	mean_f1_weighted: 0.8424340314446919
# 	mean_accuracy: 0.8433410138248847
# 	mean_recall: 0.8433410138248847
# 	mean_precision: 0.8451574313162407
# Parameters:
# 	gamma: scale
# 	pca_components: 1600
# 	C: 9
# 	kernel: rbf
# Run ID: 10fc551498f046c1a3e618f8f89a485f
# Metrics:
# 	mean_f1_weighted: 0.8404713615510018
# 	mean_accuracy: 0.8415527393753199
# 	mean_recall: 0.8415527393753199
# 	mean_precision: 0.842897530160023
# Parameters:
# 	gamma: scale
# 	pca_components: 1600
# 	C: 10
# 	kernel: rbf
# Run ID: c290ee0b2cf7497291e2160f3448859d
# Metrics:
# 	mean_f1_weighted: 0.8427493247550799
# 	mean_accuracy: 0.8436955965181772
# 	mean_recall: 0.8436955965181772
# 	mean_precision: 0.8453451989578913
# Parameters:
# 	gamma: scale
# 	pca_components: 1600
# 	C: 10.5
# 	kernel: rbf
# Run ID: 6a02bab131334ca7b93dab403e5e736f
# Metrics:
# 	mean_f1_weighted: 0.8410254623791417
# 	mean_accuracy: 0.8419124423963135
# 	mean_recall: 0.8419124423963135
# 	mean_precision: 0.8436078175699008
# Parameters:
# 	gamma: scale
# 	pca_components: 2025
# 	C: 9
# 	kernel: rbf
# Run ID: 49acda358fe8416da11244158f018ddd
# Metrics:
# 	mean_f1_weighted: 0.8410218421311667
# 	mean_accuracy: 0.8419124423963135
# 	mean_recall: 0.8419124423963135
# 	mean_precision: 0.8436605869045849
# Parameters:
# 	gamma: scale
# 	pca_components: 2025
# 	C: 10
# 	kernel: rbf
# Run ID: 76d29049bccc4c069e71031cd1f6ffb9
# Metrics:
# 	mean_f1_weighted: 0.8406505979568666
# 	mean_accuracy: 0.8415540194572453
# 	mean_recall: 0.8415540194572453
# 	mean_precision: 0.8432221257776309
# Parameters:
# 	gamma: scale
# 	pca_components: 2025
# 	C: 10.5
# 	kernel: rbf
# Run ID: d59ce32efe0d49d38b8cfb9d0c3f09c9
# Metrics:
# 	mean_f1_weighted: 0.8402654840875898
# 	mean_accuracy: 0.8411981566820277
# 	mean_recall: 0.8411981566820277
# 	mean_precision: 0.8427632494494018
# Parameters:
# 	gamma: scale
# 	pca_components: 2500
# 	C: 9
# 	kernel: rbf
# Run ID: 44d967e562ef42e792b78e1c0177f919
# Metrics:
# 	mean_f1_weighted: 0.8402736565304364
# 	mean_accuracy: 0.8411981566820277
# 	mean_recall: 0.8411981566820277
# 	mean_precision: 0.8427107982522143
# Parameters:
# 	gamma: scale
# 	pca_components: 2500
# 	C: 10
# 	kernel: rbf
# Run ID: 711754dde1004e43b840f69dd9659b1a
# Metrics:
# 	mean_f1_weighted: 0.8399183756235853
# 	mean_accuracy: 0.8408397337429596
# 	mean_recall: 0.8408397337429596
# 	mean_precision: 0.8424215570793827
# Parameters:
# 	gamma: scale
# 	pca_components: 2500
# 	C: 10.5
# 	kernel: rbf

# %%
best_run_id = max(run_metrics, key=lambda x: run_metrics[x]["mean_f1_weighted"])
best_run_params = run_params[best_run_id]
best_run_metrics = run_metrics[best_run_id]

print(f"\nBest Run ID: {best_run_id}")
print("Best Parameters:")
for key, value in best_run_params.items():
    print(f"\t{key}: {value}")

print("\nBest Run Metrics:")
for metric, value in best_run_metrics.items():
    print(f"\t{metric}: {value}")
# Out:
# Best Run ID: c290ee0b2cf7497291e2160f3448859d
# Best Parameters:
# 	gamma: scale
# 	pca_components: 1600
# 	C: 10.5
# 	kernel: rbf
#
# Best Run Metrics:
# 	mean_f1_weighted: 0.8427493247550799
# 	mean_accuracy: 0.8436955965181772
# 	mean_recall: 0.8436955965181772
# 	mean_precision: 0.8453451989578913
